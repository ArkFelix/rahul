# %% [markdown]
# <a href="https://colab.research.google.com/github/ArkFelix/rahul/blob/main/Stockrizz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #stock list (all stocks) (total 1900+ stocks)

# %%
nse_stocks = ['20MICRONS.NS', '21STCENMGM.NS', '360ONE.NS', '3IINFOLTD.NS', '3MINDIA.NS', '3PLAND.NS', '5PAISA.NS', '63MOONS.NS', 'A2ZINFRA.NS', 'AAATECH.NS', 'AAKASH.NS', 'AAREYDRUGS.NS', 'AARON.NS', 'AARTECH.NS', 'AARTIDRUGS.NS', 'AARTIIND.NS', 'AARTIPHARM.NS', 'AARTISURF.NS', 'AARVEEDEN.NS', 'AARVI.NS', 'AAVAS.NS', 'ABAN.NS', 'ABB.NS', 'ABBOTINDIA.NS', 'ABCAPITAL.NS', 'ABFRL.NS', 'ABMINTLLTD.NS', 'ABSLAMC.NS', 'ACC.NS', 'ACCELYA.NS', 'ACCURACY.NS', 'ACE.NS', 'ACEINTEG.NS', 'ACI.NS', 'ACL.NS', 'ACLGATI.NS', 'ADANIENSOL.NS', 'ADANIENT.NS', 'ADANIGREEN.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'ADFFOODS.NS', 'ADL.NS', 'ADORWELD.NS', 'ADROITINFO.NS', 'ADSL.NS', 'ADVANIHOTR.NS', 'ADVENZYMES.NS', 'AEGISCHEM.NS', 'AEROFLEX.NS', 'AETHER.NS', 'AFFLE.NS', 'AGARIND.NS', 'AGI.NS', 'AGRITECH.NS', 'AGROPHOS.NS', 'AGSTRA.NS', 'AHL.NS', 'AHLADA.NS', 'AHLEAST.NS', 'AHLUCONT.NS', 'AIAENG.NS', 'AIRAN.NS', 'AIROLAM.NS', 'AJANTPHARM.NS', 'AJMERA.NS', 'AJOONI.NS', 'AKASH.NS', 'AKG.NS', 'AKI.NS', 'AKSHAR.NS', 'AKSHARCHEM.NS', 'AKSHOPTFBR.NS', 'AKZOINDIA.NS', 'ALANKIT.NS', 'ALBERTDAVD.NS', 'ALEMBICLTD.NS', 'ALICON.NS', 'ALKALI.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'ALLCARGO.NS', 'ALLSEC.NS', 'ALMONDZ.NS', 'ALOKINDS.NS', 'ALPA.NS', 'ALPHAGEO.NS', 'ALPSINDUS.NS', 'AMBER.NS', 'AMBICAAGAR.NS', 'AMBIKCO.NS', 'AMBUJACEM.NS', 'AMDIND.NS', 'AMIORG.NS', 'AMJLAND.NS', 'AMNPLST.NS', 'AMRUTANJAN.NS', 'ANANDRATHI.NS', 'ANANTRAJ.NS', 'ANDHRAPAP.NS', 'ANDHRSUGAR.NS', 'ANGELONE.NS', 'ANIKINDS.NS', 'ANKITMETAL.NS', 'ANMOL.NS', 'ANTGRAPHIC.NS', 'ANUP.NS', 'ANURAS.NS', 'APARINDS.NS', 'APCL.NS', 'APCOTEXIND.NS', 'APEX.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'APOLLO.NS', 'APOLLOHOSP.NS', 'APOLLOPIPE.NS', 'APOLLOTYRE.NS', 'APOLSINHOT.NS', 'APTECHT.NS', 'APTUS.NS', 'ARCHIDPLY.NS', 'ARCHIES.NS', 'ARE&M.NS', 'ARENTERP.NS', 'ARIES.NS', 'ARIHANTCAP.NS', 'ARIHANTSUP.NS', 'ARMANFIN.NS', 'AROGRANITE.NS', 'ARROWGREEN.NS', 'ARSHIYA.NS', 'ARSSINFRA.NS', 'ARTEMISMED.NS', 'ARTNIRMAN.NS', 'ARVEE.NS', 'ARVIND.NS', 'ARVINDFASN.NS', 'ARVSMART.NS', 'ASAHIINDIA.NS', 'ASAHISONG.NS', 'ASAL.NS', 'ASALCBR.NS', 'ASHAPURMIN.NS', 'ASHIANA.NS', 'ASHIMASYN.NS', 'ASHOKA.NS', 'ASHOKAMET.NS', 'ASHOKLEY.NS', 'ASIANENE.NS', 'ASIANHOTNR.NS', 'ASIANPAINT.NS', 'ASIANTILES.NS', 'ASKAUTOLTD.NS', 'ASMS.NS', 'ASPINWALL.NS', 'ASTEC.NS', 'ASTERDM.NS', 'ASTRAL.NS', 'ASTRAMICRO.NS', 'ASTRAZEN.NS', 'ASTRON.NS', 'ATALREAL.NS', 'ATAM.NS', 'ATFL.NS', 'ATGL.NS', 'ATL.NS', 'ATLANTAA.NS', 'ATUL.NS', 'ATULAUTO.NS', 'AUBANK.NS', 'AURIONPRO.NS', 'AUROPHARMA.NS', 'AURUM.NS', 'AUSOMENT.NS', 'AUTOAXLES.NS', 'AUTOIND.NS', 'AVADHSUGAR.NS', 'AVALON.NS', 'AVANTIFEED.NS', 'AVG.NS', 'AVONMORE.NS', 'AVROIND.NS', 'AVTNPL.NS', 'AWHCL.NS', 'AWL.NS', 'AXISBANK.NS', 'AXISCADES.NS', 'AXITA.NS', 'AYMSYNTEX.NS', 'AZAD.NS', 'BAFNAPH.NS', 'BAGFILMS.NS', 'BAIDFIN.NS', 'BAJAJ-AUTO.NS', 'BAJAJCON.NS', 'BAJAJELEC.NS', 'BAJAJFINSV.NS', 'BAJAJHCARE.NS', 'BAJAJHIND.NS', 'BAJAJHLDNG.NS', 'BAJEL.NS', 'BAJFINANCE.NS', 'BALAJITELE.NS', 'BALAMINES.NS', 'BALAXI.NS', 'BALKRISHNA.NS', 'BALKRISIND.NS', 'BALMLAWRIE.NS', 'BALPHARMA.NS', 'BALRAMCHIN.NS', 'BANARBEADS.NS', 'BANARISUG.NS', 'BANCOINDIA.NS', 'BANDHANBNK.NS', 'BANG.NS', 'BANKA.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BANSWRAS.NS', 'BARBEQUE.NS', 'BASF.NS', 'BASML.NS', 'BATAINDIA.NS', 'BAYERCROP.NS', 'BBL.NS', 'BBOX.NS', 'BBTC.NS', 'BBTCL.NS', 'BCG.NS', 'BCLIND.NS', 'BCONCEPTS.NS', 'BDL.NS', 'BEARDSELL.NS', 'BECTORFOOD.NS', 'BEDMUTHA.NS', 'BEL.NS', 'BEML.NS', 'BEPL.NS', 'BERGEPAINT.NS', 'BFINVEST.NS', 'BFUTILITIE.NS', 'BGRENERGY.NS', 'BHAGCHEM.NS', 'BHAGERIA.NS', 'BHAGYANGR.NS', 'BHANDARI.NS', 'BHARATFORG.NS', 'BHARATGEAR.NS', 'BHARATRAS.NS', 'BHARATWIRE.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'BIGBLOC.NS', 'BIKAJI.NS', 'BIL.NS', 'BINANIIND.NS', 'BIOCON.NS', 'BIOFILCHEM.NS', 'BIRLACABLE.NS', 'BIRLACORPN.NS', 'BIRLAMONEY.NS', 'BKMINDST.NS', 'BLAL.NS', 'BLBLIMITED.NS', 'BLISSGVS.NS', 'BLKASHYAP.NS', 'BLS.NS', 'BLUECHIP.NS', 'BLUECOAST.NS', 'BLUEDART.NS', 'BLUEJET.NS', 'BLUESTARCO.NS', 'BODALCHEM.NS', 'BOHRAIND.NS', 'BOMDYEING.NS', 'BOROLTD.NS', 'BORORENEW.NS', 'BOSCHLTD.NS', 'BPCL.NS', 'BPL.NS', 'BRIGADE.NS', 'BRITANNIA.NS', 'BRNL.NS', 'BROOKS.NS', 'BSE.NS', 'BSHSL.NS', 'BSL.NS', 'BSOFT.NS', 'BTML.NS', 'BURNPUR.NS', 'BUTTERFLY.NS', 'BVCL.NS', 'BYKE.NS', 'CALSOFT.NS', 'CAMLINFINE.NS', 'CAMPUS.NS', 'CAMS.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CANTABIL.NS', 'CAPACITE.NS', 'CAPLIPOINT.NS', 'CAPTRUST.NS', 'CARBORUNIV.NS', 'CAREERP.NS', 'CARERATING.NS', 'CARTRADE.NS', 'CARYSIL.NS', 'CASTROLIND.NS', 'CCHHL.NS', 'CCL.NS', 'CDSL.NS', 'CEATLTD.NS', 'CELEBRITY.NS', 'CELLO.NS', 'CENTENKA.NS', 'CENTEXT.NS', 'CENTRALBK.NS', 'CENTRUM.NS', 'CENTUM.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CEREBRAINT.NS', 'CESC.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHALET.NS', 'CHAMBLFERT.NS', 'CHEMBOND.NS', 'CHEMCON.NS', 'CHEMFAB.NS', 'CHEMPLASTS.NS', 'CHENNPETRO.NS', 'CHEVIOT.NS', 'CHOICEIN.NS', 'CHOLAFIN.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'CIGNITITEC.NS', 'CINELINE.NS', 'CINEVISTA.NS', 'CIPLA.NS', 'CLEAN.NS', 'CLEDUCATE.NS', 'CLSEL.NS', 'CMSINFO.NS', 'COALINDIA.NS', 'COASTCORP.NS', 'COCHINSHIP.NS', 'COFFEEDAY.NS', 'COFORGE.NS', 'COLPAL.NS', 'COMPINFO.NS', 'COMPUSOFT.NS', 'CONCOR.NS', 'CONCORDBIO.NS', 'CONFIPET.NS', 'CONSOFINVT.NS', 'CONTROLPR.NS', 'CORALFINAC.NS', 'CORDSCABLE.NS', 'COROMANDEL.NS', 'COSMOFIRST.NS', 'COUNCODOS.NS', 'CRAFTSMAN.NS', 'CREATIVE.NS', 'CREATIVEYE.NS', 'CREDITACC.NS', 'CREST.NS', 'CRISIL.NS', 'CROMPTON.NS', 'CROWN.NS', 'CSBBANK.NS', 'CSLFINANCE.NS', 'CTE.NS', 'CUB.NS', 'CUBEXTUB.NS', 'CUMMINSIND.NS', 'CUPID.NS', 'CYBERMEDIA.NS', 'CYBERTECH.NS', 'CYIENT.NS', 'CYIENTDLM.NS', 'DABUR.NS', 'DALBHARAT.NS', 'DALMIASUG.NS', 'DAMODARIND.NS', 'DANGEE.NS', 'DATAMATICS.NS', 'DATAPATTNS.NS', 'DBCORP.NS', 'DBL.NS', 'DBOL.NS', 'DBREALTY.NS', 'DBSTOCKBRO.NS', 'DCAL.NS', 'DCBBANK.NS', 'DCI.NS', 'DCM.NS', 'DCMFINSERV.NS', 'DCMNVL.NS', 'DCMSHRIRAM.NS', 'DCMSRIND.NS', 'DCW.NS', 'DCXINDIA.NS', 'DECCANCE.NS', 'DEEPAKFERT.NS', 'DEEPAKNTR.NS', 'DEEPENR.NS', 'DEEPINDS.NS', 'DELHIVERY.NS', 'DELPHIFX.NS', 'DELTACORP.NS', 'DELTAMAGNT.NS', 'DEN.NS', 'DENORA.NS', 'DEVIT.NS', 'DEVYANI.NS', 'DGCONTENT.NS', 'DHAMPURSUG.NS', 'DHANBANK.NS', 'DHANI.NS', 'DHANUKA.NS', 'DHARMAJ.NS', 'DHRUV.NS', 'DHUNINV.NS', 'DIACABS.NS', 'DIAMINESQ.NS', 'DIAMONDYD.NS', 'DICIND.NS', 'DIGISPICE.NS', 'DIGJAMLMTD.NS', 'DIL.NS', 'DISHTV.NS', 'DIVGIITTS.NS', 'DIVISLAB.NS', 'DIXON.NS', 'DJML.NS', 'DLF.NS', 'DLINKINDIA.NS', 'DMART.NS', 'DMCC.NS', 'DNAMEDIA.NS', 'DODLA.NS', 'DOLATALGO.NS', 'DOLLAR.NS', 'DOLPHIN.NS', 'DOMS.NS', 'DONEAR.NS', 'DPABHUSHAN.NS', 'DPSCLTD.NS', 'DPWIRES.NS', 'DRCSYSTEMS.NS', 'DREAMFOLKS.NS', 'DREDGECORP.NS', 'DRREDDY.NS', 'DSSL.NS', 'DTIL.NS', 'DUCON.NS', 'DVL.NS', 'DWARKESH.NS', 'DYCL.NS', 'DYNAMATECH.NS', 'DYNPRO.NS', 'E2E.NS', 'EASEMYTRIP.NS', 'EASTSILK.NS', 'ECLERX.NS', 'EDELWEISS.NS', 'EDUCOMP.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'EIFFL.NS', 'EIHAHOTELS.NS', 'EIHOTEL.NS', 'EIMCOELECO.NS', 'EKC.NS', 'ELDEHSG.NS', 'ELECON.NS', 'ELECTCAST.NS', 'ELECTHERM.NS', 'ELGIEQUIP.NS', 'ELGIRUBCO.NS', 'ELIN.NS', 'EMAMILTD.NS', 'EMAMIPAP.NS', 'EMAMIREAL.NS', 'EMIL.NS', 'EMKAY.NS', 'EMMBI.NS', 'EMSLIMITED.NS', 'EMUDHRA.NS', 'ENDURANCE.NS', 'ENERGYDEV.NS', 'ENGINERSIN.NS', 'ENIL.NS', 'EPIGRAL.NS', 'EPL.NS', 'EQUIPPP.NS', 'EQUITASBNK.NS', 'ERIS.NS', 'EROSMEDIA.NS', 'ESABINDIA.NS', 'ESAFSFB.NS', 'ESCORTS.NS', 'ESSARSHPNG.NS', 'ESSENTIA.NS', 'ESTER.NS', 'ETHOSLTD.NS', 'EUROTEXIND.NS', 'EVEREADY.NS', 'EVERESTIND.NS', 'EXCEL.NS', 'EXCELINDUS.NS', 'EXIDEIND.NS', 'EXPLEOSOL.NS', 'EXXARO.NS', 'FACT.NS', 'FAIRCHEMOR.NS', 'FAZE3Q.NS', 'FCL.NS', 'FCONSUMER.NS', 'FCSSOFT.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FEDFINA.NS', 'FEL.NS', 'FELDVR.NS', 'FIBERWEB.NS', 'FIEMIND.NS', 'FILATEX.NS', 'FINCABLES.NS', 'FINEORG.NS', 'FINOPB.NS', 'FINPIPE.NS', 'FIVESTAR.NS', 'FLAIR.NS', 'FLEXITUFF.NS', 'FLFL.NS', 'FLUOROCHEM.NS', 'FMGOETZE.NS', 'FMNL.NS', 'FOCUS.NS', 'FOODSIN.NS', 'FORTIS.NS', 'FOSECOIND.NS', 'FSC.NS', 'FSL.NS', 'FUSION.NS', 'GABRIEL.NS', 'GAEL.NS', 'GAIL.NS', 'GALAXYSURF.NS', 'GALLANTT.NS', 'GANDHAR.NS', 'GANDHITUBE.NS', 'GANECOS.NS', 'GANESHBE.NS', 'GANESHHOUC.NS', 'GANGAFORGE.NS', 'GANGESSECU.NS', 'GARFIBRES.NS', 'GATECH.NS', 'GATECHDVR.NS', 'GATEWAY.NS', 'GEECEE.NS', 'GEEKAYWIRE.NS', 'GENCON.NS', 'GENESYS.NS', 'GENSOL.NS', 'GENUSPAPER.NS', 'GENUSPOWER.NS', 'GEOJITFSL.NS', 'GEPIL.NS', 'GESHIP.NS', 'GET&D.NS', 'GFLLIMITED.NS', 'GHCL.NS', 'GHCLTEXTIL.NS', 'GICHSGFIN.NS', 'GICRE.NS', 'GILLANDERS.NS', 'GILLETTE.NS', 'GINNIFILA.NS', 'GIPCL.NS', 'GKWLIMITED.NS', 'GLAND.NS', 'GLAXO.NS', 'GLENMARK.NS', 'GLFL.NS', 'GLOBAL.NS', 'GLOBALVECT.NS', 'GLOBE.NS', 'GLOBUSSPR.NS', 'GLS.NS', 'GMBREW.NS', 'GMDCLTD.NS', 'GMMPFAUDLR.NS', 'GMRINFRA.NS', 'GMRP&UI.NS', 'GNA.NS', 'GNFC.NS', 'GOACARBON.NS', 'GOCLCORP.NS', 'GOCOLORS.NS', 'GODFRYPHLP.NS', 'GODHA.NS', 'GODREJAGRO.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GODREJPROP.NS', 'GOENKA.NS', 'GOKEX.NS', 'GOKUL.NS', 'GOKULAGRO.NS', 'GOLDENTOBC.NS', 'GOLDIAM.NS', 'GOLDTECH.NS', 'GOODLUCK.NS', 'GOYALALUM.NS', 'GPIL.NS', 'GPPL.NS', 'GPTINFRA.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'GRAVITA.NS', 'GREAVESCOT.NS', 'GREENLAM.NS', 'GREENPANEL.NS', 'GREENPLY.NS', 'GREENPOWER.NS', 'GRINDWELL.NS', 'GRINFRA.NS', 'GRMOVER.NS', 'GROBTEA.NS', 'GRPLTD.NS', 'GRSE.NS', 'GRWRHITECH.NS', 'GSFC.NS', 'GSLSU.NS', 'GSPL.NS', 'GSS.NS', 'GTECJAINX.NS', 'GTL.NS', 'GTLINFRA.NS', 'GTPL.NS', 'GUFICBIO.NS', 'GUJALKALI.NS', 'GUJAPOLLO.NS', 'GUJGASLTD.NS', 'GUJRAFFIA.NS', 'GULFOILLUB.NS', 'GULFPETRO.NS', 'GULPOLY.NS', 'GVKPIL.NS', 'GVPTECH.NS', 'HAL.NS', 'HAPPSTMNDS.NS', 'HAPPYFORGE.NS', 'HARDWYN.NS', 'HARIOMPIPE.NS', 'HARRMALAYA.NS', 'HARSHA.NS', 'HATHWAY.NS', 'HATSUN.NS', 'HAVELLS.NS', 'HAVISHA.NS', 'HBLPOWER.NS', 'HBSL.NS', 'HCC.NS', 'HCG.NS', 'HCL-INSYS.NS', 'HCLTECH.NS', 'HDFCAMC.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'HEADSUP.NS', 'HECPROJECT.NS', 'HEG.NS', 'HEIDELBERG.NS', 'HEMIPROP.NS', 'HERANBA.NS', 'HERCULES.NS', 'HERITGFOOD.NS', 'HEROMOTOCO.NS', 'HESTERBIO.NS', 'HEUBACHIND.NS', 'HEXATRADEX.NS', 'HFCL.NS', 'HGINFRA.NS', 'HGS.NS', 'HIKAL.NS', 'HIL.NS', 'HILTON.NS', 'HIMATSEIDE.NS', 'HINDALCO.NS', 'HINDCOMPOS.NS', 'HINDCON.NS', 'HINDCOPPER.NS', 'HINDMOTORS.NS', 'HINDOILEXP.NS', 'HINDPETRO.NS', 'HINDUNILVR.NS', 'HINDWAREAP.NS', 'HINDZINC.NS', 'HIRECT.NS', 'HISARMETAL.NS', 'HITECH.NS', 'HITECHCORP.NS', 'HITECHGEAR.NS', 'HLEGLAS.NS', 'HLVLTD.NS', 'HMAAGRO.NS', 'HMT.NS', 'HMVL.NS', 'HNDFDS.NS', 'HOMEFIRST.NS', 'HONASA.NS', 'HONAUT.NS', 'HONDAPOWER.NS', 'HOVS.NS', 'HPAL.NS', 'HPIL.NS', 'HPL.NS', 'HSCL.NS', 'HTMEDIA.NS', 'HUBTOWN.NS', 'HUDCO.NS', 'HUHTAMAKI.NS', 'HYBRIDFIN.NS', 'IBREALEST.NS', 'IBULHSGFIN.NS', 'ICDSLTD.NS', 'ICEMAKE.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'ICIL.NS', 'ICRA.NS', 'IDBI.NS', 'IDEA.NS', 'IDEAFORGE.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IEL.NS', 'IEX.NS', 'IFBAGRO.NS', 'IFBIND.NS', 'IFCI.NS', 'IFGLEXPOR.NS', 'IGARASHI.NS', 'IGL.NS', 'IGPL.NS', 'IIFL.NS', 'IIFLSEC.NS', 'IITL.NS', 'IKIO.NS', 'IL&FSENGG.NS', 'IL&FSTRANS.NS', 'IMAGICAA.NS', 'IMFA.NS', 'IMPAL.NS', 'IMPEXFERRO.NS', 'INCREDIBLE.NS', 'INDBANK.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INDIAGLYCO.NS', 'INDIAMART.NS', 'INDIANB.NS', 'INDIANCARD.NS', 'INDIANHUME.NS', 'INDIASHLTR.NS', 'INDIGO.NS', 'INDIGOPNTS.NS', 'INDNIPPON.NS', 'INDOAMIN.NS', 'INDOBORAX.NS', 'INDOCO.NS', 'INDORAMA.NS', 'INDOSTAR.NS', 'INDOTECH.NS', 'INDOTHAI.NS', 'INDOWIND.NS', 'INDRAMEDCO.NS', 'INDSWFTLAB.NS', 'INDSWFTLTD.NS', 'INDTERRAIN.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'INFOBEAN.NS', 'INFOMEDIA.NS', 'INFY.NS', 'INGERRAND.NS', 'INNOVACAP.NS', 'INOXGREEN.NS', 'INOXINDIA.NS', 'INOXWIND.NS', 'INSECTICID.NS', 'INSPIRISYS.NS', 'INTELLECT.NS', 'INTENTECH.NS', 'INTLCONV.NS', 'INVENTURE.NS', 'IOB.NS', 'IOC.NS', 'IOLCP.NS', 'IONEXCHANG.NS', 'IPCALAB.NS', 'IPL.NS', 'IRB.NS', 'IRCON.NS', 'IRCTC.NS', 'IREDA.NS', 'IRFC.NS', 'IRIS.NS', 'IRISDOREME.NS', 'IRMENERGY.NS', 'ISEC.NS', 'ISFT.NS', 'ISGEC.NS', 'ISMTLTD.NS', 'ITC.NS', 'ITDC.NS', 'ITDCEM.NS', 'ITI.NS', 'IVC.NS', 'IVP.NS', 'IWEL.NS', 'IZMO.NS', 'J&KBANK.NS', 'JAGRAN.NS', 'JAGSNPHARM.NS', 'JAIBALAJI.NS', 'JAICORPLTD.NS', 'JAIPURKURT.NS', 'JAMNAAUTO.NS', 'JASH.NS', 'JAYAGROGN.NS', 'JAYBARMARU.NS', 'JAYNECOIND.NS', 'JAYSREETEA.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JCHAC.NS', 'JETAIRWAYS.NS', 'JETFREIGHT.NS', 'JHS.NS', 'JINDALPHOT.NS', 'JINDALPOLY.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JINDRILL.NS', 'JINDWORLD.NS', 'JIOFIN.NS', 'JISLDVREQS.NS', 'JISLJALEQS.NS', 'JITFINFRA.NS', 'JKCEMENT.NS', 'JKIL.NS', 'JKLAKSHMI.NS', 'JKPAPER.NS', 'JKTYRE.NS', 'JLHL.NS', 'JMA.NS', 'JMFINANCIL.NS', 'JOCIL.NS', 'JPASSOCIAT.NS', 'JPOLYINVST.NS', 'JPPOWER.NS', 'JSL.NS', 'JSWENERGY.NS', 'JSWHL.NS', 'JSWINFRA.NS', 'JSWSTEEL.NS', 'JTEKTINDIA.NS', 'JTLIND.NS', 'JUBLFOOD.NS', 'JUBLINDS.NS', 'JUBLINGREA.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'JWL.NS', 'JYOTHYLAB.NS', 'JYOTISTRUC.NS', 'KABRAEXTRU.NS', 'KAJARIACER.NS', 'KAKATCEM.NS', 'KALAMANDIR.NS', 'KALYANI.NS', 'KALYANIFRG.NS', 'KALYANKJIL.NS', 'KAMATHOTEL.NS', 'KAMDHENU.NS', 'KAMOPAINTS.NS', 'KANANIIND.NS', 'KANORICHEM.NS', 'KANPRPLA.NS', 'KANSAINER.NS', 'KAPSTON.NS', 'KARMAENG.NS', 'KARURVYSYA.NS', 'KAUSHALYA.NS', 'KAVVERITEL.NS', 'KAYA.NS', 'KAYNES.NS', 'KBCGLOBAL.NS', 'KCP.NS', 'KCPSUGIND.NS', 'KDDL.NS', 'KEC.NS', 'KECL.NS', 'KEEPLEARN.NS', 'KEI.NS', 'KELLTONTEC.NS', 'KERNEX.NS', 'KESORAMIND.NS', 'KEYFINSERV.NS', 'KFINTECH.NS', 'KHADIM.NS', 'KHAICHEM.NS', 'KHAITANLTD.NS', 'KHANDSE.NS', 'KICL.NS', 'KILITCH.NS', 'KIMS.NS', 'KINGFA.NS', 'KIOCL.NS', 'KIRIINDUS.NS', 'KIRLOSBROS.NS', 'KIRLOSENG.NS', 'KIRLOSIND.NS', 'KIRLPNU.NS', 'KITEX.NS', 'KKCL.NS', 'KMSUGAR.NS', 'KNRCON.NS', 'KOHINOOR.NS', 'KOKUYOCMLN.NS', 'KOLTEPATIL.NS', 'KOPRAN.NS', 'KOTAKBANK.NS', 'KOTARISUG.NS', 'KOTHARIPET.NS', 'KOTHARIPRO.NS', 'KPIGREEN.NS', 'KPIL.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'KRBL.NS', 'KREBSBIO.NS', 'KRIDHANINF.NS', 'KRISHANA.NS', 'KRITI.NS', 'KRITIKA.NS', 'KRITINUT.NS', 'KRSNAA.NS', 'KSB.NS', 'KSCL.NS', 'KSHITIJPOL.NS', 'KSL.NS', 'KSOLVES.NS', 'KTKBANK.NS', 'KUANTUM.NS', 'L&TFH.NS', 'LAGNAM.NS', 'LAKPRE.NS', 'LAL.NS', 'LALPATHLAB.NS', 'LAMBODHARA.NS', 'LANDMARK.NS', 'LAOPALA.NS', 'LASA.NS', 'LATENTVIEW.NS', 'LATTEYS.NS', 'LAURUSLABS.NS', 'LAXMICOT.NS', 'LAXMIMACH.NS', 'LCCINFOTEC.NS', 'LEMONTREE.NS', 'LEXUS.NS', 'LFIC.NS', 'LGBBROSLTD.NS', 'LGBFORGE.NS', 'LGHL.NS', 'LIBAS.NS', 'LIBERTSHOE.NS', 'LICHSGFIN.NS', 'LICI.NS', 'LIKHITHA.NS', 'LINC.NS', 'LINCOLN.NS', 'LINDEINDIA.NS', 'LLOYDS-RE.NS', 'LLOYDSENGG.NS', 'LLOYDSME.NS', 'LODHA.NS', 'LOKESHMACH.NS', 'LORDSCHLO.NS', 'LOTUSEYE.NS', 'LOVABLE.NS', 'LOYALTEX.NS', 'LPDC.NS', 'LT.NS', 'LTFOODS.NS', 'LTIM.NS', 'LTTS.NS', 'LUMAXIND.NS', 'LUMAXTECH.NS', 'LUPIN.NS', 'LUXIND.NS', 'LXCHEM.NS', 'LYKALABS.NS', 'LYPSAGEMS.NS', 'M&M.NS', 'M&MFIN.NS', 'MAANALU.NS', 'MACPOWER.NS', 'MADHAV.NS', 'MADHUCON.NS', 'MADRASFERT.NS', 'MAGADSUGAR.NS', 'MAGNUM.NS', 'MAHABANK.NS', 'MAHAPEXLTD.NS', 'MAHASTEEL.NS', 'MAHEPC.NS', 'MAHESHWARI.NS', 'MAHLIFE.NS', 'MAHLOG.NS', 'MAHSCOOTER.NS', 'MAHSEAMLES.NS', 'MAITHANALL.NS', 'MALLCOM.NS', 'MALUPAPER.NS', 'MANAKALUCO.NS', 'MANAKCOAT.NS', 'MANAKSIA.NS', 'MANAKSTEEL.NS', 'MANALIPETC.NS', 'MANAPPURAM.NS', 'MANGALAM.NS', 'MANGCHEFER.NS', 'MANGLMCEM.NS', 'MANINDS.NS', 'MANINFRA.NS', 'MANKIND.NS', 'MANOMAY.NS', 'MANORAMA.NS', 'MANORG.NS', 'MANUGRAPH.NS', 'MANYAVAR.NS', 'MAPMYINDIA.NS', 'MARALOVER.NS', 'MARATHON.NS', 'MARICO.NS', 'MARINE.NS', 'MARKSANS.NS', 'MARSHALL.NS', 'MARUTI.NS', 'MASFIN.NS', 'MASKINVEST.NS', 'MASTEK.NS', 'MATRIMONY.NS', 'MAWANASUG.NS', 'MAXESTATES.NS', 'MAXHEALTH.NS', 'MAXIND.NS', 'MAYURUNIQ.NS', 'MAZDA.NS', 'MAZDOCK.NS', 'MBAPL.NS', 'MBECL.NS', 'MBLINFRA.NS', 'MCDOWELL-N.NS', 'MCL.NS', 'MCLEODRUSS.NS', 'MCX.NS', 'MEDANTA.NS', 'MEDICAMEQ.NS', 'MEDICO.NS', 'MEDPLUS.NS', 'MEGASOFT.NS', 'MEGASTAR.NS', 'MELSTAR.NS', 'MENONBE.NS', 'MEP.NS', 'METALFORGE.NS', 'METROBRAND.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MGEL.NS', 'MGL.NS', 'MHLXMIRU.NS', 'MHRIL.NS', 'MICEL.NS', 'MIDHANI.NS', 'MINDACORP.NS', 'MINDTECK.NS', 'MIRCELECTR.NS', 'MIRZAINT.NS', 'MITCON.NS', 'MITTAL.NS', 'MKPL.NS', 'MMFL.NS', 'MMP.NS', 'MMTC.NS', 'MODIRUBBER.NS', 'MODISONLTD.NS', 'MOHITIND.NS', 'MOIL.NS', 'MOKSH.NS', 'MOL.NS', 'MOLDTECH.NS', 'MOLDTKPAC.NS', 'MONARCH.NS', 'MONTECARLO.NS', 'MORARJEE.NS', 'MOREPENLAB.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'MOTISONS.NS', 'MOTOGENFIN.NS', 'MPHASIS.NS', 'MPSLTD.NS', 'MRF.NS', 'MRO-TEK.NS', 'MRPL.NS', 'MSPL.NS', 'MSTCLTD.NS', 'MSUMI.NS', 'MTARTECH.NS', 'MTEDUCARE.NS', 'MTNL.NS', 'MUFIN.NS', 'MUFTI.NS', 'MUKANDLTD.NS', 'MUKTAARTS.NS', 'MUNJALAU.NS', 'MUNJALSHOW.NS', 'MURUDCERA.NS', 'MUTHOOTCAP.NS', 'MUTHOOTFIN.NS', 'MUTHOOTMF.NS', 'MVGJL.NS', 'NACLIND.NS', 'NAGAFERT.NS', 'NAGREEKCAP.NS', 'NAGREEKEXP.NS', 'NAHARCAP.NS', 'NAHARINDUS.NS', 'NAHARPOLY.NS', 'NAHARSPING.NS', 'NAM-INDIA.NS', 'NARMADA.NS', 'NATCOPHARM.NS', 'NATHBIOGEN.NS', 'NATIONALUM.NS', 'NAUKRI.NS', 'NAVA.NS', 'NAVINFLUOR.NS', 'NAVKARCORP.NS', 'NAVNETEDUL.NS', 'NAZARA.NS', 'NBCC.NS', 'NBIFIN.NS', 'NCC.NS', 'NCLIND.NS', 'NDGL.NS', 'NDL.NS', 'NDLVENTURE.NS', 'NDRAUTO.NS', 'NDTV.NS', 'NECCLTD.NS', 'NECLIFE.NS', 'NELCAST.NS', 'NELCO.NS', 'NEOGEN.NS', 'NESCO.NS', 'NESTLEIND.NS', 'NETWEB.NS', 'NETWORK18.NS', 'NEULANDLAB.NS', 'NEWGEN.NS', 'NEXTMEDIA.NS', 'NFL.NS', 'NGIL.NS', 'NGLFINE.NS', 'NH.NS', 'NHPC.NS', 'NIACL.NS', 'NIBL.NS', 'NIITLTD.NS', 'NIITMTS.NS', 'NILAINFRA.NS', 'NILASPACES.NS', 'NILKAMAL.NS', 'NINSYS.NS', 'NIPPOBATRY.NS', 'NIRAJ.NS', 'NIRAJISPAT.NS', 'NITCO.NS', 'NITINSPIN.NS', 'NITIRAJ.NS', 'NKIND.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NOCIL.NS', 'NOIDATOLL.NS', 'NORBTEAEXP.NS', 'NRAIL.NS', 'NRBBEARING.NS', 'NRL.NS', 'NSIL.NS', 'NSLNISP.NS', 'NTPC.NS', 'NUCLEUS.NS', 'NURECA.NS', 'NUVAMA.NS', 'NUVOCO.NS', 'NYKAA.NS', 'OAL.NS', 'OBCL.NS', 'OBEROIRLTY.NS', 'OCCL.NS', 'OFSS.NS', 'OIL.NS', 'OILCOUNTUB.NS', 'OLECTRA.NS', 'OMAXAUTO.NS', 'OMAXE.NS', 'OMINFRAL.NS', 'OMKARCHEM.NS', 'ONELIFECAP.NS', 'ONEPOINT.NS', 'ONGC.NS', 'ONMOBILE.NS', 'ONWARDTEC.NS', 'OPTIEMUS.NS', 'ORBTEXP.NS', 'ORCHPHARMA.NS', 'ORICONENT.NS', 'ORIENTALTL.NS', 'ORIENTBELL.NS', 'ORIENTCEM.NS', 'ORIENTCER.NS', 'ORIENTELEC.NS', 'ORIENTHOT.NS', 'ORIENTLTD.NS', 'ORIENTPPR.NS', 'ORISSAMINE.NS', 'ORTINLAB.NS', 'OSIAHYPER.NS', 'OSWALAGRO.NS', 'OSWALGREEN.NS', 'OSWALSEEDS.NS', 'PAGEIND.NS', 'PAISALO.NS', 'PAKKA.NS', 'PALASHSECU.NS', 'PALREDTEC.NS', 'PANACEABIO.NS', 'PANACHE.NS', 'PANAMAPET.NS', 'PANSARI.NS', 'PAR.NS', 'PARACABLES.NS', 'PARADEEP.NS', 'PARAGMILK.NS', 'PARAS.NS', 'PARASPETRO.NS', 'PARSVNATH.NS', 'PASUPTAC.NS', 'PATANJALI.NS', 'PATELENG.NS', 'PATINTLOG.NS', 'PAVNAIND.NS', 'PAYTM.NS', 'PCBL.NS', 'PCJEWELLER.NS', 'PDMJEPAPER.NS', 'PDSL.NS', 'PEARLPOLY.NS', 'PEL.NS', 'PENIND.NS', 'PENINLAND.NS', 'PERSISTENT.NS', 'PETRONET.NS', 'PFC.NS', 'PFIZER.NS', 'PFOCUS.NS', 'PFS.NS', 'PGEL.NS', 'PGHH.NS', 'PGHL.NS', 'PGIL.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'PIGL.NS', 'PIIND.NS', 'PILANIINVS.NS', 'PILITA.NS', 'PIONEEREMB.NS', 'PITTIENG.NS', 'PIXTRANS.NS', 'PKTEA.NS', 'PLASTIBLEN.NS', 'PLAZACABLE.NS', 'PNB.NS', 'PNBGILTS.NS', 'PNBHOUSING.NS', 'PNC.NS', 'PNCINFRA.NS', 'POCL.NS', 'PODDARHOUS.NS', 'PODDARMENT.NS', 'POKARNA.NS', 'POLICYBZR.NS', 'POLYCAB.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'PONNIERODE.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'POWERINDIA.NS', 'POWERMECH.NS', 'PPAP.NS', 'PPL.NS', 'PPLPHARMA.NS', 'PRAENG.NS', 'PRAJIND.NS', 'PRAKASH.NS', 'PRAKASHSTL.NS', 'PRAXIS.NS', 'PRECAM.NS', 'PRECOT.NS', 'PRECWIRE.NS', 'PREMEXPLN.NS', 'PREMIER.NS', 'PREMIERPOL.NS', 'PRESTIGE.NS', 'PRICOLLTD.NS', 'PRIMESECU.NS', 'PRINCEPIPE.NS', 'PRITI.NS', 'PRITIKAUTO.NS', 'PRIVISCL.NS', 'PROZONER.NS', 'PRSMJOHNSN.NS', 'PRUDENT.NS', 'PRUDMOULI.NS', 'PSB.NS', 'PSPPROJECT.NS', 'PTC.NS', 'PTCIL.NS', 'PTL.NS', 'PUNJABCHEM.NS', 'PURVA.NS', 'PVP.NS', 'PVRINOX.NS', 'PYRAMID.NS', 'QUESS.NS', 'QUICKHEAL.NS', 'RACE.NS', 'RADAAN.NS', 'RADHIKAJWE.NS', 'RADIANTCMS.NS', 'RADICO.NS', 'RADIOCITY.NS', 'RAILTEL.NS', 'RAIN.NS', 'RAINBOW.NS', 'RAJESHEXPO.NS', 'RAJMET.NS', 'RAJRATAN.NS', 'RAJRILTD.NS', 'RAJSREESUG.NS', 'RAJTV.NS', 'RALLIS.NS', 'RAMANEWS.NS', 'RAMAPHO.NS', 'RAMASTEEL.NS', 'RAMCOCEM.NS', 'RAMCOIND.NS', 'RAMCOSYS.NS', 'RAMKY.NS', 'RAMRAT.NS', 'RANASUG.NS', 'RANEENGINE.NS', 'RANEHOLDIN.NS', 'RATEGAIN.NS', 'RATNAMANI.NS', 'RATNAVEER.NS', 'RAYMOND.NS', 'RBA.NS', 'RBL.NS', 'RBLBANK.NS', 'RBZJEWEL.NS', 'RCF.NS', 'RECLTD.NS', 'REDINGTON.NS', 'REDTAPE.NS', 'REFEX.NS', 'REGENCERAM.NS', 'RELAXO.NS', 'RELCAPITAL.NS', 'RELCHEMQ.NS', 'RELIANCE.NS', 'RELIGARE.NS', 'RELINFRA.NS', 'REMSONSIND.NS', 'RENUKA.NS', 'REPCOHOME.NS', 'REPL.NS', 'REPRO.NS', 'RESPONIND.NS', 'RGL.NS', 'RHFL.NS', 'RHIM.NS', 'RHL.NS', 'RICOAUTO.NS', 'RIIL.NS', 'RISHABH.NS', 'RITCO.NS', 'RITES.NS', 'RKDL.NS', 'RKEC.NS', 'RKFORGE.NS', 'RML.NS', 'ROHLTD.NS', 'ROLEXRINGS.NS', 'ROLLT.NS', 'ROML.NS', 'ROSSARI.NS', 'ROSSELLIND.NS', 'ROTO.NS', 'ROUTE.NS', 'RPGLIFE.NS', 'RPOWER.NS', 'RPPINFRA.NS', 'RPPL.NS', 'RPSGVENT.NS', 'RRKABEL.NS', 'RSSOFTWARE.NS', 'RSWM.NS', 'RSYSTEMS.NS', 'RTNINDIA.NS', 'RTNPOWER.NS', 'RUBYMILLS.NS', 'RUCHINFRA.NS', 'RUCHIRA.NS', 'RUPA.NS', 'RUSHIL.NS', 'RUSTOMJEE.NS', 'RVHL.NS', 'RVNL.NS', 'S&SPOWER.NS', 'SABEVENTS.NS', 'SABTN.NS', 'SADBHAV.NS', 'SADBHIN.NS', 'SADHNANIQ.NS', 'SAFARI.NS', 'SAGARDEEP.NS', 'SAGCEM.NS', 'SAH.NS', 'SAHYADRI.NS', 'SAIL.NS', 'SAKAR.NS', 'SAKHTISUG.NS', 'SAKSOFT.NS', 'SAKUMA.NS', 'SALASAR.NS', 'SALONA.NS', 'SALSTEEL.NS', 'SALZERELEC.NS', 'SAMBHAAV.NS', 'SAMHI.NS', 'SAMPANN.NS', 'SANCO.NS', 'SANDESH.NS', 'SANDHAR.NS', 'SANDUMA.NS', 'SANGAMIND.NS', 'SANGHIIND.NS', 'SANGHVIMOV.NS', 'SANGINITA.NS', 'SANOFI.NS', 'SANSERA.NS', 'SAPPHIRE.NS', 'SARDAEN.NS', 'SAREGAMA.NS', 'SARLAPOLY.NS', 'SARVESHWAR.NS', 'SASKEN.NS', 'SASTASUNDR.NS', 'SATIA.NS', 'SATIN.NS', 'SATINDLTD.NS', 'SBC.NS', 'SBCL.NS', 'SBFC.NS', 'SBGLP.NS', 'SBICARD.NS', 'SBILIFE.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SCHAND.NS', 'SCHNEIDER.NS', 'SCI.NS', 'SCPL.NS', 'SDBL.NS', 'SEAMECLTD.NS', 'SECMARK.NS', 'SECURCRED.NS', 'SECURKLOUD.NS', 'SEJALLTD.NS', 'SELAN.NS', 'SELMC.NS', 'SEMAC.NS', 'SENCO.NS', 'SEPC.NS', 'SEQUENT.NS', 'SERVOTECH.NS', 'SESHAPAPER.NS', 'SETCO.NS', 'SEYAIND.NS', 'SFL.NS', 'SGIL.NS', 'SGL.NS', 'SHAH.NS', 'SHAHALLOYS.NS', 'SHAILY.NS', 'SHAKTIPUMP.NS', 'SHALBY.NS', 'SHALPAINTS.NS', 'SHANKARA.NS', 'SHANTI.NS', 'SHANTIGEAR.NS', 'SHARDACROP.NS', 'SHARDAMOTR.NS', 'SHAREINDIA.NS', 'SHEMAROO.NS', 'SHILPAMED.NS', 'SHIVALIK.NS', 'SHIVAMAUTO.NS', 'SHIVAMILLS.NS', 'SHIVATEX.NS', 'SHK.NS', 'SHOPERSTOP.NS', 'SHRADHA.NS', 'SHREDIGCEM.NS', 'SHREECEM.NS', 'SHREEPUSHK.NS', 'SHREERAMA.NS', 'SHRENIK.NS', 'SHREYANIND.NS', 'SHREYAS.NS', 'SHRIPISTON.NS', 'SHRIRAMFIN.NS', 'SHRIRAMPPS.NS', 'SHYAMCENT.NS', 'SHYAMMETL.NS', 'SHYAMTEL.NS', 'SICALLOG.NS', 'SIEMENS.NS', 'SIGACHI.NS', 'SIGIND.NS', 'SIGMA.NS', 'SIGNATURE.NS', 'SIKKO.NS', 'SIL.NS', 'SILGO.NS', 'SILINV.NS', 'SILLYMONKS.NS', 'SILVERTUC.NS', 'SIMBHALS.NS', 'SIMPLEXINF.NS', 'SINDHUTRAD.NS', 'SINTERCOM.NS', 'SIRCA.NS', 'SIS.NS', 'SITINET.NS', 'SIYSIL.NS', 'SJS.NS', 'SJVN.NS', 'SKFINDIA.NS', 'SKIPPER.NS', 'SKMEGGPROD.NS', 'SKYGOLD.NS', 'SMARTLINK.NS', 'SMCGLOBAL.NS', 'SMLISUZU.NS', 'SMLT.NS', 'SMSLIFE.NS', 'SMSPHARMA.NS', 'SNOWMAN.NS', 'SOBHA.NS', 'SOFTTECH.NS', 'SOLARA.NS', 'SOLARINDS.NS', 'SOMANYCERA.NS', 'SOMATEX.NS', 'SOMICONVEY.NS', 'SONACOMS.NS', 'SONAMLTD.NS', 'SONATSOFTW.NS', 'SOTL.NS', 'SOUTHBANK.NS', 'SOUTHWEST.NS', 'SPAL.NS', 'SPANDANA.NS', 'SPARC.NS', 'SPCENET.NS', 'SPECIALITY.NS', 'SPENCERS.NS', 'SPENTEX.NS', 'SPIC.NS', 'SPLIL.NS', 'SPLPETRO.NS', 'SPMLINFRA.NS', 'SPORTKING.NS', 'SPTL.NS', 'SPYL.NS', 'SREEL.NS', 'SRF.NS', 'SRGHFL.NS', 'SRHHYPOLTD.NS', 'SRPL.NS', 'SSWL.NS', 'STAR.NS', 'STARCEMENT.NS', 'STARHEALTH.NS', 'STARPAPER.NS', 'STARTECK.NS', 'STCINDIA.NS', 'STEELCAS.NS', 'STEELCITY.NS', 'STEELXIND.NS', 'STEL.NS', 'STERTOOLS.NS', 'STLTECH.NS', 'STOVEKRAFT.NS', 'STYLAMIND.NS', 'STYRENIX.NS', 'SUBEXLTD.NS', 'SUBROS.NS', 'SUDARSCHEM.NS', 'SUKHJITS.NS', 'SULA.NS', 'SUMICHEM.NS', 'SUMIT.NS', 'SUMMITSEC.NS', 'SUNCLAY.NS', 'SUNDARAM.NS', 'SUNDARMFIN.NS', 'SUNDARMHLD.NS', 'SUNDRMBRAK.NS', 'SUNDRMFAST.NS', 'SUNFLAG.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SUNTV.NS', 'SUPERHOUSE.NS', 'SUPERSPIN.NS', 'SUPRAJIT.NS', 'SUPREMEENG.NS', 'SUPREMEIND.NS', 'SUPREMEINF.NS', 'SUPRIYA.NS', 'SURAJEST.NS', 'SURANASOL.NS', 'SURANAT&P.NS', 'SURYALAXMI.NS', 'SURYAROSNI.NS', 'SURYODAY.NS', 'SUTLEJTEX.NS', 'SUULD.NS', 'SUVEN.NS', 'SUVENPHAR.NS', 'SUVIDHAA.NS', 'SUZLON.NS', 'SVLL.NS', 'SVPGLOB.NS', 'SWANENERGY.NS', 'SWARAJENG.NS', 'SWELECTES.NS', 'SWSOLAR.NS', 'SYMPHONY.NS', 'SYNCOMF.NS', 'SYNGENE.NS', 'SYRMA.NS', 'TAINWALCHM.NS', 'TAJGVK.NS', 'TAKE.NS', 'TALBROAUTO.NS', 'TANLA.NS', 'TARAPUR.NS', 'TARC.NS', 'TARMAT.NS', 'TARSONS.NS', 'TASTYBITE.NS', 'TATACHEM.NS', 'TATACOFFEE.NS', 'TATACOMM.NS', 'TATACONSUM.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TATAMETALI.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TATATECH.NS', 'TATVA.NS', 'TBZ.NS', 'TCI.NS', 'TCIEXP.NS', 'TCLCONS.NS', 'TCNSBRANDS.NS', 'TCPLPACK.NS', 'TCS.NS', 'TDPOWERSYS.NS', 'TEAMLEASE.NS', 'TECHIN.NS', 'TECHM.NS', 'TECHNOE.NS', 'TECILCHEM.NS', 'TEGA.NS', 'TEJASNET.NS', 'TEMBO.NS', 'TERASOFT.NS', 'TEXINFRA.NS', 'TEXMOPIPES.NS', 'TEXRAIL.NS', 'TFCILTD.NS', 'TFL.NS', 'TGBHOTELS.NS', 'THANGAMAYL.NS', 'THEINVEST.NS', 'THEJO.NS', 'THEMISMED.NS', 'THERMAX.NS', 'THOMASCOOK.NS', 'THOMASCOTT.NS', 'THYROCARE.NS', 'TI.NS', 'TIDEWATER.NS', 'TIIL.NS', 'TIINDIA.NS', 'TIJARIA.NS', 'TIL.NS', 'TIMESGTY.NS', 'TIMETECHNO.NS', 'TIMKEN.NS', 'TINPLATE.NS', 'TIPSFILMS.NS', 'TIPSINDLTD.NS', 'TIRUMALCHM.NS', 'TIRUPATIFL.NS', 'TITAGARH.NS', 'TITAN.NS', 'TMB.NS', 'TNPETRO.NS', 'TNPL.NS', 'TNTELE.NS', 'TOKYOPLAST.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'TOTAL.NS', 'TOUCHWOOD.NS', 'TPHQ.NS', 'TPLPLASTEH.NS', 'TRACXN.NS', 'TREEHOUSE.NS', 'TREJHARA.NS', 'TREL.NS', 'TRENT.NS', 'TRF.NS', 'TRIDENT.NS', 'TRIGYN.NS', 'TRIL.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TRU.NS', 'TTKHLTCARE.NS', 'TTKPRESTIG.NS', 'TTL.NS', 'TTML.NS', 'TV18BRDCST.NS', 'TVSELECT.NS', 'TVSHLTD.NS', 'TVSMOTOR.NS', 'TVSSCS.NS', 'TVSSRICHAK.NS', 'TVTODAY.NS', 'TVVISION.NS', 'UBL.NS', 'UCAL.NS', 'UCOBANK.NS', 'UDS.NS', 'UFLEX.NS', 'UFO.NS', 'UGARSUGAR.NS', 'UGROCAP.NS', 'UJJIVAN.NS', 'UJJIVANSFB.NS', 'ULTRACEMCO.NS', 'UMAEXPORTS.NS', 'UMANGDAIRY.NS', 'UMESLTD.NS', 'UNICHEMLAB.NS', 'UNIDT.NS', 'UNIENTER.NS', 'UNIINFO.NS', 'UNIONBANK.NS', 'UNIPARTS.NS', 'UNITECH.NS', 'UNITEDPOLY.NS', 'UNITEDTEA.NS', 'UNIVAFOODS.NS', 'UNIVASTU.NS', 'UNIVCABLES.NS', 'UNIVPHOTO.NS', 'UNOMINDA.NS', 'UPL.NS', 'URAVI.NS', 'URJA.NS', 'USHAMART.NS', 'USK.NS', 'UTIAMC.NS', 'UTKARSHBNK.NS', 'UTTAMSUGAR.NS', 'V2RETAIL.NS', 'VADILALIND.NS', 'VAIBHAVGBL.NS', 'VAISHALI.NS', 'VAKRANGEE.NS', 'VALIANTLAB.NS', 'VALIANTORG.NS', 'VARDHACRLC.NS', 'VARDMNPOLY.NS', 'VARROC.NS', 'VASCONEQ.NS', 'VASWANI.NS', 'VBL.NS', 'VCL.NS', 'VEDL.NS', 'VENKEYS.NS', 'VENUSPIPES.NS', 'VENUSREM.NS', 'VERANDA.NS', 'VERTOZ.NS', 'VESUVIUS.NS', 'VETO.NS', 'VGUARD.NS', 'VHL.NS', 'VIDHIING.NS', 'VIJAYA.NS', 'VIJIFIN.NS', 'VIKASECO.NS', 'VIKASLIFE.NS', 'VIMTALABS.NS', 'VINATIORGA.NS', 'VINDHYATEL.NS', 'VINEETLAB.NS', 'VINNY.NS', 'VINYLINDIA.NS', 'VIPCLOTHNG.NS', 'VIPIND.NS', 'VIPULLTD.NS', 'VIRINCHI.NS', 'VISAKAIND.NS', 'VISESHINFO.NS', 'VISHNU.NS', 'VISHWARAJ.NS', 'VIVIDHA.NS', 'VLEGOV.NS', 'VLSFINANCE.NS', 'VMART.NS', 'VOLTAMP.NS', 'VOLTAS.NS', 'VPRPL.NS', 'VRLLOG.NS', 'VSSL.NS', 'VSTIND.NS', 'VSTTILLERS.NS', 'VTL.NS', 'WABAG.NS', 'WALCHANNAG.NS', 'WANBURY.NS', 'WEALTH.NS', 'WEBELSOLAR.NS', 'WEIZMANIND.NS', 'WEL.NS', 'WELCORP.NS', 'WELENT.NS', 'WELINV.NS', 'WELSPUNLIV.NS', 'WENDT.NS', 'WESTLIFE.NS', 'WEWIN.NS', 'WHEELS.NS', 'WHIRLPOOL.NS', 'WILLAMAGOR.NS', 'WINDLAS.NS', 'WINDMACHIN.NS', 'WINSOME.NS', 'WIPL.NS', 'WIPRO.NS', 'WOCKPHARMA.NS', 'WONDERLA.NS', 'WORTH.NS', 'WSI.NS', 'WSTCSTPAPR.NS', 'XCHANGING.NS', 'XELPMOC.NS', 'XPROINDIA.NS', 'YAARI.NS', 'YASHO.NS', 'YATHARTH.NS', 'YATRA.NS', 'YESBANK.NS', 'YUKEN.NS', 'ZAGGLE.NS', 'ZEEL.NS', 'ZEELEARN.NS', 'ZEEMEDIA.NS', 'ZENITHEXPO.NS', 'ZENITHSTL.NS', 'ZENSARTECH.NS', 'ZENTEC.NS', 'ZFCVINDIA.NS', 'ZIMLAB.NS', 'ZODIAC.NS', 'ZODIACLOTH.NS', 'ZOMATO.NS', 'ZOTA.NS', 'ZUARI.NS', 'ZUARIIND.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS']

# %% [markdown]
# #List of stocks under 2000 (total 1762 stocks)

# %%
nse_stocks = ['20MICRONS.NS', '21STCENMGM.NS', '360ONE.NS', '3IINFOLTD.NS', '3PLAND.NS', '5PAISA.NS', '63MOONS.NS', 'A2ZINFRA.NS', 'AAATECH.NS', 'AAKASH.NS', 'AAREYDRUGS.NS', 'AARON.NS', 'AARTECH.NS', 'AARTIDRUGS.NS', 'AARTIIND.NS', 'AARTIPHARM.NS', 'AARTISURF.NS', 'AARVEEDEN.NS', 'AARVI.NS', 'AAVAS.NS', 'ABAN.NS', 'ABCAPITAL.NS', 'ABFRL.NS', 'ABMINTLLTD.NS', 'ABSLAMC.NS', 'ACCELYA.NS', 'ACCURACY.NS', 'ACE.NS', 'ACEINTEG.NS', 'ACI.NS', 'ACL.NS', 'ACLGATI.NS', 'ADANIENSOL.NS', 'ADANIGREEN.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'ADFFOODS.NS', 'ADL.NS', 'ADORWELD.NS', 'ADROITINFO.NS', 'ADSL.NS', 'ADVANIHOTR.NS', 'ADVENZYMES.NS', 'AEGISCHEM.NS', 'AEROFLEX.NS', 'AETHER.NS', 'AFFLE.NS', 'AGARIND.NS', 'AGI.NS', 'AGRITECH.NS', 'AGROPHOS.NS', 'AGSTRA.NS', 'AHL.NS', 'AHLADA.NS', 'AHLEAST.NS', 'AHLUCONT.NS', 'AIRAN.NS', 'AIROLAM.NS', 'AJMERA.NS', 'AJOONI.NS', 'AKASH.NS', 'AKG.NS', 'AKI.NS', 'AKSHAR.NS', 'AKSHARCHEM.NS', 'AKSHOPTFBR.NS', 'ALANKIT.NS', 'ALBERTDAVD.NS', 'ALEMBICLTD.NS', 'ALICON.NS', 'ALKALI.NS', 'ALLCARGO.NS', 'ALLSEC.NS', 'ALMONDZ.NS', 'ALOKINDS.NS', 'ALPA.NS', 'ALPHAGEO.NS', 'ALPSINDUS.NS', 'AMBICAAGAR.NS', 'AMBIKCO.NS', 'AMBUJACEM.NS', 'AMDIND.NS', 'AMIORG.NS', 'AMJLAND.NS', 'AMNPLST.NS', 'AMRUTANJAN.NS', 'ANANTRAJ.NS', 'ANDHRAPAP.NS', 'ANDHRSUGAR.NS', 'ANIKINDS.NS', 'ANKITMETAL.NS', 'ANMOL.NS', 'ANTGRAPHIC.NS', 'ANURAS.NS', 'APCL.NS', 'APCOTEXIND.NS', 'APEX.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'APOLLO.NS', 'APOLLOPIPE.NS', 'APOLLOTYRE.NS', 'APTECHT.NS', 'APTUS.NS', 'ARCHIDPLY.NS', 'ARCHIES.NS', 'ARE&M.NS', 'ARENTERP.NS', 'ARIES.NS', 'ARIHANTCAP.NS', 'ARIHANTSUP.NS', 'AROGRANITE.NS', 'ARROWGREEN.NS', 'ARSHIYA.NS', 'ARSSINFRA.NS', 'ARTEMISMED.NS', 'ARTNIRMAN.NS', 'ARVEE.NS', 'ARVIND.NS', 'ARVINDFASN.NS', 'ARVSMART.NS', 'ASAHIINDIA.NS', 'ASAHISONG.NS', 'ASAL.NS', 'ASALCBR.NS', 'ASHAPURMIN.NS', 'ASHIANA.NS', 'ASHIMASYN.NS', 'ASHOKA.NS', 'ASHOKAMET.NS', 'ASHOKLEY.NS', 'ASIANENE.NS', 'ASIANHOTNR.NS', 'ASIANTILES.NS', 'ASKAUTOLTD.NS', 'ASMS.NS', 'ASPINWALL.NS', 'ASTEC.NS', 'ASTERDM.NS', 'ASTRAL.NS', 'ASTRAMICRO.NS', 'ASTRON.NS', 'ATALREAL.NS', 'ATAM.NS', 'ATFL.NS', 'ATGL.NS', 'ATL.NS', 'ATLANTAA.NS', 'ATULAUTO.NS', 'AUBANK.NS', 'AUROPHARMA.NS', 'AURUM.NS', 'AUSOMENT.NS', 'AUTOIND.NS', 'AVADHSUGAR.NS', 'AVALON.NS', 'AVANTIFEED.NS', 'AVG.NS', 'AVONMORE.NS', 'AVROIND.NS', 'AVTNPL.NS', 'AWHCL.NS', 'AWL.NS', 'AXISBANK.NS', 'AXISCADES.NS', 'AXITA.NS', 'AYMSYNTEX.NS', 'AZAD.NS', 'BAFNAPH.NS', 'BAGFILMS.NS', 'BAIDFIN.NS', 'BAJAJCON.NS', 'BAJAJELEC.NS', 'BAJAJFINSV.NS', 'BAJAJHCARE.NS', 'BAJAJHIND.NS', 'BAJEL.NS', 'BALAJITELE.NS', 'BALAXI.NS', 'BALKRISHNA.NS', 'BALMLAWRIE.NS', 'BALPHARMA.NS', 'BALRAMCHIN.NS', 'BANARBEADS.NS', 'BANCOINDIA.NS', 'BANDHANBNK.NS', 'BANG.NS', 'BANKA.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BANSWRAS.NS', 'BARBEQUE.NS', 'BASML.NS', 'BATAINDIA.NS', 'BBOX.NS', 'BBTC.NS', 'BBTCL.NS', 'BCG.NS', 'BCLIND.NS', 'BCONCEPTS.NS', 'BDL.NS', 'BEARDSELL.NS', 'BECTORFOOD.NS', 'BEDMUTHA.NS', 'BEL.NS', 'BEPL.NS', 'BERGEPAINT.NS', 'BFINVEST.NS', 'BFUTILITIE.NS', 'BGRENERGY.NS', 'BHAGCHEM.NS', 'BHAGERIA.NS', 'BHAGYANGR.NS', 'BHANDARI.NS', 'BHARATFORG.NS', 'BHARATGEAR.NS', 'BHARATWIRE.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'BIGBLOC.NS', 'BIKAJI.NS', 'BIL.NS', 'BINANIIND.NS', 'BIOCON.NS', 'BIOFILCHEM.NS', 'BIRLACABLE.NS', 'BIRLACORPN.NS', 'BIRLAMONEY.NS', 'BKMINDST.NS', 'BLAL.NS', 'BLBLIMITED.NS', 'BLISSGVS.NS', 'BLKASHYAP.NS', 'BLS.NS', 'BLUECHIP.NS', 'BLUECOAST.NS', 'BLUEJET.NS', 'BLUESTARCO.NS', 'BODALCHEM.NS', 'BOHRAIND.NS', 'BOMDYEING.NS', 'BOROLTD.NS', 'BORORENEW.NS', 'BPCL.NS', 'BPL.NS', 'BRIGADE.NS', 'BRNL.NS', 'BROOKS.NS', 'BSHSL.NS', 'BSL.NS', 'BSOFT.NS', 'BTML.NS', 'BURNPUR.NS', 'BUTTERFLY.NS', 'BVCL.NS', 'BYKE.NS', 'CALSOFT.NS', 'CAMLINFINE.NS', 'CAMPUS.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CANTABIL.NS', 'CAPACITE.NS', 'CAPLIPOINT.NS', 'CAPTRUST.NS', 'CARBORUNIV.NS', 'CAREERP.NS', 'CARERATING.NS', 'CARTRADE.NS', 'CARYSIL.NS', 'CASTROLIND.NS', 'CCHHL.NS', 'CCL.NS', 'CDSL.NS', 'CELEBRITY.NS', 'CELLO.NS', 'CENTENKA.NS', 'CENTEXT.NS', 'CENTRALBK.NS', 'CENTRUM.NS', 'CENTUM.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CEREBRAINT.NS', 'CESC.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHALET.NS', 'CHAMBLFERT.NS', 'CHEMBOND.NS', 'CHEMCON.NS', 'CHEMFAB.NS', 'CHEMPLASTS.NS', 'CHENNPETRO.NS', 'CHEVIOT.NS', 'CHOICEIN.NS', 'CHOLAFIN.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'CIGNITITEC.NS', 'CINELINE.NS', 'CINEVISTA.NS', 'CIPLA.NS', 'CLEAN.NS', 'CLEDUCATE.NS', 'CLSEL.NS', 'CMSINFO.NS', 'COALINDIA.NS', 'COASTCORP.NS', 'COCHINSHIP.NS', 'COFFEEDAY.NS', 'COMPINFO.NS', 'COMPUSOFT.NS', 'CONCOR.NS', 'CONCORDBIO.NS', 'CONFIPET.NS', 'CONSOFINVT.NS', 'CONTROLPR.NS', 'CORALFINAC.NS', 'CORDSCABLE.NS', 'COROMANDEL.NS', 'COSMOFIRST.NS', 'COUNCODOS.NS', 'CREATIVE.NS', 'CREATIVEYE.NS', 'CREDITACC.NS', 'CREST.NS', 'CROMPTON.NS', 'CROWN.NS', 'CSBBANK.NS', 'CSLFINANCE.NS', 'CTE.NS', 'CUB.NS', 'CUBEXTUB.NS', 'CUPID.NS', 'CYBERMEDIA.NS', 'CYBERTECH.NS', 'CYIENTDLM.NS', 'DABUR.NS', 'DALMIASUG.NS', 'DAMODARIND.NS', 'DANGEE.NS', 'DATAMATICS.NS', 'DATAPATTNS.NS', 'DBCORP.NS', 'DBL.NS', 'DBOL.NS', 'DBREALTY.NS', 'DBSTOCKBRO.NS', 'DCAL.NS', 'DCBBANK.NS', 'DCI.NS', 'DCM.NS', 'DCMFINSERV.NS', 'DCMNVL.NS', 'DCMSHRIRAM.NS', 'DCMSRIND.NS', 'DCW.NS', 'DCXINDIA.NS', 'DECCANCE.NS', 'DEEPAKFERT.NS', 'DEEPENR.NS', 'DEEPINDS.NS', 'DELHIVERY.NS', 'DELPHIFX.NS', 'DELTACORP.NS', 'DELTAMAGNT.NS', 'DEN.NS', 'DENORA.NS', 'DEVIT.NS', 'DEVYANI.NS', 'DGCONTENT.NS', 'DHAMPURSUG.NS', 'DHANBANK.NS', 'DHANI.NS', 'DHANUKA.NS', 'DHARMAJ.NS', 'DHRUV.NS', 'DHUNINV.NS', 'DIACABS.NS', 'DIAMINESQ.NS', 'DIAMONDYD.NS', 'DICIND.NS', 'DIGISPICE.NS', 'DIGJAMLMTD.NS', 'DIL.NS', 'DISHTV.NS', 'DIVGIITTS.NS', 'DJML.NS', 'DLF.NS', 'DLINKINDIA.NS', 'DMCC.NS', 'DNAMEDIA.NS', 'DODLA.NS', 'DOLATALGO.NS', 'DOLLAR.NS', 'DOLPHIN.NS', 'DOMS.NS', 'DONEAR.NS', 'DPABHUSHAN.NS', 'DPSCLTD.NS', 'DPWIRES.NS', 'DRCSYSTEMS.NS', 'DREAMFOLKS.NS', 'DREDGECORP.NS', 'DSSL.NS', 'DTIL.NS', 'DUCON.NS', 'DVL.NS', 'DWARKESH.NS', 'DYCL.NS', 'DYNPRO.NS', 'E2E.NS', 'EASEMYTRIP.NS', 'EASTSILK.NS', 'EDELWEISS.NS', 'EDUCOMP.NS', 'EIDPARRY.NS', 'EIFFL.NS', 'EIHAHOTELS.NS', 'EIHOTEL.NS', 'EIMCOELECO.NS', 'EKC.NS', 'ELDEHSG.NS', 'ELECON.NS', 'ELECTCAST.NS', 'ELECTHERM.NS', 'ELGIEQUIP.NS', 'ELGIRUBCO.NS', 'ELIN.NS', 'EMAMILTD.NS', 'EMAMIPAP.NS', 'EMAMIREAL.NS', 'EMIL.NS', 'EMKAY.NS', 'EMMBI.NS', 'EMSLIMITED.NS', 'EMUDHRA.NS', 'ENDURANCE.NS', 'ENERGYDEV.NS', 'ENGINERSIN.NS', 'ENIL.NS', 'EPIGRAL.NS', 'EPL.NS', 'EQUIPPP.NS', 'EQUITASBNK.NS', 'ERIS.NS', 'EROSMEDIA.NS', 'ESAFSFB.NS', 'ESSARSHPNG.NS', 'ESSENTIA.NS', 'ESTER.NS', 'EUROTEXIND.NS', 'EVEREADY.NS', 'EVERESTIND.NS', 'EXCEL.NS', 'EXCELINDUS.NS', 'EXIDEIND.NS', 'EXPLEOSOL.NS', 'EXXARO.NS', 'FACT.NS', 'FAIRCHEMOR.NS', 'FAZE3Q.NS', 'FCL.NS', 'FCONSUMER.NS', 'FCSSOFT.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FEDFINA.NS', 'FEL.NS', 'FELDVR.NS', 'FIBERWEB.NS', 'FILATEX.NS', 'FINCABLES.NS', 'FINOPB.NS', 'FINPIPE.NS', 'FIVESTAR.NS', 'FLAIR.NS', 'FLEXITUFF.NS', 'FLFL.NS', 'FMGOETZE.NS', 'FMNL.NS', 'FOCUS.NS', 'FOODSIN.NS', 'FORTIS.NS', 'FSC.NS', 'FSL.NS', 'FUSION.NS', 'GABRIEL.NS', 'GAEL.NS', 'GAIL.NS', 'GALLANTT.NS', 'GANDHAR.NS', 'GANDHITUBE.NS', 'GANECOS.NS', 'GANESHBE.NS', 'GANESHHOUC.NS', 'GANGAFORGE.NS', 'GANGESSECU.NS', 'GATECH.NS', 'GATECHDVR.NS', 'GATEWAY.NS', 'GEECEE.NS', 'GEEKAYWIRE.NS', 'GENCON.NS', 'GENESYS.NS', 'GENSOL.NS', 'GENUSPAPER.NS', 'GENUSPOWER.NS', 'GEOJITFSL.NS', 'GEPIL.NS', 'GESHIP.NS', 'GET&D.NS', 'GFLLIMITED.NS', 'GHCL.NS', 'GHCLTEXTIL.NS', 'GICHSGFIN.NS', 'GICRE.NS', 'GILLANDERS.NS', 'GINNIFILA.NS', 'GIPCL.NS', 'GKWLIMITED.NS', 'GLAND.NS', 'GLENMARK.NS', 'GLFL.NS', 'GLOBAL.NS', 'GLOBALVECT.NS', 'GLOBE.NS', 'GLOBUSSPR.NS', 'GLS.NS', 'GMBREW.NS', 'GMDCLTD.NS', 'GMMPFAUDLR.NS', 'GMRINFRA.NS', 'GMRP&UI.NS', 'GNA.NS', 'GNFC.NS', 'GOACARBON.NS', 'GOCLCORP.NS', 'GOCOLORS.NS', 'GODHA.NS', 'GODREJAGRO.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GOENKA.NS', 'GOKEX.NS', 'GOKUL.NS', 'GOKULAGRO.NS', 'GOLDENTOBC.NS', 'GOLDIAM.NS', 'GOLDTECH.NS', 'GOODLUCK.NS', 'GOYALALUM.NS', 'GPIL.NS', 'GPPL.NS', 'GPTINFRA.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GRAVITA.NS', 'GREAVESCOT.NS', 'GREENLAM.NS', 'GREENPANEL.NS', 'GREENPLY.NS', 'GREENPOWER.NS', 'GRINFRA.NS', 'GRMOVER.NS', 'GROBTEA.NS', 'GRSE.NS', 'GRWRHITECH.NS', 'GSFC.NS', 'GSLSU.NS', 'GSPL.NS', 'GSS.NS', 'GTECJAINX.NS', 'GTL.NS', 'GTLINFRA.NS', 'GTPL.NS', 'GUFICBIO.NS', 'GUJALKALI.NS', 'GUJAPOLLO.NS', 'GUJGASLTD.NS', 'GUJRAFFIA.NS', 'GULFOILLUB.NS', 'GULFPETRO.NS', 'GULPOLY.NS', 'GVKPIL.NS', 'GVPTECH.NS', 'HAPPSTMNDS.NS', 'HAPPYFORGE.NS', 'HARDWYN.NS', 'HARIOMPIPE.NS', 'HARRMALAYA.NS', 'HARSHA.NS', 'HATHWAY.NS', 'HATSUN.NS', 'HAVELLS.NS', 'HAVISHA.NS', 'HBLPOWER.NS', 'HBSL.NS', 'HCC.NS', 'HCG.NS', 'HCL-INSYS.NS', 'HCLTECH.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'HEADSUP.NS', 'HECPROJECT.NS', 'HEG.NS', 'HEIDELBERG.NS', 'HEMIPROP.NS', 'HERANBA.NS', 'HERCULES.NS', 'HERITGFOOD.NS', 'HESTERBIO.NS', 'HEUBACHIND.NS', 'HEXATRADEX.NS', 'HFCL.NS', 'HGINFRA.NS', 'HGS.NS', 'HIKAL.NS', 'HILTON.NS', 'HIMATSEIDE.NS', 'HINDALCO.NS', 'HINDCOMPOS.NS', 'HINDCON.NS', 'HINDCOPPER.NS', 'HINDMOTORS.NS', 'HINDOILEXP.NS', 'HINDPETRO.NS', 'HINDWAREAP.NS', 'HINDZINC.NS', 'HIRECT.NS', 'HISARMETAL.NS', 'HITECH.NS', 'HITECHCORP.NS', 'HITECHGEAR.NS', 'HLEGLAS.NS', 'HLVLTD.NS', 'HMAAGRO.NS', 'HMT.NS', 'HMVL.NS', 'HNDFDS.NS', 'HOMEFIRST.NS', 'HONASA.NS', 'HOVS.NS', 'HPAL.NS', 'HPIL.NS', 'HPL.NS', 'HSCL.NS', 'HTMEDIA.NS', 'HUBTOWN.NS', 'HUDCO.NS', 'HUHTAMAKI.NS', 'HYBRIDFIN.NS', 'IBREALEST.NS', 'IBULHSGFIN.NS', 'ICDSLTD.NS', 'ICEMAKE.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'ICIL.NS', 'IDBI.NS', 'IDEA.NS', 'IDEAFORGE.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IEL.NS', 'IEX.NS', 'IFBAGRO.NS', 'IFBIND.NS', 'IFCI.NS', 'IFGLEXPOR.NS', 'IGARASHI.NS', 'IGL.NS', 'IGPL.NS', 'IIFL.NS', 'IIFLSEC.NS', 'IITL.NS', 'IKIO.NS', 'IL&FSENGG.NS', 'IL&FSTRANS.NS', 'IMAGICAA.NS', 'IMFA.NS', 'IMPAL.NS', 'IMPEXFERRO.NS', 'INCREDIBLE.NS', 'INDBANK.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INDIAGLYCO.NS', 'INDIANB.NS', 'INDIANCARD.NS', 'INDIANHUME.NS', 'INDIASHLTR.NS', 'INDIGOPNTS.NS', 'INDNIPPON.NS', 'INDOAMIN.NS', 'INDOBORAX.NS', 'INDOCO.NS', 'INDORAMA.NS', 'INDOSTAR.NS', 'INDOTECH.NS', 'INDOTHAI.NS', 'INDOWIND.NS', 'INDRAMEDCO.NS', 'INDSWFTLAB.NS', 'INDSWFTLTD.NS', 'INDTERRAIN.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'INFOBEAN.NS', 'INFOMEDIA.NS', 'INFY.NS', 'INNOVACAP.NS', 'INOXGREEN.NS', 'INOXINDIA.NS', 'INOXWIND.NS', 'INSECTICID.NS', 'INSPIRISYS.NS', 'INTELLECT.NS', 'INTENTECH.NS', 'INTLCONV.NS', 'INVENTURE.NS', 'IOB.NS', 'IOC.NS', 'IOLCP.NS', 'IONEXCHANG.NS', 'IPCALAB.NS', 'IPL.NS', 'IRB.NS', 'IRCON.NS', 'IRCTC.NS', 'IREDA.NS', 'IRFC.NS', 'IRIS.NS', 'IRISDOREME.NS', 'IRMENERGY.NS', 'ISEC.NS', 'ISFT.NS', 'ISGEC.NS', 'ISMTLTD.NS', 'ITC.NS', 'ITDC.NS', 'ITDCEM.NS', 'ITI.NS', 'IVC.NS', 'IVP.NS', 'IZMO.NS', 'J&KBANK.NS', 'JAGRAN.NS', 'JAGSNPHARM.NS', 'JAIBALAJI.NS', 'JAICORPLTD.NS', 'JAIPURKURT.NS', 'JAMNAAUTO.NS', 'JASH.NS', 'JAYAGROGN.NS', 'JAYBARMARU.NS', 'JAYNECOIND.NS', 'JAYSREETEA.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JCHAC.NS', 'JETAIRWAYS.NS', 'JETFREIGHT.NS', 'JHS.NS', 'JINDALPHOT.NS', 'JINDALPOLY.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JINDRILL.NS', 'JINDWORLD.NS', 'JIOFIN.NS', 'JISLDVREQS.NS', 'JISLJALEQS.NS', 'JITFINFRA.NS', 'JKIL.NS', 'JKLAKSHMI.NS', 'JKPAPER.NS', 'JKTYRE.NS', 'JLHL.NS', 'JMA.NS', 'JMFINANCIL.NS', 'JOCIL.NS', 'JPASSOCIAT.NS', 'JPOLYINVST.NS', 'JPPOWER.NS', 'JSL.NS', 'JSWENERGY.NS', 'JSWINFRA.NS', 'JSWSTEEL.NS', 'JTEKTINDIA.NS', 'JTLIND.NS', 'JUBLFOOD.NS', 'JUBLINDS.NS', 'JUBLINGREA.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'JWL.NS', 'JYOTHYLAB.NS', 'JYOTISTRUC.NS', 'KABRAEXTRU.NS', 'KAJARIACER.NS', 'KAKATCEM.NS', 'KALAMANDIR.NS', 'KALYANIFRG.NS', 'KALYANKJIL.NS', 'KAMATHOTEL.NS', 'KAMDHENU.NS', 'KAMOPAINTS.NS', 'KANANIIND.NS', 'KANORICHEM.NS', 'KANPRPLA.NS', 'KANSAINER.NS', 'KAPSTON.NS', 'KARMAENG.NS', 'KARURVYSYA.NS', 'KAUSHALYA.NS', 'KAVVERITEL.NS', 'KAYA.NS', 'KBCGLOBAL.NS', 'KCP.NS', 'KCPSUGIND.NS', 'KEC.NS', 'KECL.NS', 'KEEPLEARN.NS', 'KELLTONTEC.NS', 'KERNEX.NS', 'KESORAMIND.NS', 'KEYFINSERV.NS', 'KFINTECH.NS', 'KHADIM.NS', 'KHAICHEM.NS', 'KHAITANLTD.NS', 'KHANDSE.NS', 'KILITCH.NS', 'KIOCL.NS', 'KIRIINDUS.NS', 'KIRLOSBROS.NS', 'KIRLOSENG.NS', 'KIRLPNU.NS', 'KITEX.NS', 'KKCL.NS', 'KMSUGAR.NS', 'KNRCON.NS', 'KOHINOOR.NS', 'KOKUYOCMLN.NS', 'KOLTEPATIL.NS', 'KOPRAN.NS', 'KOTAKBANK.NS', 'KOTARISUG.NS', 'KOTHARIPET.NS', 'KOTHARIPRO.NS', 'KPIGREEN.NS', 'KPIL.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'KRBL.NS', 'KREBSBIO.NS', 'KRIDHANINF.NS', 'KRISHANA.NS', 'KRITI.NS', 'KRITIKA.NS', 'KRITINUT.NS', 'KRSNAA.NS', 'KSCL.NS', 'KSHITIJPOL.NS', 'KSL.NS', 'KSOLVES.NS', 'KTKBANK.NS', 'KUANTUM.NS', 'L&TFH.NS', 'LAGNAM.NS', 'LAKPRE.NS', 'LAL.NS', 'LAMBODHARA.NS', 'LANDMARK.NS', 'LAOPALA.NS', 'LASA.NS', 'LATENTVIEW.NS', 'LATTEYS.NS', 'LAURUSLABS.NS', 'LAXMICOT.NS', 'LCCINFOTEC.NS', 'LEMONTREE.NS', 'LEXUS.NS', 'LFIC.NS', 'LGBBROSLTD.NS', 'LGBFORGE.NS', 'LGHL.NS', 'LIBAS.NS', 'LIBERTSHOE.NS', 'LICHSGFIN.NS', 'LICI.NS', 'LIKHITHA.NS', 'LINC.NS', 'LINCOLN.NS', 'LLOYDSENGG.NS', 'LLOYDSME.NS', 'LODHA.NS', 'LOKESHMACH.NS', 'LORDSCHLO.NS', 'LOTUSEYE.NS', 'LOVABLE.NS', 'LOYALTEX.NS', 'LPDC.NS', 'LTFOODS.NS', 'LUMAXTECH.NS', 'LUPIN.NS', 'LUXIND.NS', 'LXCHEM.NS', 'LYKALABS.NS', 'LYPSAGEMS.NS', 'M&M.NS', 'M&MFIN.NS', 'MAANALU.NS', 'MACPOWER.NS', 'MADHAV.NS', 'MADHUCON.NS', 'MADRASFERT.NS', 'MAGADSUGAR.NS', 'MAGNUM.NS', 'MAHABANK.NS', 'MAHAPEXLTD.NS', 'MAHASTEEL.NS', 'MAHEPC.NS', 'MAHESHWARI.NS', 'MAHLIFE.NS', 'MAHLOG.NS', 'MAHSEAMLES.NS', 'MAITHANALL.NS', 'MALLCOM.NS', 'MALUPAPER.NS', 'MANAKALUCO.NS', 'MANAKCOAT.NS', 'MANAKSIA.NS', 'MANAKSTEEL.NS', 'MANALIPETC.NS', 'MANAPPURAM.NS', 'MANGALAM.NS', 'MANGCHEFER.NS', 'MANGLMCEM.NS', 'MANINDS.NS', 'MANINFRA.NS', 'MANOMAY.NS', 'MANORG.NS', 'MANUGRAPH.NS', 'MANYAVAR.NS', 'MARALOVER.NS', 'MARATHON.NS', 'MARICO.NS', 'MARINE.NS', 'MARKSANS.NS', 'MARSHALL.NS', 'MASFIN.NS', 'MASKINVEST.NS', 'MATRIMONY.NS', 'MAWANASUG.NS', 'MAXESTATES.NS', 'MAXHEALTH.NS', 'MAXIND.NS', 'MAYURUNIQ.NS', 'MAZDA.NS', 'MBAPL.NS', 'MBECL.NS', 'MBLINFRA.NS', 'MCDOWELL-N.NS', 'MCL.NS', 'MCLEODRUSS.NS', 'MEDANTA.NS', 'MEDICAMEQ.NS', 'MEDICO.NS', 'MEDPLUS.NS', 'MEGASOFT.NS', 'MEGASTAR.NS', 'MELSTAR.NS', 'MENONBE.NS', 'MEP.NS', 'METALFORGE.NS', 'METROBRAND.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MGEL.NS', 'MGL.NS', 'MHLXMIRU.NS', 'MHRIL.NS', 'MICEL.NS', 'MIDHANI.NS', 'MINDACORP.NS', 'MINDTECK.NS', 'MIRCELECTR.NS', 'MIRZAINT.NS', 'MITCON.NS', 'MITTAL.NS', 'MKPL.NS', 'MMFL.NS', 'MMP.NS', 'MMTC.NS', 'MODIRUBBER.NS', 'MODISONLTD.NS', 'MOHITIND.NS', 'MOIL.NS', 'MOKSH.NS', 'MOL.NS', 'MOLDTECH.NS', 'MOLDTKPAC.NS', 'MONARCH.NS', 'MONTECARLO.NS', 'MORARJEE.NS', 'MOREPENLAB.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'MOTISONS.NS', 'MOTOGENFIN.NS', 'MPSLTD.NS', 'MRO-TEK.NS', 'MRPL.NS', 'MSPL.NS', 'MSTCLTD.NS', 'MSUMI.NS', 'MTEDUCARE.NS', 'MTNL.NS', 'MUFIN.NS', 'MUFTI.NS', 'MUKANDLTD.NS', 'MUKTAARTS.NS', 'MUNJALAU.NS', 'MUNJALSHOW.NS', 'MURUDCERA.NS', 'MUTHOOTCAP.NS', 'MUTHOOTFIN.NS', 'MUTHOOTMF.NS', 'MVGJL.NS', 'NACLIND.NS', 'NAGAFERT.NS', 'NAGREEKCAP.NS', 'NAGREEKEXP.NS', 'NAHARCAP.NS', 'NAHARINDUS.NS', 'NAHARPOLY.NS', 'NAHARSPING.NS', 'NAM-INDIA.NS', 'NARMADA.NS', 'NATCOPHARM.NS', 'NATHBIOGEN.NS', 'NATIONALUM.NS', 'NAVA.NS', 'NAVKARCORP.NS', 'NAVNETEDUL.NS', 'NAZARA.NS', 'NBCC.NS', 'NBIFIN.NS', 'NCC.NS', 'NCLIND.NS', 'NDL.NS', 'NDLVENTURE.NS', 'NDRAUTO.NS', 'NDTV.NS', 'NECCLTD.NS', 'NECLIFE.NS', 'NELCAST.NS', 'NELCO.NS', 'NEOGEN.NS', 'NESCO.NS', 'NETWEB.NS', 'NETWORK18.NS', 'NEWGEN.NS', 'NEXTMEDIA.NS', 'NFL.NS', 'NGIL.NS', 'NH.NS', 'NHPC.NS', 'NIACL.NS', 'NIBL.NS', 'NIITLTD.NS', 'NIITMTS.NS', 'NILAINFRA.NS', 'NILASPACES.NS', 'NINSYS.NS', 'NIPPOBATRY.NS', 'NIRAJ.NS', 'NITCO.NS', 'NITINSPIN.NS', 'NITIRAJ.NS', 'NKIND.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NOCIL.NS', 'NOIDATOLL.NS', 'NORBTEAEXP.NS', 'NRAIL.NS', 'NRBBEARING.NS', 'NRL.NS', 'NSLNISP.NS', 'NTPC.NS', 'NUCLEUS.NS', 'NURECA.NS', 'NUVOCO.NS', 'NYKAA.NS', 'OAL.NS', 'OBCL.NS', 'OBEROIRLTY.NS', 'OCCL.NS', 'OIL.NS', 'OILCOUNTUB.NS', 'OLECTRA.NS', 'OMAXAUTO.NS', 'OMAXE.NS', 'OMINFRAL.NS', 'OMKARCHEM.NS', 'ONELIFECAP.NS', 'ONEPOINT.NS', 'ONGC.NS', 'ONMOBILE.NS', 'ONWARDTEC.NS', 'OPTIEMUS.NS', 'ORBTEXP.NS', 'ORCHPHARMA.NS', 'ORICONENT.NS', 'ORIENTALTL.NS', 'ORIENTBELL.NS', 'ORIENTCEM.NS', 'ORIENTCER.NS', 'ORIENTELEC.NS', 'ORIENTHOT.NS', 'ORIENTLTD.NS', 'ORIENTPPR.NS', 'ORTINLAB.NS', 'OSIAHYPER.NS', 'OSWALAGRO.NS', 'OSWALGREEN.NS', 'OSWALSEEDS.NS', 'PAISALO.NS', 'PAKKA.NS', 'PALASHSECU.NS', 'PALREDTEC.NS', 'PANACEABIO.NS', 'PANACHE.NS', 'PANAMAPET.NS', 'PANSARI.NS', 'PAR.NS', 'PARACABLES.NS', 'PARADEEP.NS', 'PARAGMILK.NS', 'PARAS.NS', 'PARASPETRO.NS', 'PARSVNATH.NS', 'PASUPTAC.NS', 'PATANJALI.NS', 'PATELENG.NS', 'PATINTLOG.NS', 'PAVNAIND.NS', 'PAYTM.NS', 'PCBL.NS', 'PCJEWELLER.NS', 'PDMJEPAPER.NS', 'PDSL.NS', 'PEARLPOLY.NS', 'PEL.NS', 'PENIND.NS', 'PENINLAND.NS', 'PETRONET.NS', 'PFC.NS', 'PFOCUS.NS', 'PFS.NS', 'PGIL.NS', 'PIGL.NS', 'PILITA.NS', 'PIONEEREMB.NS', 'PITTIENG.NS', 'PIXTRANS.NS', 'PKTEA.NS', 'PLASTIBLEN.NS', 'PLAZACABLE.NS', 'PNB.NS', 'PNBGILTS.NS', 'PNBHOUSING.NS', 'PNC.NS', 'PNCINFRA.NS', 'POCL.NS', 'PODDARHOUS.NS', 'PODDARMENT.NS', 'POKARNA.NS', 'POLICYBZR.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'PONNIERODE.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'PPAP.NS', 'PPL.NS', 'PPLPHARMA.NS', 'PRAENG.NS', 'PRAJIND.NS', 'PRAKASH.NS', 'PRAKASHSTL.NS', 'PRAXIS.NS', 'PRECAM.NS', 'PRECOT.NS', 'PRECWIRE.NS', 'PREMEXPLN.NS', 'PREMIER.NS', 'PREMIERPOL.NS', 'PRESTIGE.NS', 'PRICOLLTD.NS', 'PRIMESECU.NS', 'PRINCEPIPE.NS', 'PRITI.NS', 'PRITIKAUTO.NS', 'PRIVISCL.NS', 'PROZONER.NS', 'PRSMJOHNSN.NS', 'PRUDENT.NS', 'PRUDMOULI.NS', 'PSB.NS', 'PSPPROJECT.NS', 'PTC.NS', 'PTL.NS', 'PUNJABCHEM.NS', 'PURVA.NS', 'PVP.NS', 'PVRINOX.NS', 'PYRAMID.NS', 'QUESS.NS', 'QUICKHEAL.NS', 'RACE.NS', 'RADAAN.NS', 'RADHIKAJWE.NS', 'RADIANTCMS.NS', 'RADICO.NS', 'RADIOCITY.NS', 'RAILTEL.NS', 'RAIN.NS', 'RAINBOW.NS', 'RAJESHEXPO.NS', 'RAJMET.NS', 'RAJRATAN.NS', 'RAJRILTD.NS', 'RAJSREESUG.NS', 'RAJTV.NS', 'RALLIS.NS', 'RAMANEWS.NS', 'RAMAPHO.NS', 'RAMASTEEL.NS', 'RAMCOCEM.NS', 'RAMCOIND.NS', 'RAMCOSYS.NS', 'RAMKY.NS', 'RAMRAT.NS', 'RANASUG.NS', 'RANEENGINE.NS', 'RANEHOLDIN.NS', 'RATEGAIN.NS', 'RATNAVEER.NS', 'RAYMOND.NS', 'RBA.NS', 'RBL.NS', 'RBLBANK.NS', 'RBZJEWEL.NS', 'RCF.NS', 'RECLTD.NS', 'REDINGTON.NS', 'REDTAPE.NS', 'REFEX.NS', 'REGENCERAM.NS', 'RELAXO.NS', 'RELCAPITAL.NS', 'RELCHEMQ.NS', 'RELIGARE.NS', 'RELINFRA.NS', 'REMSONSIND.NS', 'RENUKA.NS', 'REPCOHOME.NS', 'REPL.NS', 'REPRO.NS', 'RESPONIND.NS', 'RGL.NS', 'RHFL.NS', 'RHIM.NS', 'RHL.NS', 'RICOAUTO.NS', 'RIIL.NS', 'RISHABH.NS', 'RITCO.NS', 'RITES.NS', 'RKDL.NS', 'RKEC.NS', 'RKFORGE.NS', 'RML.NS', 'ROHLTD.NS', 'ROLLT.NS', 'ROML.NS', 'ROSSARI.NS', 'ROSSELLIND.NS', 'ROTO.NS', 'ROUTE.NS', 'RPGLIFE.NS', 'RPOWER.NS', 'RPPINFRA.NS', 'RPPL.NS', 'RPSGVENT.NS', 'RRKABEL.NS', 'RSSOFTWARE.NS', 'RSWM.NS', 'RSYSTEMS.NS', 'RTNINDIA.NS', 'RTNPOWER.NS', 'RUBYMILLS.NS', 'RUCHINFRA.NS', 'RUCHIRA.NS', 'RUPA.NS', 'RUSHIL.NS', 'RUSTOMJEE.NS', 'RVHL.NS', 'RVNL.NS', 'S&SPOWER.NS', 'SABEVENTS.NS', 'SABTN.NS', 'SADBHAV.NS', 'SADBHIN.NS', 'SADHNANIQ.NS', 'SAFARI.NS', 'SAGARDEEP.NS', 'SAGCEM.NS', 'SAH.NS', 'SAHYADRI.NS', 'SAIL.NS', 'SAKAR.NS', 'SAKHTISUG.NS', 'SAKSOFT.NS', 'SAKUMA.NS', 'SALASAR.NS', 'SALONA.NS', 'SALSTEEL.NS', 'SALZERELEC.NS', 'SAMBHAAV.NS', 'SAMHI.NS', 'SAMPANN.NS', 'SANCO.NS', 'SANDESH.NS', 'SANDHAR.NS', 'SANGAMIND.NS', 'SANGHIIND.NS', 'SANGHVIMOV.NS', 'SANGINITA.NS', 'SANSERA.NS', 'SAPPHIRE.NS', 'SARDAEN.NS', 'SAREGAMA.NS', 'SARLAPOLY.NS', 'SARVESHWAR.NS', 'SASKEN.NS', 'SASTASUNDR.NS', 'SATIA.NS', 'SATIN.NS', 'SATINDLTD.NS', 'SBC.NS', 'SBCL.NS', 'SBFC.NS', 'SBGLP.NS', 'SBICARD.NS', 'SBILIFE.NS', 'SBIN.NS', 'SCHAND.NS', 'SCHNEIDER.NS', 'SCI.NS', 'SCPL.NS', 'SDBL.NS', 'SEAMECLTD.NS', 'SECMARK.NS', 'SECURCRED.NS', 'SECURKLOUD.NS', 'SEJALLTD.NS', 'SELAN.NS', 'SELMC.NS', 'SENCO.NS', 'SEPC.NS', 'SEQUENT.NS', 'SERVOTECH.NS', 'SESHAPAPER.NS', 'SETCO.NS', 'SEYAIND.NS', 'SFL.NS', 'SGIL.NS', 'SGL.NS', 'SHAH.NS', 'SHAHALLOYS.NS', 'SHAILY.NS', 'SHAKTIPUMP.NS', 'SHALBY.NS', 'SHALPAINTS.NS', 'SHANKARA.NS', 'SHANTI.NS', 'SHANTIGEAR.NS', 'SHARDACROP.NS', 'SHARDAMOTR.NS', 'SHAREINDIA.NS', 'SHEMAROO.NS', 'SHILPAMED.NS', 'SHIVALIK.NS', 'SHIVAMAUTO.NS', 'SHIVAMILLS.NS', 'SHIVATEX.NS', 'SHK.NS', 'SHOPERSTOP.NS', 'SHRADHA.NS', 'SHREDIGCEM.NS', 'SHREEPUSHK.NS', 'SHREERAMA.NS', 'SHRENIK.NS', 'SHREYANIND.NS', 'SHREYAS.NS', 'SHRIPISTON.NS', 'SHRIRAMPPS.NS', 'SHYAMCENT.NS', 'SHYAMMETL.NS', 'SHYAMTEL.NS', 'SICALLOG.NS', 'SIGACHI.NS', 'SIGIND.NS', 'SIGMA.NS', 'SIGNATURE.NS', 'SIKKO.NS', 'SIL.NS', 'SILGO.NS', 'SILINV.NS', 'SILLYMONKS.NS', 'SILVERTUC.NS', 'SIMBHALS.NS', 'SIMPLEXINF.NS', 'SINDHUTRAD.NS', 'SINTERCOM.NS', 'SIRCA.NS', 'SIS.NS', 'SITINET.NS', 'SIYSIL.NS', 'SJS.NS', 'SJVN.NS', 'SKIPPER.NS', 'SKMEGGPROD.NS', 'SKYGOLD.NS', 'SMARTLINK.NS', 'SMCGLOBAL.NS', 'SMLISUZU.NS', 'SMLT.NS', 'SMSLIFE.NS', 'SMSPHARMA.NS', 'SNOWMAN.NS', 'SOBHA.NS', 'SOFTTECH.NS', 'SOLARA.NS', 'SOMANYCERA.NS', 'SOMATEX.NS', 'SOMICONVEY.NS', 'SONACOMS.NS', 'SONAMLTD.NS', 'SONATSOFTW.NS', 'SOTL.NS', 'SOUTHBANK.NS', 'SOUTHWEST.NS', 'SPAL.NS', 'SPANDANA.NS', 'SPARC.NS', 'SPCENET.NS', 'SPECIALITY.NS', 'SPENCERS.NS', 'SPENTEX.NS', 'SPIC.NS', 'SPLIL.NS', 'SPLPETRO.NS', 'SPMLINFRA.NS', 'SPORTKING.NS', 'SPTL.NS', 'SPYL.NS', 'SREEL.NS', 'SRGHFL.NS', 'SRHHYPOLTD.NS', 'SRPL.NS', 'SSWL.NS', 'STAR.NS', 'STARCEMENT.NS', 'STARHEALTH.NS', 'STARPAPER.NS', 'STARTECK.NS', 'STCINDIA.NS', 'STEELCAS.NS', 'STEELCITY.NS', 'STEELXIND.NS', 'STEL.NS', 'STERTOOLS.NS', 'STLTECH.NS', 'STOVEKRAFT.NS', 'STYLAMIND.NS', 'STYRENIX.NS', 'SUBEXLTD.NS', 'SUBROS.NS', 'SUDARSCHEM.NS', 'SUKHJITS.NS', 'SULA.NS', 'SUMICHEM.NS', 'SUMIT.NS', 'SUMMITSEC.NS', 'SUNCLAY.NS', 'SUNDARAM.NS', 'SUNDARMHLD.NS', 'SUNDRMBRAK.NS', 'SUNDRMFAST.NS', 'SUNFLAG.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SUNTV.NS', 'SUPERHOUSE.NS', 'SUPERSPIN.NS', 'SUPRAJIT.NS', 'SUPREMEENG.NS', 'SUPREMEINF.NS', 'SUPRIYA.NS', 'SURAJEST.NS', 'SURANASOL.NS', 'SURANAT&P.NS', 'SURYALAXMI.NS', 'SURYAROSNI.NS', 'SURYODAY.NS', 'SUTLEJTEX.NS', 'SUULD.NS', 'SUVEN.NS', 'SUVENPHAR.NS', 'SUVIDHAA.NS', 'SUZLON.NS', 'SVLL.NS', 'SVPGLOB.NS', 'SWANENERGY.NS', 'SWELECTES.NS', 'SWSOLAR.NS', 'SYMPHONY.NS', 'SYNCOMF.NS', 'SYNGENE.NS', 'SYRMA.NS', 'TAINWALCHM.NS', 'TAJGVK.NS', 'TAKE.NS', 'TALBROAUTO.NS', 'TANLA.NS', 'TARAPUR.NS', 'TARC.NS', 'TARMAT.NS', 'TARSONS.NS', 'TATACHEM.NS', 'TATACOFFEE.NS', 'TATACOMM.NS', 'TATACONSUM.NS', 'TATAMETALI.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TATATECH.NS', 'TATVA.NS', 'TBZ.NS', 'TCI.NS', 'TCIEXP.NS', 'TCLCONS.NS', 'TCNSBRANDS.NS', 'TDPOWERSYS.NS', 'TECHIN.NS', 'TECHM.NS', 'TECHNOE.NS', 'TECILCHEM.NS', 'TEGA.NS', 'TEJASNET.NS', 'TEMBO.NS', 'TERASOFT.NS', 'TEXINFRA.NS', 'TEXMOPIPES.NS', 'TEXRAIL.NS', 'TFCILTD.NS', 'TFL.NS', 'TGBHOTELS.NS', 'THANGAMAYL.NS', 'THEINVEST.NS', 'THEJO.NS', 'THEMISMED.NS', 'THOMASCOOK.NS', 'THOMASCOTT.NS', 'THYROCARE.NS', 'TI.NS', 'TIDEWATER.NS', 'TIJARIA.NS', 'TIL.NS', 'TIMESGTY.NS', 'TIMETECHNO.NS', 'TINPLATE.NS', 'TIPSFILMS.NS', 'TIPSINDLTD.NS', 'TIRUMALCHM.NS', 'TIRUPATIFL.NS', 'TITAGARH.NS', 'TMB.NS', 'TNPETRO.NS', 'TNPL.NS', 'TNTELE.NS', 'TOKYOPLAST.NS', 'TORNTPOWER.NS', 'TOTAL.NS', 'TOUCHWOOD.NS', 'TPHQ.NS', 'TPLPLASTEH.NS', 'TRACXN.NS', 'TREEHOUSE.NS', 'TREJHARA.NS', 'TREL.NS', 'TRF.NS', 'TRIDENT.NS', 'TRIGYN.NS', 'TRIL.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TRU.NS', 'TTKHLTCARE.NS', 'TTKPRESTIG.NS', 'TTL.NS', 'TTML.NS', 'TV18BRDCST.NS', 'TVSELECT.NS', 'TVSSCS.NS', 'TVTODAY.NS', 'TVVISION.NS', 'UBL.NS', 'UCAL.NS', 'UCOBANK.NS', 'UDS.NS', 'UFLEX.NS', 'UFO.NS', 'UGARSUGAR.NS', 'UGROCAP.NS', 'UJJIVAN.NS', 'UJJIVANSFB.NS', 'UMAEXPORTS.NS', 'UMANGDAIRY.NS', 'UMESLTD.NS', 'UNICHEMLAB.NS', 'UNIDT.NS', 'UNIENTER.NS', 'UNIINFO.NS', 'UNIONBANK.NS', 'UNIPARTS.NS', 'UNITECH.NS', 'UNITEDPOLY.NS', 'UNITEDTEA.NS', 'UNIVAFOODS.NS', 'UNIVASTU.NS', 'UNIVCABLES.NS', 'UNIVPHOTO.NS', 'UNOMINDA.NS', 'UPL.NS', 'URAVI.NS', 'URJA.NS', 'USHAMART.NS', 'USK.NS', 'UTIAMC.NS', 'UTKARSHBNK.NS', 'UTTAMSUGAR.NS', 'V2RETAIL.NS', 'VAIBHAVGBL.NS', 'VAISHALI.NS', 'VAKRANGEE.NS', 'VALIANTLAB.NS', 'VALIANTORG.NS', 'VARDHACRLC.NS', 'VARDMNPOLY.NS', 'VARROC.NS', 'VASCONEQ.NS', 'VASWANI.NS', 'VBL.NS', 'VCL.NS', 'VEDL.NS', 'VENUSPIPES.NS', 'VENUSREM.NS', 'VERANDA.NS', 'VERTOZ.NS', 'VETO.NS', 'VGUARD.NS', 'VIDHIING.NS', 'VIJAYA.NS', 'VIJIFIN.NS', 'VIKASECO.NS', 'VIKASLIFE.NS', 'VIMTALABS.NS', 'VINATIORGA.NS', 'VINEETLAB.NS', 'VINNY.NS', 'VINYLINDIA.NS', 'VIPCLOTHNG.NS', 'VIPIND.NS', 'VIPULLTD.NS', 'VIRINCHI.NS', 'VISAKAIND.NS', 'VISESHINFO.NS', 'VISHNU.NS', 'VISHWARAJ.NS', 'VIVIDHA.NS', 'VLEGOV.NS', 'VLSFINANCE.NS', 'VOLTAS.NS', 'VPRPL.NS', 'VRLLOG.NS', 'VSSL.NS', 'VTL.NS', 'WABAG.NS', 'WALCHANNAG.NS', 'WANBURY.NS', 'WEALTH.NS', 'WEBELSOLAR.NS', 'WEIZMANIND.NS', 'WEL.NS', 'WELCORP.NS', 'WELENT.NS', 'WELINV.NS', 'WELSPUNLIV.NS', 'WESTLIFE.NS', 'WEWIN.NS', 'WHEELS.NS', 'WHIRLPOOL.NS', 'WILLAMAGOR.NS', 'WINDLAS.NS', 'WINDMACHIN.NS', 'WINSOME.NS', 'WIPL.NS', 'WIPRO.NS', 'WOCKPHARMA.NS', 'WONDERLA.NS', 'WORTH.NS', 'WSI.NS', 'WSTCSTPAPR.NS', 'XCHANGING.NS', 'XELPMOC.NS', 'XPROINDIA.NS', 'YAARI.NS', 'YASHO.NS', 'YATHARTH.NS', 'YATRA.NS', 'YESBANK.NS', 'YUKEN.NS', 'ZAGGLE.NS', 'ZEEL.NS', 'ZEELEARN.NS', 'ZEEMEDIA.NS', 'ZENITHEXPO.NS', 'ZENITHSTL.NS', 'ZENSARTECH.NS', 'ZENTEC.NS', 'ZIMLAB.NS', 'ZODIAC.NS', 'ZODIACLOTH.NS', 'ZOMATO.NS', 'ZOTA.NS', 'ZUARI.NS', 'ZUARIIND.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS']

# %% [markdown]
# #for finding selected stocks (without excel)

# %%
import yfinance as yf
import pandas as pd
import plotly.graph_objects as go

def fetch_data(stock):
    # Fetch historical data for the stock for the last 7 days with 1-minute intervals
    data = yf.download(stock, period="1d", interval="1m")
    return data

# def historical_volume_average(stock):
#     # Fetch historical data for volume average calculation
#     hist_data = yf.download(stock, period="60d", interval="1d")
#     return hist_data['Volume'].mean()

def plot_candlestick(data, stock, date):
    # Create a candlestick chart
    fig = go.Figure(data=[go.Candlestick(x=data.index,
                                         open=data['Open'],
                                         high=data['High'],
                                         low=data['Low'],
                                         close=data['Close'])])
    fig.update_layout(title=f'Candlestick chart for {stock} on {date}',
                      xaxis_title='Time',
                      yaxis_title='Price',
                      xaxis_rangeslider_visible=False)
    fig.show()

# List of NSE stocks
nse_stocks = ['20MICRONS.NS', '21STCENMGM.NS', '360ONE.NS', '3IINFOLTD.NS', '3MINDIA.NS', '3PLAND.NS', '5PAISA.NS', '63MOONS.NS', 'A2ZINFRA.NS', 'AAATECH.NS', 'AAKASH.NS', 'AAREYDRUGS.NS', 'AARON.NS', 'AARTECH.NS', 'AARTIDRUGS.NS', 'AARTIIND.NS', 'AARTIPHARM.NS', 'AARTISURF.NS', 'AARVEEDEN.NS', 'AARVI.NS', 'AAVAS.NS', 'ABAN.NS', 'ABB.NS', 'ABBOTINDIA.NS', 'ABCAPITAL.NS', 'ABFRL.NS', 'ABMINTLLTD.NS', 'ABSLAMC.NS', 'ACC.NS', 'ACCELYA.NS', 'ACCURACY.NS', 'ACE.NS', 'ACEINTEG.NS', 'ACI.NS', 'ACL.NS', 'ACLGATI.NS', 'ADANIENSOL.NS', 'ADANIENT.NS', 'ADANIGREEN.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'ADFFOODS.NS', 'ADL.NS', 'ADORWELD.NS', 'ADROITINFO.NS', 'ADSL.NS', 'ADVANIHOTR.NS', 'ADVENZYMES.NS', 'AEGISCHEM.NS', 'AEROFLEX.NS', 'AETHER.NS', 'AFFLE.NS', 'AGARIND.NS', 'AGI.NS', 'AGRITECH.NS', 'AGROPHOS.NS', 'AGSTRA.NS', 'AHL.NS', 'AHLADA.NS', 'AHLEAST.NS', 'AHLUCONT.NS', 'AIAENG.NS', 'AIRAN.NS', 'AIROLAM.NS', 'AJANTPHARM.NS', 'AJMERA.NS', 'AJOONI.NS', 'AKASH.NS', 'AKG.NS', 'AKI.NS', 'AKSHAR.NS', 'AKSHARCHEM.NS', 'AKSHOPTFBR.NS', 'AKZOINDIA.NS', 'ALANKIT.NS', 'ALBERTDAVD.NS', 'ALEMBICLTD.NS', 'ALICON.NS', 'ALKALI.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'ALLCARGO.NS', 'ALLSEC.NS', 'ALMONDZ.NS', 'ALOKINDS.NS', 'ALPA.NS', 'ALPHAGEO.NS', 'ALPSINDUS.NS', 'AMBER.NS', 'AMBICAAGAR.NS', 'AMBIKCO.NS', 'AMBUJACEM.NS', 'AMDIND.NS', 'AMIORG.NS', 'AMJLAND.NS', 'AMNPLST.NS', 'AMRUTANJAN.NS', 'ANANDRATHI.NS', 'ANANTRAJ.NS', 'ANDHRAPAP.NS', 'ANDHRSUGAR.NS', 'ANGELONE.NS', 'ANIKINDS.NS', 'ANKITMETAL.NS', 'ANMOL.NS', 'ANTGRAPHIC.NS', 'ANUP.NS', 'ANURAS.NS', 'APARINDS.NS', 'APCL.NS', 'APCOTEXIND.NS', 'APEX.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'APOLLO.NS', 'APOLLOHOSP.NS', 'APOLLOPIPE.NS', 'APOLLOTYRE.NS', 'APOLSINHOT.NS', 'APTECHT.NS', 'APTUS.NS', 'ARCHIDPLY.NS', 'ARCHIES.NS', 'ARE&M.NS', 'ARENTERP.NS', 'ARIES.NS', 'ARIHANTCAP.NS', 'ARIHANTSUP.NS', 'ARMANFIN.NS', 'AROGRANITE.NS', 'ARROWGREEN.NS', 'ARSHIYA.NS', 'ARSSINFRA.NS', 'ARTEMISMED.NS', 'ARTNIRMAN.NS', 'ARVEE.NS', 'ARVIND.NS', 'ARVINDFASN.NS', 'ARVSMART.NS', 'ASAHIINDIA.NS', 'ASAHISONG.NS', 'ASAL.NS', 'ASALCBR.NS', 'ASHAPURMIN.NS', 'ASHIANA.NS', 'ASHIMASYN.NS', 'ASHOKA.NS', 'ASHOKAMET.NS', 'ASHOKLEY.NS', 'ASIANENE.NS', 'ASIANHOTNR.NS', 'ASIANPAINT.NS', 'ASIANTILES.NS', 'ASKAUTOLTD.NS', 'ASMS.NS', 'ASPINWALL.NS', 'ASTEC.NS', 'ASTERDM.NS', 'ASTRAL.NS', 'ASTRAMICRO.NS', 'ASTRAZEN.NS', 'ASTRON.NS', 'ATALREAL.NS', 'ATAM.NS', 'ATFL.NS', 'ATGL.NS', 'ATL.NS', 'ATLANTAA.NS', 'ATUL.NS', 'ATULAUTO.NS', 'AUBANK.NS', 'AURIONPRO.NS', 'AUROPHARMA.NS', 'AURUM.NS', 'AUSOMENT.NS', 'AUTOAXLES.NS', 'AUTOIND.NS', 'AVADHSUGAR.NS', 'AVALON.NS', 'AVANTIFEED.NS', 'AVG.NS', 'AVONMORE.NS', 'AVROIND.NS', 'AVTNPL.NS', 'AWHCL.NS', 'AWL.NS', 'AXISBANK.NS', 'AXISCADES.NS', 'AXITA.NS', 'AYMSYNTEX.NS', 'AZAD.NS', 'BAFNAPH.NS', 'BAGFILMS.NS', 'BAIDFIN.NS', 'BAJAJ-AUTO.NS', 'BAJAJCON.NS', 'BAJAJELEC.NS', 'BAJAJFINSV.NS', 'BAJAJHCARE.NS', 'BAJAJHIND.NS', 'BAJAJHLDNG.NS', 'BAJEL.NS', 'BAJFINANCE.NS', 'BALAJITELE.NS', 'BALAMINES.NS', 'BALAXI.NS', 'BALKRISHNA.NS', 'BALKRISIND.NS', 'BALMLAWRIE.NS', 'BALPHARMA.NS', 'BALRAMCHIN.NS', 'BANARBEADS.NS', 'BANARISUG.NS', 'BANCOINDIA.NS', 'BANDHANBNK.NS', 'BANG.NS', 'BANKA.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BANSWRAS.NS', 'BARBEQUE.NS', 'BASF.NS', 'BASML.NS', 'BATAINDIA.NS', 'BAYERCROP.NS', 'BBL.NS', 'BBOX.NS', 'BBTC.NS', 'BBTCL.NS', 'BCG.NS', 'BCLIND.NS', 'BCONCEPTS.NS', 'BDL.NS', 'BEARDSELL.NS', 'BECTORFOOD.NS', 'BEDMUTHA.NS', 'BEL.NS', 'BEML.NS', 'BEPL.NS', 'BERGEPAINT.NS', 'BFINVEST.NS', 'BFUTILITIE.NS', 'BGRENERGY.NS', 'BHAGCHEM.NS', 'BHAGERIA.NS', 'BHAGYANGR.NS', 'BHANDARI.NS', 'BHARATFORG.NS', 'BHARATGEAR.NS', 'BHARATRAS.NS', 'BHARATWIRE.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'BIGBLOC.NS', 'BIKAJI.NS', 'BIL.NS', 'BINANIIND.NS', 'BIOCON.NS', 'BIOFILCHEM.NS', 'BIRLACABLE.NS', 'BIRLACORPN.NS', 'BIRLAMONEY.NS', 'BKMINDST.NS', 'BLAL.NS', 'BLBLIMITED.NS', 'BLISSGVS.NS', 'BLKASHYAP.NS', 'BLS.NS', 'BLUECHIP.NS', 'BLUECOAST.NS', 'BLUEDART.NS', 'BLUEJET.NS', 'BLUESTARCO.NS', 'BODALCHEM.NS', 'BOHRAIND.NS', 'BOMDYEING.NS', 'BOROLTD.NS', 'BORORENEW.NS', 'BOSCHLTD.NS', 'BPCL.NS', 'BPL.NS', 'BRIGADE.NS', 'BRITANNIA.NS', 'BRNL.NS', 'BROOKS.NS', 'BSE.NS', 'BSHSL.NS', 'BSL.NS', 'BSOFT.NS', 'BTML.NS', 'BURNPUR.NS', 'BUTTERFLY.NS', 'BVCL.NS', 'BYKE.NS', 'CALSOFT.NS', 'CAMLINFINE.NS', 'CAMPUS.NS', 'CAMS.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CANTABIL.NS', 'CAPACITE.NS', 'CAPLIPOINT.NS', 'CAPTRUST.NS', 'CARBORUNIV.NS', 'CAREERP.NS', 'CARERATING.NS', 'CARTRADE.NS', 'CARYSIL.NS', 'CASTROLIND.NS', 'CCHHL.NS', 'CCL.NS', 'CDSL.NS', 'CEATLTD.NS', 'CELEBRITY.NS', 'CELLO.NS', 'CENTENKA.NS', 'CENTEXT.NS', 'CENTRALBK.NS', 'CENTRUM.NS', 'CENTUM.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CEREBRAINT.NS', 'CESC.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHALET.NS', 'CHAMBLFERT.NS', 'CHEMBOND.NS', 'CHEMCON.NS', 'CHEMFAB.NS', 'CHEMPLASTS.NS', 'CHENNPETRO.NS', 'CHEVIOT.NS', 'CHOICEIN.NS', 'CHOLAFIN.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'CIGNITITEC.NS', 'CINELINE.NS', 'CINEVISTA.NS', 'CIPLA.NS', 'CLEAN.NS', 'CLEDUCATE.NS', 'CLSEL.NS', 'CMSINFO.NS', 'COALINDIA.NS', 'COASTCORP.NS', 'COCHINSHIP.NS', 'COFFEEDAY.NS', 'COFORGE.NS', 'COLPAL.NS', 'COMPINFO.NS', 'COMPUSOFT.NS', 'CONCOR.NS', 'CONCORDBIO.NS', 'CONFIPET.NS', 'CONSOFINVT.NS', 'CONTROLPR.NS', 'CORALFINAC.NS', 'CORDSCABLE.NS', 'COROMANDEL.NS', 'COSMOFIRST.NS', 'COUNCODOS.NS', 'CRAFTSMAN.NS', 'CREATIVE.NS', 'CREATIVEYE.NS', 'CREDITACC.NS', 'CREST.NS', 'CRISIL.NS', 'CROMPTON.NS', 'CROWN.NS', 'CSBBANK.NS', 'CSLFINANCE.NS', 'CTE.NS', 'CUB.NS', 'CUBEXTUB.NS', 'CUMMINSIND.NS', 'CUPID.NS', 'CYBERMEDIA.NS', 'CYBERTECH.NS', 'CYIENT.NS', 'CYIENTDLM.NS', 'DABUR.NS', 'DALBHARAT.NS', 'DALMIASUG.NS', 'DAMODARIND.NS', 'DANGEE.NS', 'DATAMATICS.NS', 'DATAPATTNS.NS', 'DBCORP.NS', 'DBL.NS', 'DBOL.NS', 'DBREALTY.NS', 'DBSTOCKBRO.NS', 'DCAL.NS', 'DCBBANK.NS', 'DCI.NS', 'DCM.NS', 'DCMFINSERV.NS', 'DCMNVL.NS', 'DCMSHRIRAM.NS', 'DCMSRIND.NS', 'DCW.NS', 'DCXINDIA.NS', 'DECCANCE.NS', 'DEEPAKFERT.NS', 'DEEPAKNTR.NS', 'DEEPENR.NS', 'DEEPINDS.NS', 'DELHIVERY.NS', 'DELPHIFX.NS', 'DELTACORP.NS', 'DELTAMAGNT.NS', 'DEN.NS', 'DENORA.NS', 'DEVIT.NS', 'DEVYANI.NS', 'DGCONTENT.NS', 'DHAMPURSUG.NS', 'DHANBANK.NS', 'DHANI.NS', 'DHANUKA.NS', 'DHARMAJ.NS', 'DHRUV.NS', 'DHUNINV.NS', 'DIACABS.NS', 'DIAMINESQ.NS', 'DIAMONDYD.NS', 'DICIND.NS', 'DIGISPICE.NS', 'DIGJAMLMTD.NS', 'DIL.NS', 'DISHTV.NS', 'DIVGIITTS.NS', 'DIVISLAB.NS', 'DIXON.NS', 'DJML.NS', 'DLF.NS', 'DLINKINDIA.NS', 'DMART.NS', 'DMCC.NS', 'DNAMEDIA.NS', 'DODLA.NS', 'DOLATALGO.NS', 'DOLLAR.NS', 'DOLPHIN.NS', 'DOMS.NS', 'DONEAR.NS', 'DPABHUSHAN.NS', 'DPSCLTD.NS', 'DPWIRES.NS', 'DRCSYSTEMS.NS', 'DREAMFOLKS.NS', 'DREDGECORP.NS', 'DRREDDY.NS', 'DSSL.NS', 'DTIL.NS', 'DUCON.NS', 'DVL.NS', 'DWARKESH.NS', 'DYCL.NS', 'DYNAMATECH.NS', 'DYNPRO.NS', 'E2E.NS', 'EASEMYTRIP.NS', 'EASTSILK.NS', 'ECLERX.NS', 'EDELWEISS.NS', 'EDUCOMP.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'EIFFL.NS', 'EIHAHOTELS.NS', 'EIHOTEL.NS', 'EIMCOELECO.NS', 'EKC.NS', 'ELDEHSG.NS', 'ELECON.NS', 'ELECTCAST.NS', 'ELECTHERM.NS', 'ELGIEQUIP.NS', 'ELGIRUBCO.NS', 'ELIN.NS', 'EMAMILTD.NS', 'EMAMIPAP.NS', 'EMAMIREAL.NS', 'EMIL.NS', 'EMKAY.NS', 'EMMBI.NS', 'EMSLIMITED.NS', 'EMUDHRA.NS', 'ENDURANCE.NS', 'ENERGYDEV.NS', 'ENGINERSIN.NS', 'ENIL.NS', 'EPIGRAL.NS', 'EPL.NS', 'EQUIPPP.NS', 'EQUITASBNK.NS', 'ERIS.NS', 'EROSMEDIA.NS', 'ESABINDIA.NS', 'ESAFSFB.NS', 'ESCORTS.NS', 'ESSARSHPNG.NS', 'ESSENTIA.NS', 'ESTER.NS', 'ETHOSLTD.NS', 'EUROTEXIND.NS', 'EVEREADY.NS', 'EVERESTIND.NS', 'EXCEL.NS', 'EXCELINDUS.NS', 'EXIDEIND.NS', 'EXPLEOSOL.NS', 'EXXARO.NS', 'FACT.NS', 'FAIRCHEMOR.NS', 'FAZE3Q.NS', 'FCL.NS', 'FCONSUMER.NS', 'FCSSOFT.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FEDFINA.NS', 'FEL.NS', 'FELDVR.NS', 'FIBERWEB.NS', 'FIEMIND.NS', 'FILATEX.NS', 'FINCABLES.NS', 'FINEORG.NS', 'FINOPB.NS', 'FINPIPE.NS', 'FIVESTAR.NS', 'FLAIR.NS', 'FLEXITUFF.NS', 'FLFL.NS', 'FLUOROCHEM.NS', 'FMGOETZE.NS', 'FMNL.NS', 'FOCUS.NS', 'FOODSIN.NS', 'FORTIS.NS', 'FOSECOIND.NS', 'FSC.NS', 'FSL.NS', 'FUSION.NS', 'GABRIEL.NS', 'GAEL.NS', 'GAIL.NS', 'GALAXYSURF.NS', 'GALLANTT.NS', 'GANDHAR.NS', 'GANDHITUBE.NS', 'GANECOS.NS', 'GANESHBE.NS', 'GANESHHOUC.NS', 'GANGAFORGE.NS', 'GANGESSECU.NS', 'GARFIBRES.NS', 'GATECH.NS', 'GATECHDVR.NS', 'GATEWAY.NS', 'GEECEE.NS', 'GEEKAYWIRE.NS', 'GENCON.NS', 'GENESYS.NS', 'GENSOL.NS', 'GENUSPAPER.NS', 'GENUSPOWER.NS', 'GEOJITFSL.NS', 'GEPIL.NS', 'GESHIP.NS', 'GET&D.NS', 'GFLLIMITED.NS', 'GHCL.NS', 'GHCLTEXTIL.NS', 'GICHSGFIN.NS', 'GICRE.NS', 'GILLANDERS.NS', 'GILLETTE.NS', 'GINNIFILA.NS', 'GIPCL.NS', 'GKWLIMITED.NS', 'GLAND.NS', 'GLAXO.NS', 'GLENMARK.NS', 'GLFL.NS', 'GLOBAL.NS', 'GLOBALVECT.NS', 'GLOBE.NS', 'GLOBUSSPR.NS', 'GLS.NS', 'GMBREW.NS', 'GMDCLTD.NS', 'GMMPFAUDLR.NS', 'GMRINFRA.NS', 'GMRP&UI.NS', 'GNA.NS', 'GNFC.NS', 'GOACARBON.NS', 'GOCLCORP.NS', 'GOCOLORS.NS', 'GODFRYPHLP.NS', 'GODHA.NS', 'GODREJAGRO.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GODREJPROP.NS', 'GOENKA.NS', 'GOKEX.NS', 'GOKUL.NS', 'GOKULAGRO.NS', 'GOLDENTOBC.NS', 'GOLDIAM.NS', 'GOLDTECH.NS', 'GOODLUCK.NS', 'GOYALALUM.NS', 'GPIL.NS', 'GPPL.NS', 'GPTINFRA.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'GRAVITA.NS', 'GREAVESCOT.NS', 'GREENLAM.NS', 'GREENPANEL.NS', 'GREENPLY.NS', 'GREENPOWER.NS', 'GRINDWELL.NS', 'GRINFRA.NS', 'GRMOVER.NS', 'GROBTEA.NS', 'GRPLTD.NS', 'GRSE.NS', 'GRWRHITECH.NS', 'GSFC.NS', 'GSLSU.NS', 'GSPL.NS', 'GSS.NS', 'GTECJAINX.NS', 'GTL.NS', 'GTLINFRA.NS', 'GTPL.NS', 'GUFICBIO.NS', 'GUJALKALI.NS', 'GUJAPOLLO.NS', 'GUJGASLTD.NS', 'GUJRAFFIA.NS', 'GULFOILLUB.NS', 'GULFPETRO.NS', 'GULPOLY.NS', 'GVKPIL.NS', 'GVPTECH.NS', 'HAL.NS', 'HAPPSTMNDS.NS', 'HAPPYFORGE.NS', 'HARDWYN.NS', 'HARIOMPIPE.NS', 'HARRMALAYA.NS', 'HARSHA.NS', 'HATHWAY.NS', 'HATSUN.NS', 'HAVELLS.NS', 'HAVISHA.NS', 'HBLPOWER.NS', 'HBSL.NS', 'HCC.NS', 'HCG.NS', 'HCL-INSYS.NS', 'HCLTECH.NS', 'HDFCAMC.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'HEADSUP.NS', 'HECPROJECT.NS', 'HEG.NS', 'HEIDELBERG.NS', 'HEMIPROP.NS', 'HERANBA.NS', 'HERCULES.NS', 'HERITGFOOD.NS', 'HEROMOTOCO.NS', 'HESTERBIO.NS', 'HEUBACHIND.NS', 'HEXATRADEX.NS', 'HFCL.NS', 'HGINFRA.NS', 'HGS.NS', 'HIKAL.NS', 'HIL.NS', 'HILTON.NS', 'HIMATSEIDE.NS', 'HINDALCO.NS', 'HINDCOMPOS.NS', 'HINDCON.NS', 'HINDCOPPER.NS', 'HINDMOTORS.NS', 'HINDOILEXP.NS', 'HINDPETRO.NS', 'HINDUNILVR.NS', 'HINDWAREAP.NS', 'HINDZINC.NS', 'HIRECT.NS', 'HISARMETAL.NS', 'HITECH.NS', 'HITECHCORP.NS', 'HITECHGEAR.NS', 'HLEGLAS.NS', 'HLVLTD.NS', 'HMAAGRO.NS', 'HMT.NS', 'HMVL.NS', 'HNDFDS.NS', 'HOMEFIRST.NS', 'HONASA.NS', 'HONAUT.NS', 'HONDAPOWER.NS', 'HOVS.NS', 'HPAL.NS', 'HPIL.NS', 'HPL.NS', 'HSCL.NS', 'HTMEDIA.NS', 'HUBTOWN.NS', 'HUDCO.NS', 'HUHTAMAKI.NS', 'HYBRIDFIN.NS', 'IBREALEST.NS', 'IBULHSGFIN.NS', 'ICDSLTD.NS', 'ICEMAKE.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'ICIL.NS', 'ICRA.NS', 'IDBI.NS', 'IDEA.NS', 'IDEAFORGE.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IEL.NS', 'IEX.NS', 'IFBAGRO.NS', 'IFBIND.NS', 'IFCI.NS', 'IFGLEXPOR.NS', 'IGARASHI.NS', 'IGL.NS', 'IGPL.NS', 'IIFL.NS', 'IIFLSEC.NS', 'IITL.NS', 'IKIO.NS', 'IL&FSENGG.NS', 'IL&FSTRANS.NS', 'IMAGICAA.NS', 'IMFA.NS', 'IMPAL.NS', 'IMPEXFERRO.NS', 'INCREDIBLE.NS', 'INDBANK.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INDIAGLYCO.NS', 'INDIAMART.NS', 'INDIANB.NS', 'INDIANCARD.NS', 'INDIANHUME.NS', 'INDIASHLTR.NS', 'INDIGO.NS', 'INDIGOPNTS.NS', 'INDNIPPON.NS', 'INDOAMIN.NS', 'INDOBORAX.NS', 'INDOCO.NS', 'INDORAMA.NS', 'INDOSTAR.NS', 'INDOTECH.NS', 'INDOTHAI.NS', 'INDOWIND.NS', 'INDRAMEDCO.NS', 'INDSWFTLAB.NS', 'INDSWFTLTD.NS', 'INDTERRAIN.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'INFOBEAN.NS', 'INFOMEDIA.NS', 'INFY.NS', 'INGERRAND.NS', 'INNOVACAP.NS', 'INOXGREEN.NS', 'INOXINDIA.NS', 'INOXWIND.NS', 'INSECTICID.NS', 'INSPIRISYS.NS', 'INTELLECT.NS', 'INTENTECH.NS', 'INTLCONV.NS', 'INVENTURE.NS', 'IOB.NS', 'IOC.NS', 'IOLCP.NS', 'IONEXCHANG.NS', 'IPCALAB.NS', 'IPL.NS', 'IRB.NS', 'IRCON.NS', 'IRCTC.NS', 'IREDA.NS', 'IRFC.NS', 'IRIS.NS', 'IRISDOREME.NS', 'IRMENERGY.NS', 'ISEC.NS', 'ISFT.NS', 'ISGEC.NS', 'ISMTLTD.NS', 'ITC.NS', 'ITDC.NS', 'ITDCEM.NS', 'ITI.NS', 'IVC.NS', 'IVP.NS', 'IWEL.NS', 'IZMO.NS', 'J&KBANK.NS', 'JAGRAN.NS', 'JAGSNPHARM.NS', 'JAIBALAJI.NS', 'JAICORPLTD.NS', 'JAIPURKURT.NS', 'JAMNAAUTO.NS', 'JASH.NS', 'JAYAGROGN.NS', 'JAYBARMARU.NS', 'JAYNECOIND.NS', 'JAYSREETEA.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JCHAC.NS', 'JETAIRWAYS.NS', 'JETFREIGHT.NS', 'JHS.NS', 'JINDALPHOT.NS', 'JINDALPOLY.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JINDRILL.NS', 'JINDWORLD.NS', 'JIOFIN.NS', 'JISLDVREQS.NS', 'JISLJALEQS.NS', 'JITFINFRA.NS', 'JKCEMENT.NS', 'JKIL.NS', 'JKLAKSHMI.NS', 'JKPAPER.NS', 'JKTYRE.NS', 'JLHL.NS', 'JMA.NS', 'JMFINANCIL.NS', 'JOCIL.NS', 'JPASSOCIAT.NS', 'JPOLYINVST.NS', 'JPPOWER.NS', 'JSL.NS', 'JSWENERGY.NS', 'JSWHL.NS', 'JSWINFRA.NS', 'JSWSTEEL.NS', 'JTEKTINDIA.NS', 'JTLIND.NS', 'JUBLFOOD.NS', 'JUBLINDS.NS', 'JUBLINGREA.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'JWL.NS', 'JYOTHYLAB.NS', 'JYOTISTRUC.NS', 'KABRAEXTRU.NS', 'KAJARIACER.NS', 'KAKATCEM.NS', 'KALAMANDIR.NS', 'KALYANI.NS', 'KALYANIFRG.NS', 'KALYANKJIL.NS', 'KAMATHOTEL.NS', 'KAMDHENU.NS', 'KAMOPAINTS.NS', 'KANANIIND.NS', 'KANORICHEM.NS', 'KANPRPLA.NS', 'KANSAINER.NS', 'KAPSTON.NS', 'KARMAENG.NS', 'KARURVYSYA.NS', 'KAUSHALYA.NS', 'KAVVERITEL.NS', 'KAYA.NS', 'KAYNES.NS', 'KBCGLOBAL.NS', 'KCP.NS', 'KCPSUGIND.NS', 'KDDL.NS', 'KEC.NS', 'KECL.NS', 'KEEPLEARN.NS', 'KEI.NS', 'KELLTONTEC.NS', 'KERNEX.NS', 'KESORAMIND.NS', 'KEYFINSERV.NS', 'KFINTECH.NS', 'KHADIM.NS', 'KHAICHEM.NS', 'KHAITANLTD.NS', 'KHANDSE.NS', 'KICL.NS', 'KILITCH.NS', 'KIMS.NS', 'KINGFA.NS', 'KIOCL.NS', 'KIRIINDUS.NS', 'KIRLOSBROS.NS', 'KIRLOSENG.NS', 'KIRLOSIND.NS', 'KIRLPNU.NS', 'KITEX.NS', 'KKCL.NS', 'KMSUGAR.NS', 'KNRCON.NS', 'KOHINOOR.NS', 'KOKUYOCMLN.NS', 'KOLTEPATIL.NS', 'KOPRAN.NS', 'KOTAKBANK.NS', 'KOTARISUG.NS', 'KOTHARIPET.NS', 'KOTHARIPRO.NS', 'KPIGREEN.NS', 'KPIL.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'KRBL.NS', 'KREBSBIO.NS', 'KRIDHANINF.NS', 'KRISHANA.NS', 'KRITI.NS', 'KRITIKA.NS', 'KRITINUT.NS', 'KRSNAA.NS', 'KSB.NS', 'KSCL.NS', 'KSHITIJPOL.NS', 'KSL.NS', 'KSOLVES.NS', 'KTKBANK.NS', 'KUANTUM.NS', 'L&TFH.NS', 'LAGNAM.NS', 'LAKPRE.NS', 'LAL.NS', 'LALPATHLAB.NS', 'LAMBODHARA.NS', 'LANDMARK.NS', 'LAOPALA.NS', 'LASA.NS', 'LATENTVIEW.NS', 'LATTEYS.NS', 'LAURUSLABS.NS', 'LAXMICOT.NS', 'LAXMIMACH.NS', 'LCCINFOTEC.NS', 'LEMONTREE.NS', 'LEXUS.NS', 'LFIC.NS', 'LGBBROSLTD.NS', 'LGBFORGE.NS', 'LGHL.NS', 'LIBAS.NS', 'LIBERTSHOE.NS', 'LICHSGFIN.NS', 'LICI.NS', 'LIKHITHA.NS', 'LINC.NS', 'LINCOLN.NS', 'LINDEINDIA.NS', 'LLOYDS-RE.NS', 'LLOYDSENGG.NS', 'LLOYDSME.NS', 'LODHA.NS', 'LOKESHMACH.NS', 'LORDSCHLO.NS', 'LOTUSEYE.NS', 'LOVABLE.NS', 'LOYALTEX.NS', 'LPDC.NS', 'LT.NS', 'LTFOODS.NS', 'LTIM.NS', 'LTTS.NS', 'LUMAXIND.NS', 'LUMAXTECH.NS', 'LUPIN.NS', 'LUXIND.NS', 'LXCHEM.NS', 'LYKALABS.NS', 'LYPSAGEMS.NS', 'M&M.NS', 'M&MFIN.NS', 'MAANALU.NS', 'MACPOWER.NS', 'MADHAV.NS', 'MADHUCON.NS', 'MADRASFERT.NS', 'MAGADSUGAR.NS', 'MAGNUM.NS', 'MAHABANK.NS', 'MAHAPEXLTD.NS', 'MAHASTEEL.NS', 'MAHEPC.NS', 'MAHESHWARI.NS', 'MAHLIFE.NS', 'MAHLOG.NS', 'MAHSCOOTER.NS', 'MAHSEAMLES.NS', 'MAITHANALL.NS', 'MALLCOM.NS', 'MALUPAPER.NS', 'MANAKALUCO.NS', 'MANAKCOAT.NS', 'MANAKSIA.NS', 'MANAKSTEEL.NS', 'MANALIPETC.NS', 'MANAPPURAM.NS', 'MANGALAM.NS', 'MANGCHEFER.NS', 'MANGLMCEM.NS', 'MANINDS.NS', 'MANINFRA.NS', 'MANKIND.NS', 'MANOMAY.NS', 'MANORAMA.NS', 'MANORG.NS', 'MANUGRAPH.NS', 'MANYAVAR.NS', 'MAPMYINDIA.NS', 'MARALOVER.NS', 'MARATHON.NS', 'MARICO.NS', 'MARINE.NS', 'MARKSANS.NS', 'MARSHALL.NS', 'MARUTI.NS', 'MASFIN.NS', 'MASKINVEST.NS', 'MASTEK.NS', 'MATRIMONY.NS', 'MAWANASUG.NS', 'MAXESTATES.NS', 'MAXHEALTH.NS', 'MAXIND.NS', 'MAYURUNIQ.NS', 'MAZDA.NS', 'MAZDOCK.NS', 'MBAPL.NS', 'MBECL.NS', 'MBLINFRA.NS', 'MCDOWELL-N.NS', 'MCL.NS', 'MCLEODRUSS.NS', 'MCX.NS', 'MEDANTA.NS', 'MEDICAMEQ.NS', 'MEDICO.NS', 'MEDPLUS.NS', 'MEGASOFT.NS', 'MEGASTAR.NS', 'MELSTAR.NS', 'MENONBE.NS', 'MEP.NS', 'METALFORGE.NS', 'METROBRAND.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MGEL.NS', 'MGL.NS', 'MHLXMIRU.NS', 'MHRIL.NS', 'MICEL.NS', 'MIDHANI.NS', 'MINDACORP.NS', 'MINDTECK.NS', 'MIRCELECTR.NS', 'MIRZAINT.NS', 'MITCON.NS', 'MITTAL.NS', 'MKPL.NS', 'MMFL.NS', 'MMP.NS', 'MMTC.NS', 'MODIRUBBER.NS', 'MODISONLTD.NS', 'MOHITIND.NS', 'MOIL.NS', 'MOKSH.NS', 'MOL.NS', 'MOLDTECH.NS', 'MOLDTKPAC.NS', 'MONARCH.NS', 'MONTECARLO.NS', 'MORARJEE.NS', 'MOREPENLAB.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'MOTISONS.NS', 'MOTOGENFIN.NS', 'MPHASIS.NS', 'MPSLTD.NS', 'MRF.NS', 'MRO-TEK.NS', 'MRPL.NS', 'MSPL.NS', 'MSTCLTD.NS', 'MSUMI.NS', 'MTARTECH.NS', 'MTEDUCARE.NS', 'MTNL.NS', 'MUFIN.NS', 'MUFTI.NS', 'MUKANDLTD.NS', 'MUKTAARTS.NS', 'MUNJALAU.NS', 'MUNJALSHOW.NS', 'MURUDCERA.NS', 'MUTHOOTCAP.NS', 'MUTHOOTFIN.NS', 'MUTHOOTMF.NS', 'MVGJL.NS', 'NACLIND.NS', 'NAGAFERT.NS', 'NAGREEKCAP.NS', 'NAGREEKEXP.NS', 'NAHARCAP.NS', 'NAHARINDUS.NS', 'NAHARPOLY.NS', 'NAHARSPING.NS', 'NAM-INDIA.NS', 'NARMADA.NS', 'NATCOPHARM.NS', 'NATHBIOGEN.NS', 'NATIONALUM.NS', 'NAUKRI.NS', 'NAVA.NS', 'NAVINFLUOR.NS', 'NAVKARCORP.NS', 'NAVNETEDUL.NS', 'NAZARA.NS', 'NBCC.NS', 'NBIFIN.NS', 'NCC.NS', 'NCLIND.NS', 'NDGL.NS', 'NDL.NS', 'NDLVENTURE.NS', 'NDRAUTO.NS', 'NDTV.NS', 'NECCLTD.NS', 'NECLIFE.NS', 'NELCAST.NS', 'NELCO.NS', 'NEOGEN.NS', 'NESCO.NS', 'NESTLEIND.NS', 'NETWEB.NS', 'NETWORK18.NS', 'NEULANDLAB.NS', 'NEWGEN.NS', 'NEXTMEDIA.NS', 'NFL.NS', 'NGIL.NS', 'NGLFINE.NS', 'NH.NS', 'NHPC.NS', 'NIACL.NS', 'NIBL.NS', 'NIITLTD.NS', 'NIITMTS.NS', 'NILAINFRA.NS', 'NILASPACES.NS', 'NILKAMAL.NS', 'NINSYS.NS', 'NIPPOBATRY.NS', 'NIRAJ.NS', 'NIRAJISPAT.NS', 'NITCO.NS', 'NITINSPIN.NS', 'NITIRAJ.NS', 'NKIND.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NOCIL.NS', 'NOIDATOLL.NS', 'NORBTEAEXP.NS', 'NRAIL.NS', 'NRBBEARING.NS', 'NRL.NS', 'NSIL.NS', 'NSLNISP.NS', 'NTPC.NS', 'NUCLEUS.NS', 'NURECA.NS', 'NUVAMA.NS', 'NUVOCO.NS', 'NYKAA.NS', 'OAL.NS', 'OBCL.NS', 'OBEROIRLTY.NS', 'OCCL.NS', 'OFSS.NS', 'OIL.NS', 'OILCOUNTUB.NS', 'OLECTRA.NS', 'OMAXAUTO.NS', 'OMAXE.NS', 'OMINFRAL.NS', 'OMKARCHEM.NS', 'ONELIFECAP.NS', 'ONEPOINT.NS', 'ONGC.NS', 'ONMOBILE.NS', 'ONWARDTEC.NS', 'OPTIEMUS.NS', 'ORBTEXP.NS', 'ORCHPHARMA.NS', 'ORICONENT.NS', 'ORIENTALTL.NS', 'ORIENTBELL.NS', 'ORIENTCEM.NS', 'ORIENTCER.NS', 'ORIENTELEC.NS', 'ORIENTHOT.NS', 'ORIENTLTD.NS', 'ORIENTPPR.NS', 'ORISSAMINE.NS', 'ORTINLAB.NS', 'OSIAHYPER.NS', 'OSWALAGRO.NS', 'OSWALGREEN.NS', 'OSWALSEEDS.NS', 'PAGEIND.NS', 'PAISALO.NS', 'PAKKA.NS', 'PALASHSECU.NS', 'PALREDTEC.NS', 'PANACEABIO.NS', 'PANACHE.NS', 'PANAMAPET.NS', 'PANSARI.NS', 'PAR.NS', 'PARACABLES.NS', 'PARADEEP.NS', 'PARAGMILK.NS', 'PARAS.NS', 'PARASPETRO.NS', 'PARSVNATH.NS', 'PASUPTAC.NS', 'PATANJALI.NS', 'PATELENG.NS', 'PATINTLOG.NS', 'PAVNAIND.NS', 'PAYTM.NS', 'PCBL.NS', 'PCJEWELLER.NS', 'PDMJEPAPER.NS', 'PDSL.NS', 'PEARLPOLY.NS', 'PEL.NS', 'PENIND.NS', 'PENINLAND.NS', 'PERSISTENT.NS', 'PETRONET.NS', 'PFC.NS', 'PFIZER.NS', 'PFOCUS.NS', 'PFS.NS', 'PGEL.NS', 'PGHH.NS', 'PGHL.NS', 'PGIL.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'PIGL.NS', 'PIIND.NS', 'PILANIINVS.NS', 'PILITA.NS', 'PIONEEREMB.NS', 'PITTIENG.NS', 'PIXTRANS.NS', 'PKTEA.NS', 'PLASTIBLEN.NS', 'PLAZACABLE.NS', 'PNB.NS', 'PNBGILTS.NS', 'PNBHOUSING.NS', 'PNC.NS', 'PNCINFRA.NS', 'POCL.NS', 'PODDARHOUS.NS', 'PODDARMENT.NS', 'POKARNA.NS', 'POLICYBZR.NS', 'POLYCAB.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'PONNIERODE.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'POWERINDIA.NS', 'POWERMECH.NS', 'PPAP.NS', 'PPL.NS', 'PPLPHARMA.NS', 'PRAENG.NS', 'PRAJIND.NS', 'PRAKASH.NS', 'PRAKASHSTL.NS', 'PRAXIS.NS', 'PRECAM.NS', 'PRECOT.NS', 'PRECWIRE.NS', 'PREMEXPLN.NS', 'PREMIER.NS', 'PREMIERPOL.NS', 'PRESTIGE.NS', 'PRICOLLTD.NS', 'PRIMESECU.NS', 'PRINCEPIPE.NS', 'PRITI.NS', 'PRITIKAUTO.NS', 'PRIVISCL.NS', 'PROZONER.NS', 'PRSMJOHNSN.NS', 'PRUDENT.NS', 'PRUDMOULI.NS', 'PSB.NS', 'PSPPROJECT.NS', 'PTC.NS', 'PTCIL.NS', 'PTL.NS', 'PUNJABCHEM.NS', 'PURVA.NS', 'PVP.NS', 'PVRINOX.NS', 'PYRAMID.NS', 'QUESS.NS', 'QUICKHEAL.NS', 'RACE.NS', 'RADAAN.NS', 'RADHIKAJWE.NS', 'RADIANTCMS.NS', 'RADICO.NS', 'RADIOCITY.NS', 'RAILTEL.NS', 'RAIN.NS', 'RAINBOW.NS', 'RAJESHEXPO.NS', 'RAJMET.NS', 'RAJRATAN.NS', 'RAJRILTD.NS', 'RAJSREESUG.NS', 'RAJTV.NS', 'RALLIS.NS', 'RAMANEWS.NS', 'RAMAPHO.NS', 'RAMASTEEL.NS', 'RAMCOCEM.NS', 'RAMCOIND.NS', 'RAMCOSYS.NS', 'RAMKY.NS', 'RAMRAT.NS', 'RANASUG.NS', 'RANEENGINE.NS', 'RANEHOLDIN.NS', 'RATEGAIN.NS', 'RATNAMANI.NS', 'RATNAVEER.NS', 'RAYMOND.NS', 'RBA.NS', 'RBL.NS', 'RBLBANK.NS', 'RBZJEWEL.NS', 'RCF.NS', 'RECLTD.NS', 'REDINGTON.NS', 'REDTAPE.NS', 'REFEX.NS', 'REGENCERAM.NS', 'RELAXO.NS', 'RELCAPITAL.NS', 'RELCHEMQ.NS', 'RELIANCE.NS', 'RELIGARE.NS', 'RELINFRA.NS', 'REMSONSIND.NS', 'RENUKA.NS', 'REPCOHOME.NS', 'REPL.NS', 'REPRO.NS', 'RESPONIND.NS', 'RGL.NS', 'RHFL.NS', 'RHIM.NS', 'RHL.NS', 'RICOAUTO.NS', 'RIIL.NS', 'RISHABH.NS', 'RITCO.NS', 'RITES.NS', 'RKDL.NS', 'RKEC.NS', 'RKFORGE.NS', 'RML.NS', 'ROHLTD.NS', 'ROLEXRINGS.NS', 'ROLLT.NS', 'ROML.NS', 'ROSSARI.NS', 'ROSSELLIND.NS', 'ROTO.NS', 'ROUTE.NS', 'RPGLIFE.NS', 'RPOWER.NS', 'RPPINFRA.NS', 'RPPL.NS', 'RPSGVENT.NS', 'RRKABEL.NS', 'RSSOFTWARE.NS', 'RSWM.NS', 'RSYSTEMS.NS', 'RTNINDIA.NS', 'RTNPOWER.NS', 'RUBYMILLS.NS', 'RUCHINFRA.NS', 'RUCHIRA.NS', 'RUPA.NS', 'RUSHIL.NS', 'RUSTOMJEE.NS', 'RVHL.NS', 'RVNL.NS', 'S&SPOWER.NS', 'SABEVENTS.NS', 'SABTN.NS', 'SADBHAV.NS', 'SADBHIN.NS', 'SADHNANIQ.NS', 'SAFARI.NS', 'SAGARDEEP.NS', 'SAGCEM.NS', 'SAH.NS', 'SAHYADRI.NS', 'SAIL.NS', 'SAKAR.NS', 'SAKHTISUG.NS', 'SAKSOFT.NS', 'SAKUMA.NS', 'SALASAR.NS', 'SALONA.NS', 'SALSTEEL.NS', 'SALZERELEC.NS', 'SAMBHAAV.NS', 'SAMHI.NS', 'SAMPANN.NS', 'SANCO.NS', 'SANDESH.NS', 'SANDHAR.NS', 'SANDUMA.NS', 'SANGAMIND.NS', 'SANGHIIND.NS', 'SANGHVIMOV.NS', 'SANGINITA.NS', 'SANOFI.NS', 'SANSERA.NS', 'SAPPHIRE.NS', 'SARDAEN.NS', 'SAREGAMA.NS', 'SARLAPOLY.NS', 'SARVESHWAR.NS', 'SASKEN.NS', 'SASTASUNDR.NS', 'SATIA.NS', 'SATIN.NS', 'SATINDLTD.NS', 'SBC.NS', 'SBCL.NS', 'SBFC.NS', 'SBGLP.NS', 'SBICARD.NS', 'SBILIFE.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SCHAND.NS', 'SCHNEIDER.NS', 'SCI.NS', 'SCPL.NS', 'SDBL.NS', 'SEAMECLTD.NS', 'SECMARK.NS', 'SECURCRED.NS', 'SECURKLOUD.NS', 'SEJALLTD.NS', 'SELAN.NS', 'SELMC.NS', 'SEMAC.NS', 'SENCO.NS', 'SEPC.NS', 'SEQUENT.NS', 'SERVOTECH.NS', 'SESHAPAPER.NS', 'SETCO.NS', 'SEYAIND.NS', 'SFL.NS', 'SGIL.NS', 'SGL.NS', 'SHAH.NS', 'SHAHALLOYS.NS', 'SHAILY.NS', 'SHAKTIPUMP.NS', 'SHALBY.NS', 'SHALPAINTS.NS', 'SHANKARA.NS', 'SHANTI.NS', 'SHANTIGEAR.NS', 'SHARDACROP.NS', 'SHARDAMOTR.NS', 'SHAREINDIA.NS', 'SHEMAROO.NS', 'SHILPAMED.NS', 'SHIVALIK.NS', 'SHIVAMAUTO.NS', 'SHIVAMILLS.NS', 'SHIVATEX.NS', 'SHK.NS', 'SHOPERSTOP.NS', 'SHRADHA.NS', 'SHREDIGCEM.NS', 'SHREECEM.NS', 'SHREEPUSHK.NS', 'SHREERAMA.NS', 'SHRENIK.NS', 'SHREYANIND.NS', 'SHREYAS.NS', 'SHRIPISTON.NS', 'SHRIRAMFIN.NS', 'SHRIRAMPPS.NS', 'SHYAMCENT.NS', 'SHYAMMETL.NS', 'SHYAMTEL.NS', 'SICALLOG.NS', 'SIEMENS.NS', 'SIGACHI.NS', 'SIGIND.NS', 'SIGMA.NS', 'SIGNATURE.NS', 'SIKKO.NS', 'SIL.NS', 'SILGO.NS', 'SILINV.NS', 'SILLYMONKS.NS', 'SILVERTUC.NS', 'SIMBHALS.NS', 'SIMPLEXINF.NS', 'SINDHUTRAD.NS', 'SINTERCOM.NS', 'SIRCA.NS', 'SIS.NS', 'SITINET.NS', 'SIYSIL.NS', 'SJS.NS', 'SJVN.NS', 'SKFINDIA.NS', 'SKIPPER.NS', 'SKMEGGPROD.NS', 'SKYGOLD.NS', 'SMARTLINK.NS', 'SMCGLOBAL.NS', 'SMLISUZU.NS', 'SMLT.NS', 'SMSLIFE.NS', 'SMSPHARMA.NS', 'SNOWMAN.NS', 'SOBHA.NS', 'SOFTTECH.NS', 'SOLARA.NS', 'SOLARINDS.NS', 'SOMANYCERA.NS', 'SOMATEX.NS', 'SOMICONVEY.NS', 'SONACOMS.NS', 'SONAMLTD.NS', 'SONATSOFTW.NS', 'SOTL.NS', 'SOUTHBANK.NS', 'SOUTHWEST.NS', 'SPAL.NS', 'SPANDANA.NS', 'SPARC.NS', 'SPCENET.NS', 'SPECIALITY.NS', 'SPENCERS.NS', 'SPENTEX.NS', 'SPIC.NS', 'SPLIL.NS', 'SPLPETRO.NS', 'SPMLINFRA.NS', 'SPORTKING.NS', 'SPTL.NS', 'SPYL.NS', 'SREEL.NS', 'SRF.NS', 'SRGHFL.NS', 'SRHHYPOLTD.NS', 'SRPL.NS', 'SSWL.NS', 'STAR.NS', 'STARCEMENT.NS', 'STARHEALTH.NS', 'STARPAPER.NS', 'STARTECK.NS', 'STCINDIA.NS', 'STEELCAS.NS', 'STEELCITY.NS', 'STEELXIND.NS', 'STEL.NS', 'STERTOOLS.NS', 'STLTECH.NS', 'STOVEKRAFT.NS', 'STYLAMIND.NS', 'STYRENIX.NS', 'SUBEXLTD.NS', 'SUBROS.NS', 'SUDARSCHEM.NS', 'SUKHJITS.NS', 'SULA.NS', 'SUMICHEM.NS', 'SUMIT.NS', 'SUMMITSEC.NS', 'SUNCLAY.NS', 'SUNDARAM.NS', 'SUNDARMFIN.NS', 'SUNDARMHLD.NS', 'SUNDRMBRAK.NS', 'SUNDRMFAST.NS', 'SUNFLAG.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SUNTV.NS', 'SUPERHOUSE.NS', 'SUPERSPIN.NS', 'SUPRAJIT.NS', 'SUPREMEENG.NS', 'SUPREMEIND.NS', 'SUPREMEINF.NS', 'SUPRIYA.NS', 'SURAJEST.NS', 'SURANASOL.NS', 'SURANAT&P.NS', 'SURYALAXMI.NS', 'SURYAROSNI.NS', 'SURYODAY.NS', 'SUTLEJTEX.NS', 'SUULD.NS', 'SUVEN.NS', 'SUVENPHAR.NS', 'SUVIDHAA.NS', 'SUZLON.NS', 'SVLL.NS', 'SVPGLOB.NS', 'SWANENERGY.NS', 'SWARAJENG.NS', 'SWELECTES.NS', 'SWSOLAR.NS', 'SYMPHONY.NS', 'SYNCOMF.NS', 'SYNGENE.NS', 'SYRMA.NS', 'TAINWALCHM.NS', 'TAJGVK.NS', 'TAKE.NS', 'TALBROAUTO.NS', 'TANLA.NS', 'TARAPUR.NS', 'TARC.NS', 'TARMAT.NS', 'TARSONS.NS', 'TASTYBITE.NS', 'TATACHEM.NS', 'TATACOFFEE.NS', 'TATACOMM.NS', 'TATACONSUM.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TATAMETALI.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TATATECH.NS', 'TATVA.NS', 'TBZ.NS', 'TCI.NS', 'TCIEXP.NS', 'TCLCONS.NS', 'TCNSBRANDS.NS', 'TCPLPACK.NS', 'TCS.NS', 'TDPOWERSYS.NS', 'TEAMLEASE.NS', 'TECHIN.NS', 'TECHM.NS', 'TECHNOE.NS', 'TECILCHEM.NS', 'TEGA.NS', 'TEJASNET.NS', 'TEMBO.NS', 'TERASOFT.NS', 'TEXINFRA.NS', 'TEXMOPIPES.NS', 'TEXRAIL.NS', 'TFCILTD.NS', 'TFL.NS', 'TGBHOTELS.NS', 'THANGAMAYL.NS', 'THEINVEST.NS', 'THEJO.NS', 'THEMISMED.NS', 'THERMAX.NS', 'THOMASCOOK.NS', 'THOMASCOTT.NS', 'THYROCARE.NS', 'TI.NS', 'TIDEWATER.NS', 'TIIL.NS', 'TIINDIA.NS', 'TIJARIA.NS', 'TIL.NS', 'TIMESGTY.NS', 'TIMETECHNO.NS', 'TIMKEN.NS', 'TINPLATE.NS', 'TIPSFILMS.NS', 'TIPSINDLTD.NS', 'TIRUMALCHM.NS', 'TIRUPATIFL.NS', 'TITAGARH.NS', 'TITAN.NS', 'TMB.NS', 'TNPETRO.NS', 'TNPL.NS', 'TNTELE.NS', 'TOKYOPLAST.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'TOTAL.NS', 'TOUCHWOOD.NS', 'TPHQ.NS', 'TPLPLASTEH.NS', 'TRACXN.NS', 'TREEHOUSE.NS', 'TREJHARA.NS', 'TREL.NS', 'TRENT.NS', 'TRF.NS', 'TRIDENT.NS', 'TRIGYN.NS', 'TRIL.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TRU.NS', 'TTKHLTCARE.NS', 'TTKPRESTIG.NS', 'TTL.NS', 'TTML.NS', 'TV18BRDCST.NS', 'TVSELECT.NS', 'TVSHLTD.NS', 'TVSMOTOR.NS', 'TVSSCS.NS', 'TVSSRICHAK.NS', 'TVTODAY.NS', 'TVVISION.NS', 'UBL.NS', 'UCAL.NS', 'UCOBANK.NS', 'UDS.NS', 'UFLEX.NS', 'UFO.NS', 'UGARSUGAR.NS', 'UGROCAP.NS', 'UJJIVAN.NS', 'UJJIVANSFB.NS', 'ULTRACEMCO.NS', 'UMAEXPORTS.NS', 'UMANGDAIRY.NS', 'UMESLTD.NS', 'UNICHEMLAB.NS', 'UNIDT.NS', 'UNIENTER.NS', 'UNIINFO.NS', 'UNIONBANK.NS', 'UNIPARTS.NS', 'UNITECH.NS', 'UNITEDPOLY.NS', 'UNITEDTEA.NS', 'UNIVAFOODS.NS', 'UNIVASTU.NS', 'UNIVCABLES.NS', 'UNIVPHOTO.NS', 'UNOMINDA.NS', 'UPL.NS', 'URAVI.NS', 'URJA.NS', 'USHAMART.NS', 'USK.NS', 'UTIAMC.NS', 'UTKARSHBNK.NS', 'UTTAMSUGAR.NS', 'V2RETAIL.NS', 'VADILALIND.NS', 'VAIBHAVGBL.NS', 'VAISHALI.NS', 'VAKRANGEE.NS', 'VALIANTLAB.NS', 'VALIANTORG.NS', 'VARDHACRLC.NS', 'VARDMNPOLY.NS', 'VARROC.NS', 'VASCONEQ.NS', 'VASWANI.NS', 'VBL.NS', 'VCL.NS', 'VEDL.NS', 'VENKEYS.NS', 'VENUSPIPES.NS', 'VENUSREM.NS', 'VERANDA.NS', 'VERTOZ.NS', 'VESUVIUS.NS', 'VETO.NS', 'VGUARD.NS', 'VHL.NS', 'VIDHIING.NS', 'VIJAYA.NS', 'VIJIFIN.NS', 'VIKASECO.NS', 'VIKASLIFE.NS', 'VIMTALABS.NS', 'VINATIORGA.NS', 'VINDHYATEL.NS', 'VINEETLAB.NS', 'VINNY.NS', 'VINYLINDIA.NS', 'VIPCLOTHNG.NS', 'VIPIND.NS', 'VIPULLTD.NS', 'VIRINCHI.NS', 'VISAKAIND.NS', 'VISESHINFO.NS', 'VISHNU.NS', 'VISHWARAJ.NS', 'VIVIDHA.NS', 'VLEGOV.NS', 'VLSFINANCE.NS', 'VMART.NS', 'VOLTAMP.NS', 'VOLTAS.NS', 'VPRPL.NS', 'VRLLOG.NS', 'VSSL.NS', 'VSTIND.NS', 'VSTTILLERS.NS', 'VTL.NS', 'WABAG.NS', 'WALCHANNAG.NS', 'WANBURY.NS', 'WEALTH.NS', 'WEBELSOLAR.NS', 'WEIZMANIND.NS', 'WEL.NS', 'WELCORP.NS', 'WELENT.NS', 'WELINV.NS', 'WELSPUNLIV.NS', 'WENDT.NS', 'WESTLIFE.NS', 'WEWIN.NS', 'WHEELS.NS', 'WHIRLPOOL.NS', 'WILLAMAGOR.NS', 'WINDLAS.NS', 'WINDMACHIN.NS', 'WINSOME.NS', 'WIPL.NS', 'WIPRO.NS', 'WOCKPHARMA.NS', 'WONDERLA.NS', 'WORTH.NS', 'WSI.NS', 'WSTCSTPAPR.NS', 'XCHANGING.NS', 'XELPMOC.NS', 'XPROINDIA.NS', 'YAARI.NS', 'YASHO.NS', 'YATHARTH.NS', 'YATRA.NS', 'YESBANK.NS', 'YUKEN.NS', 'ZAGGLE.NS', 'ZEEL.NS', 'ZEELEARN.NS', 'ZEEMEDIA.NS', 'ZENITHEXPO.NS', 'ZENITHSTL.NS', 'ZENSARTECH.NS', 'ZENTEC.NS', 'ZFCVINDIA.NS', 'ZIMLAB.NS', 'ZODIAC.NS', 'ZODIACLOTH.NS', 'ZOMATO.NS', 'ZOTA.NS', 'ZUARI.NS', 'ZUARIIND.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS']# Scan stocks
selected_stocks = []
for stock in nse_stocks:
    print(f"Processing {stock}...")
    data = fetch_data(stock)
    # Ensure the index is a DateTimeIndex
    if not isinstance(data.index, pd.DatetimeIndex):
        data.index = pd.to_datetime(data.index)
    # Extract 9:15 to 9:20 interval for each day
    for date in data.index.normalize().unique():
        daily_data = data[data.index.normalize() == date]  # Filter data for the specific date
        first_interval = daily_data.between_time('09:15', '09:20')
        if not first_interval.empty:
            open_equals_low = first_interval.iloc[0]['Open'] == first_interval['Low'].min()
            #volume_breakout = first_interval.iloc[0]['Volume'] > historical_volume_average(stock)
            if open_equals_low:
                selected_stocks.append((stock, date.date()))
                # Plot the candlestick for this interval
                #plot_candlestick(first_interval, stock, date.date())

# Output the selected stocks
print("Selected Stocks:")
for stock, date in selected_stocks:
    print(f"{stock} on {date}")

# %% [markdown]
# #for finding selected stocks with excel (stock,date,volume,marketcap)

# %%
import yfinance as yf
import pandas as pd
import plotly.graph_objects as go
from datetime import datetime

def fetch_data(stock):
    # Fetch historical data for the stock for the last 7 days with 1-minute intervals
    data = yf.download(stock, period="1d", interval="5m")
    return data

def fetch_market_cap(stock):
    stock_info = yf.Ticker(stock)
    market_cap = stock_info.info.get("marketCap")
    return market_cap

def plot_candlestick(data, stock, date):
    # Create a candlestick chart
    fig = go.Figure(data=[go.Candlestick(x=data.index,
                                         open=data['Open'],
                                         high=data['High'],
                                         low=data['Low'],
                                         close=data['Close'])])
    fig.update_layout(title=f'Candlestick chart for {stock} on {date}',
                      xaxis_title='Time',
                      yaxis_title='Price',
                      xaxis_rangeslider_visible=False)
    fig.show()

# List of NSE stocks
nse_stocks = ['20MICRONS.NS', '21STCENMGM.NS', '360ONE.NS']

# Initialize lists to store selected stocks and their volumes and market caps
selected_stocks = []
selected_stocks_volume = []
selected_stocks_market_cap = []

for stock in nse_stocks:
    print(f"Processing {stock}...")
    data = fetch_data(stock)
    market_cap = fetch_market_cap(stock)

    if not isinstance(data.index, pd.DatetimeIndex):
        data.index = pd.to_datetime(data.index)

    for date in data.index.normalize().unique():
        daily_data = data[data.index.normalize() == date]
        first_interval = daily_data.between_time('09:15', '09:20')
        if not first_interval.empty:
            open_equals_low = first_interval.iloc[0]['Open'] == first_interval['Low'].min()
            if open_equals_low:
                selected_stocks.append((stock, date.date()))
                selected_stocks_volume.append((stock, date.date(), first_interval['Volume'].sum()))
                selected_stocks_market_cap.append((stock, date.date(), market_cap))

# Create DataFrames
df_volume = pd.DataFrame(selected_stocks_volume, columns=['Stock', 'Date', 'Volume'])
df_market_cap = pd.DataFrame(selected_stocks_market_cap, columns=['Stock', 'Date', 'MarketCap'])

# Merge DataFrames
df_merged = pd.merge(df_volume, df_market_cap, on=['Stock', 'Date'], how='inner')

# Get today's date for the file name
today_date = datetime.today().strftime('%Y-%m-%d')

# Export the DataFrame to an Excel file with today's date in the file name
file_name = f'selected_stockss_volume_and_marketcap_{today_date}.xlsx'
df_merged.to_excel(file_name, index=False)

# Output the selected stocks
print("Selected Stocks:")
for stock, date in selected_stocks:
    print(f"{stock} on {date}")

# %% [markdown]
# #for finding selected stocks with excel (stock,date,volume, marketcap, entry price)

# %% [markdown]
# The provided script is a Python program designed for financial analysis, particularly focusing on stocks from the National Stock Exchange (NSE) of India. It performs several functions including data fetching, analysis, and visualization. Here's a breakdown of its key components and functionalities:
#
# 1. **Importing Libraries**:
#    - `yfinance`: Used to fetch historical stock data.
#    - `pandas`: For data manipulation and analysis.
#    - `plotly.graph_objects`: For creating interactive candlestick charts.
#    - `datetime`: To handle dates and times.
#
# 2. **Function Definitions**:
#    - `fetch_data(stock)`: Fetches historical data for a given stock over the last day with 5-minute intervals.
#    - `fetch_market_cap(stock)`: Retrieves the market capitalization of a given stock.
#    - `plot_candlestick(data, stock, date)`: Generates a candlestick chart for the specified stock and date.
#
# 3. **Stocks Selection and Data Fetching**:
#    - A list of NSE stocks (`nse_stocks`) is defined.
#    - For each stock in this list, the script fetches historical data and market capitalization.
#
# 4. **Data Analysis**:
#    - The script examines the first 5-minute interval of each trading day (09:15 to 09:20) for each stock.
#    - It identifies if the opening price is equal to the lowest price in this interval, a condition used to select stocks.
#    - If this condition is met, the stock is added to a list of selected stocks.
#
# 5. **Data Storage and Aggregation**:
#    - The script creates lists to store selected stocks, their trading volumes, market caps, and entry prices.
#    - These lists are converted into Pandas DataFrames for easier manipulation and merging.
#
# 6. **Merging and Exporting Data**:
#    - The separate DataFrames for volume, market cap, and entry price are merged into a single DataFrame.
#    - This merged DataFrame is then exported to an Excel file, named with the current date for reference.
#
# 7. **Output**:
#    - The script prints out the list of selected stocks along with their respective dates and entry prices.
#
# 8. **Entry Price Addition**:
#    - The script has been modified to include the entry price, assumed to be the closing price of the first 5-minute interval.
#
# This script is particularly useful for traders or analysts who are looking for specific patterns in stock prices at the market open. It automates the process of data collection, pattern detection, and preliminary analysis, thereby saving time and providing a quick overview of potential stocks of interest.

# %%
import yfinance as yf
import pandas as pd
import plotly.graph_objects as go
from datetime import datetime

def fetch_data(stock):
    # Fetch historical data for the stock for today with 5-minute intervals
    data = yf.download(stock, period="1d", interval="5m")
    return data

def fetch_market_cap(stock):
    stock_info = yf.Ticker(stock)
    market_cap = stock_info.info.get("marketCap")
    return market_cap

def plot_candlestick(data, stock, date):
    # Create a candlestick chart
    fig = go.Figure(data=[go.Candlestick(x=data.index,
                                         open=data['Open'],
                                         high=data['High'],
                                         low=data['Low'],
                                         close=data['Close'])])
    fig.update_layout(title=f'Candlestick chart for {stock} on {date}',
                      xaxis_title='Time',
                      yaxis_title='Price',
                      xaxis_rangeslider_visible=False)
    fig.show()

# List of NSE stocks
nse_stocks = ['20MICRONS.NS', '21STCENMGM.NS', '360ONE.NS', '3IINFOLTD.NS', '3PLAND.NS', '5PAISA.NS', '63MOONS.NS', 'A2ZINFRA.NS', 'AAATECH.NS', 'AAKASH.NS', 'AAREYDRUGS.NS', 'AARON.NS', 'AARTECH.NS', 'AARTIDRUGS.NS', 'AARTIIND.NS', 'AARTIPHARM.NS', 'AARTISURF.NS', 'AARVEEDEN.NS', 'AARVI.NS', 'AAVAS.NS', 'ABAN.NS', 'ABCAPITAL.NS', 'ABFRL.NS', 'ABMINTLLTD.NS', 'ABSLAMC.NS', 'ACCELYA.NS', 'ACCURACY.NS', 'ACE.NS', 'ACEINTEG.NS', 'ACI.NS', 'ACL.NS', 'ACLGATI.NS', 'ADANIENSOL.NS', 'ADANIGREEN.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'ADFFOODS.NS', 'ADL.NS', 'ADORWELD.NS', 'ADROITINFO.NS', 'ADSL.NS', 'ADVANIHOTR.NS', 'ADVENZYMES.NS', 'AEGISCHEM.NS', 'AEROFLEX.NS', 'AETHER.NS', 'AFFLE.NS', 'AGARIND.NS', 'AGI.NS', 'AGRITECH.NS', 'AGROPHOS.NS', 'AGSTRA.NS', 'AHL.NS', 'AHLADA.NS', 'AHLEAST.NS', 'AHLUCONT.NS', 'AIRAN.NS', 'AIROLAM.NS', 'AJMERA.NS', 'AJOONI.NS', 'AKASH.NS', 'AKG.NS', 'AKI.NS', 'AKSHAR.NS', 'AKSHARCHEM.NS', 'AKSHOPTFBR.NS', 'ALANKIT.NS', 'ALBERTDAVD.NS', 'ALEMBICLTD.NS', 'ALICON.NS', 'ALKALI.NS', 'ALLCARGO.NS', 'ALLSEC.NS', 'ALMONDZ.NS', 'ALOKINDS.NS', 'ALPA.NS', 'ALPHAGEO.NS', 'ALPSINDUS.NS', 'AMBICAAGAR.NS', 'AMBIKCO.NS', 'AMBUJACEM.NS', 'AMDIND.NS', 'AMIORG.NS', 'AMJLAND.NS', 'AMNPLST.NS', 'AMRUTANJAN.NS', 'ANANTRAJ.NS', 'ANDHRAPAP.NS', 'ANDHRSUGAR.NS', 'ANIKINDS.NS', 'ANKITMETAL.NS', 'ANMOL.NS', 'ANTGRAPHIC.NS', 'ANURAS.NS', 'APCL.NS', 'APCOTEXIND.NS', 'APEX.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'APOLLO.NS', 'APOLLOPIPE.NS', 'APOLLOTYRE.NS', 'APTECHT.NS', 'APTUS.NS', 'ARCHIDPLY.NS', 'ARCHIES.NS', 'ARE&M.NS', 'ARENTERP.NS', 'ARIES.NS', 'ARIHANTCAP.NS', 'ARIHANTSUP.NS', 'AROGRANITE.NS', 'ARROWGREEN.NS', 'ARSHIYA.NS', 'ARSSINFRA.NS', 'ARTEMISMED.NS', 'ARTNIRMAN.NS', 'ARVEE.NS', 'ARVIND.NS', 'ARVINDFASN.NS', 'ARVSMART.NS', 'ASAHIINDIA.NS', 'ASAHISONG.NS', 'ASAL.NS', 'ASALCBR.NS', 'ASHAPURMIN.NS', 'ASHIANA.NS', 'ASHIMASYN.NS', 'ASHOKA.NS', 'ASHOKAMET.NS', 'ASHOKLEY.NS', 'ASIANENE.NS', 'ASIANHOTNR.NS', 'ASIANTILES.NS', 'ASKAUTOLTD.NS', 'ASMS.NS', 'ASPINWALL.NS', 'ASTEC.NS', 'ASTERDM.NS', 'ASTRAL.NS', 'ASTRAMICRO.NS', 'ASTRON.NS', 'ATALREAL.NS', 'ATAM.NS', 'ATFL.NS', 'ATGL.NS', 'ATL.NS', 'ATLANTAA.NS', 'ATULAUTO.NS', 'AUBANK.NS', 'AUROPHARMA.NS', 'AURUM.NS', 'AUSOMENT.NS', 'AUTOIND.NS', 'AVADHSUGAR.NS', 'AVALON.NS', 'AVANTIFEED.NS', 'AVG.NS', 'AVONMORE.NS', 'AVROIND.NS', 'AVTNPL.NS', 'AWHCL.NS', 'AWL.NS', 'AXISBANK.NS', 'AXISCADES.NS', 'AXITA.NS', 'AYMSYNTEX.NS', 'AZAD.NS', 'BAFNAPH.NS', 'BAGFILMS.NS', 'BAIDFIN.NS', 'BAJAJCON.NS', 'BAJAJELEC.NS', 'BAJAJFINSV.NS', 'BAJAJHCARE.NS', 'BAJAJHIND.NS', 'BAJEL.NS', 'BALAJITELE.NS', 'BALAXI.NS', 'BALKRISHNA.NS', 'BALMLAWRIE.NS', 'BALPHARMA.NS', 'BALRAMCHIN.NS', 'BANARBEADS.NS', 'BANCOINDIA.NS', 'BANDHANBNK.NS', 'BANG.NS', 'BANKA.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BANSWRAS.NS', 'BARBEQUE.NS', 'BASML.NS', 'BATAINDIA.NS', 'BBOX.NS', 'BBTC.NS', 'BBTCL.NS', 'BCG.NS', 'BCLIND.NS', 'BCONCEPTS.NS', 'BDL.NS', 'BEARDSELL.NS', 'BECTORFOOD.NS', 'BEDMUTHA.NS', 'BEL.NS', 'BEPL.NS', 'BERGEPAINT.NS', 'BFINVEST.NS', 'BFUTILITIE.NS', 'BGRENERGY.NS', 'BHAGCHEM.NS', 'BHAGERIA.NS', 'BHAGYANGR.NS', 'BHANDARI.NS', 'BHARATFORG.NS', 'BHARATGEAR.NS', 'BHARATWIRE.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'BIGBLOC.NS', 'BIKAJI.NS', 'BIL.NS', 'BINANIIND.NS', 'BIOCON.NS', 'BIOFILCHEM.NS', 'BIRLACABLE.NS', 'BIRLACORPN.NS', 'BIRLAMONEY.NS', 'BKMINDST.NS', 'BLAL.NS', 'BLBLIMITED.NS', 'BLISSGVS.NS', 'BLKASHYAP.NS', 'BLS.NS', 'BLUECHIP.NS', 'BLUECOAST.NS', 'BLUEJET.NS', 'BLUESTARCO.NS', 'BODALCHEM.NS', 'BOHRAIND.NS', 'BOMDYEING.NS', 'BOROLTD.NS', 'BORORENEW.NS', 'BPCL.NS', 'BPL.NS', 'BRIGADE.NS', 'BRNL.NS', 'BROOKS.NS', 'BSHSL.NS', 'BSL.NS', 'BSOFT.NS', 'BTML.NS', 'BURNPUR.NS', 'BUTTERFLY.NS', 'BVCL.NS', 'BYKE.NS', 'CALSOFT.NS', 'CAMLINFINE.NS', 'CAMPUS.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CANTABIL.NS', 'CAPACITE.NS', 'CAPLIPOINT.NS', 'CAPTRUST.NS', 'CARBORUNIV.NS', 'CAREERP.NS', 'CARERATING.NS', 'CARTRADE.NS', 'CARYSIL.NS', 'CASTROLIND.NS', 'CCHHL.NS', 'CCL.NS', 'CDSL.NS', 'CELEBRITY.NS', 'CELLO.NS', 'CENTENKA.NS', 'CENTEXT.NS', 'CENTRALBK.NS', 'CENTRUM.NS', 'CENTUM.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CEREBRAINT.NS', 'CESC.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHALET.NS', 'CHAMBLFERT.NS', 'CHEMBOND.NS', 'CHEMCON.NS', 'CHEMFAB.NS', 'CHEMPLASTS.NS', 'CHENNPETRO.NS', 'CHEVIOT.NS', 'CHOICEIN.NS', 'CHOLAFIN.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'CIGNITITEC.NS', 'CINELINE.NS', 'CINEVISTA.NS', 'CIPLA.NS', 'CLEAN.NS', 'CLEDUCATE.NS', 'CLSEL.NS', 'CMSINFO.NS', 'COALINDIA.NS', 'COASTCORP.NS', 'COCHINSHIP.NS', 'COFFEEDAY.NS', 'COMPINFO.NS', 'COMPUSOFT.NS', 'CONCOR.NS', 'CONCORDBIO.NS', 'CONFIPET.NS', 'CONSOFINVT.NS', 'CONTROLPR.NS', 'CORALFINAC.NS', 'CORDSCABLE.NS', 'COROMANDEL.NS', 'COSMOFIRST.NS', 'COUNCODOS.NS', 'CREATIVE.NS', 'CREATIVEYE.NS', 'CREDITACC.NS', 'CREST.NS', 'CROMPTON.NS', 'CROWN.NS', 'CSBBANK.NS', 'CSLFINANCE.NS', 'CTE.NS', 'CUB.NS', 'CUBEXTUB.NS', 'CUPID.NS', 'CYBERMEDIA.NS', 'CYBERTECH.NS', 'CYIENTDLM.NS', 'DABUR.NS', 'DALMIASUG.NS', 'DAMODARIND.NS', 'DANGEE.NS', 'DATAMATICS.NS', 'DATAPATTNS.NS', 'DBCORP.NS', 'DBL.NS', 'DBOL.NS', 'DBREALTY.NS', 'DBSTOCKBRO.NS', 'DCAL.NS', 'DCBBANK.NS', 'DCI.NS', 'DCM.NS', 'DCMFINSERV.NS', 'DCMNVL.NS', 'DCMSHRIRAM.NS', 'DCMSRIND.NS', 'DCW.NS', 'DCXINDIA.NS', 'DECCANCE.NS', 'DEEPAKFERT.NS', 'DEEPENR.NS', 'DEEPINDS.NS', 'DELHIVERY.NS', 'DELPHIFX.NS', 'DELTACORP.NS', 'DELTAMAGNT.NS', 'DEN.NS', 'DENORA.NS', 'DEVIT.NS', 'DEVYANI.NS', 'DGCONTENT.NS', 'DHAMPURSUG.NS', 'DHANBANK.NS', 'DHANI.NS', 'DHANUKA.NS', 'DHARMAJ.NS', 'DHRUV.NS', 'DHUNINV.NS', 'DIACABS.NS', 'DIAMINESQ.NS', 'DIAMONDYD.NS', 'DICIND.NS', 'DIGISPICE.NS', 'DIGJAMLMTD.NS', 'DIL.NS', 'DISHTV.NS', 'DIVGIITTS.NS', 'DJML.NS', 'DLF.NS', 'DLINKINDIA.NS', 'DMCC.NS', 'DNAMEDIA.NS', 'DODLA.NS', 'DOLATALGO.NS', 'DOLLAR.NS', 'DOLPHIN.NS', 'DOMS.NS', 'DONEAR.NS', 'DPABHUSHAN.NS', 'DPSCLTD.NS', 'DPWIRES.NS', 'DRCSYSTEMS.NS', 'DREAMFOLKS.NS', 'DREDGECORP.NS', 'DSSL.NS', 'DTIL.NS', 'DUCON.NS', 'DVL.NS', 'DWARKESH.NS', 'DYCL.NS', 'DYNPRO.NS', 'E2E.NS', 'EASEMYTRIP.NS', 'EASTSILK.NS', 'EDELWEISS.NS', 'EDUCOMP.NS', 'EIDPARRY.NS', 'EIFFL.NS', 'EIHAHOTELS.NS', 'EIHOTEL.NS', 'EIMCOELECO.NS', 'EKC.NS', 'ELDEHSG.NS', 'ELECON.NS', 'ELECTCAST.NS', 'ELECTHERM.NS', 'ELGIEQUIP.NS', 'ELGIRUBCO.NS', 'ELIN.NS', 'EMAMILTD.NS', 'EMAMIPAP.NS', 'EMAMIREAL.NS', 'EMIL.NS', 'EMKAY.NS', 'EMMBI.NS', 'EMSLIMITED.NS', 'EMUDHRA.NS', 'ENDURANCE.NS', 'ENERGYDEV.NS', 'ENGINERSIN.NS', 'ENIL.NS', 'EPIGRAL.NS', 'EPL.NS', 'EQUIPPP.NS', 'EQUITASBNK.NS', 'ERIS.NS', 'EROSMEDIA.NS', 'ESAFSFB.NS', 'ESSARSHPNG.NS', 'ESSENTIA.NS', 'ESTER.NS', 'EUROTEXIND.NS', 'EVEREADY.NS', 'EVERESTIND.NS', 'EXCEL.NS', 'EXCELINDUS.NS', 'EXIDEIND.NS', 'EXPLEOSOL.NS', 'EXXARO.NS', 'FACT.NS', 'FAIRCHEMOR.NS', 'FAZE3Q.NS', 'FCL.NS', 'FCONSUMER.NS', 'FCSSOFT.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FEDFINA.NS', 'FEL.NS', 'FELDVR.NS', 'FIBERWEB.NS', 'FILATEX.NS', 'FINCABLES.NS', 'FINOPB.NS', 'FINPIPE.NS', 'FIVESTAR.NS', 'FLAIR.NS', 'FLEXITUFF.NS', 'FLFL.NS', 'FMGOETZE.NS', 'FMNL.NS', 'FOCUS.NS', 'FOODSIN.NS', 'FORTIS.NS', 'FSC.NS', 'FSL.NS', 'FUSION.NS', 'GABRIEL.NS', 'GAEL.NS', 'GAIL.NS', 'GALLANTT.NS', 'GANDHAR.NS', 'GANDHITUBE.NS', 'GANECOS.NS', 'GANESHBE.NS', 'GANESHHOUC.NS', 'GANGAFORGE.NS', 'GANGESSECU.NS', 'GATECH.NS', 'GATECHDVR.NS', 'GATEWAY.NS', 'GEECEE.NS', 'GEEKAYWIRE.NS', 'GENCON.NS', 'GENESYS.NS', 'GENSOL.NS', 'GENUSPAPER.NS', 'GENUSPOWER.NS', 'GEOJITFSL.NS', 'GEPIL.NS', 'GESHIP.NS', 'GET&D.NS', 'GFLLIMITED.NS', 'GHCL.NS', 'GHCLTEXTIL.NS', 'GICHSGFIN.NS', 'GICRE.NS', 'GILLANDERS.NS', 'GINNIFILA.NS', 'GIPCL.NS', 'GKWLIMITED.NS', 'GLAND.NS', 'GLENMARK.NS', 'GLFL.NS', 'GLOBAL.NS', 'GLOBALVECT.NS', 'GLOBE.NS', 'GLOBUSSPR.NS', 'GLS.NS', 'GMBREW.NS', 'GMDCLTD.NS', 'GMMPFAUDLR.NS', 'GMRINFRA.NS', 'GMRP&UI.NS', 'GNA.NS', 'GNFC.NS', 'GOACARBON.NS', 'GOCLCORP.NS', 'GOCOLORS.NS', 'GODHA.NS', 'GODREJAGRO.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GOENKA.NS', 'GOKEX.NS', 'GOKUL.NS', 'GOKULAGRO.NS', 'GOLDENTOBC.NS', 'GOLDIAM.NS', 'GOLDTECH.NS', 'GOODLUCK.NS', 'GOYALALUM.NS', 'GPIL.NS', 'GPPL.NS', 'GPTINFRA.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GRAVITA.NS', 'GREAVESCOT.NS', 'GREENLAM.NS', 'GREENPANEL.NS', 'GREENPLY.NS', 'GREENPOWER.NS', 'GRINFRA.NS', 'GRMOVER.NS', 'GROBTEA.NS', 'GRSE.NS', 'GRWRHITECH.NS', 'GSFC.NS', 'GSLSU.NS', 'GSPL.NS', 'GSS.NS', 'GTECJAINX.NS', 'GTL.NS', 'GTLINFRA.NS', 'GTPL.NS', 'GUFICBIO.NS', 'GUJALKALI.NS', 'GUJAPOLLO.NS', 'GUJGASLTD.NS', 'GUJRAFFIA.NS', 'GULFOILLUB.NS', 'GULFPETRO.NS', 'GULPOLY.NS', 'GVKPIL.NS', 'GVPTECH.NS', 'HAPPSTMNDS.NS', 'HAPPYFORGE.NS', 'HARDWYN.NS', 'HARIOMPIPE.NS', 'HARRMALAYA.NS', 'HARSHA.NS', 'HATHWAY.NS', 'HATSUN.NS', 'HAVELLS.NS', 'HAVISHA.NS', 'HBLPOWER.NS', 'HBSL.NS', 'HCC.NS', 'HCG.NS', 'HCL-INSYS.NS', 'HCLTECH.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'HEADSUP.NS', 'HECPROJECT.NS', 'HEG.NS', 'HEIDELBERG.NS', 'HEMIPROP.NS', 'HERANBA.NS', 'HERCULES.NS', 'HERITGFOOD.NS', 'HESTERBIO.NS', 'HEUBACHIND.NS', 'HEXATRADEX.NS', 'HFCL.NS', 'HGINFRA.NS', 'HGS.NS', 'HIKAL.NS', 'HILTON.NS', 'HIMATSEIDE.NS', 'HINDALCO.NS', 'HINDCOMPOS.NS', 'HINDCON.NS', 'HINDCOPPER.NS', 'HINDMOTORS.NS', 'HINDOILEXP.NS', 'HINDPETRO.NS', 'HINDWAREAP.NS', 'HINDZINC.NS', 'HIRECT.NS', 'HISARMETAL.NS', 'HITECH.NS', 'HITECHCORP.NS', 'HITECHGEAR.NS', 'HLEGLAS.NS', 'HLVLTD.NS', 'HMAAGRO.NS', 'HMT.NS', 'HMVL.NS', 'HNDFDS.NS', 'HOMEFIRST.NS', 'HONASA.NS', 'HOVS.NS', 'HPAL.NS', 'HPIL.NS', 'HPL.NS', 'HSCL.NS', 'HTMEDIA.NS', 'HUBTOWN.NS', 'HUDCO.NS', 'HUHTAMAKI.NS', 'HYBRIDFIN.NS', 'IBREALEST.NS', 'IBULHSGFIN.NS', 'ICDSLTD.NS', 'ICEMAKE.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'ICIL.NS', 'IDBI.NS', 'IDEA.NS', 'IDEAFORGE.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IEL.NS', 'IEX.NS', 'IFBAGRO.NS', 'IFBIND.NS', 'IFCI.NS', 'IFGLEXPOR.NS', 'IGARASHI.NS', 'IGL.NS', 'IGPL.NS', 'IIFL.NS', 'IIFLSEC.NS', 'IITL.NS', 'IKIO.NS', 'IL&FSENGG.NS', 'IL&FSTRANS.NS', 'IMAGICAA.NS', 'IMFA.NS', 'IMPAL.NS', 'IMPEXFERRO.NS', 'INCREDIBLE.NS', 'INDBANK.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INDIAGLYCO.NS', 'INDIANB.NS', 'INDIANCARD.NS', 'INDIANHUME.NS', 'INDIASHLTR.NS', 'INDIGOPNTS.NS', 'INDNIPPON.NS', 'INDOAMIN.NS', 'INDOBORAX.NS', 'INDOCO.NS', 'INDORAMA.NS', 'INDOSTAR.NS', 'INDOTECH.NS', 'INDOTHAI.NS', 'INDOWIND.NS', 'INDRAMEDCO.NS', 'INDSWFTLAB.NS', 'INDSWFTLTD.NS', 'INDTERRAIN.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'INFOBEAN.NS', 'INFOMEDIA.NS', 'INFY.NS', 'INNOVACAP.NS', 'INOXGREEN.NS', 'INOXINDIA.NS', 'INOXWIND.NS', 'INSECTICID.NS', 'INSPIRISYS.NS', 'INTELLECT.NS', 'INTENTECH.NS', 'INTLCONV.NS', 'INVENTURE.NS', 'IOB.NS', 'IOC.NS', 'IOLCP.NS', 'IONEXCHANG.NS', 'IPCALAB.NS', 'IPL.NS', 'IRB.NS', 'IRCON.NS', 'IRCTC.NS', 'IREDA.NS', 'IRFC.NS', 'IRIS.NS', 'IRISDOREME.NS', 'IRMENERGY.NS', 'ISEC.NS', 'ISFT.NS', 'ISGEC.NS', 'ISMTLTD.NS', 'ITC.NS', 'ITDC.NS', 'ITDCEM.NS', 'ITI.NS', 'IVC.NS', 'IVP.NS', 'IZMO.NS', 'J&KBANK.NS', 'JAGRAN.NS', 'JAGSNPHARM.NS', 'JAIBALAJI.NS', 'JAICORPLTD.NS', 'JAIPURKURT.NS', 'JAMNAAUTO.NS', 'JASH.NS', 'JAYAGROGN.NS', 'JAYBARMARU.NS', 'JAYNECOIND.NS', 'JAYSREETEA.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JCHAC.NS', 'JETAIRWAYS.NS', 'JETFREIGHT.NS', 'JHS.NS', 'JINDALPHOT.NS', 'JINDALPOLY.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JINDRILL.NS', 'JINDWORLD.NS', 'JIOFIN.NS', 'JISLDVREQS.NS', 'JISLJALEQS.NS', 'JITFINFRA.NS', 'JKIL.NS', 'JKLAKSHMI.NS', 'JKPAPER.NS', 'JKTYRE.NS', 'JLHL.NS', 'JMA.NS', 'JMFINANCIL.NS', 'JOCIL.NS', 'JPASSOCIAT.NS', 'JPOLYINVST.NS', 'JPPOWER.NS', 'JSL.NS', 'JSWENERGY.NS', 'JSWINFRA.NS', 'JSWSTEEL.NS', 'JTEKTINDIA.NS', 'JTLIND.NS', 'JUBLFOOD.NS', 'JUBLINDS.NS', 'JUBLINGREA.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'JWL.NS', 'JYOTHYLAB.NS', 'JYOTISTRUC.NS', 'KABRAEXTRU.NS', 'KAJARIACER.NS', 'KAKATCEM.NS', 'KALAMANDIR.NS', 'KALYANIFRG.NS', 'KALYANKJIL.NS', 'KAMATHOTEL.NS', 'KAMDHENU.NS', 'KAMOPAINTS.NS', 'KANANIIND.NS', 'KANORICHEM.NS', 'KANPRPLA.NS', 'KANSAINER.NS', 'KAPSTON.NS', 'KARMAENG.NS', 'KARURVYSYA.NS', 'KAUSHALYA.NS', 'KAVVERITEL.NS', 'KAYA.NS', 'KBCGLOBAL.NS', 'KCP.NS', 'KCPSUGIND.NS', 'KEC.NS', 'KECL.NS', 'KEEPLEARN.NS', 'KELLTONTEC.NS', 'KERNEX.NS', 'KESORAMIND.NS', 'KEYFINSERV.NS', 'KFINTECH.NS', 'KHADIM.NS', 'KHAICHEM.NS', 'KHAITANLTD.NS', 'KHANDSE.NS', 'KILITCH.NS', 'KIOCL.NS', 'KIRIINDUS.NS', 'KIRLOSBROS.NS', 'KIRLOSENG.NS', 'KIRLPNU.NS', 'KITEX.NS', 'KKCL.NS', 'KMSUGAR.NS', 'KNRCON.NS', 'KOHINOOR.NS', 'KOKUYOCMLN.NS', 'KOLTEPATIL.NS', 'KOPRAN.NS', 'KOTAKBANK.NS', 'KOTARISUG.NS', 'KOTHARIPET.NS', 'KOTHARIPRO.NS', 'KPIGREEN.NS', 'KPIL.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'KRBL.NS', 'KREBSBIO.NS', 'KRIDHANINF.NS', 'KRISHANA.NS', 'KRITI.NS', 'KRITIKA.NS', 'KRITINUT.NS', 'KRSNAA.NS', 'KSCL.NS', 'KSHITIJPOL.NS', 'KSL.NS', 'KSOLVES.NS', 'KTKBANK.NS', 'KUANTUM.NS', 'L&TFH.NS', 'LAGNAM.NS', 'LAKPRE.NS', 'LAL.NS', 'LAMBODHARA.NS', 'LANDMARK.NS', 'LAOPALA.NS', 'LASA.NS', 'LATENTVIEW.NS', 'LATTEYS.NS', 'LAURUSLABS.NS', 'LAXMICOT.NS', 'LCCINFOTEC.NS', 'LEMONTREE.NS', 'LEXUS.NS', 'LFIC.NS', 'LGBBROSLTD.NS', 'LGBFORGE.NS', 'LGHL.NS', 'LIBAS.NS', 'LIBERTSHOE.NS', 'LICHSGFIN.NS', 'LICI.NS', 'LIKHITHA.NS', 'LINC.NS', 'LINCOLN.NS', 'LLOYDSENGG.NS', 'LLOYDSME.NS', 'LODHA.NS', 'LOKESHMACH.NS', 'LORDSCHLO.NS', 'LOTUSEYE.NS', 'LOVABLE.NS', 'LOYALTEX.NS', 'LPDC.NS', 'LTFOODS.NS', 'LUMAXTECH.NS', 'LUPIN.NS', 'LUXIND.NS', 'LXCHEM.NS', 'LYKALABS.NS', 'LYPSAGEMS.NS', 'M&M.NS', 'M&MFIN.NS', 'MAANALU.NS', 'MACPOWER.NS', 'MADHAV.NS', 'MADHUCON.NS', 'MADRASFERT.NS', 'MAGADSUGAR.NS', 'MAGNUM.NS', 'MAHABANK.NS', 'MAHAPEXLTD.NS', 'MAHASTEEL.NS', 'MAHEPC.NS', 'MAHESHWARI.NS', 'MAHLIFE.NS', 'MAHLOG.NS', 'MAHSEAMLES.NS', 'MAITHANALL.NS', 'MALLCOM.NS', 'MALUPAPER.NS', 'MANAKALUCO.NS', 'MANAKCOAT.NS', 'MANAKSIA.NS', 'MANAKSTEEL.NS', 'MANALIPETC.NS', 'MANAPPURAM.NS', 'MANGALAM.NS', 'MANGCHEFER.NS', 'MANGLMCEM.NS', 'MANINDS.NS', 'MANINFRA.NS', 'MANOMAY.NS', 'MANORG.NS', 'MANUGRAPH.NS', 'MANYAVAR.NS', 'MARALOVER.NS', 'MARATHON.NS', 'MARICO.NS', 'MARINE.NS', 'MARKSANS.NS', 'MARSHALL.NS', 'MASFIN.NS', 'MASKINVEST.NS', 'MATRIMONY.NS', 'MAWANASUG.NS', 'MAXESTATES.NS', 'MAXHEALTH.NS', 'MAXIND.NS', 'MAYURUNIQ.NS', 'MAZDA.NS', 'MBAPL.NS', 'MBECL.NS', 'MBLINFRA.NS', 'MCDOWELL-N.NS', 'MCL.NS', 'MCLEODRUSS.NS', 'MEDANTA.NS', 'MEDICAMEQ.NS', 'MEDICO.NS', 'MEDPLUS.NS', 'MEGASOFT.NS', 'MEGASTAR.NS', 'MELSTAR.NS', 'MENONBE.NS', 'MEP.NS', 'METALFORGE.NS', 'METROBRAND.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MGEL.NS', 'MGL.NS', 'MHLXMIRU.NS', 'MHRIL.NS', 'MICEL.NS', 'MIDHANI.NS', 'MINDACORP.NS', 'MINDTECK.NS', 'MIRCELECTR.NS', 'MIRZAINT.NS', 'MITCON.NS', 'MITTAL.NS', 'MKPL.NS', 'MMFL.NS', 'MMP.NS', 'MMTC.NS', 'MODIRUBBER.NS', 'MODISONLTD.NS', 'MOHITIND.NS', 'MOIL.NS', 'MOKSH.NS', 'MOL.NS', 'MOLDTECH.NS', 'MOLDTKPAC.NS', 'MONARCH.NS', 'MONTECARLO.NS', 'MORARJEE.NS', 'MOREPENLAB.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'MOTISONS.NS', 'MOTOGENFIN.NS', 'MPSLTD.NS', 'MRO-TEK.NS', 'MRPL.NS', 'MSPL.NS', 'MSTCLTD.NS', 'MSUMI.NS', 'MTEDUCARE.NS', 'MTNL.NS', 'MUFIN.NS', 'MUFTI.NS', 'MUKANDLTD.NS', 'MUKTAARTS.NS', 'MUNJALAU.NS', 'MUNJALSHOW.NS', 'MURUDCERA.NS', 'MUTHOOTCAP.NS', 'MUTHOOTFIN.NS', 'MUTHOOTMF.NS', 'MVGJL.NS', 'NACLIND.NS', 'NAGAFERT.NS', 'NAGREEKCAP.NS', 'NAGREEKEXP.NS', 'NAHARCAP.NS', 'NAHARINDUS.NS', 'NAHARPOLY.NS', 'NAHARSPING.NS', 'NAM-INDIA.NS', 'NARMADA.NS', 'NATCOPHARM.NS', 'NATHBIOGEN.NS', 'NATIONALUM.NS', 'NAVA.NS', 'NAVKARCORP.NS', 'NAVNETEDUL.NS', 'NAZARA.NS', 'NBCC.NS', 'NBIFIN.NS', 'NCC.NS', 'NCLIND.NS', 'NDL.NS', 'NDLVENTURE.NS', 'NDRAUTO.NS', 'NDTV.NS', 'NECCLTD.NS', 'NECLIFE.NS', 'NELCAST.NS', 'NELCO.NS', 'NEOGEN.NS', 'NESCO.NS', 'NETWEB.NS', 'NETWORK18.NS', 'NEWGEN.NS', 'NEXTMEDIA.NS', 'NFL.NS', 'NGIL.NS', 'NH.NS', 'NHPC.NS', 'NIACL.NS', 'NIBL.NS', 'NIITLTD.NS', 'NIITMTS.NS', 'NILAINFRA.NS', 'NILASPACES.NS', 'NINSYS.NS', 'NIPPOBATRY.NS', 'NIRAJ.NS', 'NITCO.NS', 'NITINSPIN.NS', 'NITIRAJ.NS', 'NKIND.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NOCIL.NS', 'NOIDATOLL.NS', 'NORBTEAEXP.NS', 'NRAIL.NS', 'NRBBEARING.NS', 'NRL.NS', 'NSLNISP.NS', 'NTPC.NS', 'NUCLEUS.NS', 'NURECA.NS', 'NUVOCO.NS', 'NYKAA.NS', 'OAL.NS', 'OBCL.NS', 'OBEROIRLTY.NS', 'OCCL.NS', 'OIL.NS', 'OILCOUNTUB.NS', 'OLECTRA.NS', 'OMAXAUTO.NS', 'OMAXE.NS', 'OMINFRAL.NS', 'OMKARCHEM.NS', 'ONELIFECAP.NS', 'ONEPOINT.NS', 'ONGC.NS', 'ONMOBILE.NS', 'ONWARDTEC.NS', 'OPTIEMUS.NS', 'ORBTEXP.NS', 'ORCHPHARMA.NS', 'ORICONENT.NS', 'ORIENTALTL.NS', 'ORIENTBELL.NS', 'ORIENTCEM.NS', 'ORIENTCER.NS', 'ORIENTELEC.NS', 'ORIENTHOT.NS', 'ORIENTLTD.NS', 'ORIENTPPR.NS', 'ORTINLAB.NS', 'OSIAHYPER.NS', 'OSWALAGRO.NS', 'OSWALGREEN.NS', 'OSWALSEEDS.NS', 'PAISALO.NS', 'PAKKA.NS', 'PALASHSECU.NS', 'PALREDTEC.NS', 'PANACEABIO.NS', 'PANACHE.NS', 'PANAMAPET.NS', 'PANSARI.NS', 'PAR.NS', 'PARACABLES.NS', 'PARADEEP.NS', 'PARAGMILK.NS', 'PARAS.NS', 'PARASPETRO.NS', 'PARSVNATH.NS', 'PASUPTAC.NS', 'PATANJALI.NS', 'PATELENG.NS', 'PATINTLOG.NS', 'PAVNAIND.NS', 'PAYTM.NS', 'PCBL.NS', 'PCJEWELLER.NS', 'PDMJEPAPER.NS', 'PDSL.NS', 'PEARLPOLY.NS', 'PEL.NS', 'PENIND.NS', 'PENINLAND.NS', 'PETRONET.NS', 'PFC.NS', 'PFOCUS.NS', 'PFS.NS', 'PGIL.NS', 'PIGL.NS', 'PILITA.NS', 'PIONEEREMB.NS', 'PITTIENG.NS', 'PIXTRANS.NS', 'PKTEA.NS', 'PLASTIBLEN.NS', 'PLAZACABLE.NS', 'PNB.NS', 'PNBGILTS.NS', 'PNBHOUSING.NS', 'PNC.NS', 'PNCINFRA.NS', 'POCL.NS', 'PODDARHOUS.NS', 'PODDARMENT.NS', 'POKARNA.NS', 'POLICYBZR.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'PONNIERODE.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'PPAP.NS', 'PPL.NS', 'PPLPHARMA.NS', 'PRAENG.NS', 'PRAJIND.NS', 'PRAKASH.NS', 'PRAKASHSTL.NS', 'PRAXIS.NS', 'PRECAM.NS', 'PRECOT.NS', 'PRECWIRE.NS', 'PREMEXPLN.NS', 'PREMIER.NS', 'PREMIERPOL.NS', 'PRESTIGE.NS', 'PRICOLLTD.NS', 'PRIMESECU.NS', 'PRINCEPIPE.NS', 'PRITI.NS', 'PRITIKAUTO.NS', 'PRIVISCL.NS', 'PROZONER.NS', 'PRSMJOHNSN.NS', 'PRUDENT.NS', 'PRUDMOULI.NS', 'PSB.NS', 'PSPPROJECT.NS', 'PTC.NS', 'PTL.NS', 'PUNJABCHEM.NS', 'PURVA.NS', 'PVP.NS', 'PVRINOX.NS', 'PYRAMID.NS', 'QUESS.NS', 'QUICKHEAL.NS', 'RACE.NS', 'RADAAN.NS', 'RADHIKAJWE.NS', 'RADIANTCMS.NS', 'RADICO.NS', 'RADIOCITY.NS', 'RAILTEL.NS', 'RAIN.NS', 'RAINBOW.NS', 'RAJESHEXPO.NS', 'RAJMET.NS', 'RAJRATAN.NS', 'RAJRILTD.NS', 'RAJSREESUG.NS', 'RAJTV.NS', 'RALLIS.NS', 'RAMANEWS.NS', 'RAMAPHO.NS', 'RAMASTEEL.NS', 'RAMCOCEM.NS', 'RAMCOIND.NS', 'RAMCOSYS.NS', 'RAMKY.NS', 'RAMRAT.NS', 'RANASUG.NS', 'RANEENGINE.NS', 'RANEHOLDIN.NS', 'RATEGAIN.NS', 'RATNAVEER.NS', 'RAYMOND.NS', 'RBA.NS', 'RBL.NS', 'RBLBANK.NS', 'RBZJEWEL.NS', 'RCF.NS', 'RECLTD.NS', 'REDINGTON.NS', 'REDTAPE.NS', 'REFEX.NS', 'REGENCERAM.NS', 'RELAXO.NS', 'RELCAPITAL.NS', 'RELCHEMQ.NS', 'RELIGARE.NS', 'RELINFRA.NS', 'REMSONSIND.NS', 'RENUKA.NS', 'REPCOHOME.NS', 'REPL.NS', 'REPRO.NS', 'RESPONIND.NS', 'RGL.NS', 'RHFL.NS', 'RHIM.NS', 'RHL.NS', 'RICOAUTO.NS', 'RIIL.NS', 'RISHABH.NS', 'RITCO.NS', 'RITES.NS', 'RKDL.NS', 'RKEC.NS', 'RKFORGE.NS', 'RML.NS', 'ROHLTD.NS', 'ROLLT.NS', 'ROML.NS', 'ROSSARI.NS', 'ROSSELLIND.NS', 'ROTO.NS', 'ROUTE.NS', 'RPGLIFE.NS', 'RPOWER.NS', 'RPPINFRA.NS', 'RPPL.NS', 'RPSGVENT.NS', 'RRKABEL.NS', 'RSSOFTWARE.NS', 'RSWM.NS', 'RSYSTEMS.NS', 'RTNINDIA.NS', 'RTNPOWER.NS', 'RUBYMILLS.NS', 'RUCHINFRA.NS', 'RUCHIRA.NS', 'RUPA.NS', 'RUSHIL.NS', 'RUSTOMJEE.NS', 'RVHL.NS', 'RVNL.NS', 'S&SPOWER.NS', 'SABEVENTS.NS', 'SABTN.NS', 'SADBHAV.NS', 'SADBHIN.NS', 'SADHNANIQ.NS', 'SAFARI.NS', 'SAGARDEEP.NS', 'SAGCEM.NS', 'SAH.NS', 'SAHYADRI.NS', 'SAIL.NS', 'SAKAR.NS', 'SAKHTISUG.NS', 'SAKSOFT.NS', 'SAKUMA.NS', 'SALASAR.NS', 'SALONA.NS', 'SALSTEEL.NS', 'SALZERELEC.NS', 'SAMBHAAV.NS', 'SAMHI.NS', 'SAMPANN.NS', 'SANCO.NS', 'SANDESH.NS', 'SANDHAR.NS', 'SANGAMIND.NS', 'SANGHIIND.NS', 'SANGHVIMOV.NS', 'SANGINITA.NS', 'SANSERA.NS', 'SAPPHIRE.NS', 'SARDAEN.NS', 'SAREGAMA.NS', 'SARLAPOLY.NS', 'SARVESHWAR.NS', 'SASKEN.NS', 'SASTASUNDR.NS', 'SATIA.NS', 'SATIN.NS', 'SATINDLTD.NS', 'SBC.NS', 'SBCL.NS', 'SBFC.NS', 'SBGLP.NS', 'SBICARD.NS', 'SBILIFE.NS', 'SBIN.NS', 'SCHAND.NS', 'SCHNEIDER.NS', 'SCI.NS', 'SCPL.NS', 'SDBL.NS', 'SEAMECLTD.NS', 'SECMARK.NS', 'SECURCRED.NS', 'SECURKLOUD.NS', 'SEJALLTD.NS', 'SELAN.NS', 'SELMC.NS', 'SENCO.NS', 'SEPC.NS', 'SEQUENT.NS', 'SERVOTECH.NS', 'SESHAPAPER.NS', 'SETCO.NS', 'SEYAIND.NS', 'SFL.NS', 'SGIL.NS', 'SGL.NS', 'SHAH.NS', 'SHAHALLOYS.NS', 'SHAILY.NS', 'SHAKTIPUMP.NS', 'SHALBY.NS', 'SHALPAINTS.NS', 'SHANKARA.NS', 'SHANTI.NS', 'SHANTIGEAR.NS', 'SHARDACROP.NS', 'SHARDAMOTR.NS', 'SHAREINDIA.NS', 'SHEMAROO.NS', 'SHILPAMED.NS', 'SHIVALIK.NS', 'SHIVAMAUTO.NS', 'SHIVAMILLS.NS', 'SHIVATEX.NS', 'SHK.NS', 'SHOPERSTOP.NS', 'SHRADHA.NS', 'SHREDIGCEM.NS', 'SHREEPUSHK.NS', 'SHREERAMA.NS', 'SHRENIK.NS', 'SHREYANIND.NS', 'SHREYAS.NS', 'SHRIPISTON.NS', 'SHRIRAMPPS.NS', 'SHYAMCENT.NS', 'SHYAMMETL.NS', 'SHYAMTEL.NS', 'SICALLOG.NS', 'SIGACHI.NS', 'SIGIND.NS', 'SIGMA.NS', 'SIGNATURE.NS', 'SIKKO.NS', 'SIL.NS', 'SILGO.NS', 'SILINV.NS', 'SILLYMONKS.NS', 'SILVERTUC.NS', 'SIMBHALS.NS', 'SIMPLEXINF.NS', 'SINDHUTRAD.NS', 'SINTERCOM.NS', 'SIRCA.NS', 'SIS.NS', 'SITINET.NS', 'SIYSIL.NS', 'SJS.NS', 'SJVN.NS', 'SKIPPER.NS', 'SKMEGGPROD.NS', 'SKYGOLD.NS', 'SMARTLINK.NS', 'SMCGLOBAL.NS', 'SMLISUZU.NS', 'SMLT.NS', 'SMSLIFE.NS', 'SMSPHARMA.NS', 'SNOWMAN.NS', 'SOBHA.NS', 'SOFTTECH.NS', 'SOLARA.NS', 'SOMANYCERA.NS', 'SOMATEX.NS', 'SOMICONVEY.NS', 'SONACOMS.NS', 'SONAMLTD.NS', 'SONATSOFTW.NS', 'SOTL.NS', 'SOUTHBANK.NS', 'SOUTHWEST.NS', 'SPAL.NS', 'SPANDANA.NS', 'SPARC.NS', 'SPCENET.NS', 'SPECIALITY.NS', 'SPENCERS.NS', 'SPENTEX.NS', 'SPIC.NS', 'SPLIL.NS', 'SPLPETRO.NS', 'SPMLINFRA.NS', 'SPORTKING.NS', 'SPTL.NS', 'SPYL.NS', 'SREEL.NS', 'SRGHFL.NS', 'SRHHYPOLTD.NS', 'SRPL.NS', 'SSWL.NS', 'STAR.NS', 'STARCEMENT.NS', 'STARHEALTH.NS', 'STARPAPER.NS', 'STARTECK.NS', 'STCINDIA.NS', 'STEELCAS.NS', 'STEELCITY.NS', 'STEELXIND.NS', 'STEL.NS', 'STERTOOLS.NS', 'STLTECH.NS', 'STOVEKRAFT.NS', 'STYLAMIND.NS', 'STYRENIX.NS', 'SUBEXLTD.NS', 'SUBROS.NS', 'SUDARSCHEM.NS', 'SUKHJITS.NS', 'SULA.NS', 'SUMICHEM.NS', 'SUMIT.NS', 'SUMMITSEC.NS', 'SUNCLAY.NS', 'SUNDARAM.NS', 'SUNDARMHLD.NS', 'SUNDRMBRAK.NS', 'SUNDRMFAST.NS', 'SUNFLAG.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SUNTV.NS', 'SUPERHOUSE.NS', 'SUPERSPIN.NS', 'SUPRAJIT.NS', 'SUPREMEENG.NS', 'SUPREMEINF.NS', 'SUPRIYA.NS', 'SURAJEST.NS', 'SURANASOL.NS', 'SURANAT&P.NS', 'SURYALAXMI.NS', 'SURYAROSNI.NS', 'SURYODAY.NS', 'SUTLEJTEX.NS', 'SUULD.NS', 'SUVEN.NS', 'SUVENPHAR.NS', 'SUVIDHAA.NS', 'SUZLON.NS', 'SVLL.NS', 'SVPGLOB.NS', 'SWANENERGY.NS', 'SWELECTES.NS', 'SWSOLAR.NS', 'SYMPHONY.NS', 'SYNCOMF.NS', 'SYNGENE.NS', 'SYRMA.NS', 'TAINWALCHM.NS', 'TAJGVK.NS', 'TAKE.NS', 'TALBROAUTO.NS', 'TANLA.NS', 'TARAPUR.NS', 'TARC.NS', 'TARMAT.NS', 'TARSONS.NS', 'TATACHEM.NS', 'TATACOFFEE.NS', 'TATACOMM.NS', 'TATACONSUM.NS', 'TATAMETALI.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TATATECH.NS', 'TATVA.NS', 'TBZ.NS', 'TCI.NS', 'TCIEXP.NS', 'TCLCONS.NS', 'TCNSBRANDS.NS', 'TDPOWERSYS.NS', 'TECHIN.NS', 'TECHM.NS', 'TECHNOE.NS', 'TECILCHEM.NS', 'TEGA.NS', 'TEJASNET.NS', 'TEMBO.NS', 'TERASOFT.NS', 'TEXINFRA.NS', 'TEXMOPIPES.NS', 'TEXRAIL.NS', 'TFCILTD.NS', 'TFL.NS', 'TGBHOTELS.NS', 'THANGAMAYL.NS', 'THEINVEST.NS', 'THEJO.NS', 'THEMISMED.NS', 'THOMASCOOK.NS', 'THOMASCOTT.NS', 'THYROCARE.NS', 'TI.NS', 'TIDEWATER.NS', 'TIJARIA.NS', 'TIL.NS', 'TIMESGTY.NS', 'TIMETECHNO.NS', 'TINPLATE.NS', 'TIPSFILMS.NS', 'TIPSINDLTD.NS', 'TIRUMALCHM.NS', 'TIRUPATIFL.NS', 'TITAGARH.NS', 'TMB.NS', 'TNPETRO.NS', 'TNPL.NS', 'TNTELE.NS', 'TOKYOPLAST.NS', 'TORNTPOWER.NS', 'TOTAL.NS', 'TOUCHWOOD.NS', 'TPHQ.NS', 'TPLPLASTEH.NS', 'TRACXN.NS', 'TREEHOUSE.NS', 'TREJHARA.NS', 'TREL.NS', 'TRF.NS', 'TRIDENT.NS', 'TRIGYN.NS', 'TRIL.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TRU.NS', 'TTKHLTCARE.NS', 'TTKPRESTIG.NS', 'TTL.NS', 'TTML.NS', 'TV18BRDCST.NS', 'TVSELECT.NS', 'TVSSCS.NS', 'TVTODAY.NS', 'TVVISION.NS', 'UBL.NS', 'UCAL.NS', 'UCOBANK.NS', 'UDS.NS', 'UFLEX.NS', 'UFO.NS', 'UGARSUGAR.NS', 'UGROCAP.NS', 'UJJIVAN.NS', 'UJJIVANSFB.NS', 'UMAEXPORTS.NS', 'UMANGDAIRY.NS', 'UMESLTD.NS', 'UNICHEMLAB.NS', 'UNIDT.NS', 'UNIENTER.NS', 'UNIINFO.NS', 'UNIONBANK.NS', 'UNIPARTS.NS', 'UNITECH.NS', 'UNITEDPOLY.NS', 'UNITEDTEA.NS', 'UNIVAFOODS.NS', 'UNIVASTU.NS', 'UNIVCABLES.NS', 'UNIVPHOTO.NS', 'UNOMINDA.NS', 'UPL.NS', 'URAVI.NS', 'URJA.NS', 'USHAMART.NS', 'USK.NS', 'UTIAMC.NS', 'UTKARSHBNK.NS', 'UTTAMSUGAR.NS', 'V2RETAIL.NS', 'VAIBHAVGBL.NS', 'VAISHALI.NS', 'VAKRANGEE.NS', 'VALIANTLAB.NS', 'VALIANTORG.NS', 'VARDHACRLC.NS', 'VARDMNPOLY.NS', 'VARROC.NS', 'VASCONEQ.NS', 'VASWANI.NS', 'VBL.NS', 'VCL.NS', 'VEDL.NS', 'VENUSPIPES.NS', 'VENUSREM.NS', 'VERANDA.NS', 'VERTOZ.NS', 'VETO.NS', 'VGUARD.NS', 'VIDHIING.NS', 'VIJAYA.NS', 'VIJIFIN.NS', 'VIKASECO.NS', 'VIKASLIFE.NS', 'VIMTALABS.NS', 'VINATIORGA.NS', 'VINEETLAB.NS', 'VINNY.NS', 'VINYLINDIA.NS', 'VIPCLOTHNG.NS', 'VIPIND.NS', 'VIPULLTD.NS', 'VIRINCHI.NS', 'VISAKAIND.NS', 'VISESHINFO.NS', 'VISHNU.NS', 'VISHWARAJ.NS', 'VIVIDHA.NS', 'VLEGOV.NS', 'VLSFINANCE.NS', 'VOLTAS.NS', 'VPRPL.NS', 'VRLLOG.NS', 'VSSL.NS', 'VTL.NS', 'WABAG.NS', 'WALCHANNAG.NS', 'WANBURY.NS', 'WEALTH.NS', 'WEBELSOLAR.NS', 'WEIZMANIND.NS', 'WEL.NS', 'WELCORP.NS', 'WELENT.NS', 'WELINV.NS', 'WELSPUNLIV.NS', 'WESTLIFE.NS', 'WEWIN.NS', 'WHEELS.NS', 'WHIRLPOOL.NS', 'WILLAMAGOR.NS', 'WINDLAS.NS', 'WINDMACHIN.NS', 'WINSOME.NS', 'WIPL.NS', 'WIPRO.NS', 'WOCKPHARMA.NS', 'WONDERLA.NS', 'WORTH.NS', 'WSI.NS', 'WSTCSTPAPR.NS', 'XCHANGING.NS', 'XELPMOC.NS', 'XPROINDIA.NS', 'YAARI.NS', 'YASHO.NS', 'YATHARTH.NS', 'YATRA.NS', 'YESBANK.NS', 'YUKEN.NS', 'ZAGGLE.NS', 'ZEEL.NS', 'ZEELEARN.NS', 'ZEEMEDIA.NS', 'ZENITHEXPO.NS', 'ZENITHSTL.NS', 'ZENSARTECH.NS', 'ZENTEC.NS', 'ZIMLAB.NS', 'ZODIAC.NS', 'ZODIACLOTH.NS', 'ZOMATO.NS', 'ZOTA.NS', 'ZUARI.NS', 'ZUARIIND.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS']

# Initialize lists to store selected stocks, their volumes, market caps, and entry prices
selected_stocks = []
selected_stocks_volume = []
selected_stocks_market_cap = []
selected_stocks_entry_price = []

for stock in nse_stocks:
    print(f"Processing {stock}...")
    data = fetch_data(stock)
    market_cap = fetch_market_cap(stock)

    if not isinstance(data.index, pd.DatetimeIndex):
        data.index = pd.to_datetime(data.index)

    for date in data.index.normalize().unique():
        daily_data = data[data.index.normalize() == date]
        first_interval = daily_data.between_time('09:15', '09:20')
        if not first_interval.empty:
            open_equals_low = first_interval.iloc[0]['Open'] == first_interval['Low'].min()
            if open_equals_low:
                entry_price = first_interval.iloc[0]['Close']  # Assuming entry at the close of the interval
                selected_stocks.append((stock, date.date()))
                selected_stocks_volume.append((stock, date.date(), first_interval['Volume'].sum()))
                selected_stocks_market_cap.append((stock, date.date(), market_cap))
                selected_stocks_entry_price.append((stock, date.date(), entry_price))

# Create DataFrames
df_volume = pd.DataFrame(selected_stocks_volume, columns=['Stock', 'Date', 'Volume'])
df_market_cap = pd.DataFrame(selected_stocks_market_cap, columns=['Stock', 'Date', 'MarketCap'])
df_entry_price = pd.DataFrame(selected_stocks_entry_price, columns=['Stock', 'Date', 'EntryPrice'])

# Merge DataFrames
df_merged = pd.merge(df_volume, df_market_cap, on=['Stock', 'Date'], how='inner')
df_merged = pd.merge(df_merged, df_entry_price, on=['Stock', 'Date'], how='inner')

# Get today's date for the file name
today_date = datetime.today().strftime('%Y-%m-%d')

# Export the DataFrame to an Excel file with today's date in the file name
file_name = f'selected_stockss_volume_and_marketcap_{today_date}.xlsx'
df_merged.to_excel(file_name, index=False)

# Output the selected stocks
print("Selected Stocks:")
for stock, date in selected_stocks:
    print(f"{stock} on {date} - Entry Price: {df_merged.loc[df_merged['Stock'] == stock, 'EntryPrice'].iloc[0]}")
# Out:
# /usr/local/lib/python3.10/dist-packages/yfinance/base.py:48: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _empty_series = pd.Series()
# Processing 20MICRONS.NS...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Processing 21STCENMGM.NS...
# [*********************100%%**********************]  1 of 1 completed
# Processing 360ONE.NS...
# [*********************100%%**********************]  1 of 1 completed
# Processing 3IINFOLTD.NS...
# Processing 3PLAND.NS...
# [*********************100%%**********************]  1 of 1 completed
# Processing 5PAISA.NS...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Processing 63MOONS.NS...
# Processing A2ZINFRA.NS...
# ...

# %% [markdown]
# #For finding selected stocks with excel (modified)

# %% [markdown]
# This code will process the stocks from the NSE list, identify the ones meeting the specified criteria, and then export two Excel files: one with all the selected stocks and their details, and another with the top 25 stocks sorted by volume.

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime

def fetch_data(stock):
    # Fetch historical data for the stock for today with 5-minute intervals
    data = yf.download(stock, period="1d", interval="5m")
    return data

# List of NSE stocks
nse_stocks = ['20MICRONS.NS', '21STCENMGM.NS', '360ONE.NS', '3IINFOLTD.NS', '3PLAND.NS', '5PAISA.NS', '63MOONS.NS', 'A2ZINFRA.NS', 'AAATECH.NS', 'AAKASH.NS', 'AAREYDRUGS.NS', 'AARON.NS', 'AARTECH.NS', 'AARTIDRUGS.NS', 'AARTIIND.NS', 'AARTIPHARM.NS', 'AARTISURF.NS', 'AARVEEDEN.NS', 'AARVI.NS', 'AAVAS.NS', 'ABAN.NS', 'ABCAPITAL.NS', 'ABFRL.NS', 'ABMINTLLTD.NS', 'ABSLAMC.NS', 'ACCELYA.NS', 'ACCURACY.NS', 'ACE.NS', 'ACEINTEG.NS', 'ACI.NS', 'ACL.NS', 'ACLGATI.NS', 'ADANIENSOL.NS', 'ADANIGREEN.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'ADFFOODS.NS', 'ADL.NS', 'ADORWELD.NS', 'ADROITINFO.NS', 'ADSL.NS', 'ADVANIHOTR.NS', 'ADVENZYMES.NS', 'AEGISCHEM.NS', 'AEROFLEX.NS', 'AETHER.NS', 'AFFLE.NS', 'AGARIND.NS', 'AGI.NS', 'AGRITECH.NS', 'AGROPHOS.NS', 'AGSTRA.NS', 'AHL.NS', 'AHLADA.NS', 'AHLEAST.NS', 'AHLUCONT.NS', 'AIRAN.NS', 'AIROLAM.NS', 'AJMERA.NS', 'AJOONI.NS', 'AKASH.NS', 'AKG.NS', 'AKI.NS', 'AKSHAR.NS', 'AKSHARCHEM.NS', 'AKSHOPTFBR.NS', 'ALANKIT.NS', 'ALBERTDAVD.NS', 'ALEMBICLTD.NS', 'ALICON.NS', 'ALKALI.NS', 'ALLCARGO.NS', 'ALLSEC.NS', 'ALMONDZ.NS', 'ALOKINDS.NS', 'ALPA.NS', 'ALPHAGEO.NS', 'ALPSINDUS.NS', 'AMBICAAGAR.NS', 'AMBIKCO.NS', 'AMBUJACEM.NS', 'AMDIND.NS', 'AMIORG.NS', 'AMJLAND.NS', 'AMNPLST.NS', 'AMRUTANJAN.NS', 'ANANTRAJ.NS', 'ANDHRAPAP.NS', 'ANDHRSUGAR.NS', 'ANIKINDS.NS', 'ANKITMETAL.NS', 'ANMOL.NS', 'ANTGRAPHIC.NS', 'ANURAS.NS', 'APCL.NS', 'APCOTEXIND.NS', 'APEX.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'APOLLO.NS', 'APOLLOPIPE.NS', 'APOLLOTYRE.NS', 'APTECHT.NS', 'APTUS.NS', 'ARCHIDPLY.NS', 'ARCHIES.NS', 'ARE&M.NS', 'ARENTERP.NS', 'ARIES.NS', 'ARIHANTCAP.NS', 'ARIHANTSUP.NS', 'AROGRANITE.NS', 'ARROWGREEN.NS', 'ARSHIYA.NS', 'ARSSINFRA.NS', 'ARTEMISMED.NS', 'ARTNIRMAN.NS', 'ARVEE.NS', 'ARVIND.NS', 'ARVINDFASN.NS', 'ARVSMART.NS', 'ASAHIINDIA.NS', 'ASAHISONG.NS', 'ASAL.NS', 'ASALCBR.NS', 'ASHAPURMIN.NS', 'ASHIANA.NS', 'ASHIMASYN.NS', 'ASHOKA.NS', 'ASHOKAMET.NS', 'ASHOKLEY.NS', 'ASIANENE.NS', 'ASIANHOTNR.NS', 'ASIANTILES.NS', 'ASKAUTOLTD.NS', 'ASMS.NS', 'ASPINWALL.NS', 'ASTEC.NS', 'ASTERDM.NS', 'ASTRAL.NS', 'ASTRAMICRO.NS', 'ASTRON.NS', 'ATALREAL.NS', 'ATAM.NS', 'ATFL.NS', 'ATGL.NS', 'ATL.NS', 'ATLANTAA.NS', 'ATULAUTO.NS', 'AUBANK.NS', 'AUROPHARMA.NS', 'AURUM.NS', 'AUSOMENT.NS', 'AUTOIND.NS', 'AVADHSUGAR.NS', 'AVALON.NS', 'AVANTIFEED.NS', 'AVG.NS', 'AVONMORE.NS', 'AVROIND.NS', 'AVTNPL.NS', 'AWHCL.NS', 'AWL.NS', 'AXISBANK.NS', 'AXISCADES.NS', 'AXITA.NS', 'AYMSYNTEX.NS', 'AZAD.NS', 'BAFNAPH.NS', 'BAGFILMS.NS', 'BAIDFIN.NS', 'BAJAJCON.NS', 'BAJAJELEC.NS', 'BAJAJFINSV.NS', 'BAJAJHCARE.NS', 'BAJAJHIND.NS', 'BAJEL.NS', 'BALAJITELE.NS', 'BALAXI.NS', 'BALKRISHNA.NS', 'BALMLAWRIE.NS', 'BALPHARMA.NS', 'BALRAMCHIN.NS', 'BANARBEADS.NS', 'BANCOINDIA.NS', 'BANDHANBNK.NS', 'BANG.NS', 'BANKA.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BANSWRAS.NS', 'BARBEQUE.NS', 'BASML.NS', 'BATAINDIA.NS', 'BBOX.NS', 'BBTC.NS', 'BBTCL.NS', 'BCG.NS', 'BCLIND.NS', 'BCONCEPTS.NS', 'BDL.NS', 'BEARDSELL.NS', 'BECTORFOOD.NS', 'BEDMUTHA.NS', 'BEL.NS', 'BEPL.NS', 'BERGEPAINT.NS', 'BFINVEST.NS', 'BFUTILITIE.NS', 'BGRENERGY.NS', 'BHAGCHEM.NS', 'BHAGERIA.NS', 'BHAGYANGR.NS', 'BHANDARI.NS', 'BHARATFORG.NS', 'BHARATGEAR.NS', 'BHARATWIRE.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'BIGBLOC.NS', 'BIKAJI.NS', 'BIL.NS', 'BINANIIND.NS', 'BIOCON.NS', 'BIOFILCHEM.NS', 'BIRLACABLE.NS', 'BIRLACORPN.NS', 'BIRLAMONEY.NS', 'BKMINDST.NS', 'BLAL.NS', 'BLBLIMITED.NS', 'BLISSGVS.NS', 'BLKASHYAP.NS', 'BLS.NS', 'BLUECHIP.NS', 'BLUECOAST.NS', 'BLUEJET.NS', 'BLUESTARCO.NS', 'BODALCHEM.NS', 'BOHRAIND.NS', 'BOMDYEING.NS', 'BOROLTD.NS', 'BORORENEW.NS', 'BPCL.NS', 'BPL.NS', 'BRIGADE.NS', 'BRNL.NS', 'BROOKS.NS', 'BSHSL.NS', 'BSL.NS', 'BSOFT.NS', 'BTML.NS', 'BURNPUR.NS', 'BUTTERFLY.NS', 'BVCL.NS', 'BYKE.NS', 'CALSOFT.NS', 'CAMLINFINE.NS', 'CAMPUS.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CANTABIL.NS', 'CAPACITE.NS', 'CAPLIPOINT.NS', 'CAPTRUST.NS', 'CARBORUNIV.NS', 'CAREERP.NS', 'CARERATING.NS', 'CARTRADE.NS', 'CARYSIL.NS', 'CASTROLIND.NS', 'CCHHL.NS', 'CCL.NS', 'CDSL.NS', 'CELEBRITY.NS', 'CELLO.NS', 'CENTENKA.NS', 'CENTEXT.NS', 'CENTRALBK.NS', 'CENTRUM.NS', 'CENTUM.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CEREBRAINT.NS', 'CESC.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHALET.NS', 'CHAMBLFERT.NS', 'CHEMBOND.NS', 'CHEMCON.NS', 'CHEMFAB.NS', 'CHEMPLASTS.NS', 'CHENNPETRO.NS', 'CHEVIOT.NS', 'CHOICEIN.NS', 'CHOLAFIN.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'CIGNITITEC.NS', 'CINELINE.NS', 'CINEVISTA.NS', 'CIPLA.NS', 'CLEAN.NS', 'CLEDUCATE.NS', 'CLSEL.NS', 'CMSINFO.NS', 'COALINDIA.NS', 'COASTCORP.NS', 'COCHINSHIP.NS', 'COFFEEDAY.NS', 'COMPINFO.NS', 'COMPUSOFT.NS', 'CONCOR.NS', 'CONCORDBIO.NS', 'CONFIPET.NS', 'CONSOFINVT.NS', 'CONTROLPR.NS', 'CORALFINAC.NS', 'CORDSCABLE.NS', 'COROMANDEL.NS', 'COSMOFIRST.NS', 'COUNCODOS.NS', 'CREATIVE.NS', 'CREATIVEYE.NS', 'CREDITACC.NS', 'CREST.NS', 'CROMPTON.NS', 'CROWN.NS', 'CSBBANK.NS', 'CSLFINANCE.NS', 'CTE.NS', 'CUB.NS', 'CUBEXTUB.NS', 'CUPID.NS', 'CYBERMEDIA.NS', 'CYBERTECH.NS', 'CYIENTDLM.NS', 'DABUR.NS', 'DALMIASUG.NS', 'DAMODARIND.NS', 'DANGEE.NS', 'DATAMATICS.NS', 'DATAPATTNS.NS', 'DBCORP.NS', 'DBL.NS', 'DBOL.NS', 'DBREALTY.NS', 'DBSTOCKBRO.NS', 'DCAL.NS', 'DCBBANK.NS', 'DCI.NS', 'DCM.NS', 'DCMFINSERV.NS', 'DCMNVL.NS', 'DCMSHRIRAM.NS', 'DCMSRIND.NS', 'DCW.NS', 'DCXINDIA.NS', 'DECCANCE.NS', 'DEEPAKFERT.NS', 'DEEPENR.NS', 'DEEPINDS.NS', 'DELHIVERY.NS', 'DELPHIFX.NS', 'DELTACORP.NS', 'DELTAMAGNT.NS', 'DEN.NS', 'DENORA.NS', 'DEVIT.NS', 'DEVYANI.NS', 'DGCONTENT.NS', 'DHAMPURSUG.NS', 'DHANBANK.NS', 'DHANI.NS', 'DHANUKA.NS', 'DHARMAJ.NS', 'DHRUV.NS', 'DHUNINV.NS', 'DIACABS.NS', 'DIAMINESQ.NS', 'DIAMONDYD.NS', 'DICIND.NS', 'DIGISPICE.NS', 'DIGJAMLMTD.NS', 'DIL.NS', 'DISHTV.NS', 'DIVGIITTS.NS', 'DJML.NS', 'DLF.NS', 'DLINKINDIA.NS', 'DMCC.NS', 'DNAMEDIA.NS', 'DODLA.NS', 'DOLATALGO.NS', 'DOLLAR.NS', 'DOLPHIN.NS', 'DOMS.NS', 'DONEAR.NS', 'DPABHUSHAN.NS', 'DPSCLTD.NS', 'DPWIRES.NS', 'DRCSYSTEMS.NS', 'DREAMFOLKS.NS', 'DREDGECORP.NS', 'DSSL.NS', 'DTIL.NS', 'DUCON.NS', 'DVL.NS', 'DWARKESH.NS', 'DYCL.NS', 'DYNPRO.NS', 'E2E.NS', 'EASEMYTRIP.NS', 'EASTSILK.NS', 'EDELWEISS.NS', 'EDUCOMP.NS', 'EIDPARRY.NS', 'EIFFL.NS', 'EIHAHOTELS.NS', 'EIHOTEL.NS', 'EIMCOELECO.NS', 'EKC.NS', 'ELDEHSG.NS', 'ELECON.NS', 'ELECTCAST.NS', 'ELECTHERM.NS', 'ELGIEQUIP.NS', 'ELGIRUBCO.NS', 'ELIN.NS', 'EMAMILTD.NS', 'EMAMIPAP.NS', 'EMAMIREAL.NS', 'EMIL.NS', 'EMKAY.NS', 'EMMBI.NS', 'EMSLIMITED.NS', 'EMUDHRA.NS', 'ENDURANCE.NS', 'ENERGYDEV.NS', 'ENGINERSIN.NS', 'ENIL.NS', 'EPIGRAL.NS', 'EPL.NS', 'EQUIPPP.NS', 'EQUITASBNK.NS', 'ERIS.NS', 'EROSMEDIA.NS', 'ESAFSFB.NS', 'ESSARSHPNG.NS', 'ESSENTIA.NS', 'ESTER.NS', 'EUROTEXIND.NS', 'EVEREADY.NS', 'EVERESTIND.NS', 'EXCEL.NS', 'EXCELINDUS.NS', 'EXIDEIND.NS', 'EXPLEOSOL.NS', 'EXXARO.NS', 'FACT.NS', 'FAIRCHEMOR.NS', 'FAZE3Q.NS', 'FCL.NS', 'FCONSUMER.NS', 'FCSSOFT.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FEDFINA.NS', 'FEL.NS', 'FELDVR.NS', 'FIBERWEB.NS', 'FILATEX.NS', 'FINCABLES.NS', 'FINOPB.NS', 'FINPIPE.NS', 'FIVESTAR.NS', 'FLAIR.NS', 'FLEXITUFF.NS', 'FLFL.NS', 'FMGOETZE.NS', 'FMNL.NS', 'FOCUS.NS', 'FOODSIN.NS', 'FORTIS.NS', 'FSC.NS', 'FSL.NS', 'FUSION.NS', 'GABRIEL.NS', 'GAEL.NS', 'GAIL.NS', 'GALLANTT.NS', 'GANDHAR.NS', 'GANDHITUBE.NS', 'GANECOS.NS', 'GANESHBE.NS', 'GANESHHOUC.NS', 'GANGAFORGE.NS', 'GANGESSECU.NS', 'GATECH.NS', 'GATECHDVR.NS', 'GATEWAY.NS', 'GEECEE.NS', 'GEEKAYWIRE.NS', 'GENCON.NS', 'GENESYS.NS', 'GENSOL.NS', 'GENUSPAPER.NS', 'GENUSPOWER.NS', 'GEOJITFSL.NS', 'GEPIL.NS', 'GESHIP.NS', 'GET&D.NS', 'GFLLIMITED.NS', 'GHCL.NS', 'GHCLTEXTIL.NS', 'GICHSGFIN.NS', 'GICRE.NS', 'GILLANDERS.NS', 'GINNIFILA.NS', 'GIPCL.NS', 'GKWLIMITED.NS', 'GLAND.NS', 'GLENMARK.NS', 'GLFL.NS', 'GLOBAL.NS', 'GLOBALVECT.NS', 'GLOBE.NS', 'GLOBUSSPR.NS', 'GLS.NS', 'GMBREW.NS', 'GMDCLTD.NS', 'GMMPFAUDLR.NS', 'GMRINFRA.NS', 'GMRP&UI.NS', 'GNA.NS', 'GNFC.NS', 'GOACARBON.NS', 'GOCLCORP.NS', 'GOCOLORS.NS', 'GODHA.NS', 'GODREJAGRO.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GOENKA.NS', 'GOKEX.NS', 'GOKUL.NS', 'GOKULAGRO.NS', 'GOLDENTOBC.NS', 'GOLDIAM.NS', 'GOLDTECH.NS', 'GOODLUCK.NS', 'GOYALALUM.NS', 'GPIL.NS', 'GPPL.NS', 'GPTINFRA.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GRAVITA.NS', 'GREAVESCOT.NS', 'GREENLAM.NS', 'GREENPANEL.NS', 'GREENPLY.NS', 'GREENPOWER.NS', 'GRINFRA.NS', 'GRMOVER.NS', 'GROBTEA.NS', 'GRSE.NS', 'GRWRHITECH.NS', 'GSFC.NS', 'GSLSU.NS', 'GSPL.NS', 'GSS.NS', 'GTECJAINX.NS', 'GTL.NS', 'GTLINFRA.NS', 'GTPL.NS', 'GUFICBIO.NS', 'GUJALKALI.NS', 'GUJAPOLLO.NS', 'GUJGASLTD.NS', 'GUJRAFFIA.NS', 'GULFOILLUB.NS', 'GULFPETRO.NS', 'GULPOLY.NS', 'GVKPIL.NS', 'GVPTECH.NS', 'HAPPSTMNDS.NS', 'HAPPYFORGE.NS', 'HARDWYN.NS', 'HARIOMPIPE.NS', 'HARRMALAYA.NS', 'HARSHA.NS', 'HATHWAY.NS', 'HATSUN.NS', 'HAVELLS.NS', 'HAVISHA.NS', 'HBLPOWER.NS', 'HBSL.NS', 'HCC.NS', 'HCG.NS', 'HCL-INSYS.NS', 'HCLTECH.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'HEADSUP.NS', 'HECPROJECT.NS', 'HEG.NS', 'HEIDELBERG.NS', 'HEMIPROP.NS', 'HERANBA.NS', 'HERCULES.NS', 'HERITGFOOD.NS', 'HESTERBIO.NS', 'HEUBACHIND.NS', 'HEXATRADEX.NS', 'HFCL.NS', 'HGINFRA.NS', 'HGS.NS', 'HIKAL.NS', 'HILTON.NS', 'HIMATSEIDE.NS', 'HINDALCO.NS', 'HINDCOMPOS.NS', 'HINDCON.NS', 'HINDCOPPER.NS', 'HINDMOTORS.NS', 'HINDOILEXP.NS', 'HINDPETRO.NS', 'HINDWAREAP.NS', 'HINDZINC.NS', 'HIRECT.NS', 'HISARMETAL.NS', 'HITECH.NS', 'HITECHCORP.NS', 'HITECHGEAR.NS', 'HLEGLAS.NS', 'HLVLTD.NS', 'HMAAGRO.NS', 'HMT.NS', 'HMVL.NS', 'HNDFDS.NS', 'HOMEFIRST.NS', 'HONASA.NS', 'HOVS.NS', 'HPAL.NS', 'HPIL.NS', 'HPL.NS', 'HSCL.NS', 'HTMEDIA.NS', 'HUBTOWN.NS', 'HUDCO.NS', 'HUHTAMAKI.NS', 'HYBRIDFIN.NS', 'IBREALEST.NS', 'IBULHSGFIN.NS', 'ICDSLTD.NS', 'ICEMAKE.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'ICIL.NS', 'IDBI.NS', 'IDEA.NS', 'IDEAFORGE.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IEL.NS', 'IEX.NS', 'IFBAGRO.NS', 'IFBIND.NS', 'IFCI.NS', 'IFGLEXPOR.NS', 'IGARASHI.NS', 'IGL.NS', 'IGPL.NS', 'IIFL.NS', 'IIFLSEC.NS', 'IITL.NS', 'IKIO.NS', 'IL&FSENGG.NS', 'IL&FSTRANS.NS', 'IMAGICAA.NS', 'IMFA.NS', 'IMPAL.NS', 'IMPEXFERRO.NS', 'INCREDIBLE.NS', 'INDBANK.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INDIAGLYCO.NS', 'INDIANB.NS', 'INDIANCARD.NS', 'INDIANHUME.NS', 'INDIASHLTR.NS', 'INDIGOPNTS.NS', 'INDNIPPON.NS', 'INDOAMIN.NS', 'INDOBORAX.NS', 'INDOCO.NS', 'INDORAMA.NS', 'INDOSTAR.NS', 'INDOTECH.NS', 'INDOTHAI.NS', 'INDOWIND.NS', 'INDRAMEDCO.NS', 'INDSWFTLAB.NS', 'INDSWFTLTD.NS', 'INDTERRAIN.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'INFOBEAN.NS', 'INFOMEDIA.NS', 'INFY.NS', 'INNOVACAP.NS', 'INOXGREEN.NS', 'INOXINDIA.NS', 'INOXWIND.NS', 'INSECTICID.NS', 'INSPIRISYS.NS', 'INTELLECT.NS', 'INTENTECH.NS', 'INTLCONV.NS', 'INVENTURE.NS', 'IOB.NS', 'IOC.NS', 'IOLCP.NS', 'IONEXCHANG.NS', 'IPCALAB.NS', 'IPL.NS', 'IRB.NS', 'IRCON.NS', 'IRCTC.NS', 'IREDA.NS', 'IRFC.NS', 'IRIS.NS', 'IRISDOREME.NS', 'IRMENERGY.NS', 'ISEC.NS', 'ISFT.NS', 'ISGEC.NS', 'ISMTLTD.NS', 'ITC.NS', 'ITDC.NS', 'ITDCEM.NS', 'ITI.NS', 'IVC.NS', 'IVP.NS', 'IZMO.NS', 'J&KBANK.NS', 'JAGRAN.NS', 'JAGSNPHARM.NS', 'JAIBALAJI.NS', 'JAICORPLTD.NS', 'JAIPURKURT.NS', 'JAMNAAUTO.NS', 'JASH.NS', 'JAYAGROGN.NS', 'JAYBARMARU.NS', 'JAYNECOIND.NS', 'JAYSREETEA.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JCHAC.NS', 'JETAIRWAYS.NS', 'JETFREIGHT.NS', 'JHS.NS', 'JINDALPHOT.NS', 'JINDALPOLY.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JINDRILL.NS', 'JINDWORLD.NS', 'JIOFIN.NS', 'JISLDVREQS.NS', 'JISLJALEQS.NS', 'JITFINFRA.NS', 'JKIL.NS', 'JKLAKSHMI.NS', 'JKPAPER.NS', 'JKTYRE.NS', 'JLHL.NS', 'JMA.NS', 'JMFINANCIL.NS', 'JOCIL.NS', 'JPASSOCIAT.NS', 'JPOLYINVST.NS', 'JPPOWER.NS', 'JSL.NS', 'JSWENERGY.NS', 'JSWINFRA.NS', 'JSWSTEEL.NS', 'JTEKTINDIA.NS', 'JTLIND.NS', 'JUBLFOOD.NS', 'JUBLINDS.NS', 'JUBLINGREA.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'JWL.NS', 'JYOTHYLAB.NS', 'JYOTISTRUC.NS', 'KABRAEXTRU.NS', 'KAJARIACER.NS', 'KAKATCEM.NS', 'KALAMANDIR.NS', 'KALYANIFRG.NS', 'KALYANKJIL.NS', 'KAMATHOTEL.NS', 'KAMDHENU.NS', 'KAMOPAINTS.NS', 'KANANIIND.NS', 'KANORICHEM.NS', 'KANPRPLA.NS', 'KANSAINER.NS', 'KAPSTON.NS', 'KARMAENG.NS', 'KARURVYSYA.NS', 'KAUSHALYA.NS', 'KAVVERITEL.NS', 'KAYA.NS', 'KBCGLOBAL.NS', 'KCP.NS', 'KCPSUGIND.NS', 'KEC.NS', 'KECL.NS', 'KEEPLEARN.NS', 'KELLTONTEC.NS', 'KERNEX.NS', 'KESORAMIND.NS', 'KEYFINSERV.NS', 'KFINTECH.NS', 'KHADIM.NS', 'KHAICHEM.NS', 'KHAITANLTD.NS', 'KHANDSE.NS', 'KILITCH.NS', 'KIOCL.NS', 'KIRIINDUS.NS', 'KIRLOSBROS.NS', 'KIRLOSENG.NS', 'KIRLPNU.NS', 'KITEX.NS', 'KKCL.NS', 'KMSUGAR.NS', 'KNRCON.NS', 'KOHINOOR.NS', 'KOKUYOCMLN.NS', 'KOLTEPATIL.NS', 'KOPRAN.NS', 'KOTAKBANK.NS', 'KOTARISUG.NS', 'KOTHARIPET.NS', 'KOTHARIPRO.NS', 'KPIGREEN.NS', 'KPIL.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'KRBL.NS', 'KREBSBIO.NS', 'KRIDHANINF.NS', 'KRISHANA.NS', 'KRITI.NS', 'KRITIKA.NS', 'KRITINUT.NS', 'KRSNAA.NS', 'KSCL.NS', 'KSHITIJPOL.NS', 'KSL.NS', 'KSOLVES.NS', 'KTKBANK.NS', 'KUANTUM.NS', 'L&TFH.NS', 'LAGNAM.NS', 'LAKPRE.NS', 'LAL.NS', 'LAMBODHARA.NS', 'LANDMARK.NS', 'LAOPALA.NS', 'LASA.NS', 'LATENTVIEW.NS', 'LATTEYS.NS', 'LAURUSLABS.NS', 'LAXMICOT.NS', 'LCCINFOTEC.NS', 'LEMONTREE.NS', 'LEXUS.NS', 'LFIC.NS', 'LGBBROSLTD.NS', 'LGBFORGE.NS', 'LGHL.NS', 'LIBAS.NS', 'LIBERTSHOE.NS', 'LICHSGFIN.NS', 'LICI.NS', 'LIKHITHA.NS', 'LINC.NS', 'LINCOLN.NS', 'LLOYDSENGG.NS', 'LLOYDSME.NS', 'LODHA.NS', 'LOKESHMACH.NS', 'LORDSCHLO.NS', 'LOTUSEYE.NS', 'LOVABLE.NS', 'LOYALTEX.NS', 'LPDC.NS', 'LTFOODS.NS', 'LUMAXTECH.NS', 'LUPIN.NS', 'LUXIND.NS', 'LXCHEM.NS', 'LYKALABS.NS', 'LYPSAGEMS.NS', 'M&M.NS', 'M&MFIN.NS', 'MAANALU.NS', 'MACPOWER.NS', 'MADHAV.NS', 'MADHUCON.NS', 'MADRASFERT.NS', 'MAGADSUGAR.NS', 'MAGNUM.NS', 'MAHABANK.NS', 'MAHAPEXLTD.NS', 'MAHASTEEL.NS', 'MAHEPC.NS', 'MAHESHWARI.NS', 'MAHLIFE.NS', 'MAHLOG.NS', 'MAHSEAMLES.NS', 'MAITHANALL.NS', 'MALLCOM.NS', 'MALUPAPER.NS', 'MANAKALUCO.NS', 'MANAKCOAT.NS', 'MANAKSIA.NS', 'MANAKSTEEL.NS', 'MANALIPETC.NS', 'MANAPPURAM.NS', 'MANGALAM.NS', 'MANGCHEFER.NS', 'MANGLMCEM.NS', 'MANINDS.NS', 'MANINFRA.NS', 'MANOMAY.NS', 'MANORG.NS', 'MANUGRAPH.NS', 'MANYAVAR.NS', 'MARALOVER.NS', 'MARATHON.NS', 'MARICO.NS', 'MARINE.NS', 'MARKSANS.NS', 'MARSHALL.NS', 'MASFIN.NS', 'MASKINVEST.NS', 'MATRIMONY.NS', 'MAWANASUG.NS', 'MAXESTATES.NS', 'MAXHEALTH.NS', 'MAXIND.NS', 'MAYURUNIQ.NS', 'MAZDA.NS', 'MBAPL.NS', 'MBECL.NS', 'MBLINFRA.NS', 'MCDOWELL-N.NS', 'MCL.NS', 'MCLEODRUSS.NS', 'MEDANTA.NS', 'MEDICAMEQ.NS', 'MEDICO.NS', 'MEDPLUS.NS', 'MEGASOFT.NS', 'MEGASTAR.NS', 'MELSTAR.NS', 'MENONBE.NS', 'MEP.NS', 'METALFORGE.NS', 'METROBRAND.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MGEL.NS', 'MGL.NS', 'MHLXMIRU.NS', 'MHRIL.NS', 'MICEL.NS', 'MIDHANI.NS', 'MINDACORP.NS', 'MINDTECK.NS', 'MIRCELECTR.NS', 'MIRZAINT.NS', 'MITCON.NS', 'MITTAL.NS', 'MKPL.NS', 'MMFL.NS', 'MMP.NS', 'MMTC.NS', 'MODIRUBBER.NS', 'MODISONLTD.NS', 'MOHITIND.NS', 'MOIL.NS', 'MOKSH.NS', 'MOL.NS', 'MOLDTECH.NS', 'MOLDTKPAC.NS', 'MONARCH.NS', 'MONTECARLO.NS', 'MORARJEE.NS', 'MOREPENLAB.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'MOTISONS.NS', 'MOTOGENFIN.NS', 'MPSLTD.NS', 'MRO-TEK.NS', 'MRPL.NS', 'MSPL.NS', 'MSTCLTD.NS', 'MSUMI.NS', 'MTEDUCARE.NS', 'MTNL.NS', 'MUFIN.NS', 'MUFTI.NS', 'MUKANDLTD.NS', 'MUKTAARTS.NS', 'MUNJALAU.NS', 'MUNJALSHOW.NS', 'MURUDCERA.NS', 'MUTHOOTCAP.NS', 'MUTHOOTFIN.NS', 'MUTHOOTMF.NS', 'MVGJL.NS', 'NACLIND.NS', 'NAGAFERT.NS', 'NAGREEKCAP.NS', 'NAGREEKEXP.NS', 'NAHARCAP.NS', 'NAHARINDUS.NS', 'NAHARPOLY.NS', 'NAHARSPING.NS', 'NAM-INDIA.NS', 'NARMADA.NS', 'NATCOPHARM.NS', 'NATHBIOGEN.NS', 'NATIONALUM.NS', 'NAVA.NS', 'NAVKARCORP.NS', 'NAVNETEDUL.NS', 'NAZARA.NS', 'NBCC.NS', 'NBIFIN.NS', 'NCC.NS', 'NCLIND.NS', 'NDL.NS', 'NDLVENTURE.NS', 'NDRAUTO.NS', 'NDTV.NS', 'NECCLTD.NS', 'NECLIFE.NS', 'NELCAST.NS', 'NELCO.NS', 'NEOGEN.NS', 'NESCO.NS', 'NETWEB.NS', 'NETWORK18.NS', 'NEWGEN.NS', 'NEXTMEDIA.NS', 'NFL.NS', 'NGIL.NS', 'NH.NS', 'NHPC.NS', 'NIACL.NS', 'NIBL.NS', 'NIITLTD.NS', 'NIITMTS.NS', 'NILAINFRA.NS', 'NILASPACES.NS', 'NINSYS.NS', 'NIPPOBATRY.NS', 'NIRAJ.NS', 'NITCO.NS', 'NITINSPIN.NS', 'NITIRAJ.NS', 'NKIND.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NOCIL.NS', 'NOIDATOLL.NS', 'NORBTEAEXP.NS', 'NRAIL.NS', 'NRBBEARING.NS', 'NRL.NS', 'NSLNISP.NS', 'NTPC.NS', 'NUCLEUS.NS', 'NURECA.NS', 'NUVOCO.NS', 'NYKAA.NS', 'OAL.NS', 'OBCL.NS', 'OBEROIRLTY.NS', 'OCCL.NS', 'OIL.NS', 'OILCOUNTUB.NS', 'OLECTRA.NS', 'OMAXAUTO.NS', 'OMAXE.NS', 'OMINFRAL.NS', 'OMKARCHEM.NS', 'ONELIFECAP.NS', 'ONEPOINT.NS', 'ONGC.NS', 'ONMOBILE.NS', 'ONWARDTEC.NS', 'OPTIEMUS.NS', 'ORBTEXP.NS', 'ORCHPHARMA.NS', 'ORICONENT.NS', 'ORIENTALTL.NS', 'ORIENTBELL.NS', 'ORIENTCEM.NS', 'ORIENTCER.NS', 'ORIENTELEC.NS', 'ORIENTHOT.NS', 'ORIENTLTD.NS', 'ORIENTPPR.NS', 'ORTINLAB.NS', 'OSIAHYPER.NS', 'OSWALAGRO.NS', 'OSWALGREEN.NS', 'OSWALSEEDS.NS', 'PAISALO.NS', 'PAKKA.NS', 'PALASHSECU.NS', 'PALREDTEC.NS', 'PANACEABIO.NS', 'PANACHE.NS', 'PANAMAPET.NS', 'PANSARI.NS', 'PAR.NS', 'PARACABLES.NS', 'PARADEEP.NS', 'PARAGMILK.NS', 'PARAS.NS', 'PARASPETRO.NS', 'PARSVNATH.NS', 'PASUPTAC.NS', 'PATANJALI.NS', 'PATELENG.NS', 'PATINTLOG.NS', 'PAVNAIND.NS', 'PAYTM.NS', 'PCBL.NS', 'PCJEWELLER.NS', 'PDMJEPAPER.NS', 'PDSL.NS', 'PEARLPOLY.NS', 'PEL.NS', 'PENIND.NS', 'PENINLAND.NS', 'PETRONET.NS', 'PFC.NS', 'PFOCUS.NS', 'PFS.NS', 'PGIL.NS', 'PIGL.NS', 'PILITA.NS', 'PIONEEREMB.NS', 'PITTIENG.NS', 'PIXTRANS.NS', 'PKTEA.NS', 'PLASTIBLEN.NS', 'PLAZACABLE.NS', 'PNB.NS', 'PNBGILTS.NS', 'PNBHOUSING.NS', 'PNC.NS', 'PNCINFRA.NS', 'POCL.NS', 'PODDARHOUS.NS', 'PODDARMENT.NS', 'POKARNA.NS', 'POLICYBZR.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'PONNIERODE.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'PPAP.NS', 'PPL.NS', 'PPLPHARMA.NS', 'PRAENG.NS', 'PRAJIND.NS', 'PRAKASH.NS', 'PRAKASHSTL.NS', 'PRAXIS.NS', 'PRECAM.NS', 'PRECOT.NS', 'PRECWIRE.NS', 'PREMEXPLN.NS', 'PREMIER.NS', 'PREMIERPOL.NS', 'PRESTIGE.NS', 'PRICOLLTD.NS', 'PRIMESECU.NS', 'PRINCEPIPE.NS', 'PRITI.NS', 'PRITIKAUTO.NS', 'PRIVISCL.NS', 'PROZONER.NS', 'PRSMJOHNSN.NS', 'PRUDENT.NS', 'PRUDMOULI.NS', 'PSB.NS', 'PSPPROJECT.NS', 'PTC.NS', 'PTL.NS', 'PUNJABCHEM.NS', 'PURVA.NS', 'PVP.NS', 'PVRINOX.NS', 'PYRAMID.NS', 'QUESS.NS', 'QUICKHEAL.NS', 'RACE.NS', 'RADAAN.NS', 'RADHIKAJWE.NS', 'RADIANTCMS.NS', 'RADICO.NS', 'RADIOCITY.NS', 'RAILTEL.NS', 'RAIN.NS', 'RAINBOW.NS', 'RAJESHEXPO.NS', 'RAJMET.NS', 'RAJRATAN.NS', 'RAJRILTD.NS', 'RAJSREESUG.NS', 'RAJTV.NS', 'RALLIS.NS', 'RAMANEWS.NS', 'RAMAPHO.NS', 'RAMASTEEL.NS', 'RAMCOCEM.NS', 'RAMCOIND.NS', 'RAMCOSYS.NS', 'RAMKY.NS', 'RAMRAT.NS', 'RANASUG.NS', 'RANEENGINE.NS', 'RANEHOLDIN.NS', 'RATEGAIN.NS', 'RATNAVEER.NS', 'RAYMOND.NS', 'RBA.NS', 'RBL.NS', 'RBLBANK.NS', 'RBZJEWEL.NS', 'RCF.NS', 'RECLTD.NS', 'REDINGTON.NS', 'REDTAPE.NS', 'REFEX.NS', 'REGENCERAM.NS', 'RELAXO.NS', 'RELCAPITAL.NS', 'RELCHEMQ.NS', 'RELIGARE.NS', 'RELINFRA.NS', 'REMSONSIND.NS', 'RENUKA.NS', 'REPCOHOME.NS', 'REPL.NS', 'REPRO.NS', 'RESPONIND.NS', 'RGL.NS', 'RHFL.NS', 'RHIM.NS', 'RHL.NS', 'RICOAUTO.NS', 'RIIL.NS', 'RISHABH.NS', 'RITCO.NS', 'RITES.NS', 'RKDL.NS', 'RKEC.NS', 'RKFORGE.NS', 'RML.NS', 'ROHLTD.NS', 'ROLLT.NS', 'ROML.NS', 'ROSSARI.NS', 'ROSSELLIND.NS', 'ROTO.NS', 'ROUTE.NS', 'RPGLIFE.NS', 'RPOWER.NS', 'RPPINFRA.NS', 'RPPL.NS', 'RPSGVENT.NS', 'RRKABEL.NS', 'RSSOFTWARE.NS', 'RSWM.NS', 'RSYSTEMS.NS', 'RTNINDIA.NS', 'RTNPOWER.NS', 'RUBYMILLS.NS', 'RUCHINFRA.NS', 'RUCHIRA.NS', 'RUPA.NS', 'RUSHIL.NS', 'RUSTOMJEE.NS', 'RVHL.NS', 'RVNL.NS', 'S&SPOWER.NS', 'SABEVENTS.NS', 'SABTN.NS', 'SADBHAV.NS', 'SADBHIN.NS', 'SADHNANIQ.NS', 'SAFARI.NS', 'SAGARDEEP.NS', 'SAGCEM.NS', 'SAH.NS', 'SAHYADRI.NS', 'SAIL.NS', 'SAKAR.NS', 'SAKHTISUG.NS', 'SAKSOFT.NS', 'SAKUMA.NS', 'SALASAR.NS', 'SALONA.NS', 'SALSTEEL.NS', 'SALZERELEC.NS', 'SAMBHAAV.NS', 'SAMHI.NS', 'SAMPANN.NS', 'SANCO.NS', 'SANDESH.NS', 'SANDHAR.NS', 'SANGAMIND.NS', 'SANGHIIND.NS', 'SANGHVIMOV.NS', 'SANGINITA.NS', 'SANSERA.NS', 'SAPPHIRE.NS', 'SARDAEN.NS', 'SAREGAMA.NS', 'SARLAPOLY.NS', 'SARVESHWAR.NS', 'SASKEN.NS', 'SASTASUNDR.NS', 'SATIA.NS', 'SATIN.NS', 'SATINDLTD.NS', 'SBC.NS', 'SBCL.NS', 'SBFC.NS', 'SBGLP.NS', 'SBICARD.NS', 'SBILIFE.NS', 'SBIN.NS', 'SCHAND.NS', 'SCHNEIDER.NS', 'SCI.NS', 'SCPL.NS', 'SDBL.NS', 'SEAMECLTD.NS', 'SECMARK.NS', 'SECURCRED.NS', 'SECURKLOUD.NS', 'SEJALLTD.NS', 'SELAN.NS', 'SELMC.NS', 'SENCO.NS', 'SEPC.NS', 'SEQUENT.NS', 'SERVOTECH.NS', 'SESHAPAPER.NS', 'SETCO.NS', 'SEYAIND.NS', 'SFL.NS', 'SGIL.NS', 'SGL.NS', 'SHAH.NS', 'SHAHALLOYS.NS', 'SHAILY.NS', 'SHAKTIPUMP.NS', 'SHALBY.NS', 'SHALPAINTS.NS', 'SHANKARA.NS', 'SHANTI.NS', 'SHANTIGEAR.NS', 'SHARDACROP.NS', 'SHARDAMOTR.NS', 'SHAREINDIA.NS', 'SHEMAROO.NS', 'SHILPAMED.NS', 'SHIVALIK.NS', 'SHIVAMAUTO.NS', 'SHIVAMILLS.NS', 'SHIVATEX.NS', 'SHK.NS', 'SHOPERSTOP.NS', 'SHRADHA.NS', 'SHREDIGCEM.NS', 'SHREEPUSHK.NS', 'SHREERAMA.NS', 'SHRENIK.NS', 'SHREYANIND.NS', 'SHREYAS.NS', 'SHRIPISTON.NS', 'SHRIRAMPPS.NS', 'SHYAMCENT.NS', 'SHYAMMETL.NS', 'SHYAMTEL.NS', 'SICALLOG.NS', 'SIGACHI.NS', 'SIGIND.NS', 'SIGMA.NS', 'SIGNATURE.NS', 'SIKKO.NS', 'SIL.NS', 'SILGO.NS', 'SILINV.NS', 'SILLYMONKS.NS', 'SILVERTUC.NS', 'SIMBHALS.NS', 'SIMPLEXINF.NS', 'SINDHUTRAD.NS', 'SINTERCOM.NS', 'SIRCA.NS', 'SIS.NS', 'SITINET.NS', 'SIYSIL.NS', 'SJS.NS', 'SJVN.NS', 'SKIPPER.NS', 'SKMEGGPROD.NS', 'SKYGOLD.NS', 'SMARTLINK.NS', 'SMCGLOBAL.NS', 'SMLISUZU.NS', 'SMLT.NS', 'SMSLIFE.NS', 'SMSPHARMA.NS', 'SNOWMAN.NS', 'SOBHA.NS', 'SOFTTECH.NS', 'SOLARA.NS', 'SOMANYCERA.NS', 'SOMATEX.NS', 'SOMICONVEY.NS', 'SONACOMS.NS', 'SONAMLTD.NS', 'SONATSOFTW.NS', 'SOTL.NS', 'SOUTHBANK.NS', 'SOUTHWEST.NS', 'SPAL.NS', 'SPANDANA.NS', 'SPARC.NS', 'SPCENET.NS', 'SPECIALITY.NS', 'SPENCERS.NS', 'SPENTEX.NS', 'SPIC.NS', 'SPLIL.NS', 'SPLPETRO.NS', 'SPMLINFRA.NS', 'SPORTKING.NS', 'SPTL.NS', 'SPYL.NS', 'SREEL.NS', 'SRGHFL.NS', 'SRHHYPOLTD.NS', 'SRPL.NS', 'SSWL.NS', 'STAR.NS', 'STARCEMENT.NS', 'STARHEALTH.NS', 'STARPAPER.NS', 'STARTECK.NS', 'STCINDIA.NS', 'STEELCAS.NS', 'STEELCITY.NS', 'STEELXIND.NS', 'STEL.NS', 'STERTOOLS.NS', 'STLTECH.NS', 'STOVEKRAFT.NS', 'STYLAMIND.NS', 'STYRENIX.NS', 'SUBEXLTD.NS', 'SUBROS.NS', 'SUDARSCHEM.NS', 'SUKHJITS.NS', 'SULA.NS', 'SUMICHEM.NS', 'SUMIT.NS', 'SUMMITSEC.NS', 'SUNCLAY.NS', 'SUNDARAM.NS', 'SUNDARMHLD.NS', 'SUNDRMBRAK.NS', 'SUNDRMFAST.NS', 'SUNFLAG.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SUNTV.NS', 'SUPERHOUSE.NS', 'SUPERSPIN.NS', 'SUPRAJIT.NS', 'SUPREMEENG.NS', 'SUPREMEINF.NS', 'SUPRIYA.NS', 'SURAJEST.NS', 'SURANASOL.NS', 'SURANAT&P.NS', 'SURYALAXMI.NS', 'SURYAROSNI.NS', 'SURYODAY.NS', 'SUTLEJTEX.NS', 'SUULD.NS', 'SUVEN.NS', 'SUVENPHAR.NS', 'SUVIDHAA.NS', 'SUZLON.NS', 'SVLL.NS', 'SVPGLOB.NS', 'SWANENERGY.NS', 'SWELECTES.NS', 'SWSOLAR.NS', 'SYMPHONY.NS', 'SYNCOMF.NS', 'SYNGENE.NS', 'SYRMA.NS', 'TAINWALCHM.NS', 'TAJGVK.NS', 'TAKE.NS', 'TALBROAUTO.NS', 'TANLA.NS', 'TARAPUR.NS', 'TARC.NS', 'TARMAT.NS', 'TARSONS.NS', 'TATACHEM.NS', 'TATACOFFEE.NS', 'TATACOMM.NS', 'TATACONSUM.NS', 'TATAMETALI.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TATATECH.NS', 'TATVA.NS', 'TBZ.NS', 'TCI.NS', 'TCIEXP.NS', 'TCLCONS.NS', 'TCNSBRANDS.NS', 'TDPOWERSYS.NS', 'TECHIN.NS', 'TECHM.NS', 'TECHNOE.NS', 'TECILCHEM.NS', 'TEGA.NS', 'TEJASNET.NS', 'TEMBO.NS', 'TERASOFT.NS', 'TEXINFRA.NS', 'TEXMOPIPES.NS', 'TEXRAIL.NS', 'TFCILTD.NS', 'TFL.NS', 'TGBHOTELS.NS', 'THANGAMAYL.NS', 'THEINVEST.NS', 'THEJO.NS', 'THEMISMED.NS', 'THOMASCOOK.NS', 'THOMASCOTT.NS', 'THYROCARE.NS', 'TI.NS', 'TIDEWATER.NS', 'TIJARIA.NS', 'TIL.NS', 'TIMESGTY.NS', 'TIMETECHNO.NS', 'TINPLATE.NS', 'TIPSFILMS.NS', 'TIPSINDLTD.NS', 'TIRUMALCHM.NS', 'TIRUPATIFL.NS', 'TITAGARH.NS', 'TMB.NS', 'TNPETRO.NS', 'TNPL.NS', 'TNTELE.NS', 'TOKYOPLAST.NS', 'TORNTPOWER.NS', 'TOTAL.NS', 'TOUCHWOOD.NS', 'TPHQ.NS', 'TPLPLASTEH.NS', 'TRACXN.NS', 'TREEHOUSE.NS', 'TREJHARA.NS', 'TREL.NS', 'TRF.NS', 'TRIDENT.NS', 'TRIGYN.NS', 'TRIL.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TRU.NS', 'TTKHLTCARE.NS', 'TTKPRESTIG.NS', 'TTL.NS', 'TTML.NS', 'TV18BRDCST.NS', 'TVSELECT.NS', 'TVSSCS.NS', 'TVTODAY.NS', 'TVVISION.NS', 'UBL.NS', 'UCAL.NS', 'UCOBANK.NS', 'UDS.NS', 'UFLEX.NS', 'UFO.NS', 'UGARSUGAR.NS', 'UGROCAP.NS', 'UJJIVAN.NS', 'UJJIVANSFB.NS', 'UMAEXPORTS.NS', 'UMANGDAIRY.NS', 'UMESLTD.NS', 'UNICHEMLAB.NS', 'UNIDT.NS', 'UNIENTER.NS', 'UNIINFO.NS', 'UNIONBANK.NS', 'UNIPARTS.NS', 'UNITECH.NS', 'UNITEDPOLY.NS', 'UNITEDTEA.NS', 'UNIVAFOODS.NS', 'UNIVASTU.NS', 'UNIVCABLES.NS', 'UNIVPHOTO.NS', 'UNOMINDA.NS', 'UPL.NS', 'URAVI.NS', 'URJA.NS', 'USHAMART.NS', 'USK.NS', 'UTIAMC.NS', 'UTKARSHBNK.NS', 'UTTAMSUGAR.NS', 'V2RETAIL.NS', 'VAIBHAVGBL.NS', 'VAISHALI.NS', 'VAKRANGEE.NS', 'VALIANTLAB.NS', 'VALIANTORG.NS', 'VARDHACRLC.NS', 'VARDMNPOLY.NS', 'VARROC.NS', 'VASCONEQ.NS', 'VASWANI.NS', 'VBL.NS', 'VCL.NS', 'VEDL.NS', 'VENUSPIPES.NS', 'VENUSREM.NS', 'VERANDA.NS', 'VERTOZ.NS', 'VETO.NS', 'VGUARD.NS', 'VIDHIING.NS', 'VIJAYA.NS', 'VIJIFIN.NS', 'VIKASECO.NS', 'VIKASLIFE.NS', 'VIMTALABS.NS', 'VINATIORGA.NS', 'VINEETLAB.NS', 'VINNY.NS', 'VINYLINDIA.NS', 'VIPCLOTHNG.NS', 'VIPIND.NS', 'VIPULLTD.NS', 'VIRINCHI.NS', 'VISAKAIND.NS', 'VISESHINFO.NS', 'VISHNU.NS', 'VISHWARAJ.NS', 'VIVIDHA.NS', 'VLEGOV.NS', 'VLSFINANCE.NS', 'VOLTAS.NS', 'VPRPL.NS', 'VRLLOG.NS', 'VSSL.NS', 'VTL.NS', 'WABAG.NS', 'WALCHANNAG.NS', 'WANBURY.NS', 'WEALTH.NS', 'WEBELSOLAR.NS', 'WEIZMANIND.NS', 'WEL.NS', 'WELCORP.NS', 'WELENT.NS', 'WELINV.NS', 'WELSPUNLIV.NS', 'WESTLIFE.NS', 'WEWIN.NS', 'WHEELS.NS', 'WHIRLPOOL.NS', 'WILLAMAGOR.NS', 'WINDLAS.NS', 'WINDMACHIN.NS', 'WINSOME.NS', 'WIPL.NS', 'WIPRO.NS', 'WOCKPHARMA.NS', 'WONDERLA.NS', 'WORTH.NS', 'WSI.NS', 'WSTCSTPAPR.NS', 'XCHANGING.NS', 'XELPMOC.NS', 'XPROINDIA.NS', 'YAARI.NS', 'YASHO.NS', 'YATHARTH.NS', 'YATRA.NS', 'YESBANK.NS', 'YUKEN.NS', 'ZAGGLE.NS', 'ZEEL.NS', 'ZEELEARN.NS', 'ZEEMEDIA.NS', 'ZENITHEXPO.NS', 'ZENITHSTL.NS', 'ZENSARTECH.NS', 'ZENTEC.NS', 'ZIMLAB.NS', 'ZODIAC.NS', 'ZODIACLOTH.NS', 'ZOMATO.NS', 'ZOTA.NS', 'ZUARI.NS', 'ZUARIIND.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS']
# Initialize lists to store selected stocks, their volumes, and entry prices
selected_stocks = []
selected_stocks_volume = []
selected_stocks_entry_price = []

for stock in nse_stocks:
    print(f"Processing {stock}...")
    data = fetch_data(stock)

    if not isinstance(data.index, pd.DatetimeIndex):
        data.index = pd.to_datetime(data.index)

    for date in data.index.normalize().unique():
        daily_data = data[data.index.normalize() == date]
        first_interval = daily_data.between_time('09:15', '09:20')
        if not first_interval.empty:
            open_equals_low = first_interval.iloc[0]['Open'] == first_interval['Low'].min()
            if open_equals_low:
                entry_price = first_interval.iloc[0]['Close']  # Assuming entry at the close of the interval
                selected_stocks.append((stock, date.date()))
                selected_stocks_volume.append((stock, date.date(), first_interval['Volume'].sum()))
                selected_stocks_entry_price.append((stock, date.date(), entry_price))

# Create DataFrames
df_volume = pd.DataFrame(selected_stocks_volume, columns=['Stock', 'Date', 'Volume'])
df_entry_price = pd.DataFrame(selected_stocks_entry_price, columns=['Stock', 'Date', 'EntryPrice'])

# Merge DataFrames
df_merged = pd.merge(df_volume, df_entry_price, on=['Stock', 'Date'], how='inner')

# Get today's date for the file name
today_date = datetime.today().strftime('%Y-%m-%d')

# Export the DataFrame to an Excel file with today's date in the file name
file_name = f'selected_stocks_volume_{today_date}.xlsx'
df_merged.to_excel(file_name, index=False)

# Sort the DataFrame by 'Volume' in descending order
df_sorted_by_volume = df_merged.sort_values(by='Volume', ascending=False)

# Select the top 25 rows
top_25_stocks = df_sorted_by_volume.head(25)

# Export the top 25 stocks to a new Excel file with today's date in the file name
top_25_file_name = f'top_25_selected_stocks_volume_{today_date}.xlsx'
top_25_stocks.to_excel(top_25_file_name, index=False)

# Output the selected stocks
print("Selected Stocks:")
for stock, date in selected_stocks:
    print(f"{stock} on {date} - Entry Price: {df_merged.loc[df_merged['Stock'] == stock, 'EntryPrice'].iloc[0]}")
# Out:
# Processing 20MICRONS.NS...
# [*********************100%%**********************]  1 of 1 completed
# Processing 21STCENMGM.NS...
# [*********************100%%**********************]  1 of 1 completed
# Processing 360ONE.NS...
# [*********************100%%**********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['360ONE.NS']: Exception('%ticker%: No price data found, symbol may be delisted (period=1d)')
# Processing 3IINFOLTD.NS...
# [*********************100%%**********************]  1 of 1 completed
# Processing 3PLAND.NS...
# [*********************100%%**********************]  1 of 1 completed
# Processing 5PAISA.NS...
# [*********************100%%**********************]  1 of 1 completed
# Processing 63MOONS.NS...
# [*********************100%%**********************]  1 of 1 completed
# Processing A2ZINFRA.NS...
# [*********************100%%**********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ...

# %% [markdown]
# #Backtesting with excel (stock,date, entry price, exit price, volume)

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime


def fetch_data(stock):
    # Fetch historical data for the stock for the last 7 days with 1-minute intervals
    data = yf.download(stock, period="1d", interval="5m")
    return data


def trading_strategy(data, stock):
    entry_points = []
    exit_points = []
    profits = []
    volumes = []  # Store stock volume

    for date in data.index.normalize().unique():
        daily_data = data[data.index.normalize() == date]
        interval_data = daily_data.between_time('09:15', '09:20')

        # Modify the logic to buy after the required candle is detected
        if not interval_data.empty and interval_data.iloc[0]['Open'] == interval_data['Low'].min():
            entry_price = interval_data.iloc[0]['Open']
            exit_data = daily_data.between_time('11:59', '12:00')
            if not exit_data.empty:
                exit_price = exit_data.iloc[-1]['Close']
                profit_percentage = ((exit_price - entry_price) / entry_price) * 100
                entry_points.append((date.date(), entry_price))
                exit_points.append((date.date(), exit_price))
                profits.append(profit_percentage)
                volumes.append(daily_data['Volume'].sum())  # Sum of volume during the day

    return entry_points, exit_points, profits, volumes


# List of NSE stocks
nse_stocks = ['20MICRONS.NS', '21STCENMGM.NS', '360ONE.NS', '3IINFOLTD.NS', '3PLAND.NS', '5PAISA.NS', '63MOONS.NS', 'A2ZINFRA.NS', 'AAATECH.NS', 'AAKASH.NS', 'AAREYDRUGS.NS', 'AARON.NS', 'AARTECH.NS', 'AARTIDRUGS.NS', 'AARTIIND.NS', 'AARTIPHARM.NS', 'AARTISURF.NS', 'AARVEEDEN.NS', 'AARVI.NS', 'AAVAS.NS', 'ABAN.NS', 'ABCAPITAL.NS', 'ABFRL.NS', 'ABMINTLLTD.NS', 'ABSLAMC.NS', 'ACCELYA.NS', 'ACCURACY.NS', 'ACE.NS', 'ACEINTEG.NS', 'ACI.NS', 'ACL.NS', 'ACLGATI.NS', 'ADANIENSOL.NS', 'ADANIGREEN.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'ADFFOODS.NS', 'ADL.NS', 'ADORWELD.NS', 'ADROITINFO.NS', 'ADSL.NS', 'ADVANIHOTR.NS', 'ADVENZYMES.NS', 'AEGISCHEM.NS', 'AEROFLEX.NS', 'AETHER.NS', 'AFFLE.NS', 'AGARIND.NS', 'AGI.NS', 'AGRITECH.NS', 'AGROPHOS.NS', 'AGSTRA.NS', 'AHL.NS', 'AHLADA.NS', 'AHLEAST.NS', 'AHLUCONT.NS', 'AIRAN.NS', 'AIROLAM.NS', 'AJMERA.NS', 'AJOONI.NS', 'AKASH.NS', 'AKG.NS', 'AKI.NS', 'AKSHAR.NS', 'AKSHARCHEM.NS', 'AKSHOPTFBR.NS', 'ALANKIT.NS', 'ALBERTDAVD.NS', 'ALEMBICLTD.NS', 'ALICON.NS', 'ALKALI.NS', 'ALLCARGO.NS', 'ALLSEC.NS', 'ALMONDZ.NS', 'ALOKINDS.NS', 'ALPA.NS', 'ALPHAGEO.NS', 'ALPSINDUS.NS', 'AMBICAAGAR.NS', 'AMBIKCO.NS', 'AMBUJACEM.NS', 'AMDIND.NS', 'AMIORG.NS', 'AMJLAND.NS', 'AMNPLST.NS', 'AMRUTANJAN.NS', 'ANANTRAJ.NS', 'ANDHRAPAP.NS', 'ANDHRSUGAR.NS', 'ANIKINDS.NS', 'ANKITMETAL.NS', 'ANMOL.NS', 'ANTGRAPHIC.NS', 'ANURAS.NS', 'APCL.NS', 'APCOTEXIND.NS', 'APEX.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'APOLLO.NS', 'APOLLOPIPE.NS', 'APOLLOTYRE.NS', 'APTECHT.NS', 'APTUS.NS', 'ARCHIDPLY.NS', 'ARCHIES.NS', 'ARE&M.NS', 'ARENTERP.NS', 'ARIES.NS', 'ARIHANTCAP.NS', 'ARIHANTSUP.NS', 'AROGRANITE.NS', 'ARROWGREEN.NS', 'ARSHIYA.NS', 'ARSSINFRA.NS', 'ARTEMISMED.NS', 'ARTNIRMAN.NS', 'ARVEE.NS', 'ARVIND.NS', 'ARVINDFASN.NS', 'ARVSMART.NS', 'ASAHIINDIA.NS', 'ASAHISONG.NS', 'ASAL.NS', 'ASALCBR.NS', 'ASHAPURMIN.NS', 'ASHIANA.NS', 'ASHIMASYN.NS', 'ASHOKA.NS', 'ASHOKAMET.NS', 'ASHOKLEY.NS', 'ASIANENE.NS', 'ASIANHOTNR.NS', 'ASIANTILES.NS', 'ASKAUTOLTD.NS', 'ASMS.NS', 'ASPINWALL.NS', 'ASTEC.NS', 'ASTERDM.NS', 'ASTRAL.NS', 'ASTRAMICRO.NS', 'ASTRON.NS', 'ATALREAL.NS', 'ATAM.NS', 'ATFL.NS', 'ATGL.NS', 'ATL.NS', 'ATLANTAA.NS', 'ATULAUTO.NS', 'AUBANK.NS', 'AUROPHARMA.NS', 'AURUM.NS', 'AUSOMENT.NS', 'AUTOIND.NS', 'AVADHSUGAR.NS', 'AVALON.NS', 'AVANTIFEED.NS', 'AVG.NS', 'AVONMORE.NS', 'AVROIND.NS', 'AVTNPL.NS', 'AWHCL.NS', 'AWL.NS', 'AXISBANK.NS', 'AXISCADES.NS', 'AXITA.NS', 'AYMSYNTEX.NS', 'AZAD.NS', 'BAFNAPH.NS', 'BAGFILMS.NS', 'BAIDFIN.NS', 'BAJAJCON.NS', 'BAJAJELEC.NS', 'BAJAJFINSV.NS', 'BAJAJHCARE.NS', 'BAJAJHIND.NS', 'BAJEL.NS', 'BALAJITELE.NS', 'BALAXI.NS', 'BALKRISHNA.NS', 'BALMLAWRIE.NS', 'BALPHARMA.NS', 'BALRAMCHIN.NS', 'BANARBEADS.NS', 'BANCOINDIA.NS', 'BANDHANBNK.NS', 'BANG.NS', 'BANKA.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BANSWRAS.NS', 'BARBEQUE.NS', 'BASML.NS', 'BATAINDIA.NS', 'BBOX.NS', 'BBTC.NS', 'BBTCL.NS', 'BCG.NS', 'BCLIND.NS', 'BCONCEPTS.NS', 'BDL.NS', 'BEARDSELL.NS', 'BECTORFOOD.NS', 'BEDMUTHA.NS', 'BEL.NS', 'BEPL.NS', 'BERGEPAINT.NS', 'BFINVEST.NS', 'BFUTILITIE.NS', 'BGRENERGY.NS', 'BHAGCHEM.NS', 'BHAGERIA.NS', 'BHAGYANGR.NS', 'BHANDARI.NS', 'BHARATFORG.NS', 'BHARATGEAR.NS', 'BHARATWIRE.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'BIGBLOC.NS', 'BIKAJI.NS', 'BIL.NS', 'BINANIIND.NS', 'BIOCON.NS', 'BIOFILCHEM.NS', 'BIRLACABLE.NS', 'BIRLACORPN.NS', 'BIRLAMONEY.NS', 'BKMINDST.NS', 'BLAL.NS', 'BLBLIMITED.NS', 'BLISSGVS.NS', 'BLKASHYAP.NS', 'BLS.NS', 'BLUECHIP.NS', 'BLUECOAST.NS', 'BLUEJET.NS', 'BLUESTARCO.NS', 'BODALCHEM.NS', 'BOHRAIND.NS', 'BOMDYEING.NS', 'BOROLTD.NS', 'BORORENEW.NS', 'BPCL.NS', 'BPL.NS', 'BRIGADE.NS', 'BRNL.NS', 'BROOKS.NS', 'BSHSL.NS', 'BSL.NS', 'BSOFT.NS', 'BTML.NS', 'BURNPUR.NS', 'BUTTERFLY.NS', 'BVCL.NS', 'BYKE.NS', 'CALSOFT.NS', 'CAMLINFINE.NS', 'CAMPUS.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CANTABIL.NS', 'CAPACITE.NS', 'CAPLIPOINT.NS', 'CAPTRUST.NS', 'CARBORUNIV.NS', 'CAREERP.NS', 'CARERATING.NS', 'CARTRADE.NS', 'CARYSIL.NS', 'CASTROLIND.NS', 'CCHHL.NS', 'CCL.NS', 'CDSL.NS', 'CELEBRITY.NS', 'CELLO.NS', 'CENTENKA.NS', 'CENTEXT.NS', 'CENTRALBK.NS', 'CENTRUM.NS', 'CENTUM.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CEREBRAINT.NS', 'CESC.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHALET.NS', 'CHAMBLFERT.NS', 'CHEMBOND.NS', 'CHEMCON.NS', 'CHEMFAB.NS', 'CHEMPLASTS.NS', 'CHENNPETRO.NS', 'CHEVIOT.NS', 'CHOICEIN.NS', 'CHOLAFIN.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'CIGNITITEC.NS', 'CINELINE.NS', 'CINEVISTA.NS', 'CIPLA.NS', 'CLEAN.NS', 'CLEDUCATE.NS', 'CLSEL.NS', 'CMSINFO.NS', 'COALINDIA.NS', 'COASTCORP.NS', 'COCHINSHIP.NS', 'COFFEEDAY.NS', 'COMPINFO.NS', 'COMPUSOFT.NS', 'CONCOR.NS', 'CONCORDBIO.NS', 'CONFIPET.NS', 'CONSOFINVT.NS', 'CONTROLPR.NS', 'CORALFINAC.NS', 'CORDSCABLE.NS', 'COROMANDEL.NS', 'COSMOFIRST.NS', 'COUNCODOS.NS', 'CREATIVE.NS', 'CREATIVEYE.NS', 'CREDITACC.NS', 'CREST.NS', 'CROMPTON.NS', 'CROWN.NS', 'CSBBANK.NS', 'CSLFINANCE.NS', 'CTE.NS', 'CUB.NS', 'CUBEXTUB.NS', 'CUPID.NS', 'CYBERMEDIA.NS', 'CYBERTECH.NS', 'CYIENTDLM.NS', 'DABUR.NS', 'DALMIASUG.NS', 'DAMODARIND.NS', 'DANGEE.NS', 'DATAMATICS.NS', 'DATAPATTNS.NS', 'DBCORP.NS', 'DBL.NS', 'DBOL.NS', 'DBREALTY.NS', 'DBSTOCKBRO.NS', 'DCAL.NS', 'DCBBANK.NS', 'DCI.NS', 'DCM.NS', 'DCMFINSERV.NS', 'DCMNVL.NS', 'DCMSHRIRAM.NS', 'DCMSRIND.NS', 'DCW.NS', 'DCXINDIA.NS', 'DECCANCE.NS', 'DEEPAKFERT.NS', 'DEEPENR.NS', 'DEEPINDS.NS', 'DELHIVERY.NS', 'DELPHIFX.NS', 'DELTACORP.NS', 'DELTAMAGNT.NS', 'DEN.NS', 'DENORA.NS', 'DEVIT.NS', 'DEVYANI.NS', 'DGCONTENT.NS', 'DHAMPURSUG.NS', 'DHANBANK.NS', 'DHANI.NS', 'DHANUKA.NS', 'DHARMAJ.NS', 'DHRUV.NS', 'DHUNINV.NS', 'DIACABS.NS', 'DIAMINESQ.NS', 'DIAMONDYD.NS', 'DICIND.NS', 'DIGISPICE.NS', 'DIGJAMLMTD.NS', 'DIL.NS', 'DISHTV.NS', 'DIVGIITTS.NS', 'DJML.NS', 'DLF.NS', 'DLINKINDIA.NS', 'DMCC.NS', 'DNAMEDIA.NS', 'DODLA.NS', 'DOLATALGO.NS', 'DOLLAR.NS', 'DOLPHIN.NS', 'DOMS.NS', 'DONEAR.NS', 'DPABHUSHAN.NS', 'DPSCLTD.NS', 'DPWIRES.NS', 'DRCSYSTEMS.NS', 'DREAMFOLKS.NS', 'DREDGECORP.NS', 'DSSL.NS', 'DTIL.NS', 'DUCON.NS', 'DVL.NS', 'DWARKESH.NS', 'DYCL.NS', 'DYNPRO.NS', 'E2E.NS', 'EASEMYTRIP.NS', 'EASTSILK.NS', 'EDELWEISS.NS', 'EDUCOMP.NS', 'EIDPARRY.NS', 'EIFFL.NS', 'EIHAHOTELS.NS', 'EIHOTEL.NS', 'EIMCOELECO.NS', 'EKC.NS', 'ELDEHSG.NS', 'ELECON.NS', 'ELECTCAST.NS', 'ELECTHERM.NS', 'ELGIEQUIP.NS', 'ELGIRUBCO.NS', 'ELIN.NS', 'EMAMILTD.NS', 'EMAMIPAP.NS', 'EMAMIREAL.NS', 'EMIL.NS', 'EMKAY.NS', 'EMMBI.NS', 'EMSLIMITED.NS', 'EMUDHRA.NS', 'ENDURANCE.NS', 'ENERGYDEV.NS', 'ENGINERSIN.NS', 'ENIL.NS', 'EPIGRAL.NS', 'EPL.NS', 'EQUIPPP.NS', 'EQUITASBNK.NS', 'ERIS.NS', 'EROSMEDIA.NS', 'ESAFSFB.NS', 'ESSARSHPNG.NS', 'ESSENTIA.NS', 'ESTER.NS', 'EUROTEXIND.NS', 'EVEREADY.NS', 'EVERESTIND.NS', 'EXCEL.NS', 'EXCELINDUS.NS', 'EXIDEIND.NS', 'EXPLEOSOL.NS', 'EXXARO.NS', 'FACT.NS', 'FAIRCHEMOR.NS', 'FAZE3Q.NS', 'FCL.NS', 'FCONSUMER.NS', 'FCSSOFT.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FEDFINA.NS', 'FEL.NS', 'FELDVR.NS', 'FIBERWEB.NS', 'FILATEX.NS', 'FINCABLES.NS', 'FINOPB.NS', 'FINPIPE.NS', 'FIVESTAR.NS', 'FLAIR.NS', 'FLEXITUFF.NS', 'FLFL.NS', 'FMGOETZE.NS', 'FMNL.NS', 'FOCUS.NS', 'FOODSIN.NS', 'FORTIS.NS', 'FSC.NS', 'FSL.NS', 'FUSION.NS', 'GABRIEL.NS', 'GAEL.NS', 'GAIL.NS', 'GALLANTT.NS', 'GANDHAR.NS', 'GANDHITUBE.NS', 'GANECOS.NS', 'GANESHBE.NS', 'GANESHHOUC.NS', 'GANGAFORGE.NS', 'GANGESSECU.NS', 'GATECH.NS', 'GATECHDVR.NS', 'GATEWAY.NS', 'GEECEE.NS', 'GEEKAYWIRE.NS', 'GENCON.NS', 'GENESYS.NS', 'GENSOL.NS', 'GENUSPAPER.NS', 'GENUSPOWER.NS', 'GEOJITFSL.NS', 'GEPIL.NS', 'GESHIP.NS', 'GET&D.NS', 'GFLLIMITED.NS', 'GHCL.NS', 'GHCLTEXTIL.NS', 'GICHSGFIN.NS', 'GICRE.NS', 'GILLANDERS.NS', 'GINNIFILA.NS', 'GIPCL.NS', 'GKWLIMITED.NS', 'GLAND.NS', 'GLENMARK.NS', 'GLFL.NS', 'GLOBAL.NS', 'GLOBALVECT.NS', 'GLOBE.NS', 'GLOBUSSPR.NS', 'GLS.NS', 'GMBREW.NS', 'GMDCLTD.NS', 'GMMPFAUDLR.NS', 'GMRINFRA.NS', 'GMRP&UI.NS', 'GNA.NS', 'GNFC.NS', 'GOACARBON.NS', 'GOCLCORP.NS', 'GOCOLORS.NS', 'GODHA.NS', 'GODREJAGRO.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GOENKA.NS', 'GOKEX.NS', 'GOKUL.NS', 'GOKULAGRO.NS', 'GOLDENTOBC.NS', 'GOLDIAM.NS', 'GOLDTECH.NS', 'GOODLUCK.NS', 'GOYALALUM.NS', 'GPIL.NS', 'GPPL.NS', 'GPTINFRA.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GRAVITA.NS', 'GREAVESCOT.NS', 'GREENLAM.NS', 'GREENPANEL.NS', 'GREENPLY.NS', 'GREENPOWER.NS', 'GRINFRA.NS', 'GRMOVER.NS', 'GROBTEA.NS', 'GRSE.NS', 'GRWRHITECH.NS', 'GSFC.NS', 'GSLSU.NS', 'GSPL.NS', 'GSS.NS', 'GTECJAINX.NS', 'GTL.NS', 'GTLINFRA.NS', 'GTPL.NS', 'GUFICBIO.NS', 'GUJALKALI.NS', 'GUJAPOLLO.NS', 'GUJGASLTD.NS', 'GUJRAFFIA.NS', 'GULFOILLUB.NS', 'GULFPETRO.NS', 'GULPOLY.NS', 'GVKPIL.NS', 'GVPTECH.NS', 'HAPPSTMNDS.NS', 'HAPPYFORGE.NS', 'HARDWYN.NS', 'HARIOMPIPE.NS', 'HARRMALAYA.NS', 'HARSHA.NS', 'HATHWAY.NS', 'HATSUN.NS', 'HAVELLS.NS', 'HAVISHA.NS', 'HBLPOWER.NS', 'HBSL.NS', 'HCC.NS', 'HCG.NS', 'HCL-INSYS.NS', 'HCLTECH.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'HEADSUP.NS', 'HECPROJECT.NS', 'HEG.NS', 'HEIDELBERG.NS', 'HEMIPROP.NS', 'HERANBA.NS', 'HERCULES.NS', 'HERITGFOOD.NS', 'HESTERBIO.NS', 'HEUBACHIND.NS', 'HEXATRADEX.NS', 'HFCL.NS', 'HGINFRA.NS', 'HGS.NS', 'HIKAL.NS', 'HILTON.NS', 'HIMATSEIDE.NS', 'HINDALCO.NS', 'HINDCOMPOS.NS', 'HINDCON.NS', 'HINDCOPPER.NS', 'HINDMOTORS.NS', 'HINDOILEXP.NS', 'HINDPETRO.NS', 'HINDWAREAP.NS', 'HINDZINC.NS', 'HIRECT.NS', 'HISARMETAL.NS', 'HITECH.NS', 'HITECHCORP.NS', 'HITECHGEAR.NS', 'HLEGLAS.NS', 'HLVLTD.NS', 'HMAAGRO.NS', 'HMT.NS', 'HMVL.NS', 'HNDFDS.NS', 'HOMEFIRST.NS', 'HONASA.NS', 'HOVS.NS', 'HPAL.NS', 'HPIL.NS', 'HPL.NS', 'HSCL.NS', 'HTMEDIA.NS', 'HUBTOWN.NS', 'HUDCO.NS', 'HUHTAMAKI.NS', 'HYBRIDFIN.NS', 'IBREALEST.NS', 'IBULHSGFIN.NS', 'ICDSLTD.NS', 'ICEMAKE.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'ICIL.NS', 'IDBI.NS', 'IDEA.NS', 'IDEAFORGE.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IEL.NS', 'IEX.NS', 'IFBAGRO.NS', 'IFBIND.NS', 'IFCI.NS', 'IFGLEXPOR.NS', 'IGARASHI.NS', 'IGL.NS', 'IGPL.NS', 'IIFL.NS', 'IIFLSEC.NS', 'IITL.NS', 'IKIO.NS', 'IL&FSENGG.NS', 'IL&FSTRANS.NS', 'IMAGICAA.NS', 'IMFA.NS', 'IMPAL.NS', 'IMPEXFERRO.NS', 'INCREDIBLE.NS', 'INDBANK.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INDIAGLYCO.NS', 'INDIANB.NS', 'INDIANCARD.NS', 'INDIANHUME.NS', 'INDIASHLTR.NS', 'INDIGOPNTS.NS', 'INDNIPPON.NS', 'INDOAMIN.NS', 'INDOBORAX.NS', 'INDOCO.NS', 'INDORAMA.NS', 'INDOSTAR.NS', 'INDOTECH.NS', 'INDOTHAI.NS', 'INDOWIND.NS', 'INDRAMEDCO.NS', 'INDSWFTLAB.NS', 'INDSWFTLTD.NS', 'INDTERRAIN.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'INFOBEAN.NS', 'INFOMEDIA.NS', 'INFY.NS', 'INNOVACAP.NS', 'INOXGREEN.NS', 'INOXINDIA.NS', 'INOXWIND.NS', 'INSECTICID.NS', 'INSPIRISYS.NS', 'INTELLECT.NS', 'INTENTECH.NS', 'INTLCONV.NS', 'INVENTURE.NS', 'IOB.NS', 'IOC.NS', 'IOLCP.NS', 'IONEXCHANG.NS', 'IPCALAB.NS', 'IPL.NS', 'IRB.NS', 'IRCON.NS', 'IRCTC.NS', 'IREDA.NS', 'IRFC.NS', 'IRIS.NS', 'IRISDOREME.NS', 'IRMENERGY.NS', 'ISEC.NS', 'ISFT.NS', 'ISGEC.NS', 'ISMTLTD.NS', 'ITC.NS', 'ITDC.NS', 'ITDCEM.NS', 'ITI.NS', 'IVC.NS', 'IVP.NS', 'IZMO.NS', 'J&KBANK.NS', 'JAGRAN.NS', 'JAGSNPHARM.NS', 'JAIBALAJI.NS', 'JAICORPLTD.NS', 'JAIPURKURT.NS', 'JAMNAAUTO.NS', 'JASH.NS', 'JAYAGROGN.NS', 'JAYBARMARU.NS', 'JAYNECOIND.NS', 'JAYSREETEA.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JCHAC.NS', 'JETAIRWAYS.NS', 'JETFREIGHT.NS', 'JHS.NS', 'JINDALPHOT.NS', 'JINDALPOLY.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JINDRILL.NS', 'JINDWORLD.NS', 'JIOFIN.NS', 'JISLDVREQS.NS', 'JISLJALEQS.NS', 'JITFINFRA.NS', 'JKIL.NS', 'JKLAKSHMI.NS', 'JKPAPER.NS', 'JKTYRE.NS', 'JLHL.NS', 'JMA.NS', 'JMFINANCIL.NS', 'JOCIL.NS', 'JPASSOCIAT.NS', 'JPOLYINVST.NS', 'JPPOWER.NS', 'JSL.NS', 'JSWENERGY.NS', 'JSWINFRA.NS', 'JSWSTEEL.NS', 'JTEKTINDIA.NS', 'JTLIND.NS', 'JUBLFOOD.NS', 'JUBLINDS.NS', 'JUBLINGREA.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'JWL.NS', 'JYOTHYLAB.NS', 'JYOTISTRUC.NS', 'KABRAEXTRU.NS', 'KAJARIACER.NS', 'KAKATCEM.NS', 'KALAMANDIR.NS', 'KALYANIFRG.NS', 'KALYANKJIL.NS', 'KAMATHOTEL.NS', 'KAMDHENU.NS', 'KAMOPAINTS.NS', 'KANANIIND.NS', 'KANORICHEM.NS', 'KANPRPLA.NS', 'KANSAINER.NS', 'KAPSTON.NS', 'KARMAENG.NS', 'KARURVYSYA.NS', 'KAUSHALYA.NS', 'KAVVERITEL.NS', 'KAYA.NS', 'KBCGLOBAL.NS', 'KCP.NS', 'KCPSUGIND.NS', 'KEC.NS', 'KECL.NS', 'KEEPLEARN.NS', 'KELLTONTEC.NS', 'KERNEX.NS', 'KESORAMIND.NS', 'KEYFINSERV.NS', 'KFINTECH.NS', 'KHADIM.NS', 'KHAICHEM.NS', 'KHAITANLTD.NS', 'KHANDSE.NS', 'KILITCH.NS', 'KIOCL.NS', 'KIRIINDUS.NS', 'KIRLOSBROS.NS', 'KIRLOSENG.NS', 'KIRLPNU.NS', 'KITEX.NS', 'KKCL.NS', 'KMSUGAR.NS', 'KNRCON.NS', 'KOHINOOR.NS', 'KOKUYOCMLN.NS', 'KOLTEPATIL.NS', 'KOPRAN.NS', 'KOTAKBANK.NS', 'KOTARISUG.NS', 'KOTHARIPET.NS', 'KOTHARIPRO.NS', 'KPIGREEN.NS', 'KPIL.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'KRBL.NS', 'KREBSBIO.NS', 'KRIDHANINF.NS', 'KRISHANA.NS', 'KRITI.NS', 'KRITIKA.NS', 'KRITINUT.NS', 'KRSNAA.NS', 'KSCL.NS', 'KSHITIJPOL.NS', 'KSL.NS', 'KSOLVES.NS', 'KTKBANK.NS', 'KUANTUM.NS', 'L&TFH.NS', 'LAGNAM.NS', 'LAKPRE.NS', 'LAL.NS', 'LAMBODHARA.NS', 'LANDMARK.NS', 'LAOPALA.NS', 'LASA.NS', 'LATENTVIEW.NS', 'LATTEYS.NS', 'LAURUSLABS.NS', 'LAXMICOT.NS', 'LCCINFOTEC.NS', 'LEMONTREE.NS', 'LEXUS.NS', 'LFIC.NS', 'LGBBROSLTD.NS', 'LGBFORGE.NS', 'LGHL.NS', 'LIBAS.NS', 'LIBERTSHOE.NS', 'LICHSGFIN.NS', 'LICI.NS', 'LIKHITHA.NS', 'LINC.NS', 'LINCOLN.NS', 'LLOYDSENGG.NS', 'LLOYDSME.NS', 'LODHA.NS', 'LOKESHMACH.NS', 'LORDSCHLO.NS', 'LOTUSEYE.NS', 'LOVABLE.NS', 'LOYALTEX.NS', 'LPDC.NS', 'LTFOODS.NS', 'LUMAXTECH.NS', 'LUPIN.NS', 'LUXIND.NS', 'LXCHEM.NS', 'LYKALABS.NS', 'LYPSAGEMS.NS', 'M&M.NS', 'M&MFIN.NS', 'MAANALU.NS', 'MACPOWER.NS', 'MADHAV.NS', 'MADHUCON.NS', 'MADRASFERT.NS', 'MAGADSUGAR.NS', 'MAGNUM.NS', 'MAHABANK.NS', 'MAHAPEXLTD.NS', 'MAHASTEEL.NS', 'MAHEPC.NS', 'MAHESHWARI.NS', 'MAHLIFE.NS', 'MAHLOG.NS', 'MAHSEAMLES.NS', 'MAITHANALL.NS', 'MALLCOM.NS', 'MALUPAPER.NS', 'MANAKALUCO.NS', 'MANAKCOAT.NS', 'MANAKSIA.NS', 'MANAKSTEEL.NS', 'MANALIPETC.NS', 'MANAPPURAM.NS', 'MANGALAM.NS', 'MANGCHEFER.NS', 'MANGLMCEM.NS', 'MANINDS.NS', 'MANINFRA.NS', 'MANOMAY.NS', 'MANORG.NS', 'MANUGRAPH.NS', 'MANYAVAR.NS', 'MARALOVER.NS', 'MARATHON.NS', 'MARICO.NS', 'MARINE.NS', 'MARKSANS.NS', 'MARSHALL.NS', 'MASFIN.NS', 'MASKINVEST.NS', 'MATRIMONY.NS', 'MAWANASUG.NS', 'MAXESTATES.NS', 'MAXHEALTH.NS', 'MAXIND.NS', 'MAYURUNIQ.NS', 'MAZDA.NS', 'MBAPL.NS', 'MBECL.NS', 'MBLINFRA.NS', 'MCDOWELL-N.NS', 'MCL.NS', 'MCLEODRUSS.NS', 'MEDANTA.NS', 'MEDICAMEQ.NS', 'MEDICO.NS', 'MEDPLUS.NS', 'MEGASOFT.NS', 'MEGASTAR.NS', 'MELSTAR.NS', 'MENONBE.NS', 'MEP.NS', 'METALFORGE.NS', 'METROBRAND.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MGEL.NS', 'MGL.NS', 'MHLXMIRU.NS', 'MHRIL.NS', 'MICEL.NS', 'MIDHANI.NS', 'MINDACORP.NS', 'MINDTECK.NS', 'MIRCELECTR.NS', 'MIRZAINT.NS', 'MITCON.NS', 'MITTAL.NS', 'MKPL.NS', 'MMFL.NS', 'MMP.NS', 'MMTC.NS', 'MODIRUBBER.NS', 'MODISONLTD.NS', 'MOHITIND.NS', 'MOIL.NS', 'MOKSH.NS', 'MOL.NS', 'MOLDTECH.NS', 'MOLDTKPAC.NS', 'MONARCH.NS', 'MONTECARLO.NS', 'MORARJEE.NS', 'MOREPENLAB.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'MOTISONS.NS', 'MOTOGENFIN.NS', 'MPSLTD.NS', 'MRO-TEK.NS', 'MRPL.NS', 'MSPL.NS', 'MSTCLTD.NS', 'MSUMI.NS', 'MTEDUCARE.NS', 'MTNL.NS', 'MUFIN.NS', 'MUFTI.NS', 'MUKANDLTD.NS', 'MUKTAARTS.NS', 'MUNJALAU.NS', 'MUNJALSHOW.NS', 'MURUDCERA.NS', 'MUTHOOTCAP.NS', 'MUTHOOTFIN.NS', 'MUTHOOTMF.NS', 'MVGJL.NS', 'NACLIND.NS', 'NAGAFERT.NS', 'NAGREEKCAP.NS', 'NAGREEKEXP.NS', 'NAHARCAP.NS', 'NAHARINDUS.NS', 'NAHARPOLY.NS', 'NAHARSPING.NS', 'NAM-INDIA.NS', 'NARMADA.NS', 'NATCOPHARM.NS', 'NATHBIOGEN.NS', 'NATIONALUM.NS', 'NAVA.NS', 'NAVKARCORP.NS', 'NAVNETEDUL.NS', 'NAZARA.NS', 'NBCC.NS', 'NBIFIN.NS', 'NCC.NS', 'NCLIND.NS', 'NDL.NS', 'NDLVENTURE.NS', 'NDRAUTO.NS', 'NDTV.NS', 'NECCLTD.NS', 'NECLIFE.NS', 'NELCAST.NS', 'NELCO.NS', 'NEOGEN.NS', 'NESCO.NS', 'NETWEB.NS', 'NETWORK18.NS', 'NEWGEN.NS', 'NEXTMEDIA.NS', 'NFL.NS', 'NGIL.NS', 'NH.NS', 'NHPC.NS', 'NIACL.NS', 'NIBL.NS', 'NIITLTD.NS', 'NIITMTS.NS', 'NILAINFRA.NS', 'NILASPACES.NS', 'NINSYS.NS', 'NIPPOBATRY.NS', 'NIRAJ.NS', 'NITCO.NS', 'NITINSPIN.NS', 'NITIRAJ.NS', 'NKIND.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NOCIL.NS', 'NOIDATOLL.NS', 'NORBTEAEXP.NS', 'NRAIL.NS', 'NRBBEARING.NS', 'NRL.NS', 'NSLNISP.NS', 'NTPC.NS', 'NUCLEUS.NS', 'NURECA.NS', 'NUVOCO.NS', 'NYKAA.NS', 'OAL.NS', 'OBCL.NS', 'OBEROIRLTY.NS', 'OCCL.NS', 'OIL.NS', 'OILCOUNTUB.NS', 'OLECTRA.NS', 'OMAXAUTO.NS', 'OMAXE.NS', 'OMINFRAL.NS', 'OMKARCHEM.NS', 'ONELIFECAP.NS', 'ONEPOINT.NS', 'ONGC.NS', 'ONMOBILE.NS', 'ONWARDTEC.NS', 'OPTIEMUS.NS', 'ORBTEXP.NS', 'ORCHPHARMA.NS', 'ORICONENT.NS', 'ORIENTALTL.NS', 'ORIENTBELL.NS', 'ORIENTCEM.NS', 'ORIENTCER.NS', 'ORIENTELEC.NS', 'ORIENTHOT.NS', 'ORIENTLTD.NS', 'ORIENTPPR.NS', 'ORTINLAB.NS', 'OSIAHYPER.NS', 'OSWALAGRO.NS', 'OSWALGREEN.NS', 'OSWALSEEDS.NS', 'PAISALO.NS', 'PAKKA.NS', 'PALASHSECU.NS', 'PALREDTEC.NS', 'PANACEABIO.NS', 'PANACHE.NS', 'PANAMAPET.NS', 'PANSARI.NS', 'PAR.NS', 'PARACABLES.NS', 'PARADEEP.NS', 'PARAGMILK.NS', 'PARAS.NS', 'PARASPETRO.NS', 'PARSVNATH.NS', 'PASUPTAC.NS', 'PATANJALI.NS', 'PATELENG.NS', 'PATINTLOG.NS', 'PAVNAIND.NS', 'PAYTM.NS', 'PCBL.NS', 'PCJEWELLER.NS', 'PDMJEPAPER.NS', 'PDSL.NS', 'PEARLPOLY.NS', 'PEL.NS', 'PENIND.NS', 'PENINLAND.NS', 'PETRONET.NS', 'PFC.NS', 'PFOCUS.NS', 'PFS.NS', 'PGIL.NS', 'PIGL.NS', 'PILITA.NS', 'PIONEEREMB.NS', 'PITTIENG.NS', 'PIXTRANS.NS', 'PKTEA.NS', 'PLASTIBLEN.NS', 'PLAZACABLE.NS', 'PNB.NS', 'PNBGILTS.NS', 'PNBHOUSING.NS', 'PNC.NS', 'PNCINFRA.NS', 'POCL.NS', 'PODDARHOUS.NS', 'PODDARMENT.NS', 'POKARNA.NS', 'POLICYBZR.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'PONNIERODE.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'PPAP.NS', 'PPL.NS', 'PPLPHARMA.NS', 'PRAENG.NS', 'PRAJIND.NS', 'PRAKASH.NS', 'PRAKASHSTL.NS', 'PRAXIS.NS', 'PRECAM.NS', 'PRECOT.NS', 'PRECWIRE.NS', 'PREMEXPLN.NS', 'PREMIER.NS', 'PREMIERPOL.NS', 'PRESTIGE.NS', 'PRICOLLTD.NS', 'PRIMESECU.NS', 'PRINCEPIPE.NS', 'PRITI.NS', 'PRITIKAUTO.NS', 'PRIVISCL.NS', 'PROZONER.NS', 'PRSMJOHNSN.NS', 'PRUDENT.NS', 'PRUDMOULI.NS', 'PSB.NS', 'PSPPROJECT.NS', 'PTC.NS', 'PTL.NS', 'PUNJABCHEM.NS', 'PURVA.NS', 'PVP.NS', 'PVRINOX.NS', 'PYRAMID.NS', 'QUESS.NS', 'QUICKHEAL.NS', 'RACE.NS', 'RADAAN.NS', 'RADHIKAJWE.NS', 'RADIANTCMS.NS', 'RADICO.NS', 'RADIOCITY.NS', 'RAILTEL.NS', 'RAIN.NS', 'RAINBOW.NS', 'RAJESHEXPO.NS', 'RAJMET.NS', 'RAJRATAN.NS', 'RAJRILTD.NS', 'RAJSREESUG.NS', 'RAJTV.NS', 'RALLIS.NS', 'RAMANEWS.NS', 'RAMAPHO.NS', 'RAMASTEEL.NS', 'RAMCOCEM.NS', 'RAMCOIND.NS', 'RAMCOSYS.NS', 'RAMKY.NS', 'RAMRAT.NS', 'RANASUG.NS', 'RANEENGINE.NS', 'RANEHOLDIN.NS', 'RATEGAIN.NS', 'RATNAVEER.NS', 'RAYMOND.NS', 'RBA.NS', 'RBL.NS', 'RBLBANK.NS', 'RBZJEWEL.NS', 'RCF.NS', 'RECLTD.NS', 'REDINGTON.NS', 'REDTAPE.NS', 'REFEX.NS', 'REGENCERAM.NS', 'RELAXO.NS', 'RELCAPITAL.NS', 'RELCHEMQ.NS', 'RELIGARE.NS', 'RELINFRA.NS', 'REMSONSIND.NS', 'RENUKA.NS', 'REPCOHOME.NS', 'REPL.NS', 'REPRO.NS', 'RESPONIND.NS', 'RGL.NS', 'RHFL.NS', 'RHIM.NS', 'RHL.NS', 'RICOAUTO.NS', 'RIIL.NS', 'RISHABH.NS', 'RITCO.NS', 'RITES.NS', 'RKDL.NS', 'RKEC.NS', 'RKFORGE.NS', 'RML.NS', 'ROHLTD.NS', 'ROLLT.NS', 'ROML.NS', 'ROSSARI.NS', 'ROSSELLIND.NS', 'ROTO.NS', 'ROUTE.NS', 'RPGLIFE.NS', 'RPOWER.NS', 'RPPINFRA.NS', 'RPPL.NS', 'RPSGVENT.NS', 'RRKABEL.NS', 'RSSOFTWARE.NS', 'RSWM.NS', 'RSYSTEMS.NS', 'RTNINDIA.NS', 'RTNPOWER.NS', 'RUBYMILLS.NS', 'RUCHINFRA.NS', 'RUCHIRA.NS', 'RUPA.NS', 'RUSHIL.NS', 'RUSTOMJEE.NS', 'RVHL.NS', 'RVNL.NS', 'S&SPOWER.NS', 'SABEVENTS.NS', 'SABTN.NS', 'SADBHAV.NS', 'SADBHIN.NS', 'SADHNANIQ.NS', 'SAFARI.NS', 'SAGARDEEP.NS', 'SAGCEM.NS', 'SAH.NS', 'SAHYADRI.NS', 'SAIL.NS', 'SAKAR.NS', 'SAKHTISUG.NS', 'SAKSOFT.NS', 'SAKUMA.NS', 'SALASAR.NS', 'SALONA.NS', 'SALSTEEL.NS', 'SALZERELEC.NS', 'SAMBHAAV.NS', 'SAMHI.NS', 'SAMPANN.NS', 'SANCO.NS', 'SANDESH.NS', 'SANDHAR.NS', 'SANGAMIND.NS', 'SANGHIIND.NS', 'SANGHVIMOV.NS', 'SANGINITA.NS', 'SANSERA.NS', 'SAPPHIRE.NS', 'SARDAEN.NS', 'SAREGAMA.NS', 'SARLAPOLY.NS', 'SARVESHWAR.NS', 'SASKEN.NS', 'SASTASUNDR.NS', 'SATIA.NS', 'SATIN.NS', 'SATINDLTD.NS', 'SBC.NS', 'SBCL.NS', 'SBFC.NS', 'SBGLP.NS', 'SBICARD.NS', 'SBILIFE.NS', 'SBIN.NS', 'SCHAND.NS', 'SCHNEIDER.NS', 'SCI.NS', 'SCPL.NS', 'SDBL.NS', 'SEAMECLTD.NS', 'SECMARK.NS', 'SECURCRED.NS', 'SECURKLOUD.NS', 'SEJALLTD.NS', 'SELAN.NS', 'SELMC.NS', 'SENCO.NS', 'SEPC.NS', 'SEQUENT.NS', 'SERVOTECH.NS', 'SESHAPAPER.NS', 'SETCO.NS', 'SEYAIND.NS', 'SFL.NS', 'SGIL.NS', 'SGL.NS', 'SHAH.NS', 'SHAHALLOYS.NS', 'SHAILY.NS', 'SHAKTIPUMP.NS', 'SHALBY.NS', 'SHALPAINTS.NS', 'SHANKARA.NS', 'SHANTI.NS', 'SHANTIGEAR.NS', 'SHARDACROP.NS', 'SHARDAMOTR.NS', 'SHAREINDIA.NS', 'SHEMAROO.NS', 'SHILPAMED.NS', 'SHIVALIK.NS', 'SHIVAMAUTO.NS', 'SHIVAMILLS.NS', 'SHIVATEX.NS', 'SHK.NS', 'SHOPERSTOP.NS', 'SHRADHA.NS', 'SHREDIGCEM.NS', 'SHREEPUSHK.NS', 'SHREERAMA.NS', 'SHRENIK.NS', 'SHREYANIND.NS', 'SHREYAS.NS', 'SHRIPISTON.NS', 'SHRIRAMPPS.NS', 'SHYAMCENT.NS', 'SHYAMMETL.NS', 'SHYAMTEL.NS', 'SICALLOG.NS', 'SIGACHI.NS', 'SIGIND.NS', 'SIGMA.NS', 'SIGNATURE.NS', 'SIKKO.NS', 'SIL.NS', 'SILGO.NS', 'SILINV.NS', 'SILLYMONKS.NS', 'SILVERTUC.NS', 'SIMBHALS.NS', 'SIMPLEXINF.NS', 'SINDHUTRAD.NS', 'SINTERCOM.NS', 'SIRCA.NS', 'SIS.NS', 'SITINET.NS', 'SIYSIL.NS', 'SJS.NS', 'SJVN.NS', 'SKIPPER.NS', 'SKMEGGPROD.NS', 'SKYGOLD.NS', 'SMARTLINK.NS', 'SMCGLOBAL.NS', 'SMLISUZU.NS', 'SMLT.NS', 'SMSLIFE.NS', 'SMSPHARMA.NS', 'SNOWMAN.NS', 'SOBHA.NS', 'SOFTTECH.NS', 'SOLARA.NS', 'SOMANYCERA.NS', 'SOMATEX.NS', 'SOMICONVEY.NS', 'SONACOMS.NS', 'SONAMLTD.NS', 'SONATSOFTW.NS', 'SOTL.NS', 'SOUTHBANK.NS', 'SOUTHWEST.NS', 'SPAL.NS', 'SPANDANA.NS', 'SPARC.NS', 'SPCENET.NS', 'SPECIALITY.NS', 'SPENCERS.NS', 'SPENTEX.NS', 'SPIC.NS', 'SPLIL.NS', 'SPLPETRO.NS', 'SPMLINFRA.NS', 'SPORTKING.NS', 'SPTL.NS', 'SPYL.NS', 'SREEL.NS', 'SRGHFL.NS', 'SRHHYPOLTD.NS', 'SRPL.NS', 'SSWL.NS', 'STAR.NS', 'STARCEMENT.NS', 'STARHEALTH.NS', 'STARPAPER.NS', 'STARTECK.NS', 'STCINDIA.NS', 'STEELCAS.NS', 'STEELCITY.NS', 'STEELXIND.NS', 'STEL.NS', 'STERTOOLS.NS', 'STLTECH.NS', 'STOVEKRAFT.NS', 'STYLAMIND.NS', 'STYRENIX.NS', 'SUBEXLTD.NS', 'SUBROS.NS', 'SUDARSCHEM.NS', 'SUKHJITS.NS', 'SULA.NS', 'SUMICHEM.NS', 'SUMIT.NS', 'SUMMITSEC.NS', 'SUNCLAY.NS', 'SUNDARAM.NS', 'SUNDARMHLD.NS', 'SUNDRMBRAK.NS', 'SUNDRMFAST.NS', 'SUNFLAG.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SUNTV.NS', 'SUPERHOUSE.NS', 'SUPERSPIN.NS', 'SUPRAJIT.NS', 'SUPREMEENG.NS', 'SUPREMEINF.NS', 'SUPRIYA.NS', 'SURAJEST.NS', 'SURANASOL.NS', 'SURANAT&P.NS', 'SURYALAXMI.NS', 'SURYAROSNI.NS', 'SURYODAY.NS', 'SUTLEJTEX.NS', 'SUULD.NS', 'SUVEN.NS', 'SUVENPHAR.NS', 'SUVIDHAA.NS', 'SUZLON.NS', 'SVLL.NS', 'SVPGLOB.NS', 'SWANENERGY.NS', 'SWELECTES.NS', 'SWSOLAR.NS', 'SYMPHONY.NS', 'SYNCOMF.NS', 'SYNGENE.NS', 'SYRMA.NS', 'TAINWALCHM.NS', 'TAJGVK.NS', 'TAKE.NS', 'TALBROAUTO.NS', 'TANLA.NS', 'TARAPUR.NS', 'TARC.NS', 'TARMAT.NS', 'TARSONS.NS', 'TATACHEM.NS', 'TATACOFFEE.NS', 'TATACOMM.NS', 'TATACONSUM.NS', 'TATAMETALI.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TATATECH.NS', 'TATVA.NS', 'TBZ.NS', 'TCI.NS', 'TCIEXP.NS', 'TCLCONS.NS', 'TCNSBRANDS.NS', 'TDPOWERSYS.NS', 'TECHIN.NS', 'TECHM.NS', 'TECHNOE.NS', 'TECILCHEM.NS', 'TEGA.NS', 'TEJASNET.NS', 'TEMBO.NS', 'TERASOFT.NS', 'TEXINFRA.NS', 'TEXMOPIPES.NS', 'TEXRAIL.NS', 'TFCILTD.NS', 'TFL.NS', 'TGBHOTELS.NS', 'THANGAMAYL.NS', 'THEINVEST.NS', 'THEJO.NS', 'THEMISMED.NS', 'THOMASCOOK.NS', 'THOMASCOTT.NS', 'THYROCARE.NS', 'TI.NS', 'TIDEWATER.NS', 'TIJARIA.NS', 'TIL.NS', 'TIMESGTY.NS', 'TIMETECHNO.NS', 'TINPLATE.NS', 'TIPSFILMS.NS', 'TIPSINDLTD.NS', 'TIRUMALCHM.NS', 'TIRUPATIFL.NS', 'TITAGARH.NS', 'TMB.NS', 'TNPETRO.NS', 'TNPL.NS', 'TNTELE.NS', 'TOKYOPLAST.NS', 'TORNTPOWER.NS', 'TOTAL.NS', 'TOUCHWOOD.NS', 'TPHQ.NS', 'TPLPLASTEH.NS', 'TRACXN.NS', 'TREEHOUSE.NS', 'TREJHARA.NS', 'TREL.NS', 'TRF.NS', 'TRIDENT.NS', 'TRIGYN.NS', 'TRIL.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TRU.NS', 'TTKHLTCARE.NS', 'TTKPRESTIG.NS', 'TTL.NS', 'TTML.NS', 'TV18BRDCST.NS', 'TVSELECT.NS', 'TVSSCS.NS', 'TVTODAY.NS', 'TVVISION.NS', 'UBL.NS', 'UCAL.NS', 'UCOBANK.NS', 'UDS.NS', 'UFLEX.NS', 'UFO.NS', 'UGARSUGAR.NS', 'UGROCAP.NS', 'UJJIVAN.NS', 'UJJIVANSFB.NS', 'UMAEXPORTS.NS', 'UMANGDAIRY.NS', 'UMESLTD.NS', 'UNICHEMLAB.NS', 'UNIDT.NS', 'UNIENTER.NS', 'UNIINFO.NS', 'UNIONBANK.NS', 'UNIPARTS.NS', 'UNITECH.NS', 'UNITEDPOLY.NS', 'UNITEDTEA.NS', 'UNIVAFOODS.NS', 'UNIVASTU.NS', 'UNIVCABLES.NS', 'UNIVPHOTO.NS', 'UNOMINDA.NS', 'UPL.NS', 'URAVI.NS', 'URJA.NS', 'USHAMART.NS', 'USK.NS', 'UTIAMC.NS', 'UTKARSHBNK.NS', 'UTTAMSUGAR.NS', 'V2RETAIL.NS', 'VAIBHAVGBL.NS', 'VAISHALI.NS', 'VAKRANGEE.NS', 'VALIANTLAB.NS', 'VALIANTORG.NS', 'VARDHACRLC.NS', 'VARDMNPOLY.NS', 'VARROC.NS', 'VASCONEQ.NS', 'VASWANI.NS', 'VBL.NS', 'VCL.NS', 'VEDL.NS', 'VENUSPIPES.NS', 'VENUSREM.NS', 'VERANDA.NS', 'VERTOZ.NS', 'VETO.NS', 'VGUARD.NS', 'VIDHIING.NS', 'VIJAYA.NS', 'VIJIFIN.NS', 'VIKASECO.NS', 'VIKASLIFE.NS', 'VIMTALABS.NS', 'VINATIORGA.NS', 'VINEETLAB.NS', 'VINNY.NS', 'VINYLINDIA.NS', 'VIPCLOTHNG.NS', 'VIPIND.NS', 'VIPULLTD.NS', 'VIRINCHI.NS', 'VISAKAIND.NS', 'VISESHINFO.NS', 'VISHNU.NS', 'VISHWARAJ.NS', 'VIVIDHA.NS', 'VLEGOV.NS', 'VLSFINANCE.NS', 'VOLTAS.NS', 'VPRPL.NS', 'VRLLOG.NS', 'VSSL.NS', 'VTL.NS', 'WABAG.NS', 'WALCHANNAG.NS', 'WANBURY.NS', 'WEALTH.NS', 'WEBELSOLAR.NS', 'WEIZMANIND.NS', 'WEL.NS', 'WELCORP.NS', 'WELENT.NS', 'WELINV.NS', 'WELSPUNLIV.NS', 'WESTLIFE.NS', 'WEWIN.NS', 'WHEELS.NS', 'WHIRLPOOL.NS', 'WILLAMAGOR.NS', 'WINDLAS.NS', 'WINDMACHIN.NS', 'WINSOME.NS', 'WIPL.NS', 'WIPRO.NS', 'WOCKPHARMA.NS', 'WONDERLA.NS', 'WORTH.NS', 'WSI.NS', 'WSTCSTPAPR.NS', 'XCHANGING.NS', 'XELPMOC.NS', 'XPROINDIA.NS', 'YAARI.NS', 'YASHO.NS', 'YATHARTH.NS', 'YATRA.NS', 'YESBANK.NS', 'YUKEN.NS', 'ZAGGLE.NS', 'ZEEL.NS', 'ZEELEARN.NS', 'ZEEMEDIA.NS', 'ZENITHEXPO.NS', 'ZENITHSTL.NS', 'ZENSARTECH.NS', 'ZENTEC.NS', 'ZIMLAB.NS', 'ZODIAC.NS', 'ZODIACLOTH.NS', 'ZOMATO.NS', 'ZOTA.NS', 'ZUARI.NS', 'ZUARIIND.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS']
# Define the start and end dates for the historical data

# Initialize a list to store results
results = []

# Backtesting
selected_stocks = []
for stock in nse_stocks:
    print(f"Processing {stock}...")
    try:
        data = fetch_data(stock)
        if not isinstance(data.index, pd.DatetimeIndex):
            data.index = pd.to_datetime(data.index)

        entry_points, exit_points, profits, volumes = trading_strategy(data, stock)
        if entry_points:
            selected_stocks.append(stock)
            total_profit_percent = sum(profits) / len(profits) if profits else 0
            print(f"Stock: {stock}, Average Profit: {total_profit_percent:.2f}%, Trades: {len(profits)}")

            # Add results to list
            for i in range(len(entry_points)):
                results.append({
                    "Stock": stock,
                    "Date": entry_points[i][0],
                    "Entry Price": entry_points[i][1],
                    "Exit Price": exit_points[i][1],
                    "Profit (%)": profits[i],
                    "Volume": volumes[i]  # Add volume information
                })
    except Exception as e:
        print(f"Error processing {stock}: {e}")

# Convert results list to DataFrame
results_df = pd.DataFrame(results)

# Get today's date
today_date = datetime.now().strftime("%Y-%m-%d")

# Modify the Excel file name to include today's date
excel_file_name = f"backtesting_results_{today_date}.xlsx"

# Output the selected stocks
print("Selected Stocks:")
print(selected_stocks)

# Export results to Excel with today's date in the file name
results_df.to_excel(excel_file_name, index=False)

print(f"Results exported to {excel_file_name}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Processing 20MICRONS.NS...
# Processing 21STCENMGM.NS...
# Stock: 21STCENMGM.NS, Average Profit: 0.00%, Trades: 1
# Processing 360ONE.NS...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Processing 3IINFOLTD.NS...
# Processing 3PLAND.NS...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Processing 5PAISA.NS...
# Processing 63MOONS.NS...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Processing A2ZINFRA.NS...
# Processing AAATECH.NS...
# Processing AAKASH.NS...
# ...

# %% [markdown]
# #modified back-testing with put entry price as average price of 9:20-9:30, and also add few more parameters as day high, day low,

# %% [markdown]
# The Python script you have is designed for backtesting a stock trading strategy. Here's a summary of how it works:
#
# 1. **Import Libraries**: It uses `yfinance` to fetch financial data, `pandas` for data manipulation, and `datetime` to work with dates.
#
# 2. **Data Fetching Function (`fetch_data`)**:
#    - This function takes a stock ticker symbol as input.
#    - It retrieves historical data for the last 7 days for the specified stock with 5-minute intervals using the `yfinance` library.
#
# 3. **Trading Strategy Function (`trading_strategy`)**:
#    - Input: Stock data for a specific ticker.
#    - Processes data for each day:
#      - Calculates the average entry price between 9:20 AM and 9:30 AM.
#      - Identifies the day's high and low prices.
#      - Determines the exit price based on the closing price at noon (11:59 AM to 12:00 PM).
#      - Calculates the profit percentage for each trade.
#      - Stores entry and exit points, profit percentage, trading volume, day high, and day low.
#
# 4. **Backtesting Process**:
#    - A list of stock ticker symbols (`nse_stocks`) is predefined.
#    - For each stock in the list, the script:
#      - Fetches data using `fetch_data`.
#      - Applies the trading strategy using `trading_strategy`.
#      - Stores the results if there are any entry points.
#      - Calculates and prints the average profit percentage and number of trades for each stock.
#      - Accumulates detailed results, including the stock symbol, trade dates, entry/exit prices, profit percentages, trading volumes, day highs, and lows.
#
# 5. **Results Compilation and Export**:
#    - The collected results are converted into a `pandas` DataFrame.
#    - The current date is obtained and formatted.
#    - The DataFrame is exported to an Excel file named `"backtesting_results_<current_date>.xlsx"`.
#
# 6. **Output**:
#    - The script prints the processing status for each stock.
#    - It displays a list of selected stocks based on the strategy criteria.
#    - Finally, it informs the user that the results have been exported to an Excel file.
#
# This script automates the process of evaluating a specific trading strategy across multiple stocks, allowing for an analysis of its potential profitability based on historical data.

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime

def fetch_data(stock):
    # Fetch historical data for the stock for the last 7 days with 5-minute intervals
    data = yf.download(stock, period="7d", interval="5m")
    return data

def trading_strategy(data, stock):
    entry_points = []
    exit_points = []
    profits = []
    volumes = []
    day_highs = []
    day_lows = []

    for date in data.index.normalize().unique():
        daily_data = data[data.index.normalize() == date]

        # Calculate average price between 9:20 and 9:30
        interval_data = daily_data.between_time('09:20', '09:30')
        if not interval_data.empty:
            average_entry_price = interval_data['Open'].mean()

            # Find the day's high and low
            day_high = daily_data['High'].max()
            day_low = daily_data['Low'].min()

            # Exit logic
            exit_data = daily_data.between_time('11:59', '12:00')
            if not exit_data.empty:
                exit_price = exit_data.iloc[-1]['Close']
                profit_percentage = ((exit_price - average_entry_price) / average_entry_price) * 100
                entry_points.append((date.date(), average_entry_price))
                exit_points.append((date.date(), exit_price))
                profits.append(profit_percentage)
                volumes.append(daily_data['Volume'].sum())
                day_highs.append(day_high)
                day_lows.append(day_low)

    return entry_points, exit_points, profits, volumes, day_highs, day_lows

# List of NSE stocks
nse_stocks = ['21STCENMGM.NS', '63MOONS.NS', 'AARTIIND.NS', 'AARTIPHARM.NS', 'AARVI.NS', 'ABFRL.NS', 'ABSLAMC.NS', 'ACCELYA.NS', 'ADANIGREEN.NS', 'ADSL.NS', 'AGROPHOS.NS', 'AHLADA.NS', 'AJMERA.NS', 'AKG.NS', 'ALBERTDAVD.NS', 'ALMONDZ.NS', 'AMBIKCO.NS', 'AMJLAND.NS', 'AMRUTANJAN.NS', 'ANDHRSUGAR.NS', 'ANMOL.NS', 'APTECHT.NS', 'ARIHANTCAP.NS', 'ARROWGREEN.NS', 'ARVIND.NS', 'ASAHIINDIA.NS', 'ASALCBR.NS', 'ASHOKA.NS', 'ASIANPAINT.NS', 'ASIANTILES.NS', 'ASMS.NS', 'ASTRAL.NS', 'ASTRON.NS', 'ATUL.NS', 'AVANTIFEED.NS', 'AXISBANK.NS', 'BAJAJFINSV.NS', 'BAJEL.NS', 'BANARISUG.NS', 'BANDHANBNK.NS', 'BANG.NS', 'BANKINDIA.NS', 'BARBEQUE.NS', 'BASF.NS', 'BATAINDIA.NS', 'BAYERCROP.NS', 'BBOX.NS', 'BCLIND.NS', 'BFUTILITIE.NS', 'BHANDARI.NS', 'BHARATRAS.NS', 'BIRLAMONEY.NS', 'BLISSGVS.NS', 'BLKASHYAP.NS', 'BODALCHEM.NS', 'BOMDYEING.NS', 'BOROLTD.NS', 'BOSCHLTD.NS', 'BRITANNIA.NS', 'BSOFT.NS', 'BUTTERFLY.NS', 'CALSOFT.NS', 'CANBK.NS', 'CCL.NS', 'CENTEXT.NS', 'CENTRALBK.NS', 'CERA.NS', 'CESC.NS', 'CHEMCON.NS', 'CHEMPLASTS.NS', 'CHOLAFIN.NS', 'CONSOFINVT.NS', 'CSBBANK.NS', 'CUB.NS', 'CUMMINSIND.NS', 'DABUR.NS', 'DAMODARIND.NS', 'DBOL.NS', 'DCBBANK.NS', 'DCMNVL.NS', 'DCMSRIND.NS', 'DCXINDIA.NS', 'DECCANCE.NS', 'DEEPAKNTR.NS', 'DELPHIFX.NS', 'DENORA.NS', 'DEVYANI.NS', 'DHANBANK.NS', 'DHANI.NS', 'DHANUKA.NS', 'DHRUV.NS', 'DIAMONDYD.NS', 'DIL.NS', 'DIVGIITTS.NS', 'DJML.NS', 'DLF.NS', 'DOLLAR.NS', 'DREDGECORP.NS', 'DYNAMATECH.NS', 'EASEMYTRIP.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'EIHOTEL.NS', 'EMAMIPAP.NS', 'ENDURANCE.NS', 'ENIL.NS', 'ESCORTS.NS', 'ESSARSHPNG.NS', 'ESSENTIA.NS', 'EVERESTIND.NS', 'EXXARO.NS', 'FCL.NS', 'FDC.NS', 'FELDVR.NS', 'FINEORG.NS', 'FINPIPE.NS', 'FMGOETZE.NS', 'FOODSIN.NS', 'GANESHBE.NS', 'GANESHHOUC.NS', 'GARFIBRES.NS', 'GENSOL.NS', 'GENUSPAPER.NS', 'GEPIL.NS', 'GHCL.NS', 'GICRE.NS', 'GKWLIMITED.NS', 'GLAND.NS', 'GLENMARK.NS', 'GLOBALVECT.NS', 'GNFC.NS', 'GOCLCORP.NS', 'GODREJAGRO.NS', 'GOKUL.NS', 'GREENLAM.NS', 'GRMOVER.NS', 'GRSE.NS', 'GTL.NS', 'GTLINFRA.NS', 'GUJALKALI.NS', 'GUJAPOLLO.NS', 'GVPTECH.NS', 'HAPPYFORGE.NS', 'HARIOMPIPE.NS', 'HAVISHA.NS', 'HCC.NS', 'HECPROJECT.NS', 'HEG.NS', 'HEROMOTOCO.NS', 'HEUBACHIND.NS', 'HGS.NS', 'HINDPETRO.NS', 'HISARMETAL.NS', 'HLVLTD.NS', 'HSCL.NS', 'HUBTOWN.NS', 'HUHTAMAKI.NS', 'IBULHSGFIN.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'ICRA.NS', 'IDBI.NS', 'IDFC.NS', 'IFCI.NS', 'IGPL.NS', 'IIFL.NS', 'IMFA.NS', 'INCREDIBLE.NS', 'INDIANCARD.NS', 'INDNIPPON.NS', 'INDOAMIN.NS', 'INDOBORAX.NS', 'INDOSTAR.NS', 'INDTERRAIN.NS', 'INDUSINDBK.NS', 'INGERRAND.NS', 'INTLCONV.NS', 'IOC.NS', 'IOLCP.NS', 'IRCON.NS', 'IRIS.NS', 'ISFT.NS', 'ITC.NS', 'IVP.NS', 'IZMO.NS', 'J&KBANK.NS', 'JAIBALAJI.NS', 'JAYBARMARU.NS', 'JBCHEPHARM.NS', 'JCHAC.NS', 'JETFREIGHT.NS', 'JINDALPHOT.NS', 'JINDALPOLY.NS', 'JINDALSTEL.NS', 'JINDRILL.NS', 'JITFINFRA.NS', 'JMFINANCIL.NS', 'JUBLFOOD.NS', 'JUBLINDS.NS', 'JUBLPHARMA.NS', 'JWL.NS', 'JYOTISTRUC.NS', 'KAMATHOTEL.NS', 'KAYNES.NS', 'KBCGLOBAL.NS', 'KCP.NS', 'KELLTONTEC.NS', 'KIOCL.NS', 'KMSUGAR.NS', 'KNRCON.NS', 'KOLTEPATIL.NS', 'KOTARISUG.NS', 'KRITINUT.NS', 'KSB.NS', 'KSL.NS', 'KTKBANK.NS', 'L&TFH.NS', 'LAMBODHARA.NS', 'LAOPALA.NS', 'LATTEYS.NS', 'LCCINFOTEC.NS', 'LFIC.NS', 'LGBBROSLTD.NS', 'LIBAS.NS', 'LINCOLN.NS', 'LOKESHMACH.NS', 'LORDSCHLO.NS', 'LOYALTEX.NS', 'LT.NS', 'LUMAXIND.NS', 'LUMAXTECH.NS', 'MAHABANK.NS', 'MAHEPC.NS', 'MAHSCOOTER.NS', 'MANAKSTEEL.NS', 'MANAPPURAM.NS', 'MARICO.NS', 'MATRIMONY.NS', 'MAWANASUG.NS', 'MAXIND.NS', 'MBAPL.NS', 'MCL.NS', 'MCX.NS', 'MEDICO.NS', 'MENONBE.NS', 'MFSL.NS', 'MGEL.NS', 'MMFL.NS', 'MMP.NS', 'MODISONLTD.NS', 'MOHITIND.NS', 'MOTILALOFS.NS', 'MOTISONS.NS', 'MOTOGENFIN.NS', 'MTEDUCARE.NS', 'MUFTI.NS', 'MUKTAARTS.NS', 'MUTHOOTFIN.NS', 'NACLIND.NS', 'NAGAFERT.NS', 'NAHARPOLY.NS', 'NAM-INDIA.NS', 'NARMADA.NS', 'NCC.NS', 'NELCAST.NS', 'NETWORK18.NS', 'NEWGEN.NS', 'NFL.NS', 'NIITMTS.NS', 'NILAINFRA.NS', 'NILKAMAL.NS', 'NIPPOBATRY.NS', 'NIRAJ.NS', 'NITINSPIN.NS', 'NOCIL.NS', 'NORBTEAEXP.NS', 'NSIL.NS', 'NSLNISP.NS', 'OBEROIRLTY.NS', 'OMAXAUTO.NS', 'OMKARCHEM.NS', 'ONELIFECAP.NS', 'ONMOBILE.NS', 'ORIENTALTL.NS', 'ORIENTCER.NS', 'ORIENTELEC.NS', 'ORIENTPPR.NS', 'OSWALSEEDS.NS', 'PAKKA.NS', 'PASUPTAC.NS', 'PDMJEPAPER.NS', 'PDSL.NS', 'PEL.NS', 'PENIND.NS', 'PFC.NS', 'PFS.NS', 'PGIL.NS', 'PIGL.NS', 'PNBGILTS.NS', 'POKARNA.NS', 'POLYCAB.NS', 'POWERMECH.NS', 'PPAP.NS', 'PRAKASHSTL.NS', 'PRAXIS.NS', 'PRECWIRE.NS', 'PRITIKAUTO.NS', 'PROZONER.NS', 'PSB.NS', 'PTC.NS', 'QUICKHEAL.NS', 'RAILTEL.NS', 'RAINBOW.NS', 'RAJMET.NS', 'RAJRATAN.NS', 'RAJRILTD.NS', 'RAJSREESUG.NS', 'RAJTV.NS', 'RAMCOIND.NS', 'RAMCOSYS.NS', 'RAYMOND.NS', 'RBL.NS', 'RBLBANK.NS', 'RCF.NS', 'RECLTD.NS', 'RELAXO.NS', 'REPCOHOME.NS', 'REPL.NS', 'RHIM.NS', 'RICOAUTO.NS', 'RISHABH.NS', 'RKEC.NS', 'RKFORGE.NS', 'ROLLT.NS', 'ROML.NS', 'ROUTE.NS', 'RUPA.NS', 'RUSHIL.NS', 'RVHL.NS', 'SAGARDEEP.NS', 'SAGCEM.NS', 'SAKAR.NS', 'SALASAR.NS', 'SALZERELEC.NS', 'SAMBHAAV.NS', 'SAMPANN.NS', 'SANDHAR.NS', 'SANGAMIND.NS', 'SARVESHWAR.NS', 'SATIN.NS', 'SATINDLTD.NS', 'SBC.NS', 'SELAN.NS', 'SESHAPAPER.NS', 'SHALPAINTS.NS', 'SHIVAMAUTO.NS', 'SHRADHA.NS', 'SHREERAMA.NS', 'SHREYAS.NS', 'SHRIPISTON.NS', 'SHRIRAMFIN.NS', 'SHRIRAMPPS.NS', 'SHYAMCENT.NS', 'SIKKO.NS', 'SIL.NS', 'SILINV.NS', 'SILLYMONKS.NS', 'SIRCA.NS', 'SIYSIL.NS', 'SJVN.NS', 'SKYGOLD.NS', 'SMLT.NS', 'SOFTTECH.NS', 'SOMANYCERA.NS', 'SONATSOFTW.NS', 'SPENCERS.NS', 'SPLIL.NS', 'SRHHYPOLTD.NS', 'SSWL.NS', 'STEL.NS', 'STERTOOLS.NS', 'STOVEKRAFT.NS', 'SUBROS.NS', 'SUNDARMFIN.NS', 'SUPRAJIT.NS', 'SUPRIYA.NS', 'SURYALAXMI.NS', 'SURYODAY.NS', 'SWARAJENG.NS', 'SWSOLAR.NS', 'TARSONS.NS', 'TASTYBITE.NS', 'TATACHEM.NS', 'TATACOMM.NS', 'TATACONSUM.NS', 'TATAMETALI.NS', 'TCI.NS', 'TCNSBRANDS.NS', 'TEAMLEASE.NS', 'TECHNOE.NS', 'TERASOFT.NS', 'TEXRAIL.NS', 'TFL.NS', 'THERMAX.NS', 'THYROCARE.NS', 'TIMKEN.NS', 'TIPSFILMS.NS', 'TITAN.NS', 'TNPL.NS', 'TOKYOPLAST.NS', 'TORNTPHARM.NS', 'TREJHARA.NS', 'TRIGYN.NS', 'TRIVENI.NS', 'TVSMOTOR.NS', 'UCOBANK.NS', 'UFLEX.NS', 'UJJIVAN.NS', 'UJJIVANSFB.NS', 'UNIDT.NS', 'UNITECH.NS', 'UNIVASTU.NS', 'UNIVCABLES.NS', 'URJA.NS', 'USK.NS', 'V2RETAIL.NS', 'VADILALIND.NS', 'VARROC.NS', 'VERTOZ.NS', 'VGUARD.NS', 'VIJIFIN.NS', 'VIKASECO.NS', 'VIMTALABS.NS', 'VINYLINDIA.NS', 'VIPIND.NS', 'VISHNU.NS', 'VLEGOV.NS', 'VOLTAS.NS', 'VPRPL.NS', 'WHEELS.NS', 'WONDERLA.NS', 'XCHANGING.NS', 'YATHARTH.NS', 'ZAGGLE.NS', 'ZIMLAB.NS', 'ZODIAC.NS', 'ZUARI.NS', 'ZYDUSLIFE.NS']


# Initialize a list to store results
results = []

# Backtesting
selected_stocks = []
for stock in nse_stocks:
    print(f"Processing {stock}...")
    try:
        data = fetch_data(stock)
        if not isinstance(data.index, pd.DatetimeIndex):
            data.index = pd.to_datetime(data.index)

        entry_points, exit_points, profits, volumes, day_highs, day_lows = trading_strategy(data, stock)
        if entry_points:
            selected_stocks.append(stock)
            total_profit_percent = sum(profits) / len(profits) if profits else 0
            print(f"Stock: {stock}, Average Profit: {total_profit_percent:.2f}%, Trades: {len(profits)}")

            # Add results to list
            for i in range(len(entry_points)):
                results.append({
                    "Stock": stock,
                    "Date": entry_points[i][0],
                    "Entry Price": entry_points[i][1],
                    "Exit Price": exit_points[i][1],
                    "Profit (%)": profits[i],
                    "Volume": volumes[i],
                    "Day High": day_highs[i],
                    "Day Low": day_lows[i]
                })
    except Exception as e:
        print(f"Error processing {stock}: {e}")

# Convert results list to DataFrame
results_df = pd.DataFrame(results)

# Get today's date
today_date = datetime.now().strftime("%Y-%m-%d")

# Excel file name with today's date
excel_file_name = f"backtesting_results_{today_date}.xlsx"

# Export results to Excel
results_df.to_excel(excel_file_name, index=False)

print("Selected Stocks:")
print(selected_stocks)
print(f"Results exported to {excel_file_name}")

# %% [markdown]
# #rough code (practice)

# %%
import yfinance as yf
import pandas as pd
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders
from datetime import datetime

# Your Email details
sender_email = "ainirvana2023@gmail.com"  # Replace with your email
receiver_email = "aaryashah134@gmail.com"  # Replace with the receiver's email
password = "Qwerty@123a"  # Replace with your email password or App Password


def fetch_data(stock):
    # Fetch historical data for the stock for today with 5-minute intervals
    data = yf.download(stock, period="1d", interval="5m")
    return data

def fetch_beta(stock):
    stock_info = yf.Ticker(stock)
    beta = stock_info.info.get("beta")
    return beta

def plot_candlestick(data, stock, date):
    # Create a candlestick chart
    fig = go.Figure(data=[go.Candlestick(x=data.index,
                                         open=data['Open'],
                                         high=data['High'],
                                         low=data['Low'],
                                         close=data['Close'])])
    fig.update_layout(title=f'Candlestick chart for {stock} on {date}',
                      xaxis_title='Time',
                      yaxis_title='Price',
                      xaxis_rangeslider_visible=False)
    fig.show()

# List of NSE stocks
nse_stocks = ['20MICRONS.NS', '21STCENMGM.NS', '360ONE.NS', '3IINFOLTD.NS', '3MINDIA.NS']
# Initialize lists to store selected stocks, their volumes, entry prices, and beta values
selected_stocks = []
selected_stocks_volume = []
selected_stocks_entry_price = []
selected_stocks_beta = []

for stock in nse_stocks:
    print(f"Processing {stock}...")
    data = fetch_data(stock)
    beta = fetch_beta(stock)

    if not isinstance(data.index, pd.DatetimeIndex):
        data.index = pd.to_datetime(data.index)

    for date in data.index.normalize().unique():
        daily_data = data[data.index.normalize() == date]
        first_interval = daily_data.between_time('09:15', '09:20')
        if not first_interval.empty:
            open_equals_low = first_interval.iloc[0]['Open'] == first_interval['Low'].min()
            if open_equals_low:
                entry_price = first_interval.iloc[0]['Close']  # Assuming entry at the close of the interval
                selected_stocks.append((stock, date.date()))
                selected_stocks_volume.append((stock, date.date(), first_interval['Volume'].sum()))
                selected_stocks_entry_price.append((stock, date.date(), entry_price))
                selected_stocks_beta.append((stock, date.date(), beta))

# Create DataFrames
df_volume = pd.DataFrame(selected_stocks_volume, columns=['Stock', 'Date', 'Volume'])
df_entry_price = pd.DataFrame(selected_stocks_entry_price, columns=['Stock', 'Date', 'EntryPrice'])
df_beta = pd.DataFrame(selected_stocks_beta, columns=['Stock', 'Date', 'Beta'])

# Merge DataFrames
df_merged = pd.merge(df_volume, df_entry_price, on=['Stock', 'Date'], how='inner')
df_merged = pd.merge(df_merged, df_beta, on=['Stock', 'Date'], how='inner')

# Get today's date for the file name
today_date = datetime.today().strftime('%Y-%m-%d')

# Export the DataFrame to an Excel file
file_name = f'selected_stocks_volume_beta_{today_date}.xlsx'
df_merged.to_excel(file_name, index=False)


# Function to send an email with the attachment
def send_email(file_name, sender_email, receiver_email, password):
    # Create the email object
    message = MIMEMultipart()
    message["From"] = sender_email
    message["To"] = receiver_email
    message["Subject"] = "Selected Stocks Report"

    # Attach the file
    with open(file_name, "rb") as attachment:
        part = MIMEBase("application", "octet-stream")
        part.set_payload(attachment.read())
    encoders.encode_base64(part)
    part.add_header(
        "Content-Disposition",
        f"attachment; filename= {file_name}",
    )
    message.attach(part)

    # Send the email
    server = smtplib.SMTP("smtp.gmail.com", 587)
    server.starttls()
    server.login(sender_email, password)
    server.sendmail(sender_email, receiver_email, message.as_string())
    server.quit()


# Send the email with the attachment
send_email(file_name, sender_email, receiver_email, password)

print("Email sent successfully with the attachment.")
# Out:
# Processing 20MICRONS.NS...
# [*********************100%%**********************]  1 of 1 completed
# Processing 21STCENMGM.NS...
# [*********************100%%**********************]  1 of 1 completed
# Processing 360ONE.NS...
# [*********************100%%**********************]  1 of 1 completed
# Processing 3IINFOLTD.NS...
# [*********************100%%**********************]  1 of 1 completed
# Processing 3MINDIA.NS...
# [*********************100%%**********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# <ipython-input-1-68c80116d9d6> in <cell line: 111>()
#     109
#     110 # Send the email with the attachment
# --> 111 send_email(file_name, sender_email, receiver_email, password)
#     112
#     113 print("Email sent successfully with the attachment.")
#
# ...

# %% [markdown]
# #jenish sir wali script

# %%
import yfinance as yf
import pandas as pd

# List of stock symbols
stocks = ['20MICRONS.NS', '21STCENMGM.NS', '360ONE.NS', '3IINFOLTD.NS', '3MINDIA.NS', '3PLAND.NS', '5PAISA.NS', '63MOONS.NS', 'A2ZINFRA.NS', 'AAATECH.NS', 'AAKASH.NS', 'AAREYDRUGS.NS', 'AARON.NS', 'AARTECH.NS', 'AARTIDRUGS.NS', 'AARTIIND.NS', 'AARTIPHARM.NS', 'AARTISURF.NS', 'AARVEEDEN.NS', 'AARVI.NS', 'AAVAS.NS', 'ABAN.NS', 'ABB.NS', 'ABBOTINDIA.NS', 'ABCAPITAL.NS', 'ABFRL.NS', 'ABMINTLLTD.NS', 'ABSLAMC.NS', 'ACC.NS', 'ACCELYA.NS', 'ACCURACY.NS', 'ACE.NS', 'ACEINTEG.NS', 'ACI.NS', 'ACL.NS', 'ACLGATI.NS', 'ADANIENSOL.NS', 'ADANIENT.NS', 'ADANIGREEN.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'ADFFOODS.NS', 'ADL.NS', 'ADORWELD.NS', 'ADROITINFO.NS', 'ADSL.NS', 'ADVANIHOTR.NS', 'ADVENZYMES.NS', 'AEGISCHEM.NS', 'AEROFLEX.NS', 'AETHER.NS', 'AFFLE.NS', 'AGARIND.NS', 'AGI.NS', 'AGRITECH.NS', 'AGROPHOS.NS', 'AGSTRA.NS', 'AHL.NS', 'AHLADA.NS', 'AHLEAST.NS', 'AHLUCONT.NS', 'AIAENG.NS', 'AIRAN.NS', 'AIROLAM.NS', 'AJANTPHARM.NS', 'AJMERA.NS', 'AJOONI.NS', 'AKASH.NS', 'AKG.NS', 'AKI.NS', 'AKSHAR.NS', 'AKSHARCHEM.NS', 'AKSHOPTFBR.NS', 'AKZOINDIA.NS', 'ALANKIT.NS', 'ALBERTDAVD.NS', 'ALEMBICLTD.NS', 'ALICON.NS', 'ALKALI.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'ALLCARGO.NS', 'ALLSEC.NS', 'ALMONDZ.NS', 'ALOKINDS.NS', 'ALPA.NS', 'ALPHAGEO.NS', 'ALPSINDUS.NS', 'AMBER.NS', 'AMBICAAGAR.NS', 'AMBIKCO.NS', 'AMBUJACEM.NS', 'AMDIND.NS', 'AMIORG.NS', 'AMJLAND.NS', 'AMNPLST.NS', 'AMRUTANJAN.NS', 'ANANDRATHI.NS', 'ANANTRAJ.NS', 'ANDHRAPAP.NS', 'ANDHRSUGAR.NS', 'ANGELONE.NS', 'ANIKINDS.NS', 'ANKITMETAL.NS', 'ANMOL.NS', 'ANTGRAPHIC.NS', 'ANUP.NS', 'ANURAS.NS', 'APARINDS.NS', 'APCL.NS', 'APCOTEXIND.NS', 'APEX.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'APOLLO.NS', 'APOLLOHOSP.NS', 'APOLLOPIPE.NS', 'APOLLOTYRE.NS', 'APOLSINHOT.NS', 'APTECHT.NS', 'APTUS.NS', 'ARCHIDPLY.NS', 'ARCHIES.NS', 'ARE&M.NS', 'ARENTERP.NS', 'ARIES.NS', 'ARIHANTCAP.NS', 'ARIHANTSUP.NS', 'ARMANFIN.NS', 'AROGRANITE.NS', 'ARROWGREEN.NS', 'ARSHIYA.NS', 'ARSSINFRA.NS', 'ARTEMISMED.NS', 'ARTNIRMAN.NS', 'ARVEE.NS', 'ARVIND.NS', 'ARVINDFASN.NS', 'ARVSMART.NS', 'ASAHIINDIA.NS', 'ASAHISONG.NS', 'ASAL.NS', 'ASALCBR.NS', 'ASHAPURMIN.NS', 'ASHIANA.NS', 'ASHIMASYN.NS', 'ASHOKA.NS', 'ASHOKAMET.NS', 'ASHOKLEY.NS', 'ASIANENE.NS', 'ASIANHOTNR.NS', 'ASIANPAINT.NS', 'ASIANTILES.NS', 'ASKAUTOLTD.NS', 'ASMS.NS', 'ASPINWALL.NS', 'ASTEC.NS', 'ASTERDM.NS', 'ASTRAL.NS', 'ASTRAMICRO.NS', 'ASTRAZEN.NS', 'ASTRON.NS', 'ATALREAL.NS', 'ATAM.NS', 'ATFL.NS', 'ATGL.NS', 'ATL.NS', 'ATLANTAA.NS', 'ATUL.NS', 'ATULAUTO.NS', 'AUBANK.NS', 'AURIONPRO.NS', 'AUROPHARMA.NS', 'AURUM.NS', 'AUSOMENT.NS', 'AUTOAXLES.NS', 'AUTOIND.NS', 'AVADHSUGAR.NS', 'AVALON.NS', 'AVANTIFEED.NS', 'AVG.NS', 'AVONMORE.NS', 'AVROIND.NS', 'AVTNPL.NS', 'AWHCL.NS', 'AWL.NS', 'AXISBANK.NS', 'AXISCADES.NS', 'AXITA.NS', 'AYMSYNTEX.NS', 'AZAD.NS', 'BAFNAPH.NS', 'BAGFILMS.NS', 'BAIDFIN.NS', 'BAJAJ-AUTO.NS', 'BAJAJCON.NS', 'BAJAJELEC.NS', 'BAJAJFINSV.NS', 'BAJAJHCARE.NS', 'BAJAJHIND.NS', 'BAJAJHLDNG.NS', 'BAJEL.NS', 'BAJFINANCE.NS', 'BALAJITELE.NS', 'BALAMINES.NS', 'BALAXI.NS', 'BALKRISHNA.NS', 'BALKRISIND.NS', 'BALMLAWRIE.NS', 'BALPHARMA.NS', 'BALRAMCHIN.NS', 'BANARBEADS.NS', 'BANARISUG.NS', 'BANCOINDIA.NS', 'BANDHANBNK.NS', 'BANG.NS', 'BANKA.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BANSWRAS.NS', 'BARBEQUE.NS', 'BASF.NS', 'BASML.NS', 'BATAINDIA.NS', 'BAYERCROP.NS', 'BBL.NS', 'BBOX.NS', 'BBTC.NS', 'BBTCL.NS', 'BCG.NS', 'BCLIND.NS', 'BCONCEPTS.NS', 'BDL.NS', 'BEARDSELL.NS', 'BECTORFOOD.NS', 'BEDMUTHA.NS', 'BEL.NS', 'BEML.NS', 'BEPL.NS', 'BERGEPAINT.NS', 'BFINVEST.NS', 'BFUTILITIE.NS', 'BGRENERGY.NS', 'BHAGCHEM.NS', 'BHAGERIA.NS', 'BHAGYANGR.NS', 'BHANDARI.NS', 'BHARATFORG.NS', 'BHARATGEAR.NS', 'BHARATRAS.NS', 'BHARATWIRE.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'BIGBLOC.NS', 'BIKAJI.NS', 'BIL.NS', 'BINANIIND.NS', 'BIOCON.NS', 'BIOFILCHEM.NS', 'BIRLACABLE.NS', 'BIRLACORPN.NS', 'BIRLAMONEY.NS', 'BKMINDST.NS', 'BLAL.NS', 'BLBLIMITED.NS', 'BLISSGVS.NS', 'BLKASHYAP.NS', 'BLS.NS', 'BLUECHIP.NS', 'BLUECOAST.NS', 'BLUEDART.NS', 'BLUEJET.NS', 'BLUESTARCO.NS', 'BODALCHEM.NS', 'BOHRAIND.NS', 'BOMDYEING.NS', 'BOROLTD.NS', 'BORORENEW.NS', 'BOSCHLTD.NS', 'BPCL.NS', 'BPL.NS', 'BRIGADE.NS', 'BRITANNIA.NS', 'BRNL.NS', 'BROOKS.NS', 'BSE.NS', 'BSHSL.NS', 'BSL.NS', 'BSOFT.NS', 'BTML.NS', 'BURNPUR.NS', 'BUTTERFLY.NS', 'BVCL.NS', 'BYKE.NS', 'CALSOFT.NS', 'CAMLINFINE.NS', 'CAMPUS.NS', 'CAMS.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CANTABIL.NS', 'CAPACITE.NS', 'CAPLIPOINT.NS', 'CAPTRUST.NS', 'CARBORUNIV.NS', 'CAREERP.NS', 'CARERATING.NS', 'CARTRADE.NS', 'CARYSIL.NS', 'CASTROLIND.NS', 'CCHHL.NS', 'CCL.NS', 'CDSL.NS', 'CEATLTD.NS', 'CELEBRITY.NS', 'CELLO.NS', 'CENTENKA.NS', 'CENTEXT.NS', 'CENTRALBK.NS', 'CENTRUM.NS', 'CENTUM.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CEREBRAINT.NS', 'CESC.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHALET.NS', 'CHAMBLFERT.NS', 'CHEMBOND.NS', 'CHEMCON.NS', 'CHEMFAB.NS', 'CHEMPLASTS.NS', 'CHENNPETRO.NS', 'CHEVIOT.NS', 'CHOICEIN.NS', 'CHOLAFIN.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'CIGNITITEC.NS', 'CINELINE.NS', 'CINEVISTA.NS', 'CIPLA.NS', 'CLEAN.NS', 'CLEDUCATE.NS', 'CLSEL.NS', 'CMSINFO.NS', 'COALINDIA.NS', 'COASTCORP.NS', 'COCHINSHIP.NS', 'COFFEEDAY.NS', 'COFORGE.NS', 'COLPAL.NS', 'COMPINFO.NS', 'COMPUSOFT.NS', 'CONCOR.NS', 'CONCORDBIO.NS', 'CONFIPET.NS', 'CONSOFINVT.NS', 'CONTROLPR.NS', 'CORALFINAC.NS', 'CORDSCABLE.NS', 'COROMANDEL.NS', 'COSMOFIRST.NS', 'COUNCODOS.NS', 'CRAFTSMAN.NS', 'CREATIVE.NS', 'CREATIVEYE.NS', 'CREDITACC.NS', 'CREST.NS', 'CRISIL.NS', 'CROMPTON.NS', 'CROWN.NS', 'CSBBANK.NS', 'CSLFINANCE.NS', 'CTE.NS', 'CUB.NS', 'CUBEXTUB.NS', 'CUMMINSIND.NS', 'CUPID.NS', 'CYBERMEDIA.NS', 'CYBERTECH.NS', 'CYIENT.NS', 'CYIENTDLM.NS', 'DABUR.NS', 'DALBHARAT.NS', 'DALMIASUG.NS', 'DAMODARIND.NS', 'DANGEE.NS', 'DATAMATICS.NS', 'DATAPATTNS.NS', 'DBCORP.NS', 'DBL.NS', 'DBOL.NS', 'DBREALTY.NS', 'DBSTOCKBRO.NS', 'DCAL.NS', 'DCBBANK.NS', 'DCI.NS', 'DCM.NS', 'DCMFINSERV.NS', 'DCMNVL.NS', 'DCMSHRIRAM.NS', 'DCMSRIND.NS', 'DCW.NS', 'DCXINDIA.NS', 'DECCANCE.NS', 'DEEPAKFERT.NS', 'DEEPAKNTR.NS', 'DEEPENR.NS', 'DEEPINDS.NS', 'DELHIVERY.NS', 'DELPHIFX.NS', 'DELTACORP.NS', 'DELTAMAGNT.NS', 'DEN.NS', 'DENORA.NS', 'DEVIT.NS', 'DEVYANI.NS', 'DGCONTENT.NS', 'DHAMPURSUG.NS', 'DHANBANK.NS', 'DHANI.NS', 'DHANUKA.NS', 'DHARMAJ.NS', 'DHRUV.NS', 'DHUNINV.NS', 'DIACABS.NS', 'DIAMINESQ.NS', 'DIAMONDYD.NS', 'DICIND.NS', 'DIGISPICE.NS', 'DIGJAMLMTD.NS', 'DIL.NS', 'DISHTV.NS', 'DIVGIITTS.NS', 'DIVISLAB.NS', 'DIXON.NS', 'DJML.NS', 'DLF.NS', 'DLINKINDIA.NS', 'DMART.NS', 'DMCC.NS', 'DNAMEDIA.NS', 'DODLA.NS', 'DOLATALGO.NS', 'DOLLAR.NS', 'DOLPHIN.NS', 'DOMS.NS', 'DONEAR.NS', 'DPABHUSHAN.NS', 'DPSCLTD.NS', 'DPWIRES.NS', 'DRCSYSTEMS.NS', 'DREAMFOLKS.NS', 'DREDGECORP.NS', 'DRREDDY.NS', 'DSSL.NS', 'DTIL.NS', 'DUCON.NS', 'DVL.NS', 'DWARKESH.NS', 'DYCL.NS', 'DYNAMATECH.NS', 'DYNPRO.NS', 'E2E.NS', 'EASEMYTRIP.NS', 'EASTSILK.NS', 'ECLERX.NS', 'EDELWEISS.NS', 'EDUCOMP.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'EIFFL.NS', 'EIHAHOTELS.NS', 'EIHOTEL.NS', 'EIMCOELECO.NS', 'EKC.NS', 'ELDEHSG.NS', 'ELECON.NS', 'ELECTCAST.NS', 'ELECTHERM.NS', 'ELGIEQUIP.NS', 'ELGIRUBCO.NS', 'ELIN.NS', 'EMAMILTD.NS', 'EMAMIPAP.NS', 'EMAMIREAL.NS', 'EMIL.NS', 'EMKAY.NS', 'EMMBI.NS', 'EMSLIMITED.NS', 'EMUDHRA.NS', 'ENDURANCE.NS', 'ENERGYDEV.NS', 'ENGINERSIN.NS', 'ENIL.NS', 'EPIGRAL.NS', 'EPL.NS', 'EQUIPPP.NS', 'EQUITASBNK.NS', 'ERIS.NS', 'EROSMEDIA.NS', 'ESABINDIA.NS', 'ESAFSFB.NS', 'ESCORTS.NS', 'ESSARSHPNG.NS', 'ESSENTIA.NS', 'ESTER.NS', 'ETHOSLTD.NS', 'EUROTEXIND.NS', 'EVEREADY.NS', 'EVERESTIND.NS', 'EXCEL.NS', 'EXCELINDUS.NS', 'EXIDEIND.NS', 'EXPLEOSOL.NS', 'EXXARO.NS', 'FACT.NS', 'FAIRCHEMOR.NS', 'FAZE3Q.NS', 'FCL.NS', 'FCONSUMER.NS', 'FCSSOFT.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FEDFINA.NS', 'FEL.NS', 'FELDVR.NS', 'FIBERWEB.NS', 'FIEMIND.NS', 'FILATEX.NS', 'FINCABLES.NS', 'FINEORG.NS', 'FINOPB.NS', 'FINPIPE.NS', 'FIVESTAR.NS', 'FLAIR.NS', 'FLEXITUFF.NS', 'FLFL.NS', 'FLUOROCHEM.NS', 'FMGOETZE.NS', 'FMNL.NS', 'FOCUS.NS', 'FOODSIN.NS', 'FORTIS.NS', 'FOSECOIND.NS', 'FSC.NS', 'FSL.NS', 'FUSION.NS', 'GABRIEL.NS', 'GAEL.NS', 'GAIL.NS', 'GALAXYSURF.NS', 'GALLANTT.NS', 'GANDHAR.NS', 'GANDHITUBE.NS', 'GANECOS.NS', 'GANESHBE.NS', 'GANESHHOUC.NS', 'GANGAFORGE.NS', 'GANGESSECU.NS', 'GARFIBRES.NS', 'GATECH.NS', 'GATECHDVR.NS', 'GATEWAY.NS', 'GEECEE.NS', 'GEEKAYWIRE.NS', 'GENCON.NS', 'GENESYS.NS', 'GENSOL.NS', 'GENUSPAPER.NS', 'GENUSPOWER.NS', 'GEOJITFSL.NS', 'GEPIL.NS', 'GESHIP.NS', 'GET&D.NS', 'GFLLIMITED.NS', 'GHCL.NS', 'GHCLTEXTIL.NS', 'GICHSGFIN.NS', 'GICRE.NS', 'GILLANDERS.NS', 'GILLETTE.NS', 'GINNIFILA.NS', 'GIPCL.NS', 'GKWLIMITED.NS', 'GLAND.NS', 'GLAXO.NS', 'GLENMARK.NS', 'GLFL.NS', 'GLOBAL.NS', 'GLOBALVECT.NS', 'GLOBE.NS', 'GLOBUSSPR.NS', 'GLS.NS', 'GMBREW.NS', 'GMDCLTD.NS', 'GMMPFAUDLR.NS', 'GMRINFRA.NS', 'GMRP&UI.NS', 'GNA.NS', 'GNFC.NS', 'GOACARBON.NS', 'GOCLCORP.NS', 'GOCOLORS.NS', 'GODFRYPHLP.NS', 'GODHA.NS', 'GODREJAGRO.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GODREJPROP.NS', 'GOENKA.NS', 'GOKEX.NS', 'GOKUL.NS', 'GOKULAGRO.NS', 'GOLDENTOBC.NS', 'GOLDIAM.NS', 'GOLDTECH.NS', 'GOODLUCK.NS', 'GOYALALUM.NS', 'GPIL.NS', 'GPPL.NS', 'GPTINFRA.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'GRAVITA.NS', 'GREAVESCOT.NS', 'GREENLAM.NS', 'GREENPANEL.NS', 'GREENPLY.NS', 'GREENPOWER.NS', 'GRINDWELL.NS', 'GRINFRA.NS', 'GRMOVER.NS', 'GROBTEA.NS', 'GRPLTD.NS', 'GRSE.NS', 'GRWRHITECH.NS', 'GSFC.NS', 'GSLSU.NS', 'GSPL.NS', 'GSS.NS', 'GTECJAINX.NS', 'GTL.NS', 'GTLINFRA.NS', 'GTPL.NS', 'GUFICBIO.NS', 'GUJALKALI.NS', 'GUJAPOLLO.NS', 'GUJGASLTD.NS', 'GUJRAFFIA.NS', 'GULFOILLUB.NS', 'GULFPETRO.NS', 'GULPOLY.NS', 'GVKPIL.NS', 'GVPTECH.NS', 'HAL.NS', 'HAPPSTMNDS.NS', 'HAPPYFORGE.NS', 'HARDWYN.NS', 'HARIOMPIPE.NS', 'HARRMALAYA.NS', 'HARSHA.NS', 'HATHWAY.NS', 'HATSUN.NS', 'HAVELLS.NS', 'HAVISHA.NS', 'HBLPOWER.NS', 'HBSL.NS', 'HCC.NS', 'HCG.NS', 'HCL-INSYS.NS', 'HCLTECH.NS', 'HDFCAMC.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'HEADSUP.NS', 'HECPROJECT.NS', 'HEG.NS', 'HEIDELBERG.NS', 'HEMIPROP.NS', 'HERANBA.NS', 'HERCULES.NS', 'HERITGFOOD.NS', 'HEROMOTOCO.NS', 'HESTERBIO.NS', 'HEUBACHIND.NS', 'HEXATRADEX.NS', 'HFCL.NS', 'HGINFRA.NS', 'HGS.NS', 'HIKAL.NS', 'HIL.NS', 'HILTON.NS', 'HIMATSEIDE.NS', 'HINDALCO.NS', 'HINDCOMPOS.NS', 'HINDCON.NS', 'HINDCOPPER.NS', 'HINDMOTORS.NS', 'HINDOILEXP.NS', 'HINDPETRO.NS', 'HINDUNILVR.NS', 'HINDWAREAP.NS', 'HINDZINC.NS', 'HIRECT.NS', 'HISARMETAL.NS', 'HITECH.NS', 'HITECHCORP.NS', 'HITECHGEAR.NS', 'HLEGLAS.NS', 'HLVLTD.NS', 'HMAAGRO.NS', 'HMT.NS', 'HMVL.NS', 'HNDFDS.NS', 'HOMEFIRST.NS', 'HONASA.NS', 'HONAUT.NS', 'HONDAPOWER.NS', 'HOVS.NS', 'HPAL.NS', 'HPIL.NS', 'HPL.NS', 'HSCL.NS', 'HTMEDIA.NS', 'HUBTOWN.NS', 'HUDCO.NS', 'HUHTAMAKI.NS', 'HYBRIDFIN.NS', 'IBREALEST.NS', 'IBULHSGFIN.NS', 'ICDSLTD.NS', 'ICEMAKE.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'ICIL.NS', 'ICRA.NS', 'IDBI.NS', 'IDEA.NS', 'IDEAFORGE.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IEL.NS', 'IEX.NS', 'IFBAGRO.NS', 'IFBIND.NS', 'IFCI.NS', 'IFGLEXPOR.NS', 'IGARASHI.NS', 'IGL.NS', 'IGPL.NS', 'IIFL.NS', 'IIFLSEC.NS', 'IITL.NS', 'IKIO.NS', 'IL&FSENGG.NS', 'IL&FSTRANS.NS', 'IMAGICAA.NS', 'IMFA.NS', 'IMPAL.NS', 'IMPEXFERRO.NS', 'INCREDIBLE.NS', 'INDBANK.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INDIAGLYCO.NS', 'INDIAMART.NS', 'INDIANB.NS', 'INDIANCARD.NS', 'INDIANHUME.NS', 'INDIASHLTR.NS', 'INDIGO.NS', 'INDIGOPNTS.NS', 'INDNIPPON.NS', 'INDOAMIN.NS', 'INDOBORAX.NS', 'INDOCO.NS', 'INDORAMA.NS', 'INDOSTAR.NS', 'INDOTECH.NS', 'INDOTHAI.NS', 'INDOWIND.NS', 'INDRAMEDCO.NS', 'INDSWFTLAB.NS', 'INDSWFTLTD.NS', 'INDTERRAIN.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'INFOBEAN.NS', 'INFOMEDIA.NS', 'INFY.NS', 'INGERRAND.NS', 'INNOVACAP.NS', 'INOXGREEN.NS', 'INOXINDIA.NS', 'INOXWIND.NS', 'INSECTICID.NS', 'INSPIRISYS.NS', 'INTELLECT.NS', 'INTENTECH.NS', 'INTLCONV.NS', 'INVENTURE.NS', 'IOB.NS', 'IOC.NS', 'IOLCP.NS', 'IONEXCHANG.NS', 'IPCALAB.NS', 'IPL.NS', 'IRB.NS', 'IRCON.NS', 'IRCTC.NS', 'IREDA.NS', 'IRFC.NS', 'IRIS.NS', 'IRISDOREME.NS', 'IRMENERGY.NS', 'ISEC.NS', 'ISFT.NS', 'ISGEC.NS', 'ISMTLTD.NS', 'ITC.NS', 'ITDC.NS', 'ITDCEM.NS', 'ITI.NS', 'IVC.NS', 'IVP.NS', 'IWEL.NS', 'IZMO.NS', 'J&KBANK.NS', 'JAGRAN.NS', 'JAGSNPHARM.NS', 'JAIBALAJI.NS', 'JAICORPLTD.NS', 'JAIPURKURT.NS', 'JAMNAAUTO.NS', 'JASH.NS', 'JAYAGROGN.NS', 'JAYBARMARU.NS', 'JAYNECOIND.NS', 'JAYSREETEA.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JCHAC.NS', 'JETAIRWAYS.NS', 'JETFREIGHT.NS', 'JHS.NS', 'JINDALPHOT.NS', 'JINDALPOLY.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JINDRILL.NS', 'JINDWORLD.NS', 'JIOFIN.NS', 'JISLDVREQS.NS', 'JISLJALEQS.NS', 'JITFINFRA.NS', 'JKCEMENT.NS', 'JKIL.NS', 'JKLAKSHMI.NS', 'JKPAPER.NS', 'JKTYRE.NS', 'JLHL.NS', 'JMA.NS', 'JMFINANCIL.NS', 'JOCIL.NS', 'JPASSOCIAT.NS', 'JPOLYINVST.NS', 'JPPOWER.NS', 'JSL.NS', 'JSWENERGY.NS', 'JSWHL.NS', 'JSWINFRA.NS', 'JSWSTEEL.NS', 'JTEKTINDIA.NS', 'JTLIND.NS', 'JUBLFOOD.NS', 'JUBLINDS.NS', 'JUBLINGREA.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'JWL.NS', 'JYOTHYLAB.NS', 'JYOTISTRUC.NS', 'KABRAEXTRU.NS', 'KAJARIACER.NS', 'KAKATCEM.NS', 'KALAMANDIR.NS', 'KALYANI.NS', 'KALYANIFRG.NS', 'KALYANKJIL.NS', 'KAMATHOTEL.NS', 'KAMDHENU.NS', 'KAMOPAINTS.NS', 'KANANIIND.NS', 'KANORICHEM.NS', 'KANPRPLA.NS', 'KANSAINER.NS', 'KAPSTON.NS', 'KARMAENG.NS', 'KARURVYSYA.NS', 'KAUSHALYA.NS', 'KAVVERITEL.NS', 'KAYA.NS', 'KAYNES.NS', 'KBCGLOBAL.NS', 'KCP.NS', 'KCPSUGIND.NS', 'KDDL.NS', 'KEC.NS', 'KECL.NS', 'KEEPLEARN.NS', 'KEI.NS', 'KELLTONTEC.NS', 'KERNEX.NS', 'KESORAMIND.NS', 'KEYFINSERV.NS', 'KFINTECH.NS', 'KHADIM.NS', 'KHAICHEM.NS', 'KHAITANLTD.NS', 'KHANDSE.NS', 'KICL.NS', 'KILITCH.NS', 'KIMS.NS', 'KINGFA.NS', 'KIOCL.NS', 'KIRIINDUS.NS', 'KIRLOSBROS.NS', 'KIRLOSENG.NS', 'KIRLOSIND.NS', 'KIRLPNU.NS', 'KITEX.NS', 'KKCL.NS', 'KMSUGAR.NS', 'KNRCON.NS', 'KOHINOOR.NS', 'KOKUYOCMLN.NS', 'KOLTEPATIL.NS', 'KOPRAN.NS', 'KOTAKBANK.NS', 'KOTARISUG.NS', 'KOTHARIPET.NS', 'KOTHARIPRO.NS', 'KPIGREEN.NS', 'KPIL.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'KRBL.NS', 'KREBSBIO.NS', 'KRIDHANINF.NS', 'KRISHANA.NS', 'KRITI.NS', 'KRITIKA.NS', 'KRITINUT.NS', 'KRSNAA.NS', 'KSB.NS', 'KSCL.NS', 'KSHITIJPOL.NS', 'KSL.NS', 'KSOLVES.NS', 'KTKBANK.NS', 'KUANTUM.NS', 'L&TFH.NS', 'LAGNAM.NS', 'LAKPRE.NS', 'LAL.NS', 'LALPATHLAB.NS', 'LAMBODHARA.NS', 'LANDMARK.NS', 'LAOPALA.NS', 'LASA.NS', 'LATENTVIEW.NS', 'LATTEYS.NS', 'LAURUSLABS.NS', 'LAXMICOT.NS', 'LAXMIMACH.NS', 'LCCINFOTEC.NS', 'LEMONTREE.NS', 'LEXUS.NS', 'LFIC.NS', 'LGBBROSLTD.NS', 'LGBFORGE.NS', 'LGHL.NS', 'LIBAS.NS', 'LIBERTSHOE.NS', 'LICHSGFIN.NS', 'LICI.NS', 'LIKHITHA.NS', 'LINC.NS', 'LINCOLN.NS', 'LINDEINDIA.NS', 'LLOYDS-RE.NS', 'LLOYDSENGG.NS', 'LLOYDSME.NS', 'LODHA.NS', 'LOKESHMACH.NS', 'LORDSCHLO.NS', 'LOTUSEYE.NS', 'LOVABLE.NS', 'LOYALTEX.NS', 'LPDC.NS', 'LT.NS', 'LTFOODS.NS', 'LTIM.NS', 'LTTS.NS', 'LUMAXIND.NS', 'LUMAXTECH.NS', 'LUPIN.NS', 'LUXIND.NS', 'LXCHEM.NS', 'LYKALABS.NS', 'LYPSAGEMS.NS', 'M&M.NS', 'M&MFIN.NS', 'MAANALU.NS', 'MACPOWER.NS', 'MADHAV.NS', 'MADHUCON.NS', 'MADRASFERT.NS', 'MAGADSUGAR.NS', 'MAGNUM.NS', 'MAHABANK.NS', 'MAHAPEXLTD.NS', 'MAHASTEEL.NS', 'MAHEPC.NS', 'MAHESHWARI.NS', 'MAHLIFE.NS', 'MAHLOG.NS', 'MAHSCOOTER.NS', 'MAHSEAMLES.NS', 'MAITHANALL.NS', 'MALLCOM.NS', 'MALUPAPER.NS', 'MANAKALUCO.NS', 'MANAKCOAT.NS', 'MANAKSIA.NS', 'MANAKSTEEL.NS', 'MANALIPETC.NS', 'MANAPPURAM.NS', 'MANGALAM.NS', 'MANGCHEFER.NS', 'MANGLMCEM.NS', 'MANINDS.NS', 'MANINFRA.NS', 'MANKIND.NS', 'MANOMAY.NS', 'MANORAMA.NS', 'MANORG.NS', 'MANUGRAPH.NS', 'MANYAVAR.NS', 'MAPMYINDIA.NS', 'MARALOVER.NS', 'MARATHON.NS', 'MARICO.NS', 'MARINE.NS', 'MARKSANS.NS', 'MARSHALL.NS', 'MARUTI.NS', 'MASFIN.NS', 'MASKINVEST.NS', 'MASTEK.NS', 'MATRIMONY.NS', 'MAWANASUG.NS', 'MAXESTATES.NS', 'MAXHEALTH.NS', 'MAXIND.NS', 'MAYURUNIQ.NS', 'MAZDA.NS', 'MAZDOCK.NS', 'MBAPL.NS', 'MBECL.NS', 'MBLINFRA.NS', 'MCDOWELL-N.NS', 'MCL.NS', 'MCLEODRUSS.NS', 'MCX.NS', 'MEDANTA.NS', 'MEDICAMEQ.NS', 'MEDICO.NS', 'MEDPLUS.NS', 'MEGASOFT.NS', 'MEGASTAR.NS', 'MELSTAR.NS', 'MENONBE.NS', 'MEP.NS', 'METALFORGE.NS', 'METROBRAND.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MGEL.NS', 'MGL.NS', 'MHLXMIRU.NS', 'MHRIL.NS', 'MICEL.NS', 'MIDHANI.NS', 'MINDACORP.NS', 'MINDTECK.NS', 'MIRCELECTR.NS', 'MIRZAINT.NS', 'MITCON.NS', 'MITTAL.NS', 'MKPL.NS', 'MMFL.NS', 'MMP.NS', 'MMTC.NS', 'MODIRUBBER.NS', 'MODISONLTD.NS', 'MOHITIND.NS', 'MOIL.NS', 'MOKSH.NS', 'MOL.NS', 'MOLDTECH.NS', 'MOLDTKPAC.NS', 'MONARCH.NS', 'MONTECARLO.NS', 'MORARJEE.NS', 'MOREPENLAB.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'MOTISONS.NS', 'MOTOGENFIN.NS', 'MPHASIS.NS', 'MPSLTD.NS', 'MRF.NS', 'MRO-TEK.NS', 'MRPL.NS', 'MSPL.NS', 'MSTCLTD.NS', 'MSUMI.NS', 'MTARTECH.NS', 'MTEDUCARE.NS', 'MTNL.NS', 'MUFIN.NS', 'MUFTI.NS', 'MUKANDLTD.NS', 'MUKTAARTS.NS', 'MUNJALAU.NS', 'MUNJALSHOW.NS', 'MURUDCERA.NS', 'MUTHOOTCAP.NS', 'MUTHOOTFIN.NS', 'MUTHOOTMF.NS', 'MVGJL.NS', 'NACLIND.NS', 'NAGAFERT.NS', 'NAGREEKCAP.NS', 'NAGREEKEXP.NS', 'NAHARCAP.NS', 'NAHARINDUS.NS', 'NAHARPOLY.NS', 'NAHARSPING.NS', 'NAM-INDIA.NS', 'NARMADA.NS', 'NATCOPHARM.NS', 'NATHBIOGEN.NS', 'NATIONALUM.NS', 'NAUKRI.NS', 'NAVA.NS', 'NAVINFLUOR.NS', 'NAVKARCORP.NS', 'NAVNETEDUL.NS', 'NAZARA.NS', 'NBCC.NS', 'NBIFIN.NS', 'NCC.NS', 'NCLIND.NS', 'NDGL.NS', 'NDL.NS', 'NDLVENTURE.NS', 'NDRAUTO.NS', 'NDTV.NS', 'NECCLTD.NS', 'NECLIFE.NS', 'NELCAST.NS', 'NELCO.NS', 'NEOGEN.NS', 'NESCO.NS', 'NESTLEIND.NS', 'NETWEB.NS', 'NETWORK18.NS', 'NEULANDLAB.NS', 'NEWGEN.NS', 'NEXTMEDIA.NS', 'NFL.NS', 'NGIL.NS', 'NGLFINE.NS', 'NH.NS', 'NHPC.NS', 'NIACL.NS', 'NIBL.NS', 'NIITLTD.NS', 'NIITMTS.NS', 'NILAINFRA.NS', 'NILASPACES.NS', 'NILKAMAL.NS', 'NINSYS.NS', 'NIPPOBATRY.NS', 'NIRAJ.NS', 'NIRAJISPAT.NS', 'NITCO.NS', 'NITINSPIN.NS', 'NITIRAJ.NS', 'NKIND.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NOCIL.NS', 'NOIDATOLL.NS', 'NORBTEAEXP.NS', 'NRAIL.NS', 'NRBBEARING.NS', 'NRL.NS', 'NSIL.NS', 'NSLNISP.NS', 'NTPC.NS', 'NUCLEUS.NS', 'NURECA.NS', 'NUVAMA.NS', 'NUVOCO.NS', 'NYKAA.NS', 'OAL.NS', 'OBCL.NS', 'OBEROIRLTY.NS', 'OCCL.NS', 'OFSS.NS', 'OIL.NS', 'OILCOUNTUB.NS', 'OLECTRA.NS', 'OMAXAUTO.NS', 'OMAXE.NS', 'OMINFRAL.NS', 'OMKARCHEM.NS', 'ONELIFECAP.NS', 'ONEPOINT.NS', 'ONGC.NS', 'ONMOBILE.NS', 'ONWARDTEC.NS', 'OPTIEMUS.NS', 'ORBTEXP.NS', 'ORCHPHARMA.NS', 'ORICONENT.NS', 'ORIENTALTL.NS', 'ORIENTBELL.NS', 'ORIENTCEM.NS', 'ORIENTCER.NS', 'ORIENTELEC.NS', 'ORIENTHOT.NS', 'ORIENTLTD.NS', 'ORIENTPPR.NS', 'ORISSAMINE.NS', 'ORTINLAB.NS', 'OSIAHYPER.NS', 'OSWALAGRO.NS', 'OSWALGREEN.NS', 'OSWALSEEDS.NS', 'PAGEIND.NS', 'PAISALO.NS', 'PAKKA.NS', 'PALASHSECU.NS', 'PALREDTEC.NS', 'PANACEABIO.NS', 'PANACHE.NS', 'PANAMAPET.NS', 'PANSARI.NS', 'PAR.NS', 'PARACABLES.NS', 'PARADEEP.NS', 'PARAGMILK.NS', 'PARAS.NS', 'PARASPETRO.NS', 'PARSVNATH.NS', 'PASUPTAC.NS', 'PATANJALI.NS', 'PATELENG.NS', 'PATINTLOG.NS', 'PAVNAIND.NS', 'PAYTM.NS', 'PCBL.NS', 'PCJEWELLER.NS', 'PDMJEPAPER.NS', 'PDSL.NS', 'PEARLPOLY.NS', 'PEL.NS', 'PENIND.NS', 'PENINLAND.NS', 'PERSISTENT.NS', 'PETRONET.NS', 'PFC.NS', 'PFIZER.NS', 'PFOCUS.NS', 'PFS.NS', 'PGEL.NS', 'PGHH.NS', 'PGHL.NS', 'PGIL.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'PIGL.NS', 'PIIND.NS', 'PILANIINVS.NS', 'PILITA.NS', 'PIONEEREMB.NS', 'PITTIENG.NS', 'PIXTRANS.NS', 'PKTEA.NS', 'PLASTIBLEN.NS', 'PLAZACABLE.NS', 'PNB.NS', 'PNBGILTS.NS', 'PNBHOUSING.NS', 'PNC.NS', 'PNCINFRA.NS', 'POCL.NS', 'PODDARHOUS.NS', 'PODDARMENT.NS', 'POKARNA.NS', 'POLICYBZR.NS', 'POLYCAB.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'PONNIERODE.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'POWERINDIA.NS', 'POWERMECH.NS', 'PPAP.NS', 'PPL.NS', 'PPLPHARMA.NS', 'PRAENG.NS', 'PRAJIND.NS', 'PRAKASH.NS', 'PRAKASHSTL.NS', 'PRAXIS.NS', 'PRECAM.NS', 'PRECOT.NS', 'PRECWIRE.NS', 'PREMEXPLN.NS', 'PREMIER.NS', 'PREMIERPOL.NS', 'PRESTIGE.NS', 'PRICOLLTD.NS', 'PRIMESECU.NS', 'PRINCEPIPE.NS', 'PRITI.NS', 'PRITIKAUTO.NS', 'PRIVISCL.NS', 'PROZONER.NS', 'PRSMJOHNSN.NS', 'PRUDENT.NS', 'PRUDMOULI.NS', 'PSB.NS', 'PSPPROJECT.NS', 'PTC.NS', 'PTCIL.NS', 'PTL.NS', 'PUNJABCHEM.NS', 'PURVA.NS', 'PVP.NS', 'PVRINOX.NS', 'PYRAMID.NS', 'QUESS.NS', 'QUICKHEAL.NS', 'RACE.NS', 'RADAAN.NS', 'RADHIKAJWE.NS', 'RADIANTCMS.NS', 'RADICO.NS', 'RADIOCITY.NS', 'RAILTEL.NS', 'RAIN.NS', 'RAINBOW.NS', 'RAJESHEXPO.NS', 'RAJMET.NS', 'RAJRATAN.NS', 'RAJRILTD.NS', 'RAJSREESUG.NS', 'RAJTV.NS', 'RALLIS.NS', 'RAMANEWS.NS', 'RAMAPHO.NS', 'RAMASTEEL.NS', 'RAMCOCEM.NS', 'RAMCOIND.NS', 'RAMCOSYS.NS', 'RAMKY.NS', 'RAMRAT.NS', 'RANASUG.NS', 'RANEENGINE.NS', 'RANEHOLDIN.NS', 'RATEGAIN.NS', 'RATNAMANI.NS', 'RATNAVEER.NS', 'RAYMOND.NS', 'RBA.NS', 'RBL.NS', 'RBLBANK.NS', 'RBZJEWEL.NS', 'RCF.NS', 'RECLTD.NS', 'REDINGTON.NS', 'REDTAPE.NS', 'REFEX.NS', 'REGENCERAM.NS', 'RELAXO.NS', 'RELCAPITAL.NS', 'RELCHEMQ.NS', 'RELIANCE.NS', 'RELIGARE.NS', 'RELINFRA.NS', 'REMSONSIND.NS', 'RENUKA.NS', 'REPCOHOME.NS', 'REPL.NS', 'REPRO.NS', 'RESPONIND.NS', 'RGL.NS', 'RHFL.NS', 'RHIM.NS', 'RHL.NS', 'RICOAUTO.NS', 'RIIL.NS', 'RISHABH.NS', 'RITCO.NS', 'RITES.NS', 'RKDL.NS', 'RKEC.NS', 'RKFORGE.NS', 'RML.NS', 'ROHLTD.NS', 'ROLEXRINGS.NS', 'ROLLT.NS', 'ROML.NS', 'ROSSARI.NS', 'ROSSELLIND.NS', 'ROTO.NS', 'ROUTE.NS', 'RPGLIFE.NS', 'RPOWER.NS', 'RPPINFRA.NS', 'RPPL.NS', 'RPSGVENT.NS', 'RRKABEL.NS', 'RSSOFTWARE.NS', 'RSWM.NS', 'RSYSTEMS.NS', 'RTNINDIA.NS', 'RTNPOWER.NS', 'RUBYMILLS.NS', 'RUCHINFRA.NS', 'RUCHIRA.NS', 'RUPA.NS', 'RUSHIL.NS', 'RUSTOMJEE.NS', 'RVHL.NS', 'RVNL.NS', 'S&SPOWER.NS', 'SABEVENTS.NS', 'SABTN.NS', 'SADBHAV.NS', 'SADBHIN.NS', 'SADHNANIQ.NS', 'SAFARI.NS', 'SAGARDEEP.NS', 'SAGCEM.NS', 'SAH.NS', 'SAHYADRI.NS', 'SAIL.NS', 'SAKAR.NS', 'SAKHTISUG.NS', 'SAKSOFT.NS', 'SAKUMA.NS', 'SALASAR.NS', 'SALONA.NS', 'SALSTEEL.NS', 'SALZERELEC.NS', 'SAMBHAAV.NS', 'SAMHI.NS', 'SAMPANN.NS', 'SANCO.NS', 'SANDESH.NS', 'SANDHAR.NS', 'SANDUMA.NS', 'SANGAMIND.NS', 'SANGHIIND.NS', 'SANGHVIMOV.NS', 'SANGINITA.NS', 'SANOFI.NS', 'SANSERA.NS', 'SAPPHIRE.NS', 'SARDAEN.NS', 'SAREGAMA.NS', 'SARLAPOLY.NS', 'SARVESHWAR.NS', 'SASKEN.NS', 'SASTASUNDR.NS', 'SATIA.NS', 'SATIN.NS', 'SATINDLTD.NS', 'SBC.NS', 'SBCL.NS', 'SBFC.NS', 'SBGLP.NS', 'SBICARD.NS', 'SBILIFE.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SCHAND.NS', 'SCHNEIDER.NS', 'SCI.NS', 'SCPL.NS', 'SDBL.NS', 'SEAMECLTD.NS', 'SECMARK.NS', 'SECURCRED.NS', 'SECURKLOUD.NS', 'SEJALLTD.NS', 'SELAN.NS', 'SELMC.NS', 'SEMAC.NS', 'SENCO.NS', 'SEPC.NS', 'SEQUENT.NS', 'SERVOTECH.NS', 'SESHAPAPER.NS', 'SETCO.NS', 'SEYAIND.NS', 'SFL.NS', 'SGIL.NS', 'SGL.NS', 'SHAH.NS', 'SHAHALLOYS.NS', 'SHAILY.NS', 'SHAKTIPUMP.NS', 'SHALBY.NS', 'SHALPAINTS.NS', 'SHANKARA.NS', 'SHANTI.NS', 'SHANTIGEAR.NS', 'SHARDACROP.NS', 'SHARDAMOTR.NS', 'SHAREINDIA.NS', 'SHEMAROO.NS', 'SHILPAMED.NS', 'SHIVALIK.NS', 'SHIVAMAUTO.NS', 'SHIVAMILLS.NS', 'SHIVATEX.NS', 'SHK.NS', 'SHOPERSTOP.NS', 'SHRADHA.NS', 'SHREDIGCEM.NS', 'SHREECEM.NS', 'SHREEPUSHK.NS', 'SHREERAMA.NS', 'SHRENIK.NS', 'SHREYANIND.NS', 'SHREYAS.NS', 'SHRIPISTON.NS', 'SHRIRAMFIN.NS', 'SHRIRAMPPS.NS', 'SHYAMCENT.NS', 'SHYAMMETL.NS', 'SHYAMTEL.NS', 'SICALLOG.NS', 'SIEMENS.NS', 'SIGACHI.NS', 'SIGIND.NS', 'SIGMA.NS', 'SIGNATURE.NS', 'SIKKO.NS', 'SIL.NS', 'SILGO.NS', 'SILINV.NS', 'SILLYMONKS.NS', 'SILVERTUC.NS', 'SIMBHALS.NS', 'SIMPLEXINF.NS', 'SINDHUTRAD.NS', 'SINTERCOM.NS', 'SIRCA.NS', 'SIS.NS', 'SITINET.NS', 'SIYSIL.NS', 'SJS.NS', 'SJVN.NS', 'SKFINDIA.NS', 'SKIPPER.NS', 'SKMEGGPROD.NS', 'SKYGOLD.NS', 'SMARTLINK.NS', 'SMCGLOBAL.NS', 'SMLISUZU.NS', 'SMLT.NS', 'SMSLIFE.NS', 'SMSPHARMA.NS', 'SNOWMAN.NS', 'SOBHA.NS', 'SOFTTECH.NS', 'SOLARA.NS', 'SOLARINDS.NS', 'SOMANYCERA.NS', 'SOMATEX.NS', 'SOMICONVEY.NS', 'SONACOMS.NS', 'SONAMLTD.NS', 'SONATSOFTW.NS', 'SOTL.NS', 'SOUTHBANK.NS', 'SOUTHWEST.NS', 'SPAL.NS', 'SPANDANA.NS', 'SPARC.NS', 'SPCENET.NS', 'SPECIALITY.NS', 'SPENCERS.NS', 'SPENTEX.NS', 'SPIC.NS', 'SPLIL.NS', 'SPLPETRO.NS', 'SPMLINFRA.NS', 'SPORTKING.NS', 'SPTL.NS', 'SPYL.NS', 'SREEL.NS', 'SRF.NS', 'SRGHFL.NS', 'SRHHYPOLTD.NS', 'SRPL.NS', 'SSWL.NS', 'STAR.NS', 'STARCEMENT.NS', 'STARHEALTH.NS', 'STARPAPER.NS', 'STARTECK.NS', 'STCINDIA.NS', 'STEELCAS.NS', 'STEELCITY.NS', 'STEELXIND.NS', 'STEL.NS', 'STERTOOLS.NS', 'STLTECH.NS', 'STOVEKRAFT.NS', 'STYLAMIND.NS', 'STYRENIX.NS', 'SUBEXLTD.NS', 'SUBROS.NS', 'SUDARSCHEM.NS', 'SUKHJITS.NS', 'SULA.NS', 'SUMICHEM.NS', 'SUMIT.NS', 'SUMMITSEC.NS', 'SUNCLAY.NS', 'SUNDARAM.NS', 'SUNDARMFIN.NS', 'SUNDARMHLD.NS', 'SUNDRMBRAK.NS', 'SUNDRMFAST.NS', 'SUNFLAG.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SUNTV.NS', 'SUPERHOUSE.NS', 'SUPERSPIN.NS', 'SUPRAJIT.NS', 'SUPREMEENG.NS', 'SUPREMEIND.NS', 'SUPREMEINF.NS', 'SUPRIYA.NS', 'SURAJEST.NS', 'SURANASOL.NS', 'SURANAT&P.NS', 'SURYALAXMI.NS', 'SURYAROSNI.NS', 'SURYODAY.NS', 'SUTLEJTEX.NS', 'SUULD.NS', 'SUVEN.NS', 'SUVENPHAR.NS', 'SUVIDHAA.NS', 'SUZLON.NS', 'SVLL.NS', 'SVPGLOB.NS', 'SWANENERGY.NS', 'SWARAJENG.NS', 'SWELECTES.NS', 'SWSOLAR.NS', 'SYMPHONY.NS', 'SYNCOMF.NS', 'SYNGENE.NS', 'SYRMA.NS', 'TAINWALCHM.NS', 'TAJGVK.NS', 'TAKE.NS', 'TALBROAUTO.NS', 'TANLA.NS', 'TARAPUR.NS', 'TARC.NS', 'TARMAT.NS', 'TARSONS.NS', 'TASTYBITE.NS', 'TATACHEM.NS', 'TATACOFFEE.NS', 'TATACOMM.NS', 'TATACONSUM.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TATAMETALI.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TATATECH.NS', 'TATVA.NS', 'TBZ.NS', 'TCI.NS', 'TCIEXP.NS', 'TCLCONS.NS', 'TCNSBRANDS.NS', 'TCPLPACK.NS', 'TCS.NS', 'TDPOWERSYS.NS', 'TEAMLEASE.NS', 'TECHIN.NS', 'TECHM.NS', 'TECHNOE.NS', 'TECILCHEM.NS', 'TEGA.NS', 'TEJASNET.NS', 'TEMBO.NS', 'TERASOFT.NS', 'TEXINFRA.NS', 'TEXMOPIPES.NS', 'TEXRAIL.NS', 'TFCILTD.NS', 'TFL.NS', 'TGBHOTELS.NS', 'THANGAMAYL.NS', 'THEINVEST.NS', 'THEJO.NS', 'THEMISMED.NS', 'THERMAX.NS', 'THOMASCOOK.NS', 'THOMASCOTT.NS', 'THYROCARE.NS', 'TI.NS', 'TIDEWATER.NS', 'TIIL.NS', 'TIINDIA.NS', 'TIJARIA.NS', 'TIL.NS', 'TIMESGTY.NS', 'TIMETECHNO.NS', 'TIMKEN.NS', 'TINPLATE.NS', 'TIPSFILMS.NS', 'TIPSINDLTD.NS', 'TIRUMALCHM.NS', 'TIRUPATIFL.NS', 'TITAGARH.NS', 'TITAN.NS', 'TMB.NS', 'TNPETRO.NS', 'TNPL.NS', 'TNTELE.NS', 'TOKYOPLAST.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'TOTAL.NS', 'TOUCHWOOD.NS', 'TPHQ.NS', 'TPLPLASTEH.NS', 'TRACXN.NS', 'TREEHOUSE.NS', 'TREJHARA.NS', 'TREL.NS', 'TRENT.NS', 'TRF.NS', 'TRIDENT.NS', 'TRIGYN.NS', 'TRIL.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TRU.NS', 'TTKHLTCARE.NS', 'TTKPRESTIG.NS', 'TTL.NS', 'TTML.NS', 'TV18BRDCST.NS', 'TVSELECT.NS', 'TVSHLTD.NS', 'TVSMOTOR.NS', 'TVSSCS.NS', 'TVSSRICHAK.NS', 'TVTODAY.NS', 'TVVISION.NS', 'UBL.NS', 'UCAL.NS', 'UCOBANK.NS', 'UDS.NS', 'UFLEX.NS', 'UFO.NS', 'UGARSUGAR.NS', 'UGROCAP.NS', 'UJJIVAN.NS', 'UJJIVANSFB.NS', 'ULTRACEMCO.NS', 'UMAEXPORTS.NS', 'UMANGDAIRY.NS', 'UMESLTD.NS', 'UNICHEMLAB.NS', 'UNIDT.NS', 'UNIENTER.NS', 'UNIINFO.NS', 'UNIONBANK.NS', 'UNIPARTS.NS', 'UNITECH.NS', 'UNITEDPOLY.NS', 'UNITEDTEA.NS', 'UNIVAFOODS.NS', 'UNIVASTU.NS', 'UNIVCABLES.NS', 'UNIVPHOTO.NS', 'UNOMINDA.NS', 'UPL.NS', 'URAVI.NS', 'URJA.NS', 'USHAMART.NS', 'USK.NS', 'UTIAMC.NS', 'UTKARSHBNK.NS', 'UTTAMSUGAR.NS', 'V2RETAIL.NS', 'VADILALIND.NS', 'VAIBHAVGBL.NS', 'VAISHALI.NS', 'VAKRANGEE.NS', 'VALIANTLAB.NS', 'VALIANTORG.NS', 'VARDHACRLC.NS', 'VARDMNPOLY.NS', 'VARROC.NS', 'VASCONEQ.NS', 'VASWANI.NS', 'VBL.NS', 'VCL.NS', 'VEDL.NS', 'VENKEYS.NS', 'VENUSPIPES.NS', 'VENUSREM.NS', 'VERANDA.NS', 'VERTOZ.NS', 'VESUVIUS.NS', 'VETO.NS', 'VGUARD.NS', 'VHL.NS', 'VIDHIING.NS', 'VIJAYA.NS', 'VIJIFIN.NS', 'VIKASECO.NS', 'VIKASLIFE.NS', 'VIMTALABS.NS', 'VINATIORGA.NS', 'VINDHYATEL.NS', 'VINEETLAB.NS', 'VINNY.NS', 'VINYLINDIA.NS', 'VIPCLOTHNG.NS', 'VIPIND.NS', 'VIPULLTD.NS', 'VIRINCHI.NS', 'VISAKAIND.NS', 'VISESHINFO.NS', 'VISHNU.NS', 'VISHWARAJ.NS', 'VIVIDHA.NS', 'VLEGOV.NS', 'VLSFINANCE.NS', 'VMART.NS', 'VOLTAMP.NS', 'VOLTAS.NS', 'VPRPL.NS', 'VRLLOG.NS', 'VSSL.NS', 'VSTIND.NS', 'VSTTILLERS.NS', 'VTL.NS', 'WABAG.NS', 'WALCHANNAG.NS', 'WANBURY.NS', 'WEALTH.NS', 'WEBELSOLAR.NS', 'WEIZMANIND.NS', 'WEL.NS', 'WELCORP.NS', 'WELENT.NS', 'WELINV.NS', 'WELSPUNLIV.NS', 'WENDT.NS', 'WESTLIFE.NS', 'WEWIN.NS', 'WHEELS.NS', 'WHIRLPOOL.NS', 'WILLAMAGOR.NS', 'WINDLAS.NS', 'WINDMACHIN.NS', 'WINSOME.NS', 'WIPL.NS', 'WIPRO.NS', 'WOCKPHARMA.NS', 'WONDERLA.NS', 'WORTH.NS', 'WSI.NS', 'WSTCSTPAPR.NS', 'XCHANGING.NS', 'XELPMOC.NS', 'XPROINDIA.NS', 'YAARI.NS', 'YASHO.NS', 'YATHARTH.NS', 'YATRA.NS', 'YESBANK.NS', 'YUKEN.NS', 'ZAGGLE.NS', 'ZEEL.NS', 'ZEELEARN.NS', 'ZEEMEDIA.NS', 'ZENITHEXPO.NS', 'ZENITHSTL.NS', 'ZENSARTECH.NS', 'ZENTEC.NS', 'ZFCVINDIA.NS', 'ZIMLAB.NS', 'ZODIAC.NS', 'ZODIACLOTH.NS', 'ZOMATO.NS', 'ZOTA.NS', 'ZUARI.NS', 'ZUARIIND.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS']
# Function to fetch high price of a stock
def get_stock_high(stock):
    try:
        data = yf.Ticker(stock).history(period="1d")
        return data['High'][0]
    except IndexError:
        print(f"No data found for {stock}, symbol may be delisted or incorrect.")
        return None

# Fetching high prices
high_prices = {stock: get_stock_high(stock) for stock in stocks}
print("High Prices:", high_prices)

# Filtering out None values
high_prices = {k: v for k, v in high_prices.items() if v is not None}

# Creating a DataFrame and exporting to Excel
df = pd.DataFrame(list(high_prices.items()), columns=['Stock', 'High Price'])
excel_filename = "stock_high_prices.xlsx"
df.to_excel(excel_filename, index=False)
print(f"Excel file '{excel_filename}' has been created.")
# Out:
# ERROR:yfinance:KALYANI.NS: No price data found, symbol may be delisted (period=1d)
# No data found for KALYANI.NS, symbol may be delisted or incorrect.
# ERROR:yfinance:LLOYDS-RE.NS: No price data found, symbol may be delisted (period=1d)
# No data found for LLOYDS-RE.NS, symbol may be delisted or incorrect.
# ERROR:yfinance:NIRAJISPAT.NS: No price data found, symbol may be delisted (period=1d)
# No data found for NIRAJISPAT.NS, symbol may be delisted or incorrect.
# ERROR:yfinance:TATACOFFEE.NS: No price data found, symbol may be delisted (period=1d)
# No data found for TATACOFFEE.NS, symbol may be delisted or incorrect.
# ERROR:yfinance:TINPLATE.NS: No price data found, symbol may be delisted (period=1d)
# No data found for TINPLATE.NS, symbol may be delisted or incorrect.
# ...

# %% [markdown]
# #To modify the code to include the current price and a price that is 1% above the high price for each stock, we need to make a few adjustments. Here's the updated code:

# %%
import yfinance as yf
import pandas as pd

# List of stock symbols
stocks = ['20MICRONS.NS', '21STCENMGM.NS', '360ONE.NS', '3IINFOLTD.NS', '3MINDIA.NS', '3PLAND.NS', '5PAISA.NS', '63MOONS.NS', 'A2ZINFRA.NS', 'AAATECH.NS', 'AAKASH.NS', 'AAREYDRUGS.NS', 'AARON.NS', 'AARTECH.NS', 'AARTIDRUGS.NS', 'AARTIIND.NS', 'AARTIPHARM.NS', 'AARTISURF.NS', 'AARVEEDEN.NS', 'AARVI.NS', 'AAVAS.NS', 'ABAN.NS', 'ABB.NS', 'ABBOTINDIA.NS', 'ABCAPITAL.NS', 'ABFRL.NS', 'ABMINTLLTD.NS', 'ABSLAMC.NS', 'ACC.NS', 'ACCELYA.NS', 'ACCURACY.NS', 'ACE.NS', 'ACEINTEG.NS', 'ACI.NS', 'ACL.NS', 'ACLGATI.NS', 'ADANIENSOL.NS', 'ADANIENT.NS', 'ADANIGREEN.NS', 'ADANIPORTS.NS', 'ADANIPOWER.NS', 'ADFFOODS.NS', 'ADL.NS', 'ADORWELD.NS', 'ADROITINFO.NS', 'ADSL.NS', 'ADVANIHOTR.NS', 'ADVENZYMES.NS', 'AEGISCHEM.NS', 'AEROFLEX.NS', 'AETHER.NS', 'AFFLE.NS', 'AGARIND.NS', 'AGI.NS', 'AGRITECH.NS', 'AGROPHOS.NS', 'AGSTRA.NS', 'AHL.NS', 'AHLADA.NS', 'AHLEAST.NS', 'AHLUCONT.NS', 'AIAENG.NS', 'AIRAN.NS', 'AIROLAM.NS', 'AJANTPHARM.NS', 'AJMERA.NS', 'AJOONI.NS', 'AKASH.NS', 'AKG.NS', 'AKI.NS', 'AKSHAR.NS', 'AKSHARCHEM.NS', 'AKSHOPTFBR.NS', 'AKZOINDIA.NS', 'ALANKIT.NS', 'ALBERTDAVD.NS', 'ALEMBICLTD.NS', 'ALICON.NS', 'ALKALI.NS', 'ALKEM.NS', 'ALKYLAMINE.NS', 'ALLCARGO.NS', 'ALLSEC.NS', 'ALMONDZ.NS', 'ALOKINDS.NS', 'ALPA.NS', 'ALPHAGEO.NS', 'ALPSINDUS.NS', 'AMBER.NS', 'AMBICAAGAR.NS', 'AMBIKCO.NS', 'AMBUJACEM.NS', 'AMDIND.NS', 'AMIORG.NS', 'AMJLAND.NS', 'AMNPLST.NS', 'AMRUTANJAN.NS', 'ANANDRATHI.NS', 'ANANTRAJ.NS', 'ANDHRAPAP.NS', 'ANDHRSUGAR.NS', 'ANGELONE.NS', 'ANIKINDS.NS', 'ANKITMETAL.NS', 'ANMOL.NS', 'ANTGRAPHIC.NS', 'ANUP.NS', 'ANURAS.NS', 'APARINDS.NS', 'APCL.NS', 'APCOTEXIND.NS', 'APEX.NS', 'APLAPOLLO.NS', 'APLLTD.NS', 'APOLLO.NS', 'APOLLOHOSP.NS', 'APOLLOPIPE.NS', 'APOLLOTYRE.NS', 'APOLSINHOT.NS', 'APTECHT.NS', 'APTUS.NS', 'ARCHIDPLY.NS', 'ARCHIES.NS', 'ARE&M.NS', 'ARENTERP.NS', 'ARIES.NS', 'ARIHANTCAP.NS', 'ARIHANTSUP.NS', 'ARMANFIN.NS', 'AROGRANITE.NS', 'ARROWGREEN.NS', 'ARSHIYA.NS', 'ARSSINFRA.NS', 'ARTEMISMED.NS', 'ARTNIRMAN.NS', 'ARVEE.NS', 'ARVIND.NS', 'ARVINDFASN.NS', 'ARVSMART.NS', 'ASAHIINDIA.NS', 'ASAHISONG.NS', 'ASAL.NS', 'ASALCBR.NS', 'ASHAPURMIN.NS', 'ASHIANA.NS', 'ASHIMASYN.NS', 'ASHOKA.NS', 'ASHOKAMET.NS', 'ASHOKLEY.NS', 'ASIANENE.NS', 'ASIANHOTNR.NS', 'ASIANPAINT.NS', 'ASIANTILES.NS', 'ASKAUTOLTD.NS', 'ASMS.NS', 'ASPINWALL.NS', 'ASTEC.NS', 'ASTERDM.NS', 'ASTRAL.NS', 'ASTRAMICRO.NS', 'ASTRAZEN.NS', 'ASTRON.NS', 'ATALREAL.NS', 'ATAM.NS', 'ATFL.NS', 'ATGL.NS', 'ATL.NS', 'ATLANTAA.NS', 'ATUL.NS', 'ATULAUTO.NS', 'AUBANK.NS', 'AURIONPRO.NS', 'AUROPHARMA.NS', 'AURUM.NS', 'AUSOMENT.NS', 'AUTOAXLES.NS', 'AUTOIND.NS', 'AVADHSUGAR.NS', 'AVALON.NS', 'AVANTIFEED.NS', 'AVG.NS', 'AVONMORE.NS', 'AVROIND.NS', 'AVTNPL.NS', 'AWHCL.NS', 'AWL.NS', 'AXISBANK.NS', 'AXISCADES.NS', 'AXITA.NS', 'AYMSYNTEX.NS', 'AZAD.NS', 'BAFNAPH.NS', 'BAGFILMS.NS', 'BAIDFIN.NS', 'BAJAJ-AUTO.NS', 'BAJAJCON.NS', 'BAJAJELEC.NS', 'BAJAJFINSV.NS', 'BAJAJHCARE.NS', 'BAJAJHIND.NS', 'BAJAJHLDNG.NS', 'BAJEL.NS', 'BAJFINANCE.NS', 'BALAJITELE.NS', 'BALAMINES.NS', 'BALAXI.NS', 'BALKRISHNA.NS', 'BALKRISIND.NS', 'BALMLAWRIE.NS', 'BALPHARMA.NS', 'BALRAMCHIN.NS', 'BANARBEADS.NS', 'BANARISUG.NS', 'BANCOINDIA.NS', 'BANDHANBNK.NS', 'BANG.NS', 'BANKA.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BANSWRAS.NS', 'BARBEQUE.NS', 'BASF.NS', 'BASML.NS', 'BATAINDIA.NS', 'BAYERCROP.NS', 'BBL.NS', 'BBOX.NS', 'BBTC.NS', 'BBTCL.NS', 'BCG.NS', 'BCLIND.NS', 'BCONCEPTS.NS', 'BDL.NS', 'BEARDSELL.NS', 'BECTORFOOD.NS', 'BEDMUTHA.NS', 'BEL.NS', 'BEML.NS', 'BEPL.NS', 'BERGEPAINT.NS', 'BFINVEST.NS', 'BFUTILITIE.NS', 'BGRENERGY.NS', 'BHAGCHEM.NS', 'BHAGERIA.NS', 'BHAGYANGR.NS', 'BHANDARI.NS', 'BHARATFORG.NS', 'BHARATGEAR.NS', 'BHARATRAS.NS', 'BHARATWIRE.NS', 'BHARTIARTL.NS', 'BHEL.NS', 'BIGBLOC.NS', 'BIKAJI.NS', 'BIL.NS', 'BINANIIND.NS', 'BIOCON.NS', 'BIOFILCHEM.NS', 'BIRLACABLE.NS', 'BIRLACORPN.NS', 'BIRLAMONEY.NS', 'BKMINDST.NS', 'BLAL.NS', 'BLBLIMITED.NS', 'BLISSGVS.NS', 'BLKASHYAP.NS', 'BLS.NS', 'BLUECHIP.NS', 'BLUECOAST.NS', 'BLUEDART.NS', 'BLUEJET.NS', 'BLUESTARCO.NS', 'BODALCHEM.NS', 'BOHRAIND.NS', 'BOMDYEING.NS', 'BOROLTD.NS', 'BORORENEW.NS', 'BOSCHLTD.NS', 'BPCL.NS', 'BPL.NS', 'BRIGADE.NS', 'BRITANNIA.NS', 'BRNL.NS', 'BROOKS.NS', 'BSE.NS', 'BSHSL.NS', 'BSL.NS', 'BSOFT.NS', 'BTML.NS', 'BURNPUR.NS', 'BUTTERFLY.NS', 'BVCL.NS', 'BYKE.NS', 'CALSOFT.NS', 'CAMLINFINE.NS', 'CAMPUS.NS', 'CAMS.NS', 'CANBK.NS', 'CANFINHOME.NS', 'CANTABIL.NS', 'CAPACITE.NS', 'CAPLIPOINT.NS', 'CAPTRUST.NS', 'CARBORUNIV.NS', 'CAREERP.NS', 'CARERATING.NS', 'CARTRADE.NS', 'CARYSIL.NS', 'CASTROLIND.NS', 'CCHHL.NS', 'CCL.NS', 'CDSL.NS', 'CEATLTD.NS', 'CELEBRITY.NS', 'CELLO.NS', 'CENTENKA.NS', 'CENTEXT.NS', 'CENTRALBK.NS', 'CENTRUM.NS', 'CENTUM.NS', 'CENTURYPLY.NS', 'CENTURYTEX.NS', 'CERA.NS', 'CEREBRAINT.NS', 'CESC.NS', 'CGCL.NS', 'CGPOWER.NS', 'CHALET.NS', 'CHAMBLFERT.NS', 'CHEMBOND.NS', 'CHEMCON.NS', 'CHEMFAB.NS', 'CHEMPLASTS.NS', 'CHENNPETRO.NS', 'CHEVIOT.NS', 'CHOICEIN.NS', 'CHOLAFIN.NS', 'CHOLAHLDNG.NS', 'CIEINDIA.NS', 'CIGNITITEC.NS', 'CINELINE.NS', 'CINEVISTA.NS', 'CIPLA.NS', 'CLEAN.NS', 'CLEDUCATE.NS', 'CLSEL.NS', 'CMSINFO.NS', 'COALINDIA.NS', 'COASTCORP.NS', 'COCHINSHIP.NS', 'COFFEEDAY.NS', 'COFORGE.NS', 'COLPAL.NS', 'COMPINFO.NS', 'COMPUSOFT.NS', 'CONCOR.NS', 'CONCORDBIO.NS', 'CONFIPET.NS', 'CONSOFINVT.NS', 'CONTROLPR.NS', 'CORALFINAC.NS', 'CORDSCABLE.NS', 'COROMANDEL.NS', 'COSMOFIRST.NS', 'COUNCODOS.NS', 'CRAFTSMAN.NS', 'CREATIVE.NS', 'CREATIVEYE.NS', 'CREDITACC.NS', 'CREST.NS', 'CRISIL.NS', 'CROMPTON.NS', 'CROWN.NS', 'CSBBANK.NS', 'CSLFINANCE.NS', 'CTE.NS', 'CUB.NS', 'CUBEXTUB.NS', 'CUMMINSIND.NS', 'CUPID.NS', 'CYBERMEDIA.NS', 'CYBERTECH.NS', 'CYIENT.NS', 'CYIENTDLM.NS', 'DABUR.NS', 'DALBHARAT.NS', 'DALMIASUG.NS', 'DAMODARIND.NS', 'DANGEE.NS', 'DATAMATICS.NS', 'DATAPATTNS.NS', 'DBCORP.NS', 'DBL.NS', 'DBOL.NS', 'DBREALTY.NS', 'DBSTOCKBRO.NS', 'DCAL.NS', 'DCBBANK.NS', 'DCI.NS', 'DCM.NS', 'DCMFINSERV.NS', 'DCMNVL.NS', 'DCMSHRIRAM.NS', 'DCMSRIND.NS', 'DCW.NS', 'DCXINDIA.NS', 'DECCANCE.NS', 'DEEPAKFERT.NS', 'DEEPAKNTR.NS', 'DEEPENR.NS', 'DEEPINDS.NS', 'DELHIVERY.NS', 'DELPHIFX.NS', 'DELTACORP.NS', 'DELTAMAGNT.NS', 'DEN.NS', 'DENORA.NS', 'DEVIT.NS', 'DEVYANI.NS', 'DGCONTENT.NS', 'DHAMPURSUG.NS', 'DHANBANK.NS', 'DHANI.NS', 'DHANUKA.NS', 'DHARMAJ.NS', 'DHRUV.NS', 'DHUNINV.NS', 'DIACABS.NS', 'DIAMINESQ.NS', 'DIAMONDYD.NS', 'DICIND.NS', 'DIGISPICE.NS', 'DIGJAMLMTD.NS', 'DIL.NS', 'DISHTV.NS', 'DIVGIITTS.NS', 'DIVISLAB.NS', 'DIXON.NS', 'DJML.NS', 'DLF.NS', 'DLINKINDIA.NS', 'DMART.NS', 'DMCC.NS', 'DNAMEDIA.NS', 'DODLA.NS', 'DOLATALGO.NS', 'DOLLAR.NS', 'DOLPHIN.NS', 'DOMS.NS', 'DONEAR.NS', 'DPABHUSHAN.NS', 'DPSCLTD.NS', 'DPWIRES.NS', 'DRCSYSTEMS.NS', 'DREAMFOLKS.NS', 'DREDGECORP.NS', 'DRREDDY.NS', 'DSSL.NS', 'DTIL.NS', 'DUCON.NS', 'DVL.NS', 'DWARKESH.NS', 'DYCL.NS', 'DYNAMATECH.NS', 'DYNPRO.NS', 'E2E.NS', 'EASEMYTRIP.NS', 'EASTSILK.NS', 'ECLERX.NS', 'EDELWEISS.NS', 'EDUCOMP.NS', 'EICHERMOT.NS', 'EIDPARRY.NS', 'EIFFL.NS', 'EIHAHOTELS.NS', 'EIHOTEL.NS', 'EIMCOELECO.NS', 'EKC.NS', 'ELDEHSG.NS', 'ELECON.NS', 'ELECTCAST.NS', 'ELECTHERM.NS', 'ELGIEQUIP.NS', 'ELGIRUBCO.NS', 'ELIN.NS', 'EMAMILTD.NS', 'EMAMIPAP.NS', 'EMAMIREAL.NS', 'EMIL.NS', 'EMKAY.NS', 'EMMBI.NS', 'EMSLIMITED.NS', 'EMUDHRA.NS', 'ENDURANCE.NS', 'ENERGYDEV.NS', 'ENGINERSIN.NS', 'ENIL.NS', 'EPIGRAL.NS', 'EPL.NS', 'EQUIPPP.NS', 'EQUITASBNK.NS', 'ERIS.NS', 'EROSMEDIA.NS', 'ESABINDIA.NS', 'ESAFSFB.NS', 'ESCORTS.NS', 'ESSARSHPNG.NS', 'ESSENTIA.NS', 'ESTER.NS', 'ETHOSLTD.NS', 'EUROTEXIND.NS', 'EVEREADY.NS', 'EVERESTIND.NS', 'EXCEL.NS', 'EXCELINDUS.NS', 'EXIDEIND.NS', 'EXPLEOSOL.NS', 'EXXARO.NS', 'FACT.NS', 'FAIRCHEMOR.NS', 'FAZE3Q.NS', 'FCL.NS', 'FCONSUMER.NS', 'FCSSOFT.NS', 'FDC.NS', 'FEDERALBNK.NS', 'FEDFINA.NS', 'FEL.NS', 'FELDVR.NS', 'FIBERWEB.NS', 'FIEMIND.NS', 'FILATEX.NS', 'FINCABLES.NS', 'FINEORG.NS', 'FINOPB.NS', 'FINPIPE.NS', 'FIVESTAR.NS', 'FLAIR.NS', 'FLEXITUFF.NS', 'FLFL.NS', 'FLUOROCHEM.NS', 'FMGOETZE.NS', 'FMNL.NS', 'FOCUS.NS', 'FOODSIN.NS', 'FORTIS.NS', 'FOSECOIND.NS', 'FSC.NS', 'FSL.NS', 'FUSION.NS', 'GABRIEL.NS', 'GAEL.NS', 'GAIL.NS', 'GALAXYSURF.NS', 'GALLANTT.NS', 'GANDHAR.NS', 'GANDHITUBE.NS', 'GANECOS.NS', 'GANESHBE.NS', 'GANESHHOUC.NS', 'GANGAFORGE.NS', 'GANGESSECU.NS', 'GARFIBRES.NS', 'GATECH.NS', 'GATECHDVR.NS', 'GATEWAY.NS', 'GEECEE.NS', 'GEEKAYWIRE.NS', 'GENCON.NS', 'GENESYS.NS', 'GENSOL.NS', 'GENUSPAPER.NS', 'GENUSPOWER.NS', 'GEOJITFSL.NS', 'GEPIL.NS', 'GESHIP.NS', 'GET&D.NS', 'GFLLIMITED.NS', 'GHCL.NS', 'GHCLTEXTIL.NS', 'GICHSGFIN.NS', 'GICRE.NS', 'GILLANDERS.NS', 'GILLETTE.NS', 'GINNIFILA.NS', 'GIPCL.NS', 'GKWLIMITED.NS', 'GLAND.NS', 'GLAXO.NS', 'GLENMARK.NS', 'GLFL.NS', 'GLOBAL.NS', 'GLOBALVECT.NS', 'GLOBE.NS', 'GLOBUSSPR.NS', 'GLS.NS', 'GMBREW.NS', 'GMDCLTD.NS', 'GMMPFAUDLR.NS', 'GMRINFRA.NS', 'GMRP&UI.NS', 'GNA.NS', 'GNFC.NS', 'GOACARBON.NS', 'GOCLCORP.NS', 'GOCOLORS.NS', 'GODFRYPHLP.NS', 'GODHA.NS', 'GODREJAGRO.NS', 'GODREJCP.NS', 'GODREJIND.NS', 'GODREJPROP.NS', 'GOENKA.NS', 'GOKEX.NS', 'GOKUL.NS', 'GOKULAGRO.NS', 'GOLDENTOBC.NS', 'GOLDIAM.NS', 'GOLDTECH.NS', 'GOODLUCK.NS', 'GOYALALUM.NS', 'GPIL.NS', 'GPPL.NS', 'GPTINFRA.NS', 'GRANULES.NS', 'GRAPHITE.NS', 'GRASIM.NS', 'GRAVITA.NS', 'GREAVESCOT.NS', 'GREENLAM.NS', 'GREENPANEL.NS', 'GREENPLY.NS', 'GREENPOWER.NS', 'GRINDWELL.NS', 'GRINFRA.NS', 'GRMOVER.NS', 'GROBTEA.NS', 'GRPLTD.NS', 'GRSE.NS', 'GRWRHITECH.NS', 'GSFC.NS', 'GSLSU.NS', 'GSPL.NS', 'GSS.NS', 'GTECJAINX.NS', 'GTL.NS', 'GTLINFRA.NS', 'GTPL.NS', 'GUFICBIO.NS', 'GUJALKALI.NS', 'GUJAPOLLO.NS', 'GUJGASLTD.NS', 'GUJRAFFIA.NS', 'GULFOILLUB.NS', 'GULFPETRO.NS', 'GULPOLY.NS', 'GVKPIL.NS', 'GVPTECH.NS', 'HAL.NS', 'HAPPSTMNDS.NS', 'HAPPYFORGE.NS', 'HARDWYN.NS', 'HARIOMPIPE.NS', 'HARRMALAYA.NS', 'HARSHA.NS', 'HATHWAY.NS', 'HATSUN.NS', 'HAVELLS.NS', 'HAVISHA.NS', 'HBLPOWER.NS', 'HBSL.NS', 'HCC.NS', 'HCG.NS', 'HCL-INSYS.NS', 'HCLTECH.NS', 'HDFCAMC.NS', 'HDFCBANK.NS', 'HDFCLIFE.NS', 'HEADSUP.NS', 'HECPROJECT.NS', 'HEG.NS', 'HEIDELBERG.NS', 'HEMIPROP.NS', 'HERANBA.NS', 'HERCULES.NS', 'HERITGFOOD.NS', 'HEROMOTOCO.NS', 'HESTERBIO.NS', 'HEUBACHIND.NS', 'HEXATRADEX.NS', 'HFCL.NS', 'HGINFRA.NS', 'HGS.NS', 'HIKAL.NS', 'HIL.NS', 'HILTON.NS', 'HIMATSEIDE.NS', 'HINDALCO.NS', 'HINDCOMPOS.NS', 'HINDCON.NS', 'HINDCOPPER.NS', 'HINDMOTORS.NS', 'HINDOILEXP.NS', 'HINDPETRO.NS', 'HINDUNILVR.NS', 'HINDWAREAP.NS', 'HINDZINC.NS', 'HIRECT.NS', 'HISARMETAL.NS', 'HITECH.NS', 'HITECHCORP.NS', 'HITECHGEAR.NS', 'HLEGLAS.NS', 'HLVLTD.NS', 'HMAAGRO.NS', 'HMT.NS', 'HMVL.NS', 'HNDFDS.NS', 'HOMEFIRST.NS', 'HONASA.NS', 'HONAUT.NS', 'HONDAPOWER.NS', 'HOVS.NS', 'HPAL.NS', 'HPIL.NS', 'HPL.NS', 'HSCL.NS', 'HTMEDIA.NS', 'HUBTOWN.NS', 'HUDCO.NS', 'HUHTAMAKI.NS', 'HYBRIDFIN.NS', 'IBREALEST.NS', 'IBULHSGFIN.NS', 'ICDSLTD.NS', 'ICEMAKE.NS', 'ICICIBANK.NS', 'ICICIGI.NS', 'ICICIPRULI.NS', 'ICIL.NS', 'ICRA.NS', 'IDBI.NS', 'IDEA.NS', 'IDEAFORGE.NS', 'IDFC.NS', 'IDFCFIRSTB.NS', 'IEL.NS', 'IEX.NS', 'IFBAGRO.NS', 'IFBIND.NS', 'IFCI.NS', 'IFGLEXPOR.NS', 'IGARASHI.NS', 'IGL.NS', 'IGPL.NS', 'IIFL.NS', 'IIFLSEC.NS', 'IITL.NS', 'IKIO.NS', 'IL&FSENGG.NS', 'IL&FSTRANS.NS', 'IMAGICAA.NS', 'IMFA.NS', 'IMPAL.NS', 'IMPEXFERRO.NS', 'INCREDIBLE.NS', 'INDBANK.NS', 'INDHOTEL.NS', 'INDIACEM.NS', 'INDIAGLYCO.NS', 'INDIAMART.NS', 'INDIANB.NS', 'INDIANCARD.NS', 'INDIANHUME.NS', 'INDIASHLTR.NS', 'INDIGO.NS', 'INDIGOPNTS.NS', 'INDNIPPON.NS', 'INDOAMIN.NS', 'INDOBORAX.NS', 'INDOCO.NS', 'INDORAMA.NS', 'INDOSTAR.NS', 'INDOTECH.NS', 'INDOTHAI.NS', 'INDOWIND.NS', 'INDRAMEDCO.NS', 'INDSWFTLAB.NS', 'INDSWFTLTD.NS', 'INDTERRAIN.NS', 'INDUSINDBK.NS', 'INDUSTOWER.NS', 'INFIBEAM.NS', 'INFOBEAN.NS', 'INFOMEDIA.NS', 'INFY.NS', 'INGERRAND.NS', 'INNOVACAP.NS', 'INOXGREEN.NS', 'INOXINDIA.NS', 'INOXWIND.NS', 'INSECTICID.NS', 'INSPIRISYS.NS', 'INTELLECT.NS', 'INTENTECH.NS', 'INTLCONV.NS', 'INVENTURE.NS', 'IOB.NS', 'IOC.NS', 'IOLCP.NS', 'IONEXCHANG.NS', 'IPCALAB.NS', 'IPL.NS', 'IRB.NS', 'IRCON.NS', 'IRCTC.NS', 'IREDA.NS', 'IRFC.NS', 'IRIS.NS', 'IRISDOREME.NS', 'IRMENERGY.NS', 'ISEC.NS', 'ISFT.NS', 'ISGEC.NS', 'ISMTLTD.NS', 'ITC.NS', 'ITDC.NS', 'ITDCEM.NS', 'ITI.NS', 'IVC.NS', 'IVP.NS', 'IWEL.NS', 'IZMO.NS', 'J&KBANK.NS', 'JAGRAN.NS', 'JAGSNPHARM.NS', 'JAIBALAJI.NS', 'JAICORPLTD.NS', 'JAIPURKURT.NS', 'JAMNAAUTO.NS', 'JASH.NS', 'JAYAGROGN.NS', 'JAYBARMARU.NS', 'JAYNECOIND.NS', 'JAYSREETEA.NS', 'JBCHEPHARM.NS', 'JBMA.NS', 'JCHAC.NS', 'JETAIRWAYS.NS', 'JETFREIGHT.NS', 'JHS.NS', 'JINDALPHOT.NS', 'JINDALPOLY.NS', 'JINDALSAW.NS', 'JINDALSTEL.NS', 'JINDRILL.NS', 'JINDWORLD.NS', 'JIOFIN.NS', 'JISLDVREQS.NS', 'JISLJALEQS.NS', 'JITFINFRA.NS', 'JKCEMENT.NS', 'JKIL.NS', 'JKLAKSHMI.NS', 'JKPAPER.NS', 'JKTYRE.NS', 'JLHL.NS', 'JMA.NS', 'JMFINANCIL.NS', 'JOCIL.NS', 'JPASSOCIAT.NS', 'JPOLYINVST.NS', 'JPPOWER.NS', 'JSL.NS', 'JSWENERGY.NS', 'JSWHL.NS', 'JSWINFRA.NS', 'JSWSTEEL.NS', 'JTEKTINDIA.NS', 'JTLIND.NS', 'JUBLFOOD.NS', 'JUBLINDS.NS', 'JUBLINGREA.NS', 'JUBLPHARMA.NS', 'JUSTDIAL.NS', 'JWL.NS', 'JYOTHYLAB.NS', 'JYOTISTRUC.NS', 'KABRAEXTRU.NS', 'KAJARIACER.NS', 'KAKATCEM.NS', 'KALAMANDIR.NS', 'KALYANI.NS', 'KALYANIFRG.NS', 'KALYANKJIL.NS', 'KAMATHOTEL.NS', 'KAMDHENU.NS', 'KAMOPAINTS.NS', 'KANANIIND.NS', 'KANORICHEM.NS', 'KANPRPLA.NS', 'KANSAINER.NS', 'KAPSTON.NS', 'KARMAENG.NS', 'KARURVYSYA.NS', 'KAUSHALYA.NS', 'KAVVERITEL.NS', 'KAYA.NS', 'KAYNES.NS', 'KBCGLOBAL.NS', 'KCP.NS', 'KCPSUGIND.NS', 'KDDL.NS', 'KEC.NS', 'KECL.NS', 'KEEPLEARN.NS', 'KEI.NS', 'KELLTONTEC.NS', 'KERNEX.NS', 'KESORAMIND.NS', 'KEYFINSERV.NS', 'KFINTECH.NS', 'KHADIM.NS', 'KHAICHEM.NS', 'KHAITANLTD.NS', 'KHANDSE.NS', 'KICL.NS', 'KILITCH.NS', 'KIMS.NS', 'KINGFA.NS', 'KIOCL.NS', 'KIRIINDUS.NS', 'KIRLOSBROS.NS', 'KIRLOSENG.NS', 'KIRLOSIND.NS', 'KIRLPNU.NS', 'KITEX.NS', 'KKCL.NS', 'KMSUGAR.NS', 'KNRCON.NS', 'KOHINOOR.NS', 'KOKUYOCMLN.NS', 'KOLTEPATIL.NS', 'KOPRAN.NS', 'KOTAKBANK.NS', 'KOTARISUG.NS', 'KOTHARIPET.NS', 'KOTHARIPRO.NS', 'KPIGREEN.NS', 'KPIL.NS', 'KPITTECH.NS', 'KPRMILL.NS', 'KRBL.NS', 'KREBSBIO.NS', 'KRIDHANINF.NS', 'KRISHANA.NS', 'KRITI.NS', 'KRITIKA.NS', 'KRITINUT.NS', 'KRSNAA.NS', 'KSB.NS', 'KSCL.NS', 'KSHITIJPOL.NS', 'KSL.NS', 'KSOLVES.NS', 'KTKBANK.NS', 'KUANTUM.NS', 'L&TFH.NS', 'LAGNAM.NS', 'LAKPRE.NS', 'LAL.NS', 'LALPATHLAB.NS', 'LAMBODHARA.NS', 'LANDMARK.NS', 'LAOPALA.NS', 'LASA.NS', 'LATENTVIEW.NS', 'LATTEYS.NS', 'LAURUSLABS.NS', 'LAXMICOT.NS', 'LAXMIMACH.NS', 'LCCINFOTEC.NS', 'LEMONTREE.NS', 'LEXUS.NS', 'LFIC.NS', 'LGBBROSLTD.NS', 'LGBFORGE.NS', 'LGHL.NS', 'LIBAS.NS', 'LIBERTSHOE.NS', 'LICHSGFIN.NS', 'LICI.NS', 'LIKHITHA.NS', 'LINC.NS', 'LINCOLN.NS', 'LINDEINDIA.NS', 'LLOYDS-RE.NS', 'LLOYDSENGG.NS', 'LLOYDSME.NS', 'LODHA.NS', 'LOKESHMACH.NS', 'LORDSCHLO.NS', 'LOTUSEYE.NS', 'LOVABLE.NS', 'LOYALTEX.NS', 'LPDC.NS', 'LT.NS', 'LTFOODS.NS', 'LTIM.NS', 'LTTS.NS', 'LUMAXIND.NS', 'LUMAXTECH.NS', 'LUPIN.NS', 'LUXIND.NS', 'LXCHEM.NS', 'LYKALABS.NS', 'LYPSAGEMS.NS', 'M&M.NS', 'M&MFIN.NS', 'MAANALU.NS', 'MACPOWER.NS', 'MADHAV.NS', 'MADHUCON.NS', 'MADRASFERT.NS', 'MAGADSUGAR.NS', 'MAGNUM.NS', 'MAHABANK.NS', 'MAHAPEXLTD.NS', 'MAHASTEEL.NS', 'MAHEPC.NS', 'MAHESHWARI.NS', 'MAHLIFE.NS', 'MAHLOG.NS', 'MAHSCOOTER.NS', 'MAHSEAMLES.NS', 'MAITHANALL.NS', 'MALLCOM.NS', 'MALUPAPER.NS', 'MANAKALUCO.NS', 'MANAKCOAT.NS', 'MANAKSIA.NS', 'MANAKSTEEL.NS', 'MANALIPETC.NS', 'MANAPPURAM.NS', 'MANGALAM.NS', 'MANGCHEFER.NS', 'MANGLMCEM.NS', 'MANINDS.NS', 'MANINFRA.NS', 'MANKIND.NS', 'MANOMAY.NS', 'MANORAMA.NS', 'MANORG.NS', 'MANUGRAPH.NS', 'MANYAVAR.NS', 'MAPMYINDIA.NS', 'MARALOVER.NS', 'MARATHON.NS', 'MARICO.NS', 'MARINE.NS', 'MARKSANS.NS', 'MARSHALL.NS', 'MARUTI.NS', 'MASFIN.NS', 'MASKINVEST.NS', 'MASTEK.NS', 'MATRIMONY.NS', 'MAWANASUG.NS', 'MAXESTATES.NS', 'MAXHEALTH.NS', 'MAXIND.NS', 'MAYURUNIQ.NS', 'MAZDA.NS', 'MAZDOCK.NS', 'MBAPL.NS', 'MBECL.NS', 'MBLINFRA.NS', 'MCDOWELL-N.NS', 'MCL.NS', 'MCLEODRUSS.NS', 'MCX.NS', 'MEDANTA.NS', 'MEDICAMEQ.NS', 'MEDICO.NS', 'MEDPLUS.NS', 'MEGASOFT.NS', 'MEGASTAR.NS', 'MELSTAR.NS', 'MENONBE.NS', 'MEP.NS', 'METALFORGE.NS', 'METROBRAND.NS', 'METROPOLIS.NS', 'MFSL.NS', 'MGEL.NS', 'MGL.NS', 'MHLXMIRU.NS', 'MHRIL.NS', 'MICEL.NS', 'MIDHANI.NS', 'MINDACORP.NS', 'MINDTECK.NS', 'MIRCELECTR.NS', 'MIRZAINT.NS', 'MITCON.NS', 'MITTAL.NS', 'MKPL.NS', 'MMFL.NS', 'MMP.NS', 'MMTC.NS', 'MODIRUBBER.NS', 'MODISONLTD.NS', 'MOHITIND.NS', 'MOIL.NS', 'MOKSH.NS', 'MOL.NS', 'MOLDTECH.NS', 'MOLDTKPAC.NS', 'MONARCH.NS', 'MONTECARLO.NS', 'MORARJEE.NS', 'MOREPENLAB.NS', 'MOTHERSON.NS', 'MOTILALOFS.NS', 'MOTISONS.NS', 'MOTOGENFIN.NS', 'MPHASIS.NS', 'MPSLTD.NS', 'MRF.NS', 'MRO-TEK.NS', 'MRPL.NS', 'MSPL.NS', 'MSTCLTD.NS', 'MSUMI.NS', 'MTARTECH.NS', 'MTEDUCARE.NS', 'MTNL.NS', 'MUFIN.NS', 'MUFTI.NS', 'MUKANDLTD.NS', 'MUKTAARTS.NS', 'MUNJALAU.NS', 'MUNJALSHOW.NS', 'MURUDCERA.NS', 'MUTHOOTCAP.NS', 'MUTHOOTFIN.NS', 'MUTHOOTMF.NS', 'MVGJL.NS', 'NACLIND.NS', 'NAGAFERT.NS', 'NAGREEKCAP.NS', 'NAGREEKEXP.NS', 'NAHARCAP.NS', 'NAHARINDUS.NS', 'NAHARPOLY.NS', 'NAHARSPING.NS', 'NAM-INDIA.NS', 'NARMADA.NS', 'NATCOPHARM.NS', 'NATHBIOGEN.NS', 'NATIONALUM.NS', 'NAUKRI.NS', 'NAVA.NS', 'NAVINFLUOR.NS', 'NAVKARCORP.NS', 'NAVNETEDUL.NS', 'NAZARA.NS', 'NBCC.NS', 'NBIFIN.NS', 'NCC.NS', 'NCLIND.NS', 'NDGL.NS', 'NDL.NS', 'NDLVENTURE.NS', 'NDRAUTO.NS', 'NDTV.NS', 'NECCLTD.NS', 'NECLIFE.NS', 'NELCAST.NS', 'NELCO.NS', 'NEOGEN.NS', 'NESCO.NS', 'NESTLEIND.NS', 'NETWEB.NS', 'NETWORK18.NS', 'NEULANDLAB.NS', 'NEWGEN.NS', 'NEXTMEDIA.NS', 'NFL.NS', 'NGIL.NS', 'NGLFINE.NS', 'NH.NS', 'NHPC.NS', 'NIACL.NS', 'NIBL.NS', 'NIITLTD.NS', 'NIITMTS.NS', 'NILAINFRA.NS', 'NILASPACES.NS', 'NILKAMAL.NS', 'NINSYS.NS', 'NIPPOBATRY.NS', 'NIRAJ.NS', 'NIRAJISPAT.NS', 'NITCO.NS', 'NITINSPIN.NS', 'NITIRAJ.NS', 'NKIND.NS', 'NLCINDIA.NS', 'NMDC.NS', 'NOCIL.NS', 'NOIDATOLL.NS', 'NORBTEAEXP.NS', 'NRAIL.NS', 'NRBBEARING.NS', 'NRL.NS', 'NSIL.NS', 'NSLNISP.NS', 'NTPC.NS', 'NUCLEUS.NS', 'NURECA.NS', 'NUVAMA.NS', 'NUVOCO.NS', 'NYKAA.NS', 'OAL.NS', 'OBCL.NS', 'OBEROIRLTY.NS', 'OCCL.NS', 'OFSS.NS', 'OIL.NS', 'OILCOUNTUB.NS', 'OLECTRA.NS', 'OMAXAUTO.NS', 'OMAXE.NS', 'OMINFRAL.NS', 'OMKARCHEM.NS', 'ONELIFECAP.NS', 'ONEPOINT.NS', 'ONGC.NS', 'ONMOBILE.NS', 'ONWARDTEC.NS', 'OPTIEMUS.NS', 'ORBTEXP.NS', 'ORCHPHARMA.NS', 'ORICONENT.NS', 'ORIENTALTL.NS', 'ORIENTBELL.NS', 'ORIENTCEM.NS', 'ORIENTCER.NS', 'ORIENTELEC.NS', 'ORIENTHOT.NS', 'ORIENTLTD.NS', 'ORIENTPPR.NS', 'ORISSAMINE.NS', 'ORTINLAB.NS', 'OSIAHYPER.NS', 'OSWALAGRO.NS', 'OSWALGREEN.NS', 'OSWALSEEDS.NS', 'PAGEIND.NS', 'PAISALO.NS', 'PAKKA.NS', 'PALASHSECU.NS', 'PALREDTEC.NS', 'PANACEABIO.NS', 'PANACHE.NS', 'PANAMAPET.NS', 'PANSARI.NS', 'PAR.NS', 'PARACABLES.NS', 'PARADEEP.NS', 'PARAGMILK.NS', 'PARAS.NS', 'PARASPETRO.NS', 'PARSVNATH.NS', 'PASUPTAC.NS', 'PATANJALI.NS', 'PATELENG.NS', 'PATINTLOG.NS', 'PAVNAIND.NS', 'PAYTM.NS', 'PCBL.NS', 'PCJEWELLER.NS', 'PDMJEPAPER.NS', 'PDSL.NS', 'PEARLPOLY.NS', 'PEL.NS', 'PENIND.NS', 'PENINLAND.NS', 'PERSISTENT.NS', 'PETRONET.NS', 'PFC.NS', 'PFIZER.NS', 'PFOCUS.NS', 'PFS.NS', 'PGEL.NS', 'PGHH.NS', 'PGHL.NS', 'PGIL.NS', 'PHOENIXLTD.NS', 'PIDILITIND.NS', 'PIGL.NS', 'PIIND.NS', 'PILANIINVS.NS', 'PILITA.NS', 'PIONEEREMB.NS', 'PITTIENG.NS', 'PIXTRANS.NS', 'PKTEA.NS', 'PLASTIBLEN.NS', 'PLAZACABLE.NS', 'PNB.NS', 'PNBGILTS.NS', 'PNBHOUSING.NS', 'PNC.NS', 'PNCINFRA.NS', 'POCL.NS', 'PODDARHOUS.NS', 'PODDARMENT.NS', 'POKARNA.NS', 'POLICYBZR.NS', 'POLYCAB.NS', 'POLYMED.NS', 'POLYPLEX.NS', 'PONNIERODE.NS', 'POONAWALLA.NS', 'POWERGRID.NS', 'POWERINDIA.NS', 'POWERMECH.NS', 'PPAP.NS', 'PPL.NS', 'PPLPHARMA.NS', 'PRAENG.NS', 'PRAJIND.NS', 'PRAKASH.NS', 'PRAKASHSTL.NS', 'PRAXIS.NS', 'PRECAM.NS', 'PRECOT.NS', 'PRECWIRE.NS', 'PREMEXPLN.NS', 'PREMIER.NS', 'PREMIERPOL.NS', 'PRESTIGE.NS', 'PRICOLLTD.NS', 'PRIMESECU.NS', 'PRINCEPIPE.NS', 'PRITI.NS', 'PRITIKAUTO.NS', 'PRIVISCL.NS', 'PROZONER.NS', 'PRSMJOHNSN.NS', 'PRUDENT.NS', 'PRUDMOULI.NS', 'PSB.NS', 'PSPPROJECT.NS', 'PTC.NS', 'PTCIL.NS', 'PTL.NS', 'PUNJABCHEM.NS', 'PURVA.NS', 'PVP.NS', 'PVRINOX.NS', 'PYRAMID.NS', 'QUESS.NS', 'QUICKHEAL.NS', 'RACE.NS', 'RADAAN.NS', 'RADHIKAJWE.NS', 'RADIANTCMS.NS', 'RADICO.NS', 'RADIOCITY.NS', 'RAILTEL.NS', 'RAIN.NS', 'RAINBOW.NS', 'RAJESHEXPO.NS', 'RAJMET.NS', 'RAJRATAN.NS', 'RAJRILTD.NS', 'RAJSREESUG.NS', 'RAJTV.NS', 'RALLIS.NS', 'RAMANEWS.NS', 'RAMAPHO.NS', 'RAMASTEEL.NS', 'RAMCOCEM.NS', 'RAMCOIND.NS', 'RAMCOSYS.NS', 'RAMKY.NS', 'RAMRAT.NS', 'RANASUG.NS', 'RANEENGINE.NS', 'RANEHOLDIN.NS', 'RATEGAIN.NS', 'RATNAMANI.NS', 'RATNAVEER.NS', 'RAYMOND.NS', 'RBA.NS', 'RBL.NS', 'RBLBANK.NS', 'RBZJEWEL.NS', 'RCF.NS', 'RECLTD.NS', 'REDINGTON.NS', 'REDTAPE.NS', 'REFEX.NS', 'REGENCERAM.NS', 'RELAXO.NS', 'RELCAPITAL.NS', 'RELCHEMQ.NS', 'RELIANCE.NS', 'RELIGARE.NS', 'RELINFRA.NS', 'REMSONSIND.NS', 'RENUKA.NS', 'REPCOHOME.NS', 'REPL.NS', 'REPRO.NS', 'RESPONIND.NS', 'RGL.NS', 'RHFL.NS', 'RHIM.NS', 'RHL.NS', 'RICOAUTO.NS', 'RIIL.NS', 'RISHABH.NS', 'RITCO.NS', 'RITES.NS', 'RKDL.NS', 'RKEC.NS', 'RKFORGE.NS', 'RML.NS', 'ROHLTD.NS', 'ROLEXRINGS.NS', 'ROLLT.NS', 'ROML.NS', 'ROSSARI.NS', 'ROSSELLIND.NS', 'ROTO.NS', 'ROUTE.NS', 'RPGLIFE.NS', 'RPOWER.NS', 'RPPINFRA.NS', 'RPPL.NS', 'RPSGVENT.NS', 'RRKABEL.NS', 'RSSOFTWARE.NS', 'RSWM.NS', 'RSYSTEMS.NS', 'RTNINDIA.NS', 'RTNPOWER.NS', 'RUBYMILLS.NS', 'RUCHINFRA.NS', 'RUCHIRA.NS', 'RUPA.NS', 'RUSHIL.NS', 'RUSTOMJEE.NS', 'RVHL.NS', 'RVNL.NS', 'S&SPOWER.NS', 'SABEVENTS.NS', 'SABTN.NS', 'SADBHAV.NS', 'SADBHIN.NS', 'SADHNANIQ.NS', 'SAFARI.NS', 'SAGARDEEP.NS', 'SAGCEM.NS', 'SAH.NS', 'SAHYADRI.NS', 'SAIL.NS', 'SAKAR.NS', 'SAKHTISUG.NS', 'SAKSOFT.NS', 'SAKUMA.NS', 'SALASAR.NS', 'SALONA.NS', 'SALSTEEL.NS', 'SALZERELEC.NS', 'SAMBHAAV.NS', 'SAMHI.NS', 'SAMPANN.NS', 'SANCO.NS', 'SANDESH.NS', 'SANDHAR.NS', 'SANDUMA.NS', 'SANGAMIND.NS', 'SANGHIIND.NS', 'SANGHVIMOV.NS', 'SANGINITA.NS', 'SANOFI.NS', 'SANSERA.NS', 'SAPPHIRE.NS', 'SARDAEN.NS', 'SAREGAMA.NS', 'SARLAPOLY.NS', 'SARVESHWAR.NS', 'SASKEN.NS', 'SASTASUNDR.NS', 'SATIA.NS', 'SATIN.NS', 'SATINDLTD.NS', 'SBC.NS', 'SBCL.NS', 'SBFC.NS', 'SBGLP.NS', 'SBICARD.NS', 'SBILIFE.NS', 'SBIN.NS', 'SCHAEFFLER.NS', 'SCHAND.NS', 'SCHNEIDER.NS', 'SCI.NS', 'SCPL.NS', 'SDBL.NS', 'SEAMECLTD.NS', 'SECMARK.NS', 'SECURCRED.NS', 'SECURKLOUD.NS', 'SEJALLTD.NS', 'SELAN.NS', 'SELMC.NS', 'SEMAC.NS', 'SENCO.NS', 'SEPC.NS', 'SEQUENT.NS', 'SERVOTECH.NS', 'SESHAPAPER.NS', 'SETCO.NS', 'SEYAIND.NS', 'SFL.NS', 'SGIL.NS', 'SGL.NS', 'SHAH.NS', 'SHAHALLOYS.NS', 'SHAILY.NS', 'SHAKTIPUMP.NS', 'SHALBY.NS', 'SHALPAINTS.NS', 'SHANKARA.NS', 'SHANTI.NS', 'SHANTIGEAR.NS', 'SHARDACROP.NS', 'SHARDAMOTR.NS', 'SHAREINDIA.NS', 'SHEMAROO.NS', 'SHILPAMED.NS', 'SHIVALIK.NS', 'SHIVAMAUTO.NS', 'SHIVAMILLS.NS', 'SHIVATEX.NS', 'SHK.NS', 'SHOPERSTOP.NS', 'SHRADHA.NS', 'SHREDIGCEM.NS', 'SHREECEM.NS', 'SHREEPUSHK.NS', 'SHREERAMA.NS', 'SHRENIK.NS', 'SHREYANIND.NS', 'SHREYAS.NS', 'SHRIPISTON.NS', 'SHRIRAMFIN.NS', 'SHRIRAMPPS.NS', 'SHYAMCENT.NS', 'SHYAMMETL.NS', 'SHYAMTEL.NS', 'SICALLOG.NS', 'SIEMENS.NS', 'SIGACHI.NS', 'SIGIND.NS', 'SIGMA.NS', 'SIGNATURE.NS', 'SIKKO.NS', 'SIL.NS', 'SILGO.NS', 'SILINV.NS', 'SILLYMONKS.NS', 'SILVERTUC.NS', 'SIMBHALS.NS', 'SIMPLEXINF.NS', 'SINDHUTRAD.NS', 'SINTERCOM.NS', 'SIRCA.NS', 'SIS.NS', 'SITINET.NS', 'SIYSIL.NS', 'SJS.NS', 'SJVN.NS', 'SKFINDIA.NS', 'SKIPPER.NS', 'SKMEGGPROD.NS', 'SKYGOLD.NS', 'SMARTLINK.NS', 'SMCGLOBAL.NS', 'SMLISUZU.NS', 'SMLT.NS', 'SMSLIFE.NS', 'SMSPHARMA.NS', 'SNOWMAN.NS', 'SOBHA.NS', 'SOFTTECH.NS', 'SOLARA.NS', 'SOLARINDS.NS', 'SOMANYCERA.NS', 'SOMATEX.NS', 'SOMICONVEY.NS', 'SONACOMS.NS', 'SONAMLTD.NS', 'SONATSOFTW.NS', 'SOTL.NS', 'SOUTHBANK.NS', 'SOUTHWEST.NS', 'SPAL.NS', 'SPANDANA.NS', 'SPARC.NS', 'SPCENET.NS', 'SPECIALITY.NS', 'SPENCERS.NS', 'SPENTEX.NS', 'SPIC.NS', 'SPLIL.NS', 'SPLPETRO.NS', 'SPMLINFRA.NS', 'SPORTKING.NS', 'SPTL.NS', 'SPYL.NS', 'SREEL.NS', 'SRF.NS', 'SRGHFL.NS', 'SRHHYPOLTD.NS', 'SRPL.NS', 'SSWL.NS', 'STAR.NS', 'STARCEMENT.NS', 'STARHEALTH.NS', 'STARPAPER.NS', 'STARTECK.NS', 'STCINDIA.NS', 'STEELCAS.NS', 'STEELCITY.NS', 'STEELXIND.NS', 'STEL.NS', 'STERTOOLS.NS', 'STLTECH.NS', 'STOVEKRAFT.NS', 'STYLAMIND.NS', 'STYRENIX.NS', 'SUBEXLTD.NS', 'SUBROS.NS', 'SUDARSCHEM.NS', 'SUKHJITS.NS', 'SULA.NS', 'SUMICHEM.NS', 'SUMIT.NS', 'SUMMITSEC.NS', 'SUNCLAY.NS', 'SUNDARAM.NS', 'SUNDARMFIN.NS', 'SUNDARMHLD.NS', 'SUNDRMBRAK.NS', 'SUNDRMFAST.NS', 'SUNFLAG.NS', 'SUNPHARMA.NS', 'SUNTECK.NS', 'SUNTV.NS', 'SUPERHOUSE.NS', 'SUPERSPIN.NS', 'SUPRAJIT.NS', 'SUPREMEENG.NS', 'SUPREMEIND.NS', 'SUPREMEINF.NS', 'SUPRIYA.NS', 'SURAJEST.NS', 'SURANASOL.NS', 'SURANAT&P.NS', 'SURYALAXMI.NS', 'SURYAROSNI.NS', 'SURYODAY.NS', 'SUTLEJTEX.NS', 'SUULD.NS', 'SUVEN.NS', 'SUVENPHAR.NS', 'SUVIDHAA.NS', 'SUZLON.NS', 'SVLL.NS', 'SVPGLOB.NS', 'SWANENERGY.NS', 'SWARAJENG.NS', 'SWELECTES.NS', 'SWSOLAR.NS', 'SYMPHONY.NS', 'SYNCOMF.NS', 'SYNGENE.NS', 'SYRMA.NS', 'TAINWALCHM.NS', 'TAJGVK.NS', 'TAKE.NS', 'TALBROAUTO.NS', 'TANLA.NS', 'TARAPUR.NS', 'TARC.NS', 'TARMAT.NS', 'TARSONS.NS', 'TASTYBITE.NS', 'TATACHEM.NS', 'TATACOFFEE.NS', 'TATACOMM.NS', 'TATACONSUM.NS', 'TATAELXSI.NS', 'TATAINVEST.NS', 'TATAMETALI.NS', 'TATAMOTORS.NS', 'TATAMTRDVR.NS', 'TATAPOWER.NS', 'TATASTEEL.NS', 'TATATECH.NS', 'TATVA.NS', 'TBZ.NS', 'TCI.NS', 'TCIEXP.NS', 'TCLCONS.NS', 'TCNSBRANDS.NS', 'TCPLPACK.NS', 'TCS.NS', 'TDPOWERSYS.NS', 'TEAMLEASE.NS', 'TECHIN.NS', 'TECHM.NS', 'TECHNOE.NS', 'TECILCHEM.NS', 'TEGA.NS', 'TEJASNET.NS', 'TEMBO.NS', 'TERASOFT.NS', 'TEXINFRA.NS', 'TEXMOPIPES.NS', 'TEXRAIL.NS', 'TFCILTD.NS', 'TFL.NS', 'TGBHOTELS.NS', 'THANGAMAYL.NS', 'THEINVEST.NS', 'THEJO.NS', 'THEMISMED.NS', 'THERMAX.NS', 'THOMASCOOK.NS', 'THOMASCOTT.NS', 'THYROCARE.NS', 'TI.NS', 'TIDEWATER.NS', 'TIIL.NS', 'TIINDIA.NS', 'TIJARIA.NS', 'TIL.NS', 'TIMESGTY.NS', 'TIMETECHNO.NS', 'TIMKEN.NS', 'TINPLATE.NS', 'TIPSFILMS.NS', 'TIPSINDLTD.NS', 'TIRUMALCHM.NS', 'TIRUPATIFL.NS', 'TITAGARH.NS', 'TITAN.NS', 'TMB.NS', 'TNPETRO.NS', 'TNPL.NS', 'TNTELE.NS', 'TOKYOPLAST.NS', 'TORNTPHARM.NS', 'TORNTPOWER.NS', 'TOTAL.NS', 'TOUCHWOOD.NS', 'TPHQ.NS', 'TPLPLASTEH.NS', 'TRACXN.NS', 'TREEHOUSE.NS', 'TREJHARA.NS', 'TREL.NS', 'TRENT.NS', 'TRF.NS', 'TRIDENT.NS', 'TRIGYN.NS', 'TRIL.NS', 'TRITURBINE.NS', 'TRIVENI.NS', 'TRU.NS', 'TTKHLTCARE.NS', 'TTKPRESTIG.NS', 'TTL.NS', 'TTML.NS', 'TV18BRDCST.NS', 'TVSELECT.NS', 'TVSHLTD.NS', 'TVSMOTOR.NS', 'TVSSCS.NS', 'TVSSRICHAK.NS', 'TVTODAY.NS', 'TVVISION.NS', 'UBL.NS', 'UCAL.NS', 'UCOBANK.NS', 'UDS.NS', 'UFLEX.NS', 'UFO.NS', 'UGARSUGAR.NS', 'UGROCAP.NS', 'UJJIVAN.NS', 'UJJIVANSFB.NS', 'ULTRACEMCO.NS', 'UMAEXPORTS.NS', 'UMANGDAIRY.NS', 'UMESLTD.NS', 'UNICHEMLAB.NS', 'UNIDT.NS', 'UNIENTER.NS', 'UNIINFO.NS', 'UNIONBANK.NS', 'UNIPARTS.NS', 'UNITECH.NS', 'UNITEDPOLY.NS', 'UNITEDTEA.NS', 'UNIVAFOODS.NS', 'UNIVASTU.NS', 'UNIVCABLES.NS', 'UNIVPHOTO.NS', 'UNOMINDA.NS', 'UPL.NS', 'URAVI.NS', 'URJA.NS', 'USHAMART.NS', 'USK.NS', 'UTIAMC.NS', 'UTKARSHBNK.NS', 'UTTAMSUGAR.NS', 'V2RETAIL.NS', 'VADILALIND.NS', 'VAIBHAVGBL.NS', 'VAISHALI.NS', 'VAKRANGEE.NS', 'VALIANTLAB.NS', 'VALIANTORG.NS', 'VARDHACRLC.NS', 'VARDMNPOLY.NS', 'VARROC.NS', 'VASCONEQ.NS', 'VASWANI.NS', 'VBL.NS', 'VCL.NS', 'VEDL.NS', 'VENKEYS.NS', 'VENUSPIPES.NS', 'VENUSREM.NS', 'VERANDA.NS', 'VERTOZ.NS', 'VESUVIUS.NS', 'VETO.NS', 'VGUARD.NS', 'VHL.NS', 'VIDHIING.NS', 'VIJAYA.NS', 'VIJIFIN.NS', 'VIKASECO.NS', 'VIKASLIFE.NS', 'VIMTALABS.NS', 'VINATIORGA.NS', 'VINDHYATEL.NS', 'VINEETLAB.NS', 'VINNY.NS', 'VINYLINDIA.NS', 'VIPCLOTHNG.NS', 'VIPIND.NS', 'VIPULLTD.NS', 'VIRINCHI.NS', 'VISAKAIND.NS', 'VISESHINFO.NS', 'VISHNU.NS', 'VISHWARAJ.NS', 'VIVIDHA.NS', 'VLEGOV.NS', 'VLSFINANCE.NS', 'VMART.NS', 'VOLTAMP.NS', 'VOLTAS.NS', 'VPRPL.NS', 'VRLLOG.NS', 'VSSL.NS', 'VSTIND.NS', 'VSTTILLERS.NS', 'VTL.NS', 'WABAG.NS', 'WALCHANNAG.NS', 'WANBURY.NS', 'WEALTH.NS', 'WEBELSOLAR.NS', 'WEIZMANIND.NS', 'WEL.NS', 'WELCORP.NS', 'WELENT.NS', 'WELINV.NS', 'WELSPUNLIV.NS', 'WENDT.NS', 'WESTLIFE.NS', 'WEWIN.NS', 'WHEELS.NS', 'WHIRLPOOL.NS', 'WILLAMAGOR.NS', 'WINDLAS.NS', 'WINDMACHIN.NS', 'WINSOME.NS', 'WIPL.NS', 'WIPRO.NS', 'WOCKPHARMA.NS', 'WONDERLA.NS', 'WORTH.NS', 'WSI.NS', 'WSTCSTPAPR.NS', 'XCHANGING.NS', 'XELPMOC.NS', 'XPROINDIA.NS', 'YAARI.NS', 'YASHO.NS', 'YATHARTH.NS', 'YATRA.NS', 'YESBANK.NS', 'YUKEN.NS', 'ZAGGLE.NS', 'ZEEL.NS', 'ZEELEARN.NS', 'ZEEMEDIA.NS', 'ZENITHEXPO.NS', 'ZENITHSTL.NS', 'ZENSARTECH.NS', 'ZENTEC.NS', 'ZFCVINDIA.NS', 'ZIMLAB.NS', 'ZODIAC.NS', 'ZODIACLOTH.NS', 'ZOMATO.NS', 'ZOTA.NS', 'ZUARI.NS', 'ZUARIIND.NS', 'ZYDUSLIFE.NS', 'ZYDUSWELL.NS']

# Function to fetch high price, 1% above high price, and current price of a stock
def get_stock_info(stock):
    try:
        data = yf.Ticker(stock).history(period="1d")
        high_price = data['High'][0]
        current_price = data['Close'][0]
        one_percent_above = high_price * 1.01
        return high_price, one_percent_above, current_price
    except IndexError:
        print(f"No data found for {stock}, symbol may be delisted or incorrect.")
        return None, None, None

# Fetching stock information
stock_info = {stock: get_stock_info(stock) for stock in stocks}
print("Stock Information:", stock_info)

# Creating a DataFrame
df = pd.DataFrame.from_dict(stock_info, orient='index', columns=['High Price', '1% Above High', 'Current Price'])
df.index.name = 'Stock'

# Filtering out rows with None values
df = df.dropna()

# Exporting to Excel
excel_filename = "stock_info.xlsx"
df.to_excel(excel_filename)
print(f"Excel file '{excel_filename}' has been created.")
# Out:
# ERROR:yfinance:KALYANI.NS: No price data found, symbol may be delisted (period=1d)
# No data found for KALYANI.NS, symbol may be delisted or incorrect.
# ERROR:yfinance:LLOYDS-RE.NS: No price data found, symbol may be delisted (period=1d)
# No data found for LLOYDS-RE.NS, symbol may be delisted or incorrect.
# ERROR:yfinance:NIRAJISPAT.NS: No price data found, symbol may be delisted (period=1d)
# No data found for NIRAJISPAT.NS, symbol may be delisted or incorrect.
# ERROR:yfinance:TATACOFFEE.NS: No price data found, symbol may be delisted (period=1d)
# No data found for TATACOFFEE.NS, symbol may be delisted or incorrect.
# ERROR:yfinance:TINPLATE.NS: No price data found, symbol may be delisted (period=1d)
# No data found for TINPLATE.NS, symbol may be delisted or incorrect.
# ...

# %% [markdown]
# #SL Code

# %%
# Given data
quantity = 400  # number of stocks
average_rate = 380.75  # average rate per stock
maximum_loss = 600  # maximum loss in rupees

# Calculations
total_investment = quantity * average_rate
maximum_total_value_at_stop_loss = total_investment - maximum_loss
stop_loss_price_per_share = maximum_total_value_at_stop_loss / quantity

stop_loss_price_per_share
# Out:
# 379.25
